# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [2,5,10,20]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    results_error.append(error_each)
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')

                #print('真实置换矩阵为：',true_P)
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print(num_X2feature,num_example,'置换矩阵误差：',error_P,end='   ')
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ################################################ 2 100 平均相对误差2： tensor(0.0129, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0427, dtype=torch.float64)   实验回归误差 tensor(0.0275, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################### 2 100 平均相对误差2： tensor(0.3284, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1199, dtype=torch.float64)   实验回归误差 tensor(0.0764, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################## 2 100 平均相对误差2： tensor(0.0203, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.1747, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0745, dtype=torch.float64)   实验回归误差 tensor(0.0363, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################# 2 100 平均相对误差2： tensor(0.8151, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0930, dtype=torch.float64)   实验回归误差 tensor(0.1566, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################ 2 100 平均相对误差2： tensor(0.2674, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2019, dtype=torch.float64)   实验回归误差 tensor(0.1246, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################### 2 100 平均相对误差2： tensor(0.0215, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.0767, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0338, dtype=torch.float64)   实验回归误差 tensor(0.0235, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################# 2 100 平均相对误差2： tensor(0.0141, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.1659, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0638, dtype=torch.float64)   实验回归误差 tensor(0.0388, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################### 2 100 平均相对误差2： tensor(0.4340, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0680, dtype=torch.float64)   实验回归误差 tensor(0.0973, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 2 100 平均相对误差2： tensor(0.0354, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0763, dtype=torch.float64)   实验回归误差 tensor(0.0418, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################## 2 100 平均相对误差2： tensor(0.2410, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1352, dtype=torch.float64)   实验回归误差 tensor(0.0691, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 5 100 平均相对误差2： tensor(4.4287, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0332, dtype=torch.float64)   实验回归误差 tensor(0.1147, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################################### 5 100 平均相对误差2： tensor(3.9342, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0378, dtype=torch.float64)   实验回归误差 tensor(0.1652, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################## 5 100 平均相对误差2： tensor(4.1010, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0364, dtype=torch.float64)   实验回归误差 tensor(0.1329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 5 100 平均相对误差2： tensor(3.3814, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0344, dtype=torch.float64)   实验回归误差 tensor(0.0793, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################# 5 100 平均相对误差2： tensor(1.1412, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0815, dtype=torch.float64)   实验回归误差 tensor(0.1535, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################### 5 100 平均相对误差2： tensor(2.7945, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0526, dtype=torch.float64)   实验回归误差 tensor(0.1639, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################### 5 100 平均相对误差2： tensor(1.9179, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0541, dtype=torch.float64)   实验回归误差 tensor(0.1170, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 5 100 平均相对误差2： tensor(2.7182, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0570, dtype=torch.float64)   实验回归误差 tensor(0.1249, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################## 5 100 平均相对误差2： tensor(2.2707, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0335, dtype=torch.float64)   实验回归误差 tensor(0.1218, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################## 5 100 平均相对误差2： tensor(1.8340, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0561, dtype=torch.float64)   实验回归误差 tensor(0.1424, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 10 100 平均相对误差2： tensor(4.1759, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0234, dtype=torch.float64)   实验回归误差 tensor(0.0693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################### 10 100 平均相对误差2： tensor(4.3639, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0238, dtype=torch.float64)   实验回归误差 tensor(0.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 10 100 平均相对误差2： tensor(2.5553, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0393, dtype=torch.float64)   实验回归误差 tensor(0.0959, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################### 10 100 平均相对误差2： tensor(4.6560, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0260, dtype=torch.float64)   实验回归误差 tensor(0.0899, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################################### 10 100 平均相对误差2： tensor(6.7569, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0267, dtype=torch.float64)   实验回归误差 tensor(0.0825, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################## 10 100 平均相对误差2： tensor(3.3989, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0407, dtype=torch.float64)   实验回归误差 tensor(0.1268, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################################################## 10 100 平均相对误差2： tensor(5.3927, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0307, dtype=torch.float64)   实验回归误差 tensor(0.1626, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 10 100 平均相对误差2： tensor(1.9772, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0599, dtype=torch.float64)   实验回归误差 tensor(0.1307, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################### 10 100 平均相对误差2： tensor(2.8655, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0491, dtype=torch.float64)   实验回归误差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################ 10 100 平均相对误差2： tensor(2.2659, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0425, dtype=torch.float64)   实验回归误差 tensor(0.0694, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################### 20 100 平均相对误差2： tensor(5.2822, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0302, dtype=torch.float64)   实验回归误差 tensor(0.0616, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################## 20 100 平均相对误差2： tensor(4.6045, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0242, dtype=torch.float64)   实验回归误差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################### 20 100 平均相对误差2： tensor(3.7329, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0361, dtype=torch.float64)   实验回归误差 tensor(0.0649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################ 20 100 平均相对误差2： tensor(6.6013, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0234, dtype=torch.float64)   实验回归误差 tensor(0.0673, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 20 100 平均相对误差2： tensor(4.0320, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0242, dtype=torch.float64)   实验回归误差 tensor(0.0592, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################### 20 100 平均相对误差2： tensor(3.8108, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0264, dtype=torch.float64)   实验回归误差 tensor(0.0648, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 20 100 平均相对误差2： tensor(4.3275, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0280, dtype=torch.float64)   实验回归误差 tensor(0.0673, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################### 20 100 平均相对误差2： tensor(4.2783, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0303, dtype=torch.float64)   实验回归误差 tensor(0.0604, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################### 20 100 平均相对误差2： tensor(6.6079, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0198, dtype=torch.float64)   实验回归误差 tensor(0.0612, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################## 20 100 平均相对误差2： tensor(7.5238, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0165, dtype=torch.float64)   实验回归误差 tensor(0.0689, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################## 2 100 平均相对误差2： tensor(0.4836, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1818, dtype=torch.float64)   实验回归误差 tensor(0.1270, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################## 2 100 平均相对误差2： tensor(1.0043, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1024, dtype=torch.float64)   实验回归误差 tensor(0.1841, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################ 2 100 平均相对误差2： tensor(0.9917, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1008, dtype=torch.float64)   实验回归误差 tensor(0.1939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################### 2 100 平均相对误差2： tensor(0.0141, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0887, dtype=torch.float64)   实验回归误差 tensor(0.0541, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############# 2 100 平均相对误差2： tensor(0.5791, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0985, dtype=torch.float64)   实验回归误差 tensor(0.1202, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################### 2 100 平均相对误差2： tensor(0.2529, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1092, dtype=torch.float64)   实验回归误差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 2 100 平均相对误差2： tensor(0.4525, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0449, dtype=torch.float64)   实验回归误差 tensor(0.0599, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################################################### 2 100 平均相对误差2： tensor(0.5099, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1240, dtype=torch.float64)   实验回归误差 tensor(0.0805, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 2 100 平均相对误差2： tensor(1.1651, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1284, dtype=torch.float64)   实验回归误差 tensor(0.2511, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################## 2 100 平均相对误差2： tensor(0.9708, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4058, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1384, dtype=torch.float64)   实验回归误差 tensor(0.1045, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ###################################################################################################################################### 5 100 平均相对误差2： tensor(3.2307, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0459, dtype=torch.float64)   实验回归误差 tensor(0.1173, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################### 5 100 平均相对误差2： tensor(1.3968, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0849, dtype=torch.float64)   实验回归误差 tensor(0.1089, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################### 5 100 平均相对误差2： tensor(2.0345, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0553, dtype=torch.float64)   实验回归误差 tensor(0.1468, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################# 5 100 平均相对误差2： tensor(2.0680, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0533, dtype=torch.float64)   实验回归误差 tensor(0.1881, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 5 100 平均相对误差2： tensor(3.1335, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3907, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0314, dtype=torch.float64)   实验回归误差 tensor(0.2138, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ##################### 5 100 平均相对误差2： tensor(0.4672, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0368, dtype=torch.float64)   实验回归误差 tensor(0.0589, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################## 5 100 平均相对误差2： tensor(3.8014, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0268, dtype=torch.float64)   实验回归误差 tensor(0.1277, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 5 100 平均相对误差2： tensor(1.7705, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0905, dtype=torch.float64)   实验回归误差 tensor(0.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 5 100 平均相对误差2： tensor(1.6502, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0365, dtype=torch.float64)   实验回归误差 tensor(0.1067, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################# 5 100 平均相对误差2： tensor(2.7875, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0363, dtype=torch.float64)   实验回归误差 tensor(0.1599, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################# 10 100 平均相对误差2： tensor(5.1693, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0286, dtype=torch.float64)   实验回归误差 tensor(0.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################################### 10 100 平均相对误差2： tensor(4.7273, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0321, dtype=torch.float64)   实验回归误差 tensor(0.0943, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################## 10 100 平均相对误差2： tensor(2.6071, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0322, dtype=torch.float64)   实验回归误差 tensor(0.1223, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 10 100 平均相对误差2： tensor(3.2295, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0338, dtype=torch.float64)   实验回归误差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################### 10 100 平均相对误差2： tensor(2.5783, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0484, dtype=torch.float64)   实验回归误差 tensor(0.0826, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 10 100 平均相对误差2： tensor(2.7108, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0285, dtype=torch.float64)   实验回归误差 tensor(0.1383, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################### 10 100 平均相对误差2： tensor(3.9044, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0266, dtype=torch.float64)   实验回归误差 tensor(0.0870, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################## 10 100 平均相对误差2： tensor(2.3708, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0346, dtype=torch.float64)   实验回归误差 tensor(0.0795, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 10 100 平均相对误差2： tensor(3.3860, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0343, dtype=torch.float64)   实验回归误差 tensor(0.0979, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 10 100 平均相对误差2： tensor(4.5843, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0309, dtype=torch.float64)   实验回归误差 tensor(0.0918, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################# 20 100 平均相对误差2： tensor(4.8607, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0315, dtype=torch.float64)   实验回归误差 tensor(0.0712, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################### 20 100 平均相对误差2： tensor(4.1796, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0195, dtype=torch.float64)   实验回归误差 tensor(0.0909, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################### 20 100 平均相对误差2： tensor(5.8312, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0215, dtype=torch.float64)   实验回归误差 tensor(0.0548, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 20 100 平均相对误差2： tensor(6.1732, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0265, dtype=torch.float64)   实验回归误差 tensor(0.0437, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################# 20 100 平均相对误差2： tensor(7.3554, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0193, dtype=torch.float64)   实验回归误差 tensor(0.0613, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################## 20 100 平均相对误差2： tensor(4.7053, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0239, dtype=torch.float64)   实验回归误差 tensor(0.0626, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################### 20 100 平均相对误差2： tensor(4.0654, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0374, dtype=torch.float64)   实验回归误差 tensor(0.0751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################ 20 100 平均相对误差2： tensor(6.4503, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0226, dtype=torch.float64)   实验回归误差 tensor(0.0747, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################### 20 100 平均相对误差2： tensor(4.4336, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0286, dtype=torch.float64)   实验回归误差 tensor(0.0598, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################### 20 100 平均相对误差2： tensor(6.2437, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0192, dtype=torch.float64)   实验回归误差 tensor(0.0513, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(1.0568, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0780, dtype=torch.float64)   实验回归误差 tensor(0.1756, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############# 2 100 平均相对误差2： tensor(0.5316, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0724, dtype=torch.float64)   实验回归误差 tensor(0.1222, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################## 2 100 平均相对误差2： tensor(0.0983, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3191, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1447, dtype=torch.float64)   实验回归误差 tensor(0.0713, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 2 100 平均相对误差2： tensor(0.0082, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0719, dtype=torch.float64)   实验回归误差 tensor(0.0426, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################### 2 100 平均相对误差2： tensor(1.5475, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0534, dtype=torch.float64)   实验回归误差 tensor(0.1759, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################### 2 100 平均相对误差2： tensor(0.0470, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1112, dtype=torch.float64)   实验回归误差 tensor(0.0549, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(0.9330, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1170, dtype=torch.float64)   实验回归误差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################# 2 100 平均相对误差2： tensor(0.0170, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0752, dtype=torch.float64)   实验回归误差 tensor(0.0427, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 2 100 平均相对误差2： tensor(1.4113, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0483, dtype=torch.float64)   实验回归误差 tensor(0.1253, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################### 2 100 平均相对误差2： tensor(0.0562, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0734, dtype=torch.float64)   实验回归误差 tensor(0.0444, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 5 100 平均相对误差2： tensor(1.5324, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0752, dtype=torch.float64)   实验回归误差 tensor(0.1054, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################ 5 100 平均相对误差2： tensor(1.7183, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0474, dtype=torch.float64)   实验回归误差 tensor(0.0855, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 5 100 平均相对误差2： tensor(3.7167, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0305, dtype=torch.float64)   实验回归误差 tensor(0.0946, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################## 5 100 平均相对误差2： tensor(2.6610, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0464, dtype=torch.float64)   实验回归误差 tensor(0.1426, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################################################### 5 100 平均相对误差2： tensor(1.4765, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0330, dtype=torch.float64)   实验回归误差 tensor(0.1341, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################ 5 100 平均相对误差2： tensor(1.4397, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0552, dtype=torch.float64)   实验回归误差 tensor(0.1134, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 5 100 平均相对误差2： tensor(2.0645, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0428, dtype=torch.float64)   实验回归误差 tensor(0.1416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 5 100 平均相对误差2： tensor(3.2017, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0392, dtype=torch.float64)   实验回归误差 tensor(0.1587, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 5 100 平均相对误差2： tensor(1.9676, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0693, dtype=torch.float64)   实验回归误差 tensor(0.1229, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################### 5 100 平均相对误差2： tensor(1.5598, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0464, dtype=torch.float64)   实验回归误差 tensor(0.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 10 100 平均相对误差2： tensor(3.6740, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0328, dtype=torch.float64)   实验回归误差 tensor(0.0560, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################# 10 100 平均相对误差2： tensor(4.1824, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0290, dtype=torch.float64)   实验回归误差 tensor(0.1220, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 10 100 平均相对误差2： tensor(2.6581, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0340, dtype=torch.float64)   实验回归误差 tensor(0.1125, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################### 10 100 平均相对误差2： tensor(3.4496, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0313, dtype=torch.float64)   实验回归误差 tensor(0.1012, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 10 100 平均相对误差2： tensor(4.3313, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0337, dtype=torch.float64)   实验回归误差 tensor(0.0925, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 10 100 平均相对误差2： tensor(4.1858, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0389, dtype=torch.float64)   实验回归误差 tensor(0.0623, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################### 10 100 平均相对误差2： tensor(3.9089, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0332, dtype=torch.float64)   实验回归误差 tensor(0.1607, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 10 100 平均相对误差2： tensor(2.4961, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0271, dtype=torch.float64)   实验回归误差 tensor(0.0995, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 10 100 平均相对误差2： tensor(3.0651, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0375, dtype=torch.float64)   实验回归误差 tensor(0.1021, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 10 100 平均相对误差2： tensor(4.0244, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0278, dtype=torch.float64)   实验回归误差 tensor(0.0925, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################## 20 100 平均相对误差2： tensor(6.4915, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0228, dtype=torch.float64)   实验回归误差 tensor(0.1114, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################ 20 100 平均相对误差2： tensor(5.5100, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0286, dtype=torch.float64)   实验回归误差 tensor(0.0442, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################# 20 100 平均相对误差2： tensor(4.3402, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0257, dtype=torch.float64)   实验回归误差 tensor(0.0612, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################ 20 100 平均相对误差2： tensor(4.8320, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0287, dtype=torch.float64)   实验回归误差 tensor(0.0904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################### 20 100 平均相对误差2： tensor(5.4136, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0218, dtype=torch.float64)   实验回归误差 tensor(0.0774, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 20 100 平均相对误差2： tensor(6.3357, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0207, dtype=torch.float64)   实验回归误差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################## 20 100 平均相对误差2： tensor(6.6817, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0217, dtype=torch.float64)   实验回归误差 tensor(0.0713, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################### 20 100 平均相对误差2： tensor(4.8834, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0242, dtype=torch.float64)   实验回归误差 tensor(0.0740, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################### 20 100 平均相对误差2： tensor(4.5041, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0237, dtype=torch.float64)   实验回归误差 tensor(0.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################### 20 100 平均相对误差2： tensor(4.4675, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0306, dtype=torch.float64)   实验回归误差 tensor(0.0642, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 2 100 平均相对误差2： tensor(3.2026, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0427, dtype=torch.float64)   实验回归误差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################## 2 100 平均相对误差2： tensor(0.0288, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2884, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1105, dtype=torch.float64)   实验回归误差 tensor(0.0608, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 2 100 平均相对误差2： tensor(0.3981, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0896, dtype=torch.float64)   实验回归误差 tensor(0.1261, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################# 2 100 平均相对误差2： tensor(0.0158, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0774, dtype=torch.float64)   实验回归误差 tensor(0.0393, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################## 2 100 平均相对误差2： tensor(0.0409, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0421, dtype=torch.float64)   实验回归误差 tensor(0.0295, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 2 100 平均相对误差2： tensor(0.5249, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0402, dtype=torch.float64)   实验回归误差 tensor(0.0721, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################### 2 100 平均相对误差2： tensor(0.0146, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0481, dtype=torch.float64)   实验回归误差 tensor(0.0346, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(0.5280, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0643, dtype=torch.float64)   实验回归误差 tensor(0.0910, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################# 2 100 平均相对误差2： tensor(1.2939, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0725, dtype=torch.float64)   实验回归误差 tensor(0.1963, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########### 2 100 平均相对误差2： tensor(0.1522, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3105, dtype=torch.float64)   实验回归误差 tensor(0.1514, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################### 5 100 平均相对误差2： tensor(3.3616, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0345, dtype=torch.float64)   实验回归误差 tensor(0.1208, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 5 100 平均相对误差2： tensor(0.1735, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0512, dtype=torch.float64)   实验回归误差 tensor(0.0524, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 5 100 平均相对误差2： tensor(0.7140, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0675, dtype=torch.float64)   实验回归误差 tensor(0.1085, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################### 5 100 平均相对误差2： tensor(2.8404, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0386, dtype=torch.float64)   实验回归误差 tensor(0.0943, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 5 100 平均相对误差2： tensor(1.1378, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0539, dtype=torch.float64)   实验回归误差 tensor(0.0970, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################## 5 100 平均相对误差2： tensor(1.3819, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0706, dtype=torch.float64)   实验回归误差 tensor(0.1610, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 5 100 平均相对误差2： tensor(1.7193, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0516, dtype=torch.float64)   实验回归误差 tensor(0.1144, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################ 5 100 平均相对误差2： tensor(3.3943, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0374, dtype=torch.float64)   实验回归误差 tensor(0.1497, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################## 5 100 平均相对误差2： tensor(1.3890, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0688, dtype=torch.float64)   实验回归误差 tensor(0.1183, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #####################################################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-79cab25c016d> in <module>()
#      51                         if Loss<1e-2:
#      52                             break
# ---> 53                         Loss.backward()
#      54     #                         results_Loss.append(Loss)
#      55     #                         for i_ in range(num_X1features):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:
