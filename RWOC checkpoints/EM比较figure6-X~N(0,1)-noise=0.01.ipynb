# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [2,5,10,20]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1)=generatedata(noise=0.01)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    results_error.append(error_each)
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')

                #print('真实置换矩阵为：',true_P)
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print(num_X2feature,num_example,'置换矩阵误差：',error_P,end='   ')
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############################### 2 100 平均相对误差2： tensor(0.5673, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3695, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0051, dtype=torch.float64)   实验回归误差 tensor(0.0731, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ########################################### 2 100 平均相对误差2： tensor(2.4936, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0067, dtype=torch.float64)   实验回归误差 tensor(0.1805, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 2 100 平均相对误差2： tensor(1.1587, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0099, dtype=torch.float64)   实验回归误差 tensor(0.1007, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################### 2 100 平均相对误差2： tensor(0.2252, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0388, dtype=torch.float64)   实验回归误差 tensor(0.1436, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############## 2 100 平均相对误差2： tensor(0.9204, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0077, dtype=torch.float64)   实验回归误差 tensor(0.1262, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################## 2 100 平均相对误差2： tensor(1.8481, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0065, dtype=torch.float64)   实验回归误差 tensor(0.1926, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 2 100 平均相对误差2： tensor(0.2279, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0319, dtype=torch.float64)   实验回归误差 tensor(0.1464, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(0.6965, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0131, dtype=torch.float64)   实验回归误差 tensor(0.1342, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################ 2 100 平均相对误差2： tensor(0.2282, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0090, dtype=torch.float64)   实验回归误差 tensor(0.0788, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############ 2 100 平均相对误差2： tensor(0.5034, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0173, dtype=torch.float64)   实验回归误差 tensor(0.1357, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 5 100 平均相对误差2： tensor(2.6971, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0045, dtype=torch.float64)   实验回归误差 tensor(0.1005, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################ 5 100 平均相对误差2： tensor(4.8064, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.1077, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################### 5 100 平均相对误差2： tensor(1.4111, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0102, dtype=torch.float64)   实验回归误差 tensor(0.1993, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################### 5 100 平均相对误差2： tensor(1.3827, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0072, dtype=torch.float64)   实验回归误差 tensor(0.1202, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################### 5 100 平均相对误差2： tensor(1.8555, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3997, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0045, dtype=torch.float64)   实验回归误差 tensor(0.0903, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################### 5 100 平均相对误差2： tensor(3.7141, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0033, dtype=torch.float64)   实验回归误差 tensor(0.1181, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################### 5 100 平均相对误差2： tensor(0.5212, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0087, dtype=torch.float64)   实验回归误差 tensor(0.0834, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################### 5 100 平均相对误差2： tensor(1.4055, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0082, dtype=torch.float64)   实验回归误差 tensor(0.1277, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 5 100 平均相对误差2： tensor(1.4686, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0075, dtype=torch.float64)   实验回归误差 tensor(0.0837, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################# 5 100 平均相对误差2： tensor(1.4448, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0047, dtype=torch.float64)   实验回归误差 tensor(0.1278, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 10 100 平均相对误差2： tensor(4.0866, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0028, dtype=torch.float64)   实验回归误差 tensor(0.0873, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################# 10 100 平均相对误差2： tensor(2.8417, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0035, dtype=torch.float64)   实验回归误差 tensor(0.0988, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 10 100 平均相对误差2： tensor(3.0617, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0028, dtype=torch.float64)   实验回归误差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 10 100 平均相对误差2： tensor(4.5251, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0028, dtype=torch.float64)   实验回归误差 tensor(0.0715, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 10 100 平均相对误差2： tensor(2.9178, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0035, dtype=torch.float64)   实验回归误差 tensor(0.0670, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################################################################################### 10 100 平均相对误差2： tensor(4.2496, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0040, dtype=torch.float64)   实验回归误差 tensor(0.0887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################### 10 100 平均相对误差2： tensor(4.8150, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0024, dtype=torch.float64)   实验回归误差 tensor(0.0999, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################### 10 100 平均相对误差2： tensor(3.2194, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0041, dtype=torch.float64)   实验回归误差 tensor(0.0781, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################## 10 100 平均相对误差2： tensor(2.5317, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0042, dtype=torch.float64)   实验回归误差 tensor(0.0428, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################## 10 100 平均相对误差2： tensor(4.3400, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0026, dtype=torch.float64)   实验回归误差 tensor(0.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################### 20 100 平均相对误差2： tensor(4.9648, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0025, dtype=torch.float64)   实验回归误差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################### 20 100 平均相对误差2： tensor(5.9741, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0021, dtype=torch.float64)   实验回归误差 tensor(0.0947, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################### 20 100 平均相对误差2： tensor(5.6518, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0021, dtype=torch.float64)   实验回归误差 tensor(0.0845, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################## 20 100 平均相对误差2： tensor(4.3821, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0028, dtype=torch.float64)   实验回归误差 tensor(0.0498, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################### 20 100 平均相对误差2： tensor(4.9444, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0027, dtype=torch.float64)   实验回归误差 tensor(0.0652, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################### 20 100 平均相对误差2： tensor(5.8685, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0024, dtype=torch.float64)   实验回归误差 tensor(0.0527, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 20 100 平均相对误差2： tensor(7.4270, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0022, dtype=torch.float64)   实验回归误差 tensor(0.0772, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################### 20 100 平均相对误差2： tensor(4.8958, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0023, dtype=torch.float64)   实验回归误差 tensor(0.0582, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################### 20 100 平均相对误差2： tensor(4.3029, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0028, dtype=torch.float64)   实验回归误差 tensor(0.0386, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################################ 20 100 平均相对误差2： tensor(6.1834, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0019, dtype=torch.float64)   实验回归误差 tensor(0.0584, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(0.7303, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0058, dtype=torch.float64)   实验回归误差 tensor(0.1321, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################ 2 100 平均相对误差2： tensor(1.0740, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0134, dtype=torch.float64)   实验回归误差 tensor(0.1597, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(1.2142, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0057, dtype=torch.float64)   实验回归误差 tensor(0.1467, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################## 2 100 平均相对误差2： tensor(0.1758, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0132, dtype=torch.float64)   实验回归误差 tensor(0.0819, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 2 100 平均相对误差2： tensor(0.0032, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.8602, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0181, dtype=torch.float64)   实验回归误差 tensor(0.0165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################# 2 100 平均相对误差2： tensor(0.0030, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.5099, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0046, dtype=torch.float64)   实验回归误差 tensor(0.0047, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################ 2 100 平均相对误差2： tensor(0.8763, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0095, dtype=torch.float64)   实验回归误差 tensor(0.1181, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############# 2 100 平均相对误差2： tensor(0.0042, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.6325, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0081, dtype=torch.float64)   实验回归误差 tensor(0.0082, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################# 2 100 平均相对误差2： tensor(0.7468, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3991, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0170, dtype=torch.float64)   实验回归误差 tensor(0.1522, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############ 2 100 平均相对误差2： tensor(0.0023, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.9695, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0185, dtype=torch.float64)   实验回归误差 tensor(0.0173, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 5 100 平均相对误差2： tensor(2.4541, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.0992, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################# 5 100 平均相对误差2： tensor(2.0593, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0051, dtype=torch.float64)   实验回归误差 tensor(0.1474, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################# 5 100 平均相对误差2： tensor(1.8732, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0079, dtype=torch.float64)   实验回归误差 tensor(0.1130, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 5 100 平均相对误差2： tensor(1.2396, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0043, dtype=torch.float64)   实验回归误差 tensor(0.1348, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################ 5 100 平均相对误差2： tensor(2.3256, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0045, dtype=torch.float64)   实验回归误差 tensor(0.1477, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################################################ 5 100 平均相对误差2： tensor(0.9548, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0067, dtype=torch.float64)   实验回归误差 tensor(0.1174, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################# 5 100 平均相对误差2： tensor(2.4371, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.1495, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################### 5 100 平均相对误差2： tensor(0.9606, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0053, dtype=torch.float64)   实验回归误差 tensor(0.0945, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 5 100 平均相对误差2： tensor(0.6082, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3615, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0071, dtype=torch.float64)   实验回归误差 tensor(0.1047, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ###################################################################### 5 100 平均相对误差2： tensor(1.7667, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0053, dtype=torch.float64)   实验回归误差 tensor(0.1378, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 10 100 平均相对误差2： tensor(5.8168, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0021, dtype=torch.float64)   实验回归误差 tensor(0.1640, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################### 10 100 平均相对误差2： tensor(4.4691, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.0922, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################################################# 10 100 平均相对误差2： tensor(1.8689, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0044, dtype=torch.float64)   实验回归误差 tensor(0.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 10 100 平均相对误差2： tensor(6.5157, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0024, dtype=torch.float64)   实验回归误差 tensor(0.0759, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 10 100 平均相对误差2： tensor(3.8788, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0038, dtype=torch.float64)   实验回归误差 tensor(0.1387, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################ 10 100 平均相对误差2： tensor(4.0440, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.1279, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 10 100 平均相对误差2： tensor(4.0602, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0037, dtype=torch.float64)   实验回归误差 tensor(0.1209, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################ 10 100 平均相对误差2： tensor(5.5649, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0032, dtype=torch.float64)   实验回归误差 tensor(0.0648, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################### 10 100 平均相对误差2： tensor(3.7694, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0024, dtype=torch.float64)   实验回归误差 tensor(0.1379, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################### 10 100 平均相对误差2： tensor(5.0387, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0027, dtype=torch.float64)   实验回归误差 tensor(0.1513, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################### 20 100 平均相对误差2： tensor(6.0223, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0017, dtype=torch.float64)   实验回归误差 tensor(0.0637, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 20 100 平均相对误差2： tensor(5.9969, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0022, dtype=torch.float64)   实验回归误差 tensor(0.0690, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################### 20 100 平均相对误差2： tensor(6.1980, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0025, dtype=torch.float64)   实验回归误差 tensor(0.0560, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################### 20 100 平均相对误差2： tensor(5.6019, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0026, dtype=torch.float64)   实验回归误差 tensor(0.0639, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################# 20 100 平均相对误差2： tensor(6.1336, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0021, dtype=torch.float64)   实验回归误差 tensor(0.0510, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################## 20 100 平均相对误差2： tensor(5.7478, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0020, dtype=torch.float64)   实验回归误差 tensor(0.0687, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 20 100 平均相对误差2： tensor(3.6588, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0026, dtype=torch.float64)   实验回归误差 tensor(0.0667, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################### 20 100 平均相对误差2： tensor(6.2742, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0027, dtype=torch.float64)   实验回归误差 tensor(0.0704, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 20 100 平均相对误差2： tensor(3.7153, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0029, dtype=torch.float64)   实验回归误差 tensor(0.0727, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################### 20 100 平均相对误差2： tensor(4.5760, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0025, dtype=torch.float64)   实验回归误差 tensor(0.0429, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 2 100 平均相对误差2： tensor(0.8369, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4133, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0121, dtype=torch.float64)   实验回归误差 tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############################ 2 100 平均相对误差2： tensor(1.3842, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0071, dtype=torch.float64)   实验回归误差 tensor(0.1465, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 2 100 平均相对误差2： tensor(1.5694, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0047, dtype=torch.float64)   实验回归误差 tensor(0.1611, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########## 2 100 平均相对误差2： tensor(2.3434, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0062, dtype=torch.float64)   实验回归误差 tensor(0.2987, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################## 2 100 平均相对误差2： tensor(0.0008, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.3464, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0052, dtype=torch.float64)   实验回归误差 tensor(0.0052, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(0.0060, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.6911, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0107, dtype=torch.float64)   实验回归误差 tensor(0.0107, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ################################ 2 100 平均相对误差2： tensor(0.0018, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.6804, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0060, dtype=torch.float64)   实验回归误差 tensor(0.0057, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############################## 2 100 平均相对误差2： tensor(0.3727, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3709, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0337, dtype=torch.float64)   实验回归误差 tensor(0.1333, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################## 2 100 平均相对误差2： tensor(0.0007, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.6000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0068, dtype=torch.float64)   实验回归误差 tensor(0.0064, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################### 2 100 平均相对误差2： tensor(1.3409, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0060, dtype=torch.float64)   实验回归误差 tensor(0.1253, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################## 5 100 平均相对误差2： tensor(4.3755, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0030, dtype=torch.float64)   实验回归误差 tensor(0.0885, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################### 5 100 平均相对误差2： tensor(0.9981, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0062, dtype=torch.float64)   实验回归误差 tensor(0.1305, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################## 5 100 平均相对误差2： tensor(0.0023, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(0.5716, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0056, dtype=torch.float64)   实验回归误差 tensor(0.0053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############################################# 5 100 平均相对误差2： tensor(0.1826, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0106, dtype=torch.float64)   实验回归误差 tensor(0.0608, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################## 5 100 平均相对误差2： tensor(1.9398, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0065, dtype=torch.float64)   实验回归误差 tensor(0.1021, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################ 5 100 平均相对误差2： tensor(2.6983, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0025, dtype=torch.float64)   实验回归误差 tensor(0.0880, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 5 100 平均相对误差2： tensor(1.5179, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0075, dtype=torch.float64)   实验回归误差 tensor(0.1903, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 5 100 平均相对误差2： tensor(1.3061, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0099, dtype=torch.float64)   实验回归误差 tensor(0.0872, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################### 5 100 平均相对误差2： tensor(4.3187, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0026, dtype=torch.float64)   实验回归误差 tensor(0.1129, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################### 5 100 平均相对误差2： tensor(1.7292, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0048, dtype=torch.float64)   实验回归误差 tensor(0.0901, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 10 100 平均相对误差2： tensor(3.6146, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.0874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################### 10 100 平均相对误差2： tensor(2.7087, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0030, dtype=torch.float64)   实验回归误差 tensor(0.0753, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################ 10 100 平均相对误差2： tensor(5.8451, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0025, dtype=torch.float64)   实验回归误差 tensor(0.0638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################### 10 100 平均相对误差2： tensor(4.1625, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0034, dtype=torch.float64)   实验回归误差 tensor(0.1388, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 10 100 平均相对误差2： tensor(6.9685, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0020, dtype=torch.float64)   实验回归误差 tensor(0.0805, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 10 100 平均相对误差2： tensor(3.7071, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0033, dtype=torch.float64)   实验回归误差 tensor(0.0671, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################### 10 100 平均相对误差2： tensor(3.6307, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0033, dtype=torch.float64)   实验回归误差 tensor(0.0872, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 10 100 平均相对误差2： tensor(2.8981, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0025, dtype=torch.float64)   实验回归误差 tensor(0.0767, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 10 100 平均相对误差2： tensor(2.4440, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0034, dtype=torch.float64)   实验回归误差 tensor(0.0887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################### 10 100 平均相对误差2： tensor(3.3595, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0039, dtype=torch.float64)   实验回归误差 tensor(0.0765, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################## 20 100 平均相对误差2： tensor(6.6530, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0019, dtype=torch.float64)   实验回归误差 tensor(0.0817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################### 20 100 平均相对误差2： tensor(4.1717, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0026, dtype=torch.float64)   实验回归误差 tensor(0.0587, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################### 20 100 平均相对误差2： tensor(4.7448, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0023, dtype=torch.float64)   实验回归误差 tensor(0.0810, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 20 100 平均相对误差2： tensor(5.4100, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0022, dtype=torch.float64)   实验回归误差 tensor(0.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################################### 20 100 平均相对误差2： tensor(6.5757, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0023, dtype=torch.float64)   实验回归误差 tensor(0.0897, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################### 20 100 平均相对误差2： tensor(5.8339, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0024, dtype=torch.float64)   实验回归误差 tensor(0.1315, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################################################################################### 20 100 平均相对误差2： tensor(4.6030, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0026, dtype=torch.float64)   实验回归误差 tensor(0.0533, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################## 20 100 平均相对误差2： tensor(3.5852, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0023, dtype=torch.float64)   实验回归误差 tensor(0.0671, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################################### 20 100 平均相对误差2： tensor(5.7826, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0021, dtype=torch.float64)   实验回归误差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 20 100 平均相对误差2： tensor(4.3323, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0030, dtype=torch.float64)   实验回归误差 tensor(0.0786, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################## 2 100 平均相对误差2： tensor(0.4999, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0186, dtype=torch.float64)   实验回归误差 tensor(0.1382, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 2 100 平均相对误差2： tensor(0.0005, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.5477, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0069, dtype=torch.float64)   实验回归误差 tensor(0.0062, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 2 100 平均相对误差2： tensor(1.1540, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0092, dtype=torch.float64)   实验回归误差 tensor(0.1858, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################### 2 100 平均相对误差2： tensor(0.8450, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0131, dtype=torch.float64)   实验回归误差 tensor(0.1607, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################ 2 100 平均相对误差2： tensor(1.6915, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4045, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0061, dtype=torch.float64)   实验回归误差 tensor(0.0962, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ##################### 2 100 平均相对误差2： tensor(0.8196, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0075, dtype=torch.float64)   实验回归误差 tensor(0.1042, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################### 2 100 平均相对误差2： tensor(0.0043, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.7616, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0138, dtype=torch.float64)   实验回归误差 tensor(0.0128, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################### 2 100 平均相对误差2： tensor(0.9524, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0095, dtype=torch.float64)   实验回归误差 tensor(0.1471, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######### 2 100 平均相对误差2： tensor(0.0022, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.6633, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0079, dtype=torch.float64)   实验回归误差 tensor(0.0072, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(0.0027, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.8509, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0135, dtype=torch.float64)   实验回归误差 tensor(0.0120, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ########################################################################################################## 5 100 平均相对误差2： tensor(3.2552, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0041, dtype=torch.float64)   实验回归误差 tensor(0.1936, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################### 5 100 平均相对误差2： tensor(0.6151, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0060, dtype=torch.float64)   实验回归误差 tensor(0.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 5 100 平均相对误差2： tensor(0.2854, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.2570, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0028, dtype=torch.float64)   实验回归误差 tensor(0.0431, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################### 5 100 平均相对误差2： tensor(1.0353, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0037, dtype=torch.float64)   实验回归误差 tensor(0.0971, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################### 5 100 平均相对误差2： tensor(1.2456, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0033, dtype=torch.float64)   实验回归误差 tensor(0.0611, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################### 5 100 平均相对误差2： tensor(0.8196, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0066, dtype=torch.float64)   实验回归误差 tensor(0.1122, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################################################### 5 100 平均相对误差2： tensor(3.9634, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0035, dtype=torch.float64)   实验回归误差 tensor(0.1114, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 5 100 平均相对误差2： tensor(2.8697, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0038, dtype=torch.float64)   实验回归误差 tensor(0.1186, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################## 5 100 平均相对误差2： tensor(3.5207, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4061, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0032, dtype=torch.float64)   实验回归误差 tensor(0.1303, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############################################################################# 5 100 平均相对误差2： tensor(0.3654, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0104, dtype=torch.float64)   实验回归误差 tensor(0.0814, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################## 10 100 平均相对误差2： tensor(4.5541, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.1266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 10 100 平均相对误差2： tensor(2.6461, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0042, dtype=torch.float64)   实验回归误差 tensor(0.0785, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################### 10 100 平均相对误差2： tensor(1.2027, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0075, dtype=torch.float64)   实验回归误差 tensor(0.0924, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################### 10 100 平均相对误差2： tensor(2.4194, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0048, dtype=torch.float64)   实验回归误差 tensor(0.1227, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 10 100 平均相对误差2： tensor(3.1211, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0036, dtype=torch.float64)   实验回归误差 tensor(0.0845, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################### 10 100 平均相对误差2： tensor(4.8419, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0031, dtype=torch.float64)   实验回归误差 tensor(0.0944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 10 100 平均相对误差2： tensor(4.3621, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0030, dtype=torch.float64)   实验回归误差 tensor(0.1368, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################### 10 100 平均相对误差2： tensor(5.8008, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0036, dtype=torch.float64)   实验回归误差 tensor(0.1497, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################################################## 10 100 平均相对误差2： tensor(3.0749, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0046, dtype=torch.float64)   实验回归误差 tensor(0.1138, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################### 10 100 平均相对误差2： tensor(3.4023, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0029, dtype=torch.float64)   实验回归误差 tensor(0.1724, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################### 20 100 平均相对误差2： tensor(7.1108, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0023, dtype=torch.float64)   实验回归误差 tensor(0.0550, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##############################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-748fd7674b3c> in <module>()
#      71                         if torch.norm(Loss-before1)/before1<1e-7:
#      72                             break
# ---> 73                         before1=Loss
#      74                         if t>=200:
#      75                             print('超过迭代上限')
#
# KeyboardInterrupt:
