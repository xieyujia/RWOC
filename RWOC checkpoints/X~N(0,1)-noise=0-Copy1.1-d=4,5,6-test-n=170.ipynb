# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(2):
    for num_example in range(170,171,100): 
        for num_X2feature in [4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.005
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ########################################################## 4 170 w绝对误差 tensor(0.7167, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7054, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0892, dtype=torch.float64)   实验回归残差 tensor(0.0907, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1018, dtype=torch.float64)   测试集实验回归残差 tensor(0.1303, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1813776857823806
# ###################### 4 170 w绝对误差 tensor(2.2839, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1765, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0508, dtype=torch.float64)   实验回归残差 tensor(0.1724, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0460, dtype=torch.float64)   测试集实验回归残差 tensor(0.2063, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2879838751124153
# ######################################### 4 170 w绝对误差 tensor(1.1665, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4958, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0447, dtype=torch.float64)   实验回归残差 tensor(0.0992, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0429, dtype=torch.float64)   测试集实验回归残差 tensor(0.1248, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.224288592931221
# ############################################### 4 170 w绝对误差 tensor(1.4110, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5126, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1137, dtype=torch.float64)   实验回归残差 tensor(0.1201, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0972, dtype=torch.float64)   测试集实验回归残差 tensor(0.1878, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4099, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.3320420591630606
# ########################################################################################################################################################################################################超过迭代上限
#  4 170 w绝对误差 tensor(1.0231, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4866, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0424, dtype=torch.float64)   实验回归残差 tensor(0.0702, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0445, dtype=torch.float64)   测试集实验回归残差 tensor(0.1417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.332244027233938
# ##################################################################### 4 170 w绝对误差 tensor(0.3703, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3920, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0938, dtype=torch.float64)   实验回归残差 tensor(0.0713, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0878, dtype=torch.float64)   测试集实验回归残差 tensor(0.1239, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3848, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3890, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.19688546584912
# ####################### 4 170 w绝对误差 tensor(2.7515, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1866, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0404, dtype=torch.float64)   实验回归残差 tensor(0.0873, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0438, dtype=torch.float64)   测试集实验回归残差 tensor(0.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4058, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3890, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2987902710323163
# ####################### 4 170 w绝对误差 tensor(1.7151, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0530, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0566, dtype=torch.float64)   实验回归残差 tensor(0.1267, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0572, dtype=torch.float64)   测试集实验回归残差 tensor(0.2349, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2710353193535144
# ###################################################### 4 170 w绝对误差 tensor(3.6039, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6857, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0496, dtype=torch.float64)   实验回归残差 tensor(0.0651, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0496, dtype=torch.float64)   测试集实验回归残差 tensor(0.2796, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.205484318827412
# ############################################# 5 170 w绝对误差 tensor(3.2693, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0387, dtype=torch.float64)   实验回归残差 tensor(0.1044, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0373, dtype=torch.float64)   测试集实验回归残差 tensor(0.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3212334376316621
# #################################################################################################### 5 170 w绝对误差 tensor(2.8942, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8706, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0551, dtype=torch.float64)   实验回归残差 tensor(0.0549, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0641, dtype=torch.float64)   测试集实验回归残差 tensor(0.1641, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4089, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.337837935711213
# ######################################################### 5 170 w绝对误差 tensor(1.4234, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2133, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0701, dtype=torch.float64)   实验回归残差 tensor(0.0947, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0817, dtype=torch.float64)   测试集实验回归残差 tensor(0.1907, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2808333455014296
# ################################################################### 5 170 w绝对误差 tensor(0.4827, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0130, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1865, dtype=torch.float64)   实验回归残差 tensor(0.0949, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2212, dtype=torch.float64)   测试集实验回归残差 tensor(0.0946, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4054, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4058, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2953744447143627
# ################################## 5 170 w绝对误差 tensor(3.9667, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0251, dtype=torch.float64)   实验回归残差 tensor(0.1003, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0199, dtype=torch.float64)   测试集实验回归残差 tensor(0.2414, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2762847522719025
# ###################################### 5 170 w绝对误差 tensor(1.2854, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7978, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0589, dtype=torch.float64)   实验回归残差 tensor(0.0840, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0637, dtype=torch.float64)   测试集实验回归残差 tensor(0.2057, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3763, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.298550425955663
# ################################ 5 170 w绝对误差 tensor(4.1959, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1898, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0281, dtype=torch.float64)   实验回归残差 tensor(0.1116, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0253, dtype=torch.float64)   测试集实验回归残差 tensor(0.2138, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1769540255967423
# ############################################ 5 170 w绝对误差 tensor(2.3853, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4279, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0588, dtype=torch.float64)   实验回归残差 tensor(0.0986, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0602, dtype=torch.float64)   测试集实验回归残差 tensor(0.2108, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3714459035910536
# ########################### 5 170 w绝对误差 tensor(1.6198, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0448, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0606, dtype=torch.float64)   实验回归残差 tensor(0.0919, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0626, dtype=torch.float64)   测试集实验回归残差 tensor(0.1371, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4005, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1948048017864965
# ##################################################################### 5 170 w绝对误差 tensor(2.7969, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3524, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0489, dtype=torch.float64)   实验回归残差 tensor(0.1006, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0459, dtype=torch.float64)   测试集实验回归残差 tensor(0.3224, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.25531442411595
# ########################################################################################################################################################################################################超过迭代上限
#  6 170 w绝对误差 tensor(3.4090, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3150, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0383, dtype=torch.float64)   实验回归残差 tensor(0.0831, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0427, dtype=torch.float64)   测试集实验回归残差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3082685033708419
# ####################################################### 6 170 w绝对误差 tensor(3.8554, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2509, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0347, dtype=torch.float64)   实验回归残差 tensor(0.0979, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0388, dtype=torch.float64)   测试集实验回归残差 tensor(0.1855, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3621631941631043
# #################################### 6 170 w绝对误差 tensor(2.8106, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0688, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0393, dtype=torch.float64)   实验回归残差 tensor(0.0732, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0352, dtype=torch.float64)   测试集实验回归残差 tensor(0.1313, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.399484491481296
# ################################################ 6 170 w绝对误差 tensor(2.3009, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1755, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0484, dtype=torch.float64)   实验回归残差 tensor(0.1045, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0469, dtype=torch.float64)   测试集实验回归残差 tensor(0.1414, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3222043406779174
# ################################## 6 170 w绝对误差 tensor(2.0738, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9277, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0477, dtype=torch.float64)   实验回归残差 tensor(0.0748, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0430, dtype=torch.float64)   测试集实验回归残差 tensor(0.1230, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4090, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.3180103908665444
# ############################################## 6 170 w绝对误差 tensor(3.4493, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3475, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0391, dtype=torch.float64)   实验回归残差 tensor(0.0769, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0383, dtype=torch.float64)   测试集实验回归残差 tensor(0.2509, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.35793641938035
# ############################ 6 170 w绝对误差 tensor(2.6370, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1816, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0432, dtype=torch.float64)   实验回归残差 tensor(0.0827, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0450, dtype=torch.float64)   测试集实验回归残差 tensor(0.1766, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.393897703025583
# ############################### 6 170 w绝对误差 tensor(3.0064, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9249, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0328, dtype=torch.float64)   实验回归残差 tensor(0.0761, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0283, dtype=torch.float64)   测试集实验回归残差 tensor(0.1743, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.30306365165333
# ##################################################################################################################################### 6 170 w绝对误差 tensor(3.0756, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4236, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0499, dtype=torch.float64)   实验回归残差 tensor(0.0578, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0452, dtype=torch.float64)   测试集实验回归残差 tensor(0.2744, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.5055969921208803
# ######################################### 6 170 w绝对误差 tensor(4.0013, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1587, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0303, dtype=torch.float64)   实验回归残差 tensor(0.1180, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0269, dtype=torch.float64)   测试集实验回归残差 tensor(0.1246, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.384780484086062
# #################################################################### 4 170 w绝对误差 tensor(1.9772, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3332, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0715, dtype=torch.float64)   实验回归残差 tensor(0.1154, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0676, dtype=torch.float64)   测试集实验回归残差 tensor(0.2001, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1928078835526588
# ###################################### 4 170 w绝对误差 tensor(2.0304, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5018, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0763, dtype=torch.float64)   实验回归残差 tensor(0.1193, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0767, dtype=torch.float64)   测试集实验回归残差 tensor(0.1579, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4080, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1980757856644813
# ################### 4 170 w绝对误差 tensor(1.8448, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8105, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0466, dtype=torch.float64)   实验回归残差 tensor(0.0826, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0465, dtype=torch.float64)   测试集实验回归残差 tensor(0.2842, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2454426243587873
# ################################################################## 4 170 w绝对误差 tensor(0.5338, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7513, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1321, dtype=torch.float64)   实验回归残差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1185, dtype=torch.float64)   测试集实验回归残差 tensor(0.1152, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.311194386484986
# ################# 4 170 w绝对误差 tensor(1.4074, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6116, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0480, dtype=torch.float64)   实验回归残差 tensor(0.0896, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0458, dtype=torch.float64)   测试集实验回归残差 tensor(0.1393, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.21667938907053
# ##################################################################### 4 170 w绝对误差 tensor(1.7710, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2966, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0690, dtype=torch.float64)   实验回归残差 tensor(0.0731, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0745, dtype=torch.float64)   测试集实验回归残差 tensor(0.1951, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4082, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.1831666382296728
# ###############################################################################################################################################################################################超过迭代上限
#  4 170 w绝对误差 tensor(0.6798, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6517, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0830, dtype=torch.float64)   实验回归残差 tensor(0.1287, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0892, dtype=torch.float64)   测试集实验回归残差 tensor(0.1376, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3805, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.3722187423846788
# ###################################### 4 170 w绝对误差 tensor(3.4077, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4182, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0410, dtype=torch.float64)   实验回归残差 tensor(0.0917, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0433, dtype=torch.float64)   测试集实验回归残差 tensor(0.2069, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2404061613357502
# ######################################################## 4 170 w绝对误差 tensor(3.5794, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2868, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0401, dtype=torch.float64)   实验回归残差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0346, dtype=torch.float64)   测试集实验回归残差 tensor(0.1071, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1740550843972328
# ##################################### 4 170 w绝对误差 tensor(2.4946, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6657, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0677, dtype=torch.float64)   实验回归残差 tensor(0.1491, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0768, dtype=torch.float64)   测试集实验回归残差 tensor(0.1599, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2081676834269648
# ################################################ 5 170 w绝对误差 tensor(2.6047, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1249, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0477, dtype=torch.float64)   实验回归残差 tensor(0.1250, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0444, dtype=torch.float64)   测试集实验回归残差 tensor(0.2009, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.243961415375796
# ############################## 5 170 w绝对误差 tensor(2.3251, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3208, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0576, dtype=torch.float64)   实验回归残差 tensor(0.1055, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0569, dtype=torch.float64)   测试集实验回归残差 tensor(0.1486, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4140, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1899079739441085
# #################################################################################################### 5 170 w绝对误差 tensor(4.5929, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0313, dtype=torch.float64)   实验回归残差 tensor(0.0723, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0311, dtype=torch.float64)   测试集实验回归残差 tensor(0.1681, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.4203649449688995
# ################################### 5 170 w绝对误差 tensor(1.4112, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0772, dtype=torch.float64)   实验回归残差 tensor(0.1939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0802, dtype=torch.float64)   测试集实验回归残差 tensor(0.1645, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3490502888626832
# ################################# 5 170 w绝对误差 tensor(4.1530, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5289, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0422, dtype=torch.float64)   实验回归残差 tensor(0.1110, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0374, dtype=torch.float64)   测试集实验回归残差 tensor(0.1582, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2978279307894989
# ########################################################################################################################################################################################################超过迭代上限
#  5 170 w绝对误差 tensor(1.8579, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0376, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0546, dtype=torch.float64)   实验回归残差 tensor(0.0782, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0585, dtype=torch.float64)   测试集实验回归残差 tensor(0.2035, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2469895650880074
# ################################################################### 5 170 w绝对误差 tensor(2.5804, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6272, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0637, dtype=torch.float64)   实验回归残差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0704, dtype=torch.float64)   测试集实验回归残差 tensor(0.1732, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2362894226998402
# ##################################### 5 170 w绝对误差 tensor(2.2175, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8164, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0395, dtype=torch.float64)   实验回归残差 tensor(0.1236, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0345, dtype=torch.float64)   测试集实验回归残差 tensor(0.1389, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.231046997412357
# ########################## 5 170 w绝对误差 tensor(1.9439, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3792, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0665, dtype=torch.float64)   实验回归残差 tensor(0.0773, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0729, dtype=torch.float64)   测试集实验回归残差 tensor(0.3099, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2340464991377516
# ############################## 5 170 w绝对误差 tensor(2.3032, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9776, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0416, dtype=torch.float64)   实验回归残差 tensor(0.1069, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0485, dtype=torch.float64)   测试集实验回归残差 tensor(0.2389, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2638867002917524
# #################################################################### 6 170 w绝对误差 tensor(2.9994, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2393, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0407, dtype=torch.float64)   实验回归残差 tensor(0.1090, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0431, dtype=torch.float64)   测试集实验回归残差 tensor(0.2116, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2585634923969837
# ############################################################## 6 170 w绝对误差 tensor(2.1639, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4446, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0577, dtype=torch.float64)   实验回归残差 tensor(0.0792, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0725, dtype=torch.float64)   测试集实验回归残差 tensor(0.2729, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4133, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.3093597752895216
# ######################################################################## 6 170 w绝对误差 tensor(4.1701, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3112, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0300, dtype=torch.float64)   实验回归残差 tensor(0.0716, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0327, dtype=torch.float64)   测试集实验回归残差 tensor(0.1447, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2784845280710118
# ####################################################### 6 170 w绝对误差 tensor(1.2756, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6160, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0476, dtype=torch.float64)   实验回归残差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0420, dtype=torch.float64)   测试集实验回归残差 tensor(0.1186, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3088334220076752
# ################################################################## 6 170 w绝对误差 tensor(3.8019, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3166, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0361, dtype=torch.float64)   实验回归残差 tensor(0.0667, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0311, dtype=torch.float64)   测试集实验回归残差 tensor(0.1720, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2790901017672935
# ##################################### 6 170 w绝对误差 tensor(0.7516, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4749, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0611, dtype=torch.float64)   实验回归残差 tensor(0.0638, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0725, dtype=torch.float64)   测试集实验回归残差 tensor(0.1321, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2899006447918384
# #################################### 6 170 w绝对误差 tensor(1.3172, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2877, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0242, dtype=torch.float64)   实验回归残差 tensor(0.0573, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0199, dtype=torch.float64)   测试集实验回归残差 tensor(0.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3634, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3763, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2893659246654934
# ################################################### 6 170 w绝对误差 tensor(1.3354, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9957, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0756, dtype=torch.float64)   实验回归残差 tensor(0.0796, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0807, dtype=torch.float64)   测试集实验回归残差 tensor(0.1455, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4134, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.2573677553438136
# ######################### 6 170 w绝对误差 tensor(4.4918, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5459, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0317, dtype=torch.float64)   实验回归残差 tensor(0.0626, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0332, dtype=torch.float64)   测试集实验回归残差 tensor(0.2256, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3673728847533035
# ############################################################# 6 170 w绝对误差 tensor(1.4940, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8806, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0582, dtype=torch.float64)   实验回归残差 tensor(0.0788, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0630, dtype=torch.float64)   测试集实验回归残差 tensor(0.2294, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3128950647400621
