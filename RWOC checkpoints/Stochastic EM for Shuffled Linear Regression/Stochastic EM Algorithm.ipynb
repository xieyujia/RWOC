# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from scipy.stats import norm

def mse(x,y,w): #actually returns RMSE
    assert x.dot(w).shape == y.shape
    return np.sqrt(np.mean(np.square(x.dot(w)-y)))

def log_prob_of_order(x,y,coefs,s,order):
    eps = 1e-6
    y_ = y[order]
    log_prob = np.sum(-np.square(x.dot(coefs)-y_)/(2*(s+eps)**2))
    return log_prob

def calc_relative_error(w0, w):
    w = np.array(w); w0 = np.array(w0)
    w = w.flatten()
    w0 = w0.flatten()
    return np.linalg.norm(w-w0)/np.linalg.norm(w0)

def calc_error(w0, w, multi=False):
    w = np.array(w); w0 = np.array(w0)
    if (multi):
        w = w.reshape(w0.shape)
        return np.linalg.norm(w-w0,axis=1)
    else:
        w = w.flatten()
        w0 = w0.flatten()
        return np.linalg.norm(w-w0)

def calc_normalized_error(w0, w, multi=False):
    w = np.array(w); w0 = np.array(w0)
    d = w.flatten().shape
    diff = w - w0
    err = np.abs(diff)
    err_total = np.sum(err)
    return err_total/d

def calc_rmse(y_,y):
    return np.sqrt(np.mean((y.flatten() - y_.flatten())**2))

def normalize(y):
    return (y-np.min(y))/(np.max(y) - np.min(y))


def shuffle_up_to_delta(y, eps, return_groups=False):
    vals = np.linspace(np.min(y),np.max(y),(np.max(y)-np.min(y))/eps+1)
    groups = np.copy(y)
    #print("Actual delta:",vals[1]-vals[0])
    y_ = y.copy()
    for i in range(len(vals)-1):
        idx = np.where(np.logical_and(y>=vals[i], y<=vals[i+1]))
        y_[idx] = np.random.permutation(y[idx])
        groups[idx] = i
    #plt.plot(y, y_,'.')
    if (return_groups):
        return y_, groups
    return y_

def enhanced_sort(x, w, groups):
    for i in np.unique(groups):
        idx = np.where(groups==i)[0]
        order = np.argsort(x.dot(w).flatten()[idx])
        x[idx] = x[idx][order]
    return x

def sorted_distance(y, y_):
    y = np.sort(y.flatten())
    y_ = np.sort(y_.flatten())
    return np.linalg.norm(y-y_)

def ols(x,y,alpha=0.01,fit_intercept=False):
    if alpha==0:
        lr =  LinearRegression(fit_intercept=fit_intercept)
    else:
        lr = Ridge(fit_intercept=fit_intercept, alpha=alpha)
    lr.fit(x, y)
    w = lr.coef_.T
    return w


def shuffle_within_num_groups_by_feature(features, labels, feature_index, n_clusters = 1, fraction_missorted=0, random_assignment=False):
    n,d = features.shape
    labels = labels.flatten()

    cluster_vector = np.repeat(range(n_clusters), n//n_clusters)
    padding = np.repeat([n_clusters-1],n%n_clusters)
    cluster_vector = np.concatenate((cluster_vector, padding))

    #Handle the missorts (they get randomly put into a bin ahead or behind)
    missort_idx = np.random.permutation(n)[:int(fraction_missorted*n)]
    missort = list()
    for i in missort_idx:
        if cluster_vector[i]==0:
            missort.append(1)
        elif cluster_vector[i]==n_clusters:
            missort.append(-1)
        else:
            if np.random.random()<0.5:
                missort.append(-1)
            else:
                missort.append(1)
    cluster_vector[missort_idx] += np.array(missort, dtype=int)

    #sort the features and labels
    order = np.argsort(features[:,feature_index])
    #if (random_assignment):
        #order = np.random.permutation(order)

    features = features[order]
    labels = labels[order]


    #randomize the label ordering
    for i in range(n_clusters):
        idx = np.where(cluster_vector==i)
        labels[idx] = np.random.permutation(labels[idx])
        features[idx] = np.random.permutation(features[idx])

    return features, labels, cluster_vector

def shuffle_within_num_groups(features, labels, n_clusters = 1, fraction_missorted=0, random_assignment=False):
    n,d = features.shape
    labels = labels.flatten()

    cluster_vector = np.repeat(range(n_clusters), n//n_clusters)
    padding = np.repeat([n_clusters-1],n%n_clusters)
    cluster_vector = np.concatenate((cluster_vector, padding))

    #Handle the missorts (they get randomly put into a bin ahead or behind)
    missort_idx = np.random.permutation(n)[:int(fraction_missorted*n)]
    missort = list()
    for i in missort_idx:
        if cluster_vector[i]==0:
            missort.append(1)
        elif cluster_vector[i]==n_clusters:
            missort.append(-1)
        else:
            if np.random.random()<0.5:
                missort.append(-1)
            else:
                missort.append(1)
    cluster_vector[missort_idx] += np.array(missort, dtype=int)


    #sort the features and labels
    order = np.argsort(labels)
    #if (random_assignment):
        #order = np.random.permutation(order)

    features = features[order]
    labels = labels[order]


    #randomize the label ordering
    for i in range(n_clusters):
        idx = np.where(cluster_vector==i)
        labels[idx] = np.random.permutation(labels[idx])
        features[idx] = np.random.permutation(features[idx])

    return features, labels, cluster_vector

def calc_angle(w0, w):
    w = np.array(w); w0 = np.array(w0)
    w = w.flatten()
    w0 = w0.flatten()
    return np.arccos(np.dot(w,w0)/(np.linalg.norm(w)*np.linalg.norm(w0)))


def semi_mean_ols_y(features,labels, groups, alpha=0.01):
    if alpha==0:
        lr =  LinearRegression(fit_intercept=False)
    else:
        lr = Ridge(fit_intercept=False, alpha=alpha)

    xs = list()
    ys = list()
    for i in np.unique(groups):
        idxs = np.where(groups==i)[0]
        y = np.mean(labels[idxs],axis=0)
        for idx in idxs:
            x = features[idx,:]
            xs.append(x)
            ys.append(y)
    xs = np.array(xs)
    ys = np.array(ys)
    #print(xs.shape, ys.shape)
    lr.fit(xs, ys)
    return lr.coef_.T

def semi_mean_ols_x(features,labels, groups, alpha=0.01):
    if alpha==0:
        lr =  LinearRegression(fit_intercept=False)
    else:
        lr = Ridge(fit_intercept=False, alpha=alpha)
    xs = list()
    ys = list()
    for i in np.unique(groups):
        idxs = np.where(groups==i)[0]
        x = np.mean(features[idxs,:],axis=0)
        for idx in idxs:
            xs.append(x)
            y = labels[idx]
            ys.append(y)
    xs = np.array(xs)
    ys = np.array(ys)
    #print(xs.shape, ys.shape)
    lr.fit(xs, ys)
    return lr.coef_.T

def mean_ols(features,labels, groups, alpha=0.01):
    if alpha==0:
        lr =  LinearRegression(fit_intercept=False)
    else:
        lr = Ridge(fit_intercept=False, alpha=alpha)
    xs = list()
    ys = list()
    for i in np.unique(groups):
        idxs = np.where(groups==i)[0]
        x = np.mean(features[idxs,:],axis=0)
        y = np.mean(labels[idxs],axis=0)
        for idx in idxs:
            xs.append(x)
            ys.append(y)
    xs = np.array(xs)
    ys = np.array(ys)
    lr.fit(xs, ys)
    return lr.coef_.T

def mean_ols_with_noise(features,labels, groups, noise=0.01, alpha=0.01):
    if alpha==0:
        lr =  LinearRegression(fit_intercept=False)
    else:
        lr = Ridge(fit_intercept=False, alpha=alpha)
    xs = list()
    ys = list()
    for i in np.unique(groups):
        for _ in range(100):
            idx = np.where(groups==i)[0]
            x = np.mean(features[idx,:],axis=0)
            xs.append(x)
            y = np.mean(labels[idx],axis=0)
            y = y + np.random.normal(0,noise,size=y.shape)
            ys.append(y)
    xs = np.array(xs)
    ys = np.array(ys)
    #print(xs.shape, ys.shape)
    lr.fit(xs, ys)
    return lr.coef_.T

def generate_distribution(dim=2, n=100, noise=0, dist='normal', mean=0, var=1, WA=None, bias=False, n_clusters=None):
    """generates data of a given dimension and distribution with given parameters
    WA -- if you would like to set the weight matrix, provide it here
    """
    if (dist=='normal'):
        X = np.random.normal(mean,var, size=[n, dim]);
    elif (dist=='half-normal-uniform'):
        X1 = np.random.rand(n, dim//2)-mean*0.5
        X2 = np.random.normal(mean, var, size=[n, dim//2])
        X = np.concatenate((X1, X2), axis=1)
    elif (dist=='uniform'):
        X = var*np.random.rand(n, dim)+mean
    elif (dist=='2normals'):
        X1 = np.random.normal(-mean,var, size=[n/2, dim])
        X2 = np.random.normal(mean,var, size=[n-n/2, dim]);
        X = np.concatenate((X1, X2), axis=0)
    elif (dist=='exponential'):
        X = np.random.exponential(var, size=[n, dim]);
    else:
        raise NameError('Invalid distribution: ' + str(dist))
    if (bias):
        X[:,0] = 1 #set the first column to be all 1s for the "intercept" term
    if (WA is None):
        WA = np.random.normal(0,1,size=[dim, 1]); #Actual weights
    else:
        WA = np.array(WA)
        WA = WA.reshape(dim, 1)
    y = np.dot(X,WA) + noise*np.random.normal(0,1,size=[n,1]); #Ordered labels
    if (n_clusters is None):
        return X, y, WA
    else:
        cluster_vector = np.tile(range(n_clusters), n//n_clusters)
        cluster_vector = np.concatenate((cluster_vector, range(n%n_clusters)))
        np.random.shuffle(cluster_vector)
        return X, y, WA, cluster_vector

def load_dataset_clusters(filename, normalize=True, n_clusters = 1):
    data = np.genfromtxt(filename, delimiter=',',skip_header=2)
    n,d = data.shape

    cluster_vector = np.tile(range(n_clusters), n//n_clusters)
    cluster_vector = np.concatenate((cluster_vector, range(n%n_clusters)))
    np.random.shuffle(cluster_vector)

    #normalize
    if (normalize):
        data = (data-np.min(data, axis=0))
        data = data/(np.max(data, axis=0)+0.01)

    labels = data[:,-1].copy()
    features = data[:,:].copy()
    features[:,-1] = 1 #add a bias column

    return features, labels, cluster_vector

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from scipy.stats import norm
from utils import *

# Stochastic EM Algorithm
def em_mcmc(x,y,fit_intercept=False,steps=15,return_all_weights=False,verbose=False, enhanced=False, groups=None, mcmc_steps=None, interval_between_mcmc_steps=None):
    import time

    lr =  LinearRegression(fit_intercept=fit_intercept)
    n, d = x.shape
    lr.fit(x,y)
    coefs = lr.coef_.T
    s = np.sqrt(np.sum(np.square(y - x.dot(coefs)))/(n-d)) #RMS of residuals

    ws = list()

    for i in list(range(steps)):

        order = np.arange(n)
        y_mean = np.zeros(n)

        if mcmc_steps is None:
            mcmc_steps = np.max([int(n*np.log(n)),100])
        if interval_between_mcmc_steps is None:
            interval_between_mcmc_steps = n/10
        burn_steps = int(mcmc_steps/2)
        mean_step_counter = 0
        interval_mcmc_counter = 0

        for m_step in range(mcmc_steps):
            order_ = np.copy(order)

            i = np.random.randint(0,n)

            if (enhanced):
                if not(groups is None):
                    indices_in_same_group = np.where(groups==groups[i])[0]
                    j = np.random.choice(indices_in_same_group)
                else:
                    raise ValueError("Group Information Must Be Provided for Enhanced SLS")
            else:
                j = np.random.randint(0,n)

            order_[i] = order[j]
            order_[j] = order[i]

            p1 = log_prob_of_order(x,y,coefs,s,order)
            p2 = log_prob_of_order(x,y,coefs,s,order_)

            if p1 < p2:
                order = order_
            else:
                if np.random.random() < np.exp(p2-p1): #since they're log probabilities
                    order = order_

            if m_step>=burn_steps:
                interval_mcmc_counter += 1
                if (interval_mcmc_counter>=interval_between_mcmc_steps):
                    y_mean += y.flatten()[order]
                    mean_step_counter += 1
                    interval_mcmc_counter = 0

        y = y_mean/mean_step_counter
        y = y.reshape(-1,1)

        lr.fit(x,y)
        coefs = lr.coef_.T
        s = np.sqrt(np.sum(np.square(y - x.dot(coefs)))/(n-d)) #RMS of residuals
        ws.append(coefs)
    residual=np.linalg.norm(y - x.dot(coefs))/np.linalg.norm(y)
    
    if (return_all_weights):
        return ws
    return coefs,residual

# Hard EM Algorithm
def sls(x, y, steps=15, alpha=0, w_initial=None, return_all_weights = False, enhanced=False, groups=None, fit_intercept=False, n_starts=1):
    if alpha==0:
        lr =  LinearRegression(fit_intercept=fit_intercept)
    else:
        lr = Ridge(fit_intercept=fit_intercept, alpha=alpha)

    order = np.argsort(y.flatten())
    y = y[order]
    x = x[order]
    errors = list()
    optimal_score = float("-inf")
    optimal_ws = list()

    for i_start in range(n_starts):
        ws = list()
        if w_initial is None and n_starts==1:
            lr.fit(x, y)
            w = lr.coef_.T
        elif w_initial is None:
            if i_start>0:
                y_ = np.random.permutation(y)
            elif i_start==0: #try the current permutation first
                y_ = y
            lr.fit(x, y_)
            w = lr.coef_.T
        elif w_initial=='mean':
            y_ = np.copy(y)
            for i in np.unique(groups):
                idx = np.where(groups==i)[0]
                y_[idx] = np.mean(y[idx])
            lr.fit(x, y_)
            w = lr.coef_.T
        else:
            w = w_initial

        for _ in list(range(steps)):

            if (enhanced):
                if not(groups is None):
                    x = enhanced_sort(x, w, groups)
                else:
                    raise ValueError("Group Information Must Be Provided for Enhanced SLS")
            else:
                order = np.argsort(x.dot(w).flatten())
                x = x[order]

            lr.fit(x, y)
            w = lr.coef_.T
            ws.append(w)

        if lr.score(x,y)>optimal_score:
            optimal_score = lr.score(x,y)
            optimal_ws = ws.copy()

    if (return_all_weights):
        return optimal_ws
    return optimal_ws[-1]

# %%
import sys, os;
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
#from utils import *
#from algorithms import *

# %load_ext autoreload
# %matplotlib inline
# %autoreload 2

np.set_printoptions(precision=2)
lr =  LinearRegression(fit_intercept=False)

font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

matplotlib.rc('font', **font)

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = np.random.normal(0, 1,(num_X2feature,1))
    X2_before_ =np.random.normal(0, 1, (num_example, num_X2feature))
    X2_test_before=np.random.normal(0, 1, (num_example, num_X2feature))
    y_ = np.matmul(X2_before_,true_w2)
    y_test=np.matmul(X2_test_before,true_w2)
    y_ += np.random.normal(0, noise ,size=(num_example,1))
    y_test += np.random.normal(0, noise ,size=(num_example,1))
    P_array=np.random.permutation(num_example)
    P=np.zeros((num_example,num_example))
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=np.zeros((num_example,num_example))
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=np.matmul(P,X2_before_)
    X2_test=np.matmul(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_)
    #X2_=X2_before_
    error_reg=(np.linalg.norm(y_-np.matmul(X2_before_,true_w2))/np.linalg.norm(y_))
    error_reg_test=(np.linalg.norm(y_test-np.matmul(X2_test_before,true_w2))/np.linalg.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
for i_____ in range(5):
    for num_example in range(170,171,30): 
        for num_X2feature in [1,2,3,4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                weights,residual = em_mcmc(X2_,y_,steps=50)
                error=np.linalg.norm(weights-true_w2)/np.linalg.norm(true_w2)
                print(num_X2feature,num_example,'w相对误差',error,end='   ')
                print('实验回归残差',residual,end='   ')
                print('真实回归残差',error_reg1)
# Out:
# 1 170 w相对误差 0.9926727989223123   实验回归残差 0.9960268747543758   真实回归残差 0.04424396817191973
# 1 170 w相对误差 0.9900703746490165   实验回归残差 0.9952031573624598   真实回归残差 0.26706277806130435
# 1 170 w相对误差 0.9960339324967825   实验回归残差 0.9980627845036758   真实回归残差 0.06786206362409314
# 1 170 w相对误差 0.9939453999571188   实验回归残差 0.9973233328162697   真实回归残差 0.2448798105727874
# 1 170 w相对误差 0.9986790783356286   实验回归残差 0.9993450787890142   真实回归残差 0.03945771002867594
# 1 170 w相对误差 0.9966281382101557   实验回归残差 0.9984538914493366   真实回归残差 0.17412039044670571
# 1 170 w相对误差 0.9894060748638136   实验回归残差 0.9712817306178952   真实回归残差 0.22057823816006913
# 1 170 w相对误差 0.9916997896726403   实验回归残差 0.9950697961940138   真实回归残差 0.18517911034020282
# 1 170 w相对误差 0.9991909915681327   实验回归残差 0.9995854077113634   真实回归残差 0.05555043662707829
# 1 170 w相对误差 0.9889751222590724   实验回归残差 0.9942188781568664   真实回归残差 0.04815710162177184
# 2 170 w相对误差 0.978774904775529   实验回归残差 0.9854881550657459   真实回归残差 0.2913962931192949
# 2 170 w相对误差 0.9998080194243263   实验回归残差 0.9912132674452957   真实回归残差 0.036380923308002855
# 2 170 w相对误差 0.984937939490591   实验回归残差 0.9649728491980513   真实回归残差 0.07293946446561039
# 2 170 w相对误差 0.9955922369219119   实验回归残差 0.9911623710499402   真实回归残差 0.03909971633931702
# 2 170 w相对误差 1.0003195254458928   实验回归残差 0.9950237421538735   真实回归残差 0.09750467442056984
# 2 170 w相对误差 1.00044064019932   实验回归残差 0.9603462897326174   真实回归残差 0.03772899970242708
# 2 170 w相对误差 1.02691237867939   实验回归残差 0.9494092582564805   真实回归残差 0.053770180919312356
# 2 170 w相对误差 1.0133102174318447   实验回归残差 0.9753626245565222   真实回归残差 0.1815241131591306
# 2 170 w相对误差 0.9917251613215077   实验回归残差 0.9918482248738939   真实回归残差 0.1366728824371359
# 2 170 w相对误差 0.9960593974304661   实验回归残差 0.997854854051137   真实回归残差 0.07234691791949174
# 3 170 w相对误差 0.9859877722546349   实验回归残差 0.9789812363728758   真实回归残差 0.039954809433522434
# 3 170 w相对误差 1.048847366432842   实验回归残差 0.9302614353118889   真实回归残差 0.06017683923636495
# 3 170 w相对误差 0.9987040293747276   实验回归残差 0.9892452270323715   真实回归残差 0.052022731884193575
# 3 170 w相对误差 0.9814091150679016   实验回归残差 0.9825107069305725   真实回归残差 0.1269090853701958
# 3 170 w相对误差 1.00790745039897   实验回归残差 0.9069797711668556   真实回归残差 0.03408739399227264
# 3 170 w相对误差 0.9837535392994033   实验回归残差 0.989275644392174   真实回归残差 0.053305150324015685
# 3 170 w相对误差 0.9684390604510096   实验回归残差 0.9830371595894325   真实回归残差 0.05533379775737245
# 3 170 w相对误差 0.9610321596357791   实验回归残差 0.974433432364686   真实回归残差 0.12675781709648773
# 3 170 w相对误差 0.9988040010064846   实验回归残差 0.9990802476958247   真实回归残差 0.05048467345934098
# 3 170 w相对误差 0.9867028204464038   实验回归残差 0.9923442666269799   真实回归残差 0.0567800388985103
# 4 170 w相对误差 0.9493733239230251   实验回归残差 0.9417168381486223   真实回归残差 0.06403811489399776
# 4 170 w相对误差 0.9760469627338344   实验回归残差 0.9383351857869444   真实回归残差 0.03806216714328889
# 4 170 w相对误差 0.9961924764106659   实验回归残差 0.9505053238852315   真实回归残差 0.07478570847830433
# 4 170 w相对误差 0.9976601954686547   实验回归残差 0.9944466159963085   真实回归残差 0.13548405581847947
# 4 170 w相对误差 0.9981638400815496   实验回归残差 0.9790454666545106   真实回归残差 0.05607904184509793
# 4 170 w相对误差 0.9998459633822273   实验回归残差 0.9556728707985175   真实回归残差 0.03711074573006017
# 4 170 w相对误差 0.9977010746248434   实验回归残差 0.990870488582422   真实回归残差 0.053475472962459185
# 4 170 w相对误差 1.0231045136011432   实验回归残差 0.9057076297180563   真实回归残差 0.19286567004462574
# 4 170 w相对误差 0.9900008760307346   实验回归残差 0.992102026896054   真实回归残差 0.09429083919766497
# 4 170 w相对误差 1.0152058681897416   实验回归残差 0.9620123481993955   真实回归残差 0.07596794877023141
# 5 170 w相对误差 1.0372276333732993   实验回归残差 0.9687063706172613   真实回归残差 0.04989459882236536
# 5 170 w相对误差 1.0138612666754616   实验回归残差 0.9736948958739644   真实回归残差 0.054221335201595555
# 5 170 w相对误差 1.0095086340958817   实验回归残差 0.8890193941464758   真实回归残差 0.033241454152009714
# 5 170 w相对误差 0.9863931990353128   实验回归残差 0.9662137952729166   真实回归残差 0.05116185406905218
# 5 170 w相对误差 0.9851898702520728   实验回归残差 0.9667721833164068   真实回归残差 0.07893923302301549
# 5 170 w相对误差 0.9748535878113184   实验回归残差 0.9588687770604908   真实回归残差 0.05028305668703799
# 5 170 w相对误差 1.0061065937611933   实验回归残差 0.9746430452445057   真实回归残差 0.028214564083243996
# 5 170 w相对误差 0.9919148177450618   实验回归残差 0.9889196771595122   真实回归残差 0.06693756424454468
# 5 170 w相对误差 0.9977774793944517   实验回归残差 0.9838882774332812   真实回归残差 0.025985079020407656
# 5 170 w相对误差 0.9669180586562213   实验回归残差 0.949621049802092   真实回归残差 0.03446161623312975
# 6 170 w相对误差 0.9742741508738809   实验回归残差 0.947808227597442   真实回归残差 0.035378658956641724
# 6 170 w相对误差 0.9945742423225201   实验回归残差 0.9767662796192156   真实回归残差 0.07088340222805305
# 6 170 w相对误差 0.9988854714813777   实验回归残差 0.9877266005565589   真实回归残差 0.02923404875392931
# 6 170 w相对误差 0.9858754910303608   实验回归残差 0.9317401709923372   真实回归残差 0.04445958013677092
# 6 170 w相对误差 0.9354759668213406   实验回归残差 0.9418270907777726   真实回归残差 0.035582667747853715
# 6 170 w相对误差 0.9828170094150546   实验回归残差 0.9678208550581193   真实回归残差 0.05763308243543665
# 6 170 w相对误差 0.9631447956311808   实验回归残差 0.969339989332124   真实回归残差 0.028723194153417158
# 6 170 w相对误差 1.0211129451274885   实验回归残差 0.9375282328594857   真实回归残差 0.024924347701143598
# 6 170 w相对误差 0.9837753476515554   实验回归残差 0.943305089030206   真实回归残差 0.03279364520805629
# 6 170 w相对误差 0.9919874781148702   实验回归残差 0.9695653406081194   真实回归残差 0.06628392057809165
# 1 170 w相对误差 0.9996168336622975   实验回归残差 0.9996600306194857   真实回归残差 0.3894197784886612
# 1 170 w相对误差 0.9922715398323468   实验回归残差 0.9977471778564843   真实回归残差 0.4271408725768252
# 1 170 w相对误差 0.996064106326847   实验回归残差 0.9984287389852361   真实回归残差 0.408860000696266
# 1 170 w相对误差 0.9882735947039694   实验回归残差 0.9673359842316898   真实回归残差 0.11183676351752915
# 1 170 w相对误差 0.990608038641431   实验回归残差 0.9944145945675538   真实回归残差 0.09403690957230719
# 1 170 w相对误差 0.999158443649617   实验回归残差 0.9995741698301487   真实回归残差 0.18308209763499933
# 1 170 w相对误差 0.9854159564985597   实验回归残差 0.9985199541621496   真实回归残差 0.8831924451723742
# 1 170 w相对误差 0.9873717918121812   实验回归残差 0.9943922642117506   真实回归残差 0.08024016134285665
# 1 170 w相对误差 0.993531457011156   实验回归残差 0.9974024456464864   真实回归残差 0.13344774714891663
# 1 170 w相对误差 0.9996617613605443   实验回归残差 0.9998250867945239   真实回归残差 0.041334194348199946
# 2 170 w相对误差 0.9950417241592252   实验回归残差 0.9984834847573154   真实回归残差 0.6714367138969144
# 2 170 w相对误差 0.992981147473061   实验回归残差 0.9953051284825108   真实回归残差 0.05892440837095784
# 2 170 w相对误差 0.9950333669211634   实验回归残差 0.9710963480763273   真实回归残差 0.6391019974977732
# 2 170 w相对误差 0.9964832283482968   实验回归残差 0.9743148990038758   真实回归残差 0.1516848419944137
# 2 170 w相对误差 0.9908693465674928   实验回归残差 0.9941504620630046   真实回归残差 0.08335396118778549
# 2 170 w相对误差 0.9999877853513213   实验回归残差 0.9999296668339742   真实回归残差 0.16199100663326857
# 2 170 w相对误差 0.990589310836887   实验回归残差 0.9947179796472227   真实回归残差 0.031967430326169326
# 2 170 w相对误差 0.9975668678749847   实验回归残差 0.998554715834872   真实回归残差 0.09325818909576226
# 2 170 w相对误差 0.9957735634691242   实验回归残差 0.996286058832105   真实回归残差 0.11871567348780689
# 2 170 w相对误差 0.9953981520011903   实验回归残差 0.9662909379067277   真实回归残差 0.12709230094998406
# 3 170 w相对误差 0.9998410053116992   实验回归残差 0.997447665741779   真实回归残差 0.08341176734376453
# 3 170 w相对误差 0.9917930162928175   实验回归残差 0.982598289184872   真实回归残差 0.04711688612711135
# 3 170 w相对误差 0.9914358930154982   实验回归残差 0.9905961346550357   真实回归残差 0.0879275916907625
# 3 170 w相对误差 0.997652792780281   实验回归残差 0.9781874750304123   真实回归残差 0.036978760716127525
# 3 170 w相对误差 0.9815915439114716   实验回归残差 0.9902284713818555   真实回归残差 0.05958703534130755
# 3 170 w相对误差 0.9557074570843644   实验回归残差 0.9509649168982597   真实回归残差 0.06714031792984215
# 3 170 w相对误差 0.9938312173896896   实验回归残差 0.9968964832609962   真实回归残差 0.06274541439928524
# 3 170 w相对误差 0.9960816988820772   实验回归残差 0.9938993719927018   真实回归残差 0.06207631146898907
# 3 170 w相对误差 0.9985538098301787   实验回归残差 0.9907364783940116   真实回归残差 0.035409996253385825
# 3 170 w相对误差 0.9969268958288128   实验回归残差 0.9890819979042387   真实回归残差 0.11331952470178387
# 4 170 w相对误差 0.9596955092131215   实验回归残差 0.9689823473324596   真实回归残差 0.06335854675733404
# 4 170 w相对误差 0.9941040732480791   实验回归残差 0.9863123491048692   真实回归残差 0.0520195691461825
# 4 170 w相对误差 0.9898280018538679   实验回归残差 0.9790941762970741   真实回归残差 0.03539594260500481
# 4 170 w相对误差 0.9718515673295195   实验回归残差 0.9627329720454356   真实回归残差 0.05900246212732973
# 4 170 w相对误差 1.0089115110963176   实验回归残差 0.9429534120475976   真实回归残差 0.12005756309671776
# 4 170 w相对误差 0.9743651041848052   实验回归残差 0.9335103309117204   真实回归残差 0.03816416628462482
# 4 170 w相对误差 0.9977314512445168   实验回归残差 0.9572265169648019   真实回归残差 0.067755592396123
# 4 170 w相对误差 0.9994651658933206   实验回归残差 0.9977978910957296   真实回归残差 0.026846959129543425
# 4 170 w相对误差 1.0098428435821436   实验回归残差 0.9535069933540162   真实回归残差 0.07329748546114398
# 4 170 w相对误差 0.9492785244584234   实验回归残差 0.8836954542462775   真实回归残差 0.102671287734442
# 5 170 w相对误差 0.9931565918747877   实验回归残差 0.985657993154679   真实回归残差 0.04738166087901525
# 5 170 w相对误差 0.9840681677536679   实验回归残差 0.9069031156138713   真实回归残差 0.044133896983851464
# 5 170 w相对误差 0.9995447348568871   实验回归残差 0.9906956691563187   真实回归残差 0.047048500350709434
# 5 170 w相对误差 0.9957838840840061   实验回归残差 0.9554194511478304   真实回归残差 0.08790349576371097
# 5 170 w相对误差 1.0123626419725078   实验回归残差 0.9551362496591927   真实回归残差 0.06199365213247422
# 5 170 w相对误差 1.0096559296533507   实验回归残差 0.9745129072115334   真实回归残差 0.05662190548020138
# 5 170 w相对误差 0.9466064826032946   实验回归残差 0.9496699545436905   真实回归残差 0.0550679291761517
# 5 170 w相对误差 1.0406810067636765   实验回归残差 0.9203753991036402   真实回归残差 0.04758199987800058
# 5 170 w相对误差 0.9979477620782764   实验回归残差 0.9699804557885322   真实回归残差 0.05505713152432814
# 5 170 w相对误差 0.9209417029856587   实验回归残差 0.8863896355680431   真实回归残差 0.07344965458641015
# 6 170 w相对误差 0.9913876863791086   实验回归残差 0.9877796029417657   真实回归残差 0.04733216742056806
# 6 170 w相对误差 0.9899327011813582   实验回归残差 0.9846511719053045   真实回归残差 0.03774543937110998
# 6 170 w相对误差 1.0253555789253823   实验回归残差 0.9146886546669177   真实回归残差 0.03705551501088825
# 6 170 w相对误差 0.9988650607305277   实验回归残差 0.9609790606784315   真实回归残差 0.03586965430766701
# 6 170 w相对误差 0.9670455814474869   实验回归残差 0.9632926404432732   真实回归残差 0.06947024136995879
# 6 170 w相对误差 1.0182207104518703   实验回归残差 0.9731088400268961   真实回归残差 0.05812612063261273
# 6 170 w相对误差 0.9955252875778896   实验回归残差 0.9941801645309571   真实回归残差 0.03246648791632945
# 6 170 w相对误差 1.005997110485176   实验回归残差 0.9116106180739366   真实回归残差 0.03309682530337653
# 6 170 w相对误差 0.9820843070721688   实验回归残差 0.9454669853346623   真实回归残差 0.03759011914651556
# 6 170 w相对误差 0.9849232275637254   实验回归残差 0.9223919596952783   真实回归残差 0.03257705901089003
# 1 170 w相对误差 1.1394288731834494   实验回归残差 0.9960367637769457   真实回归残差 1.0002935321407813
# 1 170 w相对误差 0.9850868378465479   实验回归残差 0.945421137098386   真实回归残差 0.07426719494382089
# 1 170 w相对误差 0.974861879604624   实验回归残差 0.9875669913041863   真实回归残差 0.060441416956569675
# 1 170 w相对误差 0.9963862605057696   实验回归残差 0.9985784564708282   真实回归残差 0.10600401115239026
# 1 170 w相对误差 0.9963125733789987   实验回归残差 0.9986797731218259   真实回归残差 0.20661774998260649
# 1 170 w相对误差 0.9893124733427788   实验回归残差 0.9772046556986584   真实回归残差 0.2517614404154946
# 1 170 w相对误差 0.9973837877306834   实验回归残差 0.9987521063096374   真实回归残差 0.0921428863592081
# 1 170 w相对误差 0.991029461748402   实验回归残差 0.9953353121848428   真实回归残差 0.07994421519883389
# 1 170 w相对误差 0.992744691940062   实验回归残差 0.9960298796233642   真实回归残差 0.2349198721006086
# 1 170 w相对误差 0.997160710347211   实验回归残差 0.9984674761657883   真实回归残差 0.11839472963308276
# 2 170 w相对误差 0.9866353866976135   实验回归残差 0.9010372195235833   真实回归残差 0.10495560522504388
# 2 170 w相对误差 0.9968815297251726   实验回归残差 0.9982100340050166   真实回归残差 0.04931400680283102
# 2 170 w相对误差 0.9969949843317744   实验回归残差 0.9985096200739819   真实回归残差 0.5392964655959197
# 2 170 w相对误差 1.0032536839551982   实验回归残差 0.9597741335844597   真实回归残差 0.10107242458655902
# 2 170 w相对误差 0.999270839155662   实验回归残差 0.9987720558714687   真实回归残差 0.13383363303352896
# 2 170 w相对误差 0.9924883403898466   实验回归残差 0.9951766035289431   真实回归残差 0.053829754023641464
# 2 170 w相对误差 0.9867654004188685   实验回归残差 0.990409642380184   真实回归残差 0.03817097870210666
# 2 170 w相对误差 0.9988948789653357   实验回归残差 0.9979786873847815   真实回归残差 0.06982244656244196
# 2 170 w相对误差 0.9874786778534062   实验回归残差 0.972278742676629   真实回归残差 0.08406622092417838
# 2 170 w相对误差 0.9967581554556902   实验回归残差 0.9922574592943089   真实回归残差 0.27831010317413335
# 3 170 w相对误差 0.9981581401662487   实验回归残差 0.9393261122265666   真实回归残差 0.06689520163202356
# 3 170 w相对误差 0.9956938130664864   实验回归残差 0.9971542055616213   真实回归残差 0.05606844007433302
# 3 170 w相对误差 0.9942864424544638   实验回归残差 0.9690001833379164   真实回归残差 0.03005656163115056
# 3 170 w相对误差 0.9967658638414936   实验回归残差 0.9965397833640163   真实回归残差 0.04306249073935508
# 3 170 w相对误差 0.9998194944677822   实验回归残差 0.995054117456944   真实回归残差 0.056518661598576256
# 3 170 w相对误差 1.0030633503326576   实验回归残差 0.9821334766373656   真实回归残差 0.0598092456108403
# 3 170 w相对误差 1.014052452746877   实验回归残差 0.9449900302263156   真实回归残差 0.06439216232308288
# 3 170 w相对误差 0.9830245076449103   实验回归残差 0.975660848917877   真实回归残差 0.07268112470261158
# 3 170 w相对误差 0.9823161576186585   实验回归残差 0.9889810475220033   真实回归残差 0.07924221212888
# 3 170 w相对误差 1.0165270717376156   实验回归残差 0.9605574440096875   真实回归残差 0.08453009006053594
# 4 170 w相对误差 1.001171505108436   实验回归残差 0.9576311175921333   真实回归残差 0.0831967462216802
# 4 170 w相对误差 0.9942940500064755   实验回归残差 0.9965173812641134   真实回归残差 0.03772555708450057
# 4 170 w相对误差 1.0020027679911818   实验回归残差 0.9512870301962029   真实回归残差 0.06877807228698618
# 4 170 w相对误差 0.9893775802069297   实验回归残差 0.9505694760519678   真实回归残差 0.05097658090272128
# 4 170 w相对误差 0.9802241895339291   实验回归残差 0.9689811462313215   真实回归残差 0.03683430682321865
# 4 170 w相对误差 0.9921289689188718   实验回归残差 0.9894200087412705   真实回归残差 0.04171702927833782
# 4 170 w相对误差 0.9470966772114852   实验回归残差 0.9585653722530822   真实回归残差 0.060974366237509084
# 4 170 w相对误差 0.9981199769770309   实验回归残差 0.9949934392309638   真实回归残差 0.09130255946773198
# 4 170 w相对误差 0.9929585070889014   实验回归残差 0.9901899872504788   真实回归残差 0.07057221979851519
# 4 170 w相对误差 0.9785356791564377   实验回归残差 0.8914943441732204   真实回归残差 0.07017167067044172
# 5 170 w相对误差 0.978003827041109   实验回归残差 0.9377605958729934   真实回归残差 0.08581156887286018
# 5 170 w相对误差 0.9885894961339381   实验回归残差 0.9867999157305222   真实回归残差 0.031755622351935915
# 5 170 w相对误差 1.000325835415746   实验回归残差 0.9644747530624517   真实回归残差 0.0561477528053589
# 5 170 w相对误差 0.979512167175008   实验回归残差 0.9851417204925138   真实回归残差 0.05444916784185472
# 5 170 w相对误差 0.9912878807978035   实验回归残差 0.9866788558567429   真实回归残差 0.06236663795349343
# 5 170 w相对误差 1.0072277276080337   实验回归残差 0.9749328141227942   真实回归残差 0.06877236982065454
# 5 170 w相对误差 1.0064572372481182   实验回归残差 0.9400352110413868   真实回归残差 0.04368445926742428
# 5 170 w相对误差 1.004735645833644   实验回归残差 0.9568313337986104   真实回归残差 0.056918812717094765
# 5 170 w相对误差 1.009633177318898   实验回归残差 0.9701179917547018   真实回归残差 0.055480591737099245
# 5 170 w相对误差 0.986750461709477   实验回归残差 0.9485230118103991   真实回归残差 0.0569417458652478
# 6 170 w相对误差 1.0275353865810326   实验回归残差 0.857005432626165   真实回归残差 0.0332980654085874
# 6 170 w相对误差 1.0076650102562694   实验回归残差 0.9773083206617591   真实回归残差 0.02921107745990879
# 6 170 w相对误差 0.9803284484827061   实验回归残差 0.9792572040665604   真实回归残差 0.05544536118551562
# 6 170 w相对误差 0.9887783080329613   实验回归残差 0.9272869426499576   真实回归残差 0.038297025893587286
# 6 170 w相对误差 0.9723320148027425   实验回归残差 0.9571188839928361   真实回归残差 0.046491873780498585
# 6 170 w相对误差 0.9923213028854061   实验回归残差 0.9619369348104495   真实回归残差 0.0854416190001174
# 6 170 w相对误差 0.9965857048243998   实验回归残差 0.991129286633828   真实回归残差 0.10671941612303652
# 6 170 w相对误差 0.9523163034749198   实验回归残差 0.9547258687710315   真实回归残差 0.0347726435250235
# 6 170 w相对误差 1.0036833139403745   实验回归残差 0.9688955974592753   真实回归残差 0.04158139596657102
# 6 170 w相对误差 0.9895643713858407   实验回归残差 0.962550179994045   真实回归残差 0.050497178462167926
# 1 170 w相对误差 0.9747839528673226   实验回归残差 0.9594295376891999   真实回归残差 0.7959618213588227
# 1 170 w相对误差 1.0050151999116121   实验回归残差 0.9638223621899727   真实回归残差 0.14206477645312696
# 1 170 w相对误差 0.9842576736259231   实验回归残差 0.9925338520584154   真实回归残差 0.1743856017240081
# 1 170 w相对误差 0.9957170814036381   实验回归残差 0.9981177085553825   真实回归残差 0.1380227622152891
# 1 170 w相对误差 0.9909184071208696   实验回归残差 0.9958485780028692   真实回归残差 0.13595866690011957
# 1 170 w相对误差 1.0033560231272736   实验回归残差 0.996646030147989   真实回归残差 0.7683270231323851
# 1 170 w相对误差 0.9992576084473581   实验回归残差 0.9996776797480074   真实回归残差 0.4380710407619103
# 1 170 w相对误差 0.99162687392656   实验回归残差 0.9965713307914604   真实回归残差 0.14868593839653588
# 1 170 w相对误差 0.996128431822672   实验回归残差 0.9974923012243248   真实回归残差 0.12727913415320088
# 1 170 w相对误差 0.9952550479152191   实验回归残差 0.9969997448830238   真实回归残差 0.12922683873095311
# 2 170 w相对误差 0.9815766756591053   实验回归残差 0.9757726251722357   真实回归残差 0.10599081660906078
# 2 170 w相对误差 0.9959929846016817   实验回归残差 0.9922120036923333   真实回归残差 0.046298311006064664
# 2 170 w相对误差 0.991073485427052   实验回归残差 0.9954017275958523   真实回归残差 0.07129388159495163
# 2 170 w相对误差 0.9999514253590795   实验回归残差 0.996135615224333   真实回归残差 0.04603200824255612
# 2 170 w相对误差 0.9899185440929804   实验回归残差 0.9575557735323095   真实回归残差 0.05691929392468533
# 2 170 w相对误差 0.9998661424320991   实验回归残差 0.9984541725148939   真实回归残差 0.07318462404908743
# 2 170 w相对误差 0.9999883751412681   实验回归残差 0.9938852725126023   真实回归残差 0.09179855938302602
# 2 170 w相对误差 0.9680319035617304   实验回归残差 0.9818928965127853   真实回归残差 0.10243406307851896
# 2 170 w相对误差 0.9469487877207526   实验回归残差 0.9720086786030423   真实回归残差 0.1299302941800163
# 2 170 w相对误差 0.9964039709289697   实验回归残差 0.9931888755720375   真实回归残差 0.3663552354258183
# 3 170 w相对误差 0.9905413095218116   实验回归残差 0.9659596434543457   真实回归残差 0.07672103097801662
# 3 170 w相对误差 0.9844222853168119   实验回归残差 0.9915119104305337   真实回归残差 0.040687731239601586
# 3 170 w相对误差 1.0031697474349826   实验回归残差 0.9775061138454741   真实回归残差 0.0758716596717431
# 3 170 w相对误差 0.9917168946941719   实验回归残差 0.9938994123043295   真实回归残差 0.05669557955914821
# 3 170 w相对误差 0.9981071460861297   实验回归残差 0.9786500941613682   真实回归残差 0.0685719158267644
# 3 170 w相对误差 1.0233691230115614   实验回归残差 0.9306304455593136   真实回归残差 0.04364736314410883
# 3 170 w相对误差 0.9731762163272741   实验回归残差 0.9807317390029963   真实回归残差 0.06155348207430053
# 3 170 w相对误差 0.9686961273714823   实验回归残差 0.9715146908648816   真实回归残差 0.05902813376354303
# 3 170 w相对误差 0.9877464231080437   实验回归残差 0.990435609814703   真实回归残差 0.07955275881342598
# 3 170 w相对误差 0.992831504529173   实验回归残差 0.9943393748940126   真实回归残差 0.07161662181683837
# 4 170 w相对误差 1.0490106066937968   实验回归残差 0.8825533397247767   真实回归残差 0.055214001806494155
# 4 170 w相对误差 0.9976420787196322   实验回归残差 0.9718208838462699   真实回归残差 0.061883985753899855
# 4 170 w相对误差 0.9934682455694397   实验回归残差 0.9894434172026352   真实回归残差 0.056458779988347266
# 4 170 w相对误差 0.9825007424593016   实验回归残差 0.9691511410845557   真实回归残差 0.06024417540128829
# 4 170 w相对误差 0.9759765240848237   实验回归残差 0.9809272122084939   真实回归残差 0.07916954626552113
# 4 170 w相对误差 0.9676954020896896   实验回归残差 0.9466471709742923   真实回归残差 0.07617358386750867
# 4 170 w相对误差 0.990149990160289   实验回归残差 0.9833813286707553   真实回归残差 0.07340381064267323
# 4 170 w相对误差 1.0245118139651235   实验回归残差 0.9374253356640017   真实回归残差 0.1106414371137404
# 4 170 w相对误差 0.9595156430846455   实验回归残差 0.9527188164796494   真实回归残差 0.03042324123319533
# 4 170 w相对误差 1.0303403150080312   实验回归残差 0.9626006897350803   真实回归残差 0.04686237705864118
# 5 170 w相对误差 0.978916457603634   实验回归残差 0.9434829633226335   真实回归残差 0.03287224449917169
# 5 170 w相对误差 0.9387849149989874   实验回归残差 0.9224244248795358   真实回归残差 0.043637687331691107
# 5 170 w相对误差 0.9654151936594062   实验回归残差 0.9372958060430856   真实回归残差 0.07027878480992433
# 5 170 w相对误差 0.9968465912255764   实验回归残差 0.9959385648671975   真实回归残差 0.040754177380083266
# 5 170 w相对误差 1.0229400282517587   实验回归残差 0.9383985398420497   真实回归残差 0.04308659156407902
# 5 170 w相对误差 0.958756660198565   实验回归残差 0.9577967414559065   真实回归残差 0.05334829381861183
# 5 170 w相对误差 0.9917073826379774   实验回归残差 0.9935161454741612   真实回归残差 0.07012694778902494
# 5 170 w相对误差 0.9889122695715699   实验回归残差 0.9814305735125526   真实回归残差 0.04426098362686094
# 5 170 w相对误差 0.9611752626295711   实验回归残差 0.9362683156506233   真实回归残差 0.09072671570457551
# 5 170 w相对误差 0.9620274622038806   实验回归残差 0.9306449348932037   真实回归残差 0.05056585438807087
# 6 170 w相对误差 0.9922928177612785   实验回归残差 0.9021527869522874   真实回归残差 0.03435750844681242
# 6 170 w相对误差 1.0155615845602222   实验回归残差 0.9136402049947614   真实回归残差 0.03764020730717826
# 6 170 w相对误差 0.999207246248496   实验回归残差 0.9643218691950316   真实回归残差 0.052410771166088714
# 6 170 w相对误差 0.9576568491303403   实验回归残差 0.8797415144647625   真实回归残差 0.05615624018519065
# 6 170 w相对误差 0.9972696073718366   实验回归残差 0.8965898305194993   真实回归残差 0.06821634642223001
# 6 170 w相对误差 0.9568769694318028   实验回归残差 0.9337560449562285   真实回归残差 0.05035253132612003
# 6 170 w相对误差 0.9901249940874985   实验回归残差 0.9630260089665749   真实回归残差 0.03923094555969268
# 6 170 w相对误差 1.001851400040458   实验回归残差 0.9533394286482527   真实回归残差 0.03498419325068433
# 6 170 w相对误差 1.0679143677304175   实验回归残差 0.6660803804792534   真实回归残差 0.05234228021234518
# 6 170 w相对误差 0.9715524194799938   实验回归残差 0.9183251112948799   真实回归残差 0.051379789471602585
# 1 170 w相对误差 0.9942136258325325   实验回归残差 0.9969633036903238   真实回归残差 0.10159851061333801
# 1 170 w相对误差 0.999660833656266   实验回归残差 0.999879487201157   真实回归残差 0.2010161870085903
# 1 170 w相对误差 0.998774920588615   实验回归残差 0.999595201418271   真实回归残差 0.17029827439289846
# 1 170 w相对误差 0.9857317011886985   实验回归残差 0.9929319545412324   真实回归残差 0.06040102772571892
# 1 170 w相对误差 0.9981440449463684   实验回归残差 0.9991704162714224   真实回归残差 0.11446634866639578
# 1 170 w相对误差 0.9747692695609169   实验回归残差 0.9862006483100091   真实回归残差 0.08094463412836965
# 1 170 w相对误差 0.9896333280567351   实验回归残差 0.9947123379330987   真实回归残差 0.05505555839452151
# 1 170 w相对误差 0.9969999215545867   实验回归残差 0.9986229375912566   真实回归残差 0.15613214973065664
# 1 170 w相对误差 0.9988747743662585   实验回归残差 0.999498941787139   真实回归残差 0.07018928057163824
# 1 170 w相对误差 1.0000037548288117   实验回归残差 0.9999988195071834   真实回归残差 0.11515361412454087
# 2 170 w相对误差 1.009811693464809   实验回归残差 0.9830909070081125   真实回归残差 0.12005396393575758
# 2 170 w相对误差 0.9989555485273628   实验回归残差 0.9978125906245113   真实回归残差 0.0791806640262623
# 2 170 w相对误差 0.995008089152596   实验回归残差 0.9980771826743638   真实回归残差 0.22861447213094765
# 2 170 w相对误差 0.9994607685721236   实验回归残差 0.996001544310403   真实回归残差 0.1267907121568789
# 2 170 w相对误差 0.9975411035438776   实验回归残差 0.9964134406217866   真实回归残差 0.17061052084804126
# 2 170 w相对误差 0.9994907897521034   实验回归残差 0.9990037741145521   真实回归残差 0.17554752058733417
# 2 170 w相对误差 1.018171403549211   实验回归残差 0.9473421756931442   真实回归残差 0.43807951904498266
# 2 170 w相对误差 0.9991017731829838   实验回归残差 0.9942570830674836   真实回归残差 0.12122794766800642
# 2 170 w相对误差 0.9896811973279802   实验回归残差 0.9922726144896977   真实回归残差 0.18024998631429304
# 2 170 w相对误差 0.9969260972907255   实验回归残差 0.9965457380052585   真实回归残差 0.04119496725458511
# 3 170 w相对误差 0.9700509603317159   实验回归残差 0.9466319002241176   真实回归残差 0.04144587695172491
# 3 170 w相对误差 0.9972870581613433   实验回归残差 0.9942364064805262   真实回归残差 0.10141880635580175
# 3 170 w相对误差 1.003607928654803   实验回归残差 0.9641422214920182   真实回归残差 0.1110055527971014
# 3 170 w相对误差 1.014895510276255   实验回归残差 0.9699066045809027   真实回归残差 0.11582674894388817
# 3 170 w相对误差 0.9892667716315494   实验回归残差 0.9921851317101845   真实回归残差 0.04563601098419875
# 3 170 w相对误差 0.9737995244410063   实验回归残差 0.985425727670507   真实回归残差 0.048743561982132866
# 3 170 w相对误差 0.9869172813496918   实验回归残差 0.992267059779659   真实回归残差 0.08050506934728661
# 3 170 w相对误差 0.9938439948384242   实验回归残差 0.9895279511747006   真实回归残差 0.05444977279661883
# 3 170 w相对误差 1.0172043965306141   实验回归残差 0.9527164459787449   真实回归残差 0.08696851650828476
# 3 170 w相对误差 1.019908475050341   实验回归残差 0.945753755119627   真实回归残差 0.04729937588096856
# 4 170 w相对误差 1.0162647005196164   实验回归残差 0.9682535851455385   真实回归残差 0.06804104275662548
# 4 170 w相对误差 0.9850105724389593   实验回归残差 0.9835343044380355   真实回归残差 0.0493764784120487
# 4 170 w相对误差 1.0006323728934852   实验回归残差 0.971194576547536   真实回归残差 0.14254469394526684
# 4 170 w相对误差 0.996860169438006   实验回归残差 0.9867703760098061   真实回归残差 0.08019632176646106
# 4 170 w相对误差 0.9824921899041107   实验回归残差 0.9768502371830138   真实回归残差 0.09661866491222447
# 4 170 w相对误差 0.9969959625740565   实验回归残差 0.9914299143279991   真实回归残差 0.08225493975651631
# 4 170 w相对误差 0.9959888193015515   实验回归残差 0.9468668892488527   真实回归残差 0.10085596616198009
# 4 170 w相对误差 0.9946452220999031   实验回归残差 0.9142976342153326   真实回归残差 0.0566230466854821
# 4 170 w相对误差 1.0201222415423223   实验回归残差 0.9725490001110758   真实回归残差 0.039752974015046336
# 4 170 w相对误差 0.9991886755680984   实验回归残差 0.9702679097801077   真实回归残差 0.041757102990791654
# 5 170 w相对误差 0.9591451830492951   实验回归残差 0.9435407337302161   真实回归残差 0.046576446112583506
# 5 170 w相对误差 0.9870145654912856   实验回归残差 0.9817917397142799   真实回归残差 0.055372291681127866
# 5 170 w相对误差 0.9658391226502779   实验回归残差 0.9145613709610764   真实回归残差 0.03651943855355864
# 5 170 w相对误差 0.993473247714449   实验回归残差 0.9944197952083508   真实回归残差 0.07775519031862063
# 5 170 w相对误差 1.0121640623608164   实验回归残差 0.917859627696735   真实回归残差 0.06223329048381969
# 5 170 w相对误差 1.019802888422184   实验回归残差 0.9345751118692464   真实回归残差 0.048041668598394496
# 5 170 w相对误差 0.9732633665357038   实验回归残差 0.9167501097220809   真实回归残差 0.04156759915899514
# 5 170 w相对误差 0.9855172902263983   实验回归残差 0.9613369901346247   真实回归残差 0.04576484438844262
# 5 170 w相对误差 0.9525505872757608   实验回归残差 0.9576200507762607   真实回归残差 0.05053504228925167
# 5 170 w相对误差 0.9916385345942506   实验回归残差 0.9665642589407026   真实回归残差 0.08298025205655478
# 6 170 w相对误差 1.0687317065917403   实验回归残差 0.8721250219652024   真实回归残差 0.03925465560646559
# 6 170 w相对误差 0.9923877420781098   实验回归残差 0.9897177620987657   真实回归残差 0.03385301314436289
# 6 170 w相对误差 0.9549449050077098   实验回归残差 0.9521390024473905   真实回归残差 0.040404058271190826
# 6 170 w相对误差 0.9810463046109499   实验回归残差 0.9555534143347076   真实回归残差 0.04306781685612552
# 6 170 w相对误差 0.9638733122245812   实验回归残差 0.9229246017509142   真实回归残差 0.019063189128385536
# 6 170 w相对误差 0.9978818914272325   实验回归残差 0.9517157848584987   真实回归残差 0.08508736841637812
# 6 170 w相对误差 1.0063911919255288   实验回归残差 0.9573326497558465   真实回归残差 0.05114509966533236
# 6 170 w相对误差 1.0025836026588095   实验回归残差 0.9671154036340803   真实回归残差 0.03436183488747487
# 6 170 w相对误差 0.9707419833911805   实验回归残差 0.848008454126438   真实回归残差 0.07361431578576302
# 6 170 w相对误差 0.9766464423475985   实验回归残差 0.9567122065441631   真实回归残差 0.05172003031466576
