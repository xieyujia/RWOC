# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(3):
    for num_example in range(140,141,100): 
        for num_X2feature in [4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ########################### 4 140 w绝对误差 tensor(0.1082, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1690, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1644, dtype=torch.float64)   实验回归残差 tensor(0.0701, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1588, dtype=torch.float64)   测试集实验回归残差 tensor(0.0672, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3673, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2417344641341275
# ################################################ 4 140 w绝对误差 tensor(1.0286, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7847, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0722, dtype=torch.float64)   实验回归残差 tensor(0.1161, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0838, dtype=torch.float64)   测试集实验回归残差 tensor(0.1815, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.155365737694759
# ##################### 4 140 w绝对误差 tensor(4.0408, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4574, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0325, dtype=torch.float64)   实验回归残差 tensor(0.1290, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0335, dtype=torch.float64)   测试集实验回归残差 tensor(0.1164, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2820345155005082
# ############################ 4 140 w绝对误差 tensor(4.5100, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9200, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0427, dtype=torch.float64)   实验回归残差 tensor(0.1336, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0455, dtype=torch.float64)   测试集实验回归残差 tensor(0.2949, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.288413590399645
# ########################## 4 140 w绝对误差 tensor(2.0225, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4701, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0692, dtype=torch.float64)   实验回归残差 tensor(0.1574, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0708, dtype=torch.float64)   测试集实验回归残差 tensor(0.1671, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2409872929680454
# ############################################# 4 140 w绝对误差 tensor(2.2608, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0957, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0494, dtype=torch.float64)   实验回归残差 tensor(0.1184, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0493, dtype=torch.float64)   测试集实验回归残差 tensor(0.1450, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2707857015302924
# ############################# 4 140 w绝对误差 tensor(0.8487, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4885, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0606, dtype=torch.float64)   实验回归残差 tensor(0.0894, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0610, dtype=torch.float64)   测试集实验回归残差 tensor(0.1237, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.209358271401667
# ########################################## 4 140 w绝对误差 tensor(1.1052, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6825, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0653, dtype=torch.float64)   实验回归残差 tensor(0.0956, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0558, dtype=torch.float64)   测试集实验回归残差 tensor(0.1380, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.331530711791841
# ############################# 4 140 w绝对误差 tensor(3.2138, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8111, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0550, dtype=torch.float64)   实验回归残差 tensor(0.1264, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0557, dtype=torch.float64)   测试集实验回归残差 tensor(0.3634, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2016960405198953
# #################################### 4 140 w绝对误差 tensor(1.7091, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0405, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0703, dtype=torch.float64)   实验回归残差 tensor(0.1002, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0600, dtype=torch.float64)   测试集实验回归残差 tensor(0.1991, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3596564861506366
# ##################################################### 5 140 w绝对误差 tensor(2.4281, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9366, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0363, dtype=torch.float64)   实验回归残差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0410, dtype=torch.float64)   测试集实验回归残差 tensor(0.1730, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3277570377216503
# ####################################################### 5 140 w绝对误差 tensor(0.0466, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0422, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0760, dtype=torch.float64)   实验回归残差 tensor(0.0400, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0968, dtype=torch.float64)   测试集实验回归残差 tensor(0.0430, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2984, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2762, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2946705154643605
# ############################ 5 140 w绝对误差 tensor(3.0222, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2422, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0401, dtype=torch.float64)   实验回归残差 tensor(0.0863, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0393, dtype=torch.float64)   测试集实验回归残差 tensor(0.1493, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.238635095476629
# ##########################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(0.0329, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0264, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0727, dtype=torch.float64)   实验回归残差 tensor(0.0348, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0759, dtype=torch.float64)   测试集实验回归残差 tensor(0.0362, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3020466051310988
# ######################## 5 140 w绝对误差 tensor(2.7349, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0667, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0380, dtype=torch.float64)   实验回归残差 tensor(0.1369, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0374, dtype=torch.float64)   测试集实验回归残差 tensor(0.1758, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2293258699352592
# ############################################ 5 140 w绝对误差 tensor(5.0269, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6090, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0321, dtype=torch.float64)   实验回归残差 tensor(0.0863, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0324, dtype=torch.float64)   测试集实验回归残差 tensor(0.4455, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3860117226508686
# ######################################## 5 140 w绝对误差 tensor(4.6454, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7677, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0317, dtype=torch.float64)   实验回归残差 tensor(0.1225, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0356, dtype=torch.float64)   测试集实验回归残差 tensor(0.1336, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4107639906543508
# ################################################# 5 140 w绝对误差 tensor(3.5393, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3068, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0362, dtype=torch.float64)   实验回归残差 tensor(0.1195, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0416, dtype=torch.float64)   测试集实验回归残差 tensor(0.2510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.462332636920992
# ################################################################## 5 140 w绝对误差 tensor(3.7344, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7949, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0540, dtype=torch.float64)   实验回归残差 tensor(0.1026, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0445, dtype=torch.float64)   测试集实验回归残差 tensor(0.3164, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2047377606447354
# #################################################################################################### 5 140 w绝对误差 tensor(4.2659, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5544, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0387, dtype=torch.float64)   实验回归残差 tensor(0.1216, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0321, dtype=torch.float64)   测试集实验回归残差 tensor(0.3019, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.286891005597798
# ########################################################################################################################################################################################################超过迭代上限
#  6 140 w绝对误差 tensor(2.9224, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9916, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0311, dtype=torch.float64)   实验回归残差 tensor(0.0790, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0346, dtype=torch.float64)   测试集实验回归残差 tensor(0.1525, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.5251874934794811
# ############################################################ 6 140 w绝对误差 tensor(3.2721, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9508, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0294, dtype=torch.float64)   实验回归残差 tensor(0.0839, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0253, dtype=torch.float64)   测试集实验回归残差 tensor(0.1486, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.438864085420884
# ############################################ 6 140 w绝对误差 tensor(4.9808, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5246, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0329, dtype=torch.float64)   实验回归残差 tensor(0.0909, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0279, dtype=torch.float64)   测试集实验回归残差 tensor(0.2212, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3639396708849014
# ################################# 6 140 w绝对误差 tensor(3.8225, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0965, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0294, dtype=torch.float64)   实验回归残差 tensor(0.1255, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0318, dtype=torch.float64)   测试集实验回归残差 tensor(0.1730, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.455684642219938
# ############################################################## 6 140 w绝对误差 tensor(3.4406, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4014, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0409, dtype=torch.float64)   实验回归残差 tensor(0.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0403, dtype=torch.float64)   测试集实验回归残差 tensor(0.1518, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3206782774286239
# ############################################################################ 6 140 w绝对误差 tensor(2.6350, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1461, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0511, dtype=torch.float64)   实验回归残差 tensor(0.1517, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0443, dtype=torch.float64)   测试集实验回归残差 tensor(0.1594, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.398478794857697
# ############################### 6 140 w绝对误差 tensor(4.7138, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3973, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0271, dtype=torch.float64)   实验回归残差 tensor(0.1770, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0306, dtype=torch.float64)   测试集实验回归残差 tensor(0.1405, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4031, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.3940244814961884
# ########################################################################################################################################################################################################超过迭代上限
#  6 140 w绝对误差 tensor(1.8453, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5900, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0723, dtype=torch.float64)   实验回归残差 tensor(0.1736, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0758, dtype=torch.float64)   测试集实验回归残差 tensor(0.2039, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4471149097454639
# ############################################# 6 140 w绝对误差 tensor(2.2593, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9763, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0441, dtype=torch.float64)   实验回归残差 tensor(0.0801, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0457, dtype=torch.float64)   测试集实验回归残差 tensor(0.1902, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4123612056274626
# ########################################################################################################################################################################################################超过迭代上限
#  6 140 w绝对误差 tensor(3.8727, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3500, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0366, dtype=torch.float64)   实验回归残差 tensor(0.0711, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0338, dtype=torch.float64)   测试集实验回归残差 tensor(0.2560, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3082497351274527
# ################################################################################# 4 140 w绝对误差 tensor(2.0027, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8891, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0815, dtype=torch.float64)   实验回归残差 tensor(0.0988, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0899, dtype=torch.float64)   测试集实验回归残差 tensor(0.2497, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4118, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2878947958764975
# #################################### 4 140 w绝对误差 tensor(2.7107, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6174, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0524, dtype=torch.float64)   实验回归残差 tensor(0.0922, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0586, dtype=torch.float64)   测试集实验回归残差 tensor(0.2136, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2826796229953472
# #################################################################################### 4 140 w绝对误差 tensor(1.8542, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1727, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0536, dtype=torch.float64)   实验回归残差 tensor(0.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0713, dtype=torch.float64)   测试集实验回归残差 tensor(0.4559, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4039, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4091, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3813896801408727
# ############################################################ 4 140 w绝对误差 tensor(0.5078, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5675, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1279, dtype=torch.float64)   实验回归残差 tensor(0.0780, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1131, dtype=torch.float64)   测试集实验回归残差 tensor(0.1468, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2600212512695819
# ################################################################# 4 140 w绝对误差 tensor(3.5464, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9655, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0524, dtype=torch.float64)   实验回归残差 tensor(0.1399, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0626, dtype=torch.float64)   测试集实验回归残差 tensor(0.2435, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.258752181155497
# ######################## 4 140 w绝对误差 tensor(2.3791, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1689, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0447, dtype=torch.float64)   实验回归残差 tensor(0.1070, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0513, dtype=torch.float64)   测试集实验回归残差 tensor(0.2947, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2772843887174705
# ################################ 4 140 w绝对误差 tensor(1.3978, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9116, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0631, dtype=torch.float64)   实验回归残差 tensor(0.1096, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0662, dtype=torch.float64)   测试集实验回归残差 tensor(0.1949, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2410458921450815
# ############################ 4 140 w绝对误差 tensor(1.4626, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8686, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0674, dtype=torch.float64)   实验回归残差 tensor(0.0857, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0580, dtype=torch.float64)   测试集实验回归残差 tensor(0.1969, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2129657592128322
# ######################################################## 4 140 w绝对误差 tensor(0.0282, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0098, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0376, dtype=torch.float64)   实验回归残差 tensor(0.0218, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0336, dtype=torch.float64)   测试集实验回归残差 tensor(0.0250, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.1019, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3243138130360308
# ############################# 5 140 w绝对误差 tensor(2.7611, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8958, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0363, dtype=torch.float64)   实验回归残差 tensor(0.1107, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0349, dtype=torch.float64)   测试集实验回归残差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2577306375628527
# ########################################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(1.9193, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2456, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0686, dtype=torch.float64)   实验回归残差 tensor(0.2892, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0617, dtype=torch.float64)   测试集实验回归残差 tensor(0.3522, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.367581078679891
# ###################################################################### 5 140 w绝对误差 tensor(2.4583, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2967, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0527, dtype=torch.float64)   实验回归残差 tensor(0.0858, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0554, dtype=torch.float64)   测试集实验回归残差 tensor(0.2321, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4527774692159865
# ##################### 5 140 w绝对误差 tensor(2.7218, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0668, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0370, dtype=torch.float64)   实验回归残差 tensor(0.1632, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0363, dtype=torch.float64)   测试集实验回归残差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2669420205281536
# ######################################################################## 5 140 w绝对误差 tensor(2.5849, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2958, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0529, dtype=torch.float64)   实验回归残差 tensor(0.1274, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0571, dtype=torch.float64)   测试集实验回归残差 tensor(0.2229, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2502618588240144
# ########################################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(1.4650, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1731, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0867, dtype=torch.float64)   实验回归残差 tensor(0.1026, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0799, dtype=torch.float64)   测试集实验回归残差 tensor(0.0998, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3575516093237288
# ############################################### 5 140 w绝对误差 tensor(2.2979, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4554, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0661, dtype=torch.float64)   实验回归残差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0577, dtype=torch.float64)   测试集实验回归残差 tensor(0.2464, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.43632385892268
# ###################### 5 140 w绝对误差 tensor(0.4308, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3873, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1006, dtype=torch.float64)   实验回归残差 tensor(0.0866, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1103, dtype=torch.float64)   测试集实验回归残差 tensor(0.0723, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3710365461416911
# ################################################## 5 140 w绝对误差 tensor(4.6520, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0330, dtype=torch.float64)   实验回归残差 tensor(0.0995, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0289, dtype=torch.float64)   测试集实验回归残差 tensor(0.1527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2642808331399447
# ########################################## 5 140 w绝对误差 tensor(2.5709, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4526, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0511, dtype=torch.float64)   实验回归残差 tensor(0.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0618, dtype=torch.float64)   测试集实验回归残差 tensor(0.1741, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3173691059416803
# ######################################### 6 140 w绝对误差 tensor(2.1210, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3858, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0664, dtype=torch.float64)   实验回归残差 tensor(0.1306, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0643, dtype=torch.float64)   测试集实验回归残差 tensor(0.2217, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4067, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3480888139056626
# ################################## 6 140 w绝对误差 tensor(4.0369, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9258, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0425, dtype=torch.float64)   实验回归残差 tensor(0.0898, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0500, dtype=torch.float64)   测试集实验回归残差 tensor(0.3128, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3597882596022013
# ################################################# 6 140 w绝对误差 tensor(2.5907, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4099, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0526, dtype=torch.float64)   实验回归残差 tensor(0.1615, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0552, dtype=torch.float64)   测试集实验回归残差 tensor(0.2218, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3467998037351285
# ########################################################################################################################################### 6 140 w绝对误差 tensor(2.5092, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5377, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0708, dtype=torch.float64)   实验回归残差 tensor(0.0772, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0728, dtype=torch.float64)   测试集实验回归残差 tensor(0.3385, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4215228037374728
# ######################################################### 6 140 w绝对误差 tensor(2.4209, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7508, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0318, dtype=torch.float64)   实验回归残差 tensor(0.0825, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0293, dtype=torch.float64)   测试集实验回归残差 tensor(0.1750, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3612322671247958
# ################### 6 140 w绝对误差 tensor(2.2156, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7915, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0405, dtype=torch.float64)   实验回归残差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0382, dtype=torch.float64)   测试集实验回归残差 tensor(0.1763, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4291141175029285
# ######################### 6 140 w绝对误差 tensor(2.7612, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8855, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0395, dtype=torch.float64)   实验回归残差 tensor(0.1644, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0281, dtype=torch.float64)   测试集实验回归残差 tensor(0.1490, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.414047839044159
# ###################### 6 140 w绝对误差 tensor(1.7166, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5425, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0334, dtype=torch.float64)   实验回归残差 tensor(0.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0269, dtype=torch.float64)   测试集实验回归残差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.35556458372563
# ############################################################################### 6 140 w绝对误差 tensor(4.7811, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7065, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0375, dtype=torch.float64)   实验回归残差 tensor(0.0709, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0380, dtype=torch.float64)   测试集实验回归残差 tensor(0.2170, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4235281785965301
# ################################################################################################################################### 6 140 w绝对误差 tensor(2.8676, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9584, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0331, dtype=torch.float64)   实验回归残差 tensor(0.0891, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0333, dtype=torch.float64)   测试集实验回归残差 tensor(0.1356, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.306224706093428
# ################################# 4 140 w绝对误差 tensor(2.7636, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3274, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0516, dtype=torch.float64)   实验回归残差 tensor(0.1105, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0558, dtype=torch.float64)   测试集实验回归残差 tensor(0.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2167834388037675
# #################### 4 140 w绝对误差 tensor(0.8060, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6450, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0728, dtype=torch.float64)   实验回归残差 tensor(0.1703, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0708, dtype=torch.float64)   测试集实验回归残差 tensor(0.1866, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1290917626239894
# ############################### 4 140 w绝对误差 tensor(1.7632, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9306, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0491, dtype=torch.float64)   实验回归残差 tensor(0.1195, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0496, dtype=torch.float64)   测试集实验回归残差 tensor(0.1462, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2059596274139637
# ################################### 4 140 w绝对误差 tensor(2.9281, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8077, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0288, dtype=torch.float64)   实验回归残差 tensor(0.0834, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0307, dtype=torch.float64)   测试集实验回归残差 tensor(0.1805, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2151029802019506
# ####################### 4 140 w绝对误差 tensor(4.0906, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5701, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0325, dtype=torch.float64)   实验回归残差 tensor(0.0883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0348, dtype=torch.float64)   测试集实验回归残差 tensor(0.2691, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2185635186150467
# #################################### 4 140 w绝对误差 tensor(1.3905, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6523, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0496, dtype=torch.float64)   实验回归残差 tensor(0.0803, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0450, dtype=torch.float64)   测试集实验回归残差 tensor(0.0827, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1935184234389147
# ########################################### 4 140 w绝对误差 tensor(1.5703, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4464, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1018, dtype=torch.float64)   实验回归残差 tensor(0.0899, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0969, dtype=torch.float64)   测试集实验回归残差 tensor(0.2993, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2312640799040777
# ######################### 4 140 w绝对误差 tensor(1.0291, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8988, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0867, dtype=torch.float64)   实验回归残差 tensor(0.1080, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0966, dtype=torch.float64)   测试集实验回归残差 tensor(0.1915, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3970, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.229540729409746
# ############################## 4 140 w绝对误差 tensor(1.2244, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0393, dtype=torch.float64)   实验回归残差 tensor(0.0644, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0349, dtype=torch.float64)   测试集实验回归残差 tensor(0.1237, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2210772194744781
# #################################### 4 140 w绝对误差 tensor(0.3184, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1573, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0510, dtype=torch.float64)   实验回归残差 tensor(0.0593, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0495, dtype=torch.float64)   测试集实验回归残差 tensor(0.0630, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3575, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3310, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1573849968943546
# ########################################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(3.1842, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0982, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0372, dtype=torch.float64)   实验回归残差 tensor(0.1422, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0315, dtype=torch.float64)   测试集实验回归残差 tensor(0.1849, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4015, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2829312871595044
# ###################################### 5 140 w绝对误差 tensor(4.9599, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9571, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0425, dtype=torch.float64)   实验回归残差 tensor(0.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0383, dtype=torch.float64)   测试集实验回归残差 tensor(0.3056, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.549787031319044
# #################################################################### 5 140 w绝对误差 tensor(2.2574, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0543, dtype=torch.float64)   实验回归残差 tensor(0.0943, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0485, dtype=torch.float64)   测试集实验回归残差 tensor(0.1808, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.309398914077029
# ####################################################################### 5 140 w绝对误差 tensor(0.5632, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9751, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1601, dtype=torch.float64)   实验回归残差 tensor(0.0948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1686, dtype=torch.float64)   测试集实验回归残差 tensor(0.1625, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.288046883304928
# ################################## 5 140 w绝对误差 tensor(1.2514, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7203, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0542, dtype=torch.float64)   实验回归残差 tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0564, dtype=torch.float64)   测试集实验回归残差 tensor(0.1364, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3579213755790924
# ############################################## 5 140 w绝对误差 tensor(1.6466, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3012, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0873, dtype=torch.float64)   实验回归残差 tensor(0.0878, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0811, dtype=torch.float64)   测试集实验回归残差 tensor(0.1816, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3968216045310813
# #################################################### 5 140 w绝对误差 tensor(0.2882, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1804, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0625, dtype=torch.float64)   实验回归残差 tensor(0.0501, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0647, dtype=torch.float64)   测试集实验回归残差 tensor(0.0690, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2984, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3470, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3459055739661527
# ############################################################################################### 5 140 w绝对误差 tensor(3.4736, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9828, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0290, dtype=torch.float64)   实验回归残差 tensor(0.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0267, dtype=torch.float64)   测试集实验回归残差 tensor(0.2589, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3226866485634736
# ##################################################### 5 140 w绝对误差 tensor(1.9434, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9243, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0523, dtype=torch.float64)   实验回归残差 tensor(0.1073, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0453, dtype=torch.float64)   测试集实验回归残差 tensor(0.2431, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4434524820404722
# ############################################################## 5 140 w绝对误差 tensor(2.4974, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8420, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0338, dtype=torch.float64)   实验回归残差 tensor(0.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0317, dtype=torch.float64)   测试集实验回归残差 tensor(0.1586, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3446824358014242
# ######################################################################### 6 140 w绝对误差 tensor(2.3807, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3012, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0589, dtype=torch.float64)   实验回归残差 tensor(0.0596, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0534, dtype=torch.float64)   测试集实验回归残差 tensor(0.1767, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4192709007055468
# ################################################################################ 6 140 w绝对误差 tensor(2.2980, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0031, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0396, dtype=torch.float64)   实验回归残差 tensor(0.0550, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0461, dtype=torch.float64)   测试集实验回归残差 tensor(0.1933, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3526795381417192
# ####################################################### 6 140 w绝对误差 tensor(1.9406, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9698, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0520, dtype=torch.float64)   实验回归残差 tensor(0.0978, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0507, dtype=torch.float64)   测试集实验回归残差 tensor(0.1612, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2620958831333624
# ######################### 6 140 w绝对误差 tensor(1.9354, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0982, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0583, dtype=torch.float64)   实验回归残差 tensor(0.0795, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0504, dtype=torch.float64)   测试集实验回归残差 tensor(0.1566, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3761611789357986
# ############################## 6 140 w绝对误差 tensor(2.3254, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3100, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0510, dtype=torch.float64)   实验回归残差 tensor(0.1602, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0542, dtype=torch.float64)   测试集实验回归残差 tensor(0.1715, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3445059591836073
# ######################################################################## 6 140 w绝对误差 tensor(3.9057, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3699, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0298, dtype=torch.float64)   实验回归残差 tensor(0.0900, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0370, dtype=torch.float64)   测试集实验回归残差 tensor(0.3397, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4197738184367816
# ################################################ 6 140 w绝对误差 tensor(2.9267, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0188, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0343, dtype=torch.float64)   实验回归残差 tensor(0.0714, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0331, dtype=torch.float64)   测试集实验回归残差 tensor(0.1205, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3262839254666183
# ################### 6 140 w绝对误差 tensor(1.5575, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9758, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0622, dtype=torch.float64)   实验回归残差 tensor(0.0947, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0595, dtype=torch.float64)   测试集实验回归残差 tensor(0.1211, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3787072829352405
# ############################################################################################################################################################################# 6 140 w绝对误差 tensor(4.3755, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4963, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0342, dtype=torch.float64)   实验回归残差 tensor(0.1159, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0314, dtype=torch.float64)   测试集实验回归残差 tensor(0.2299, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4937847705593454
# ########################################################################################################################################################################################################超过迭代上限
#  6 140 w绝对误差 tensor(2.7576, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4246, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0472, dtype=torch.float64)   实验回归残差 tensor(0.1125, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0503, dtype=torch.float64)   测试集实验回归残差 tensor(0.1707, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4889030800957765
