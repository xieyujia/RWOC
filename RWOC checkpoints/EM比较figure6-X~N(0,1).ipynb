# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [20,2,5,10]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1)=generatedata(noise=0.3)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-8:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    results_error.append(error_each)
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')

                #print('真实置换矩阵为：',true_P)
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print(num_X2feature,num_example,'置换矩阵误差：',error_P,end='   ')
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ###################################################################################### 20 100 平均相对误差2： tensor(4.3334, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0662, dtype=torch.float64)   实验回归误差 tensor(0.0882, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################### 20 100 平均相对误差2： tensor(6.4087, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0577, dtype=torch.float64)   实验回归误差 tensor(0.0748, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################# 20 100 平均相对误差2： tensor(4.8408, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0785, dtype=torch.float64)   实验回归误差 tensor(0.0640, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################ 20 100 平均相对误差2： tensor(5.1360, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0682, dtype=torch.float64)   实验回归误差 tensor(0.0623, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################################# 20 100 平均相对误差2： tensor(5.8449, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0710, dtype=torch.float64)   实验回归误差 tensor(0.0865, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################################### 20 100 平均相对误差2： tensor(7.3916, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0631, dtype=torch.float64)   实验回归误差 tensor(0.0479, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################################### 20 100 平均相对误差2： tensor(4.6851, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0974, dtype=torch.float64)   实验回归误差 tensor(0.1177, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################### 20 100 平均相对误差2： tensor(4.7233, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0709, dtype=torch.float64)   实验回归误差 tensor(0.0740, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################################## 20 100 平均相对误差2： tensor(6.7434, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0492, dtype=torch.float64)   实验回归误差 tensor(0.0514, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################################### 20 100 平均相对误差2： tensor(6.2365, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0838, dtype=torch.float64)   实验回归误差 tensor(0.0689, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################ 2 100 平均相对误差2： tensor(0.5775, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4861, dtype=torch.float64)   实验回归误差 tensor(0.1163, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################### 2 100 平均相对误差2： tensor(1.0375, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3163, dtype=torch.float64)   实验回归误差 tensor(0.1619, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################ 2 100 平均相对误差2： tensor(1.3671, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2413, dtype=torch.float64)   实验回归误差 tensor(0.1422, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################ 2 100 平均相对误差2： tensor(0.6275, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4212, dtype=torch.float64)   实验回归误差 tensor(0.1370, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############# 2 100 平均相对误差2： tensor(0.7236, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2476, dtype=torch.float64)   实验回归误差 tensor(0.1026, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################# 2 100 平均相对误差2： tensor(1.3448, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1408, dtype=torch.float64)   实验回归误差 tensor(0.1228, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################# 2 100 平均相对误差2： tensor(2.2026, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2566, dtype=torch.float64)   实验回归误差 tensor(0.1107, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################## 2 100 平均相对误差2： tensor(0.0197, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1665, dtype=torch.float64)   实验回归误差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################### 2 100 平均相对误差2： tensor(0.0967, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1860, dtype=torch.float64)   实验回归误差 tensor(0.0840, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################## 2 100 平均相对误差2： tensor(0.0899, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1972, dtype=torch.float64)   实验回归误差 tensor(0.0555, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################## 5 100 平均相对误差2： tensor(1.8237, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1677, dtype=torch.float64)   实验回归误差 tensor(0.1034, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################## 5 100 平均相对误差2： tensor(3.0988, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1441, dtype=torch.float64)   实验回归误差 tensor(0.1144, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################### 5 100 平均相对误差2： tensor(5.1195, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0799, dtype=torch.float64)   实验回归误差 tensor(0.1244, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################ 5 100 平均相对误差2： tensor(4.4118, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0935, dtype=torch.float64)   实验回归误差 tensor(0.1507, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################### 5 100 平均相对误差2： tensor(1.0033, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2108, dtype=torch.float64)   实验回归误差 tensor(0.0778, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################### 5 100 平均相对误差2： tensor(0.4140, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1868, dtype=torch.float64)   实验回归误差 tensor(0.0876, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################### 5 100 平均相对误差2： tensor(2.1668, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1937, dtype=torch.float64)   实验回归误差 tensor(0.1063, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################ 5 100 平均相对误差2： tensor(3.2153, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0769, dtype=torch.float64)   实验回归误差 tensor(0.1417, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################## 5 100 平均相对误差2： tensor(1.7375, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1209, dtype=torch.float64)   实验回归误差 tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################## 5 100 平均相对误差2： tensor(1.6163, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1719, dtype=torch.float64)   实验回归误差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################# 10 100 平均相对误差2： tensor(0.8039, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1181, dtype=torch.float64)   实验回归误差 tensor(0.0525, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################# 10 100 平均相对误差2： tensor(3.9802, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1023, dtype=torch.float64)   实验回归误差 tensor(0.1058, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################### 10 100 平均相对误差2： tensor(3.7712, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1031, dtype=torch.float64)   实验回归误差 tensor(0.0889, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################# 10 100 平均相对误差2： tensor(6.1897, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0772, dtype=torch.float64)   实验回归误差 tensor(0.0641, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################### 10 100 平均相对误差2： tensor(2.3253, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1245, dtype=torch.float64)   实验回归误差 tensor(0.0893, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################################### 10 100 平均相对误差2： tensor(5.0810, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0941, dtype=torch.float64)   实验回归误差 tensor(0.0704, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################## 10 100 平均相对误差2： tensor(2.9073, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1074, dtype=torch.float64)   实验回归误差 tensor(0.1137, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################## 10 100 平均相对误差2： tensor(3.1988, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0877, dtype=torch.float64)   实验回归误差 tensor(0.1152, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################# 10 100 平均相对误差2： tensor(1.6883, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1139, dtype=torch.float64)   实验回归误差 tensor(0.1118, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################## 10 100 平均相对误差2： tensor(2.0883, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0926, dtype=torch.float64)   实验回归误差 tensor(0.0813, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################## 20 100 平均相对误差2： tensor(5.9949, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0639, dtype=torch.float64)   实验回归误差 tensor(0.0658, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################# 20 100 平均相对误差2： tensor(6.5683, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0499, dtype=torch.float64)   实验回归误差 tensor(0.0553, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################### 20 100 平均相对误差2： tensor(5.0259, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0601, dtype=torch.float64)   实验回归误差 tensor(0.0772, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################### 20 100 平均相对误差2： tensor(7.3820, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0534, dtype=torch.float64)   实验回归误差 tensor(0.0720, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################## 20 100 平均相对误差2： tensor(7.5065, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0557, dtype=torch.float64)   实验回归误差 tensor(0.0437, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################# 20 100 平均相对误差2： tensor(3.5400, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0772, dtype=torch.float64)   实验回归误差 tensor(0.0629, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################################### 20 100 平均相对误差2： tensor(4.9352, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0665, dtype=torch.float64)   实验回归误差 tensor(0.0436, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################### 20 100 平均相对误差2： tensor(5.7265, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0741, dtype=torch.float64)   实验回归误差 tensor(0.0687, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################ 20 100 平均相对误差2： tensor(6.6732, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0601, dtype=torch.float64)   实验回归误差 tensor(0.0508, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################################################################### 20 100 平均相对误差2： tensor(4.8577, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0843, dtype=torch.float64)   实验回归误差 tensor(0.0725, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################### 2 100 平均相对误差2： tensor(0.0618, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1923, dtype=torch.float64)   实验回归误差 tensor(0.0867, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################### 2 100 平均相对误差2： tensor(0.6866, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1849, dtype=torch.float64)   实验回归误差 tensor(0.1123, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################### 2 100 平均相对误差2： tensor(0.3163, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4906, dtype=torch.float64)   实验回归误差 tensor(0.1484, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################### 2 100 平均相对误差2： tensor(2.0761, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2673, dtype=torch.float64)   实验回归误差 tensor(0.1999, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################### 2 100 平均相对误差2： tensor(1.9219, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1826, dtype=torch.float64)   实验回归误差 tensor(0.1553, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################################### 2 100 平均相对误差2： tensor(0.6598, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4526, dtype=torch.float64)   实验回归误差 tensor(0.1231, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################### 2 100 平均相对误差2： tensor(0.2589, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3935, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6556, dtype=torch.float64)   实验回归误差 tensor(0.1762, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################ 2 100 平均相对误差2： tensor(2.1885, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2314, dtype=torch.float64)   实验回归误差 tensor(0.2068, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################### 5 100 平均相对误差2： tensor(3.0911, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1547, dtype=torch.float64)   实验回归误差 tensor(0.1861, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################### 5 100 平均相对误差2： tensor(1.5036, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2435, dtype=torch.float64)   实验回归误差 tensor(0.1166, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################## 5 100 平均相对误差2： tensor(2.3649, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1583, dtype=torch.float64)   实验回归误差 tensor(0.1246, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################# 5 100 平均相对误差2： tensor(3.6728, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1016, dtype=torch.float64)   实验回归误差 tensor(0.0709, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################### 5 100 平均相对误差2： tensor(2.6117, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1547, dtype=torch.float64)   实验回归误差 tensor(0.1324, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################ 5 100 平均相对误差2： tensor(1.0942, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1858, dtype=torch.float64)   实验回归误差 tensor(0.1043, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################## 5 100 平均相对误差2： tensor(3.2373, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0987, dtype=torch.float64)   实验回归误差 tensor(0.1305, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################## 5 100 平均相对误差2： tensor(2.8240, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1129, dtype=torch.float64)   实验回归误差 tensor(0.1528, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################## 5 100 平均相对误差2： tensor(2.8989, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1276, dtype=torch.float64)   实验回归误差 tensor(0.1494, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################### 5 100 平均相对误差2： tensor(4.7141, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0685, dtype=torch.float64)   实验回归误差 tensor(0.1450, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################### 10 100 平均相对误差2： tensor(4.4578, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1305, dtype=torch.float64)   实验回归误差 tensor(0.1011, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################## 10 100 平均相对误差2： tensor(3.5986, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0975, dtype=torch.float64)   实验回归误差 tensor(0.0521, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################################################### 10 100 平均相对误差2： tensor(2.8242, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1001, dtype=torch.float64)   实验回归误差 tensor(0.1260, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################################# 10 100 平均相对误差2： tensor(3.1747, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0813, dtype=torch.float64)   实验回归误差 tensor(0.0897, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################################## 10 100 平均相对误差2： tensor(3.5671, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1325, dtype=torch.float64)   实验回归误差 tensor(0.0784, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################## 10 100 平均相对误差2： tensor(4.0700, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0998, dtype=torch.float64)   实验回归误差 tensor(0.1596, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################ 10 100 平均相对误差2： tensor(5.9280, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0833, dtype=torch.float64)   实验回归误差 tensor(0.0686, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################## 10 100 平均相对误差2： tensor(2.8839, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1422, dtype=torch.float64)   实验回归误差 tensor(0.1080, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################## 10 100 平均相对误差2： tensor(4.7186, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0567, dtype=torch.float64)   实验回归误差 tensor(0.1183, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################## 10 100 平均相对误差2： tensor(1.3500, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1323, dtype=torch.float64)   实验回归误差 tensor(0.0743, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################# 20 100 平均相对误差2： tensor(5.5294, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0554, dtype=torch.float64)   实验回归误差 tensor(0.0748, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################################################### 20 100 平均相对误差2： tensor(5.5829, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0680, dtype=torch.float64)   实验回归误差 tensor(0.0515, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################ 20 100 平均相对误差2： tensor(4.5129, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0729, dtype=torch.float64)   实验回归误差 tensor(0.0727, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################# 20 100 平均相对误差2： tensor(5.8047, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0666, dtype=torch.float64)   实验回归误差 tensor(0.0714, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################### 20 100 平均相对误差2： tensor(5.9065, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0528, dtype=torch.float64)   实验回归误差 tensor(0.0634, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################### 20 100 平均相对误差2： tensor(6.3318, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0567, dtype=torch.float64)   实验回归误差 tensor(0.0547, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################### 20 100 平均相对误差2： tensor(6.1843, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0673, dtype=torch.float64)   实验回归误差 tensor(0.1119, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################ 20 100 平均相对误差2： tensor(5.1651, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0585, dtype=torch.float64)   实验回归误差 tensor(0.0773, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################ 20 100 平均相对误差2： tensor(4.4026, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0696, dtype=torch.float64)   实验回归误差 tensor(0.0729, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################################### 2 100 平均相对误差2： tensor(0.3167, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3927, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0093, dtype=torch.float64)   实验回归误差 tensor(0.1664, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################## 2 100 平均相对误差2： tensor(0.4122, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4934, dtype=torch.float64)   实验回归误差 tensor(0.0924, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################ 2 100 平均相对误差2： tensor(0.1786, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8389, dtype=torch.float64)   实验回归误差 tensor(0.1074, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################### 2 100 平均相对误差2： tensor(0.2268, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2523, dtype=torch.float64)   实验回归误差 tensor(0.1027, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################### 2 100 平均相对误差2： tensor(0.2424, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7037, dtype=torch.float64)   实验回归误差 tensor(0.1736, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################# 2 100 平均相对误差2： tensor(0.8152, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4830, dtype=torch.float64)   实验回归误差 tensor(0.1571, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################## 2 100 平均相对误差2： tensor(0.1213, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8180, dtype=torch.float64)   实验回归误差 tensor(0.1790, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################### 2 100 平均相对误差2： tensor(1.5275, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2430, dtype=torch.float64)   实验回归误差 tensor(0.1478, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################################################### 5 100 平均相对误差2： tensor(0.7404, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1238, dtype=torch.float64)   实验回归误差 tensor(0.0647, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################ 5 100 平均相对误差2： tensor(3.2487, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1285, dtype=torch.float64)   实验回归误差 tensor(0.2072, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################## 5 100 平均相对误差2： tensor(1.9026, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2147, dtype=torch.float64)   实验回归误差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################## 5 100 平均相对误差2： tensor(1.7373, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1258, dtype=torch.float64)   实验回归误差 tensor(0.1091, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################################################ 5 100 平均相对误差2： tensor(2.0064, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1613, dtype=torch.float64)   实验回归误差 tensor(0.1004, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################################### 5 100 平均相对误差2： tensor(0.7365, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2422, dtype=torch.float64)   实验回归误差 tensor(0.1482, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################### 5 100 平均相对误差2： tensor(1.0228, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1111, dtype=torch.float64)   实验回归误差 tensor(0.0958, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################# 5 100 平均相对误差2： tensor(2.9891, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1212, dtype=torch.float64)   实验回归误差 tensor(0.1519, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################################################### 5 100 平均相对误差2： tensor(3.5881, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1009, dtype=torch.float64)   实验回归误差 tensor(0.0919, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################################################################################################### 10 100 平均相对误差2： tensor(2.8276, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1017, dtype=torch.float64)   实验回归误差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################################################################################################################### 10 100 平均相对误差2： tensor(3.5532, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1167, dtype=torch.float64)   实验回归误差 tensor(0.0757, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################### 10 100 平均相对误差2： tensor(1.5659, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1888, dtype=torch.float64)   实验回归误差 tensor(0.1158, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################### 10 100 平均相对误差2： tensor(2.6677, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0991, dtype=torch.float64)   实验回归误差 tensor(0.0732, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################ 10 100 平均相对误差2： tensor(2.6351, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1586, dtype=torch.float64)   实验回归误差 tensor(0.0480, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################################## 10 100 平均相对误差2： tensor(2.6874, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1258, dtype=torch.float64)   实验回归误差 tensor(0.0841, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################## 10 100 平均相对误差2： tensor(3.6072, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0934, dtype=torch.float64)   实验回归误差 tensor(0.0694, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################ 10 100 平均相对误差2： tensor(4.6856, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0973, dtype=torch.float64)   实验回归误差 tensor(0.1243, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################ 10 100 平均相对误差2： tensor(3.1702, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1056, dtype=torch.float64)   实验回归误差 tensor(0.0831, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################ 10 100 平均相对误差2： tensor(4.0793, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0823, dtype=torch.float64)   实验回归误差 tensor(0.1756, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################################################################### 20 100 平均相对误差2： tensor(5.3068, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0737, dtype=torch.float64)   实验回归误差 tensor(0.0685, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################# 20 100 平均相对误差2： tensor(7.0634, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0627, dtype=torch.float64)   实验回归误差 tensor(0.0647, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################################################################### 20 100 平均相对误差2： tensor(5.1490, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0900, dtype=torch.float64)   实验回归误差 tensor(0.0780, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################################################################################################## 20 100 平均相对误差2： tensor(4.8433, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0591, dtype=torch.float64)   实验回归误差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################## 20 100 平均相对误差2： tensor(6.0092, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0612, dtype=torch.float64)   实验回归误差 tensor(0.0580, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################################################################ 20 100 平均相对误差2： tensor(5.4648, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0975, dtype=torch.float64)   实验回归误差 tensor(0.0708, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################ 20 100 平均相对误差2： tensor(4.3045, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0704, dtype=torch.float64)   实验回归误差 tensor(0.0437, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################# 20 100 平均相对误差2： tensor(4.6239, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0740, dtype=torch.float64)   实验回归误差 tensor(0.0602, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################ 20 100 平均相对误差2： tensor(5.1594, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0711, dtype=torch.float64)   实验回归误差 tensor(0.1123, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################# 20 100 平均相对误差2： tensor(4.6525, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0718, dtype=torch.float64)   实验回归误差 tensor(0.0714, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############# 2 100 平均相对误差2： tensor(0.2555, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2577, dtype=torch.float64)   实验回归误差 tensor(0.1154, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################# 2 100 平均相对误差2： tensor(0.1798, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5560, dtype=torch.float64)   实验回归误差 tensor(0.1472, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################### 2 100 平均相对误差2： tensor(0.8314, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1679, dtype=torch.float64)   实验回归误差 tensor(0.1218, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################### 2 100 平均相对误差2： tensor(0.4244, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1866, dtype=torch.float64)   实验回归误差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################### 2 100 平均相对误差2： tensor(2.5228, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2304, dtype=torch.float64)   实验回归误差 tensor(0.2121, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################### 2 100 平均相对误差2： tensor(1.0617, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2579, dtype=torch.float64)   实验回归误差 tensor(0.2224, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################################################### 2 100 平均相对误差2： tensor(0.0500, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0946, dtype=torch.float64)   实验回归误差 tensor(0.0553, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################## 2 100 平均相对误差2： tensor(2.0626, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1876, dtype=torch.float64)   实验回归误差 tensor(0.1259, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################ 2 100 平均相对误差2： tensor(1.4394, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2444, dtype=torch.float64)   实验回归误差 tensor(0.1251, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################## 2 100 平均相对误差2： tensor(2.0627, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1569, dtype=torch.float64)   实验回归误差 tensor(0.1423, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################ 5 100 平均相对误差2： tensor(2.8139, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1690, dtype=torch.float64)   实验回归误差 tensor(0.1282, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################### 5 100 平均相对误差2： tensor(1.2668, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1242, dtype=torch.float64)   实验回归误差 tensor(0.1171, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################## 5 100 平均相对误差2： tensor(1.9068, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2134, dtype=torch.float64)   实验回归误差 tensor(0.1590, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################### 5 100 平均相对误差2： tensor(1.5855, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0992, dtype=torch.float64)   实验回归误差 tensor(0.1033, dtype=torch.float64, grad_fn=<DivBackward0>)
# ...
#  10 100 平均相对误差2： tensor(3.1663, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1168, dtype=torch.float64)   实验回归误差 tensor(0.0982, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################################################################### 10 100 平均相对误差2： tensor(3.8623, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0999, dtype=torch.float64)   实验回归误差 tensor(0.1054, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################### 10 100 平均相对误差2： tensor(1.9279, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1178, dtype=torch.float64)   实验回归误差 tensor(0.1081, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################ 10 100 平均相对误差2： tensor(3.7552, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0852, dtype=torch.float64)   实验回归误差 tensor(0.0763, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################## 10 100 平均相对误差2： tensor(2.7406, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1647, dtype=torch.float64)   实验回归误差 tensor(0.0831, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################## 10 100 平均相对误差2： tensor(2.0977, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1399, dtype=torch.float64)   实验回归误差 tensor(0.0921, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################## 10 100 平均相对误差2： tensor(4.3895, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0756, dtype=torch.float64)   实验回归误差 tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################ 20 100 平均相对误差2： tensor(5.6831, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0600, dtype=torch.float64)   实验回归误差 tensor(0.0515, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################## 20 100 平均相对误差2： tensor(4.2850, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0962, dtype=torch.float64)   实验回归误差 tensor(0.0547, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################################### 20 100 平均相对误差2： tensor(5.0873, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0734, dtype=torch.float64)   实验回归误差 tensor(0.0739, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################################### 20 100 平均相对误差2： tensor(5.1267, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0766, dtype=torch.float64)   实验回归误差 tensor(0.0575, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################## 20 100 平均相对误差2： tensor(6.7798, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0638, dtype=torch.float64)   实验回归误差 tensor(0.0745, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################################################################### 20 100 平均相对误差2： tensor(4.7317, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0860, dtype=torch.float64)   实验回归误差 tensor(0.0528, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################# 20 100 平均相对误差2： tensor(8.1135, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0477, dtype=torch.float64)   实验回归误差 tensor(0.0473, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################## 20 100 平均相对误差2： tensor(5.1410, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0699, dtype=torch.float64)   实验回归误差 tensor(0.0717, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################################### 20 100 平均相对误差2： tensor(4.1147, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1056, dtype=torch.float64)   实验回归误差 tensor(0.0830, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################### 20 100 平均相对误差2： tensor(4.1917, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0910, dtype=torch.float64)   实验回归误差 tensor(0.0466, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################### 2 100 平均相对误差2： tensor(0.6305, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4598, dtype=torch.float64)   实验回归误差 tensor(0.1005, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################### 2 100 平均相对误差2： tensor(1.0121, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1583, dtype=torch.float64)   实验回归误差 tensor(0.1007, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################## 2 100 平均相对误差2： tensor(0.7588, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3978, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5023, dtype=torch.float64)   实验回归误差 tensor(0.2009, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################### 2 100 平均相对误差2： tensor(0.8278, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3917, dtype=torch.float64)   实验回归误差 tensor(0.1594, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################### 2 100 平均相对误差2： tensor(0.2047, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2866, dtype=torch.float64)   实验回归误差 tensor(0.0927, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################### 2 100 平均相对误差2： tensor(0.0976, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2461, dtype=torch.float64)   实验回归误差 tensor(0.0789, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################### 2 100 平均相对误差2： tensor(1.1065, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2565, dtype=torch.float64)   实验回归误差 tensor(0.1440, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################# 2 100 平均相对误差2： tensor(0.1983, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1542, dtype=torch.float64)   实验回归误差 tensor(0.0647, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################### 2 100 平均相对误差2： tensor(0.0217, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3710, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3024, dtype=torch.float64)   实验回归误差 tensor(0.0856, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############### 2 100 平均相对误差2： tensor(0.6556, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1891, dtype=torch.float64)   实验回归误差 tensor(0.1061, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################################################################################### 5 100 平均相对误差2： tensor(2.2329, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1505, dtype=torch.float64)   实验回归误差 tensor(0.0963, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################### 5 100 平均相对误差2： tensor(0.9656, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2375, dtype=torch.float64)   实验回归误差 tensor(0.1075, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################### 5 100 平均相对误差2： tensor(0.8527, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3145, dtype=torch.float64)   实验回归误差 tensor(0.1456, dtype=torch.float64, grad_fn=<DivBackward0>)
# ###################################################################################### 5 100 平均相对误差2： tensor(1.1182, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3352, dtype=torch.float64)   实验回归误差 tensor(0.1293, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################# 5 100 平均相对误差2： tensor(3.5964, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1403, dtype=torch.float64)   实验回归误差 tensor(0.0795, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################### 5 100 平均相对误差2： tensor(3.6026, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0852, dtype=torch.float64)   实验回归误差 tensor(0.1052, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################### 5 100 平均相对误差2： tensor(1.3835, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2752, dtype=torch.float64)   实验回归误差 tensor(0.2137, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################## 5 100 平均相对误差2： tensor(1.6972, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1622, dtype=torch.float64)   实验回归误差 tensor(0.1175, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################################################################################################################ 5 100 平均相对误差2： tensor(2.0037, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1678, dtype=torch.float64)   实验回归误差 tensor(0.1180, dtype=torch.float64, grad_fn=<DivBackward0>)
# #################################################################################### 5 100 平均相对误差2： tensor(1.7982, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2358, dtype=torch.float64)   实验回归误差 tensor(0.0948, dtype=torch.float64, grad_fn=<DivBackward0>)
# ########################################################################################################## 10 100 平均相对误差2： tensor(2.9675, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1220, dtype=torch.float64)   实验回归误差 tensor(0.0777, dtype=torch.float64, grad_fn=<DivBackward0>)
# ##################################################################### 10 100 平均相对误差2： tensor(2.0451, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1012, dtype=torch.float64)   实验回归误差 tensor(0.0970, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################### 10 100 平均相对误差2： tensor(3.9939, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0871, dtype=torch.float64)   实验回归误差 tensor(0.0999, dtype=torch.float64, grad_fn=<DivBackward0>)
# ############################################# 10 100 平均相对误差2： tensor(1.1559, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2327, dtype=torch.float64)   实验回归误差 tensor(0.1087, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################## 10 100 平均相对误差2： tensor(5.9038, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0936, dtype=torch.float64)   实验回归误差 tensor(0.0771, dtype=torch.float64, grad_fn=<DivBackward0>)
# ####################################################################################################################### 10 100 平均相对误差2： tensor(4.0409, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0884, dtype=torch.float64)   实验回归误差 tensor(0.0955, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################### 10 100 平均相对误差2： tensor(4.8936, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0807, dtype=torch.float64)   实验回归误差 tensor(0.1104, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################################### 10 100 平均相对误差2： tensor(2.2169, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0793, dtype=torch.float64)   实验回归误差 tensor(0.0891, dtype=torch.float64, grad_fn=<DivBackward0>)
# ######################################################################## 10 100 平均相对误差2： tensor(3.1299, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1136, dtype=torch.float64)   实验回归误差 tensor(0.1718, dtype=torch.float64, grad_fn=<DivBackward0>)
# ################################################################################################################################# 10 100 平均相对误差2： tensor(6.1155, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0776, dtype=torch.float64)   实验回归误差 tensor(0.0979, dtype=torch.float64, grad_fn=<DivBackward0>)
