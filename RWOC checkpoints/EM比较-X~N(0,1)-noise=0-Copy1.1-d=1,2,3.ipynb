# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(50,51,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ######################################## 1 50 绝对误差 tensor(0.0011, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1022, dtype=torch.float64)   实验回归误差 tensor(0.0636, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0038, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2328, dtype=torch.float64)   实验回归误差 tensor(0.0926, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################## 1 50 绝对误差 tensor(0.2957, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.1867, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5885, dtype=torch.float64)   实验回归误差 tensor(0.1988, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0087, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1112, dtype=torch.float64)   实验回归误差 tensor(0.0797, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################## 1 50 绝对误差 tensor(0.3309, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0769, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5275, dtype=torch.float64)   实验回归误差 tensor(0.2612, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################## 1 50 绝对误差 tensor(0.0355, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0682, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1854, dtype=torch.float64)   实验回归误差 tensor(0.0829, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ##################### 1 50 绝对误差 tensor(0.0373, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6629, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9845, dtype=torch.float64)   实验回归误差 tensor(0.2402, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4135, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 48   条件数 1.0
# ################################ 1 50 绝对误差 tensor(0.0048, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0732, dtype=torch.float64)   实验回归误差 tensor(0.0465, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ###################### 1 50 绝对误差 tensor(0.0240, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0156, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0563, dtype=torch.float64)   实验回归误差 tensor(0.0431, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(0.0115, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0227, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1853, dtype=torch.float64)   实验回归误差 tensor(0.0864, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################################## 2 50 绝对误差 tensor(2.3296, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9655, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0459, dtype=torch.float64)   实验回归误差 tensor(0.1686, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2167882042369658
# ############################################################################# 2 50 绝对误差 tensor(0.0322, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0177, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0637, dtype=torch.float64)   实验回归误差 tensor(0.0503, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0119365389065331
# ############################################################################################################### 2 50 绝对误差 tensor(0.1568, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1226, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0870, dtype=torch.float64)   实验回归误差 tensor(0.0795, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1426528050877183
# ######################### 2 50 绝对误差 tensor(0.4672, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5932, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1242, dtype=torch.float64)   实验回归误差 tensor(0.1568, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0795918836437979
# ######################################################################################## 2 50 绝对误差 tensor(2.8038, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4030, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0665, dtype=torch.float64)   实验回归误差 tensor(0.2280, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.347054776759369
# ################################################################################################################## 2 50 绝对误差 tensor(0.0347, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0412, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1139, dtype=torch.float64)   实验回归误差 tensor(0.0700, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.310284901523407
# ############################################# 2 50 绝对误差 tensor(0.0509, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5062, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5669, dtype=torch.float64)   实验回归误差 tensor(0.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.362886513738655
# ###################################################################### 2 50 绝对误差 tensor(2.4019, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4264, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0600, dtype=torch.float64)   实验回归误差 tensor(0.1770, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.253835107851115
# ################################################# 2 50 绝对误差 tensor(3.6147, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4909, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0368, dtype=torch.float64)   实验回归误差 tensor(0.2714, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0570093822188473
# ####################### 2 50 绝对误差 tensor(0.0623, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0793, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1407, dtype=torch.float64)   实验回归误差 tensor(0.0844, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.132212403538016
# ################################################## 3 50 绝对误差 tensor(1.1818, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4754, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0306, dtype=torch.float64)   实验回归误差 tensor(0.0835, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2247676654706272
# ########################################################## 3 50 绝对误差 tensor(0.7597, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7637, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1024, dtype=torch.float64)   实验回归误差 tensor(0.2605, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2658206338503826
# ###################################################################### 3 50 绝对误差 tensor(1.2105, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0939, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0792, dtype=torch.float64)   实验回归误差 tensor(0.1773, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.5591029905895795
# ############################################################################################## 3 50 绝对误差 tensor(2.5931, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0433, dtype=torch.float64)   实验回归误差 tensor(0.1458, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2213998932147883
# ################################# 3 50 绝对误差 tensor(1.1801, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0719, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0959, dtype=torch.float64)   实验回归误差 tensor(0.2393, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2400497696764317
# #################################### 3 50 绝对误差 tensor(1.8153, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6715, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0370, dtype=torch.float64)   实验回归误差 tensor(0.1336, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3120940062924507
# ############################################################################################################## 3 50 绝对误差 tensor(0.3144, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1279, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3100, dtype=torch.float64)   实验回归误差 tensor(0.2560, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2782332000327876
# ######################################################################################################################################### 3 50 绝对误差 tensor(0.0219, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0350, dtype=torch.float64)   实验回归误差 tensor(0.0266, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1400994351441347
# ########################################### 3 50 绝对误差 tensor(0.0404, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0312, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0883, dtype=torch.float64)   实验回归误差 tensor(0.0623, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.31588591402673
# ######################################################## 3 50 绝对误差 tensor(4.0170, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4434, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0341, dtype=torch.float64)   实验回归误差 tensor(0.2093, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2318183315567561
# ############################## 1 50 绝对误差 tensor(0.0023, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0077, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3321, dtype=torch.float64)   实验回归误差 tensor(0.1196, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################ 1 50 绝对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0129, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1206, dtype=torch.float64)   实验回归误差 tensor(0.0816, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(2.0019, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9982, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0961, dtype=torch.float64)   实验回归误差 tensor(0.1827, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0061, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0048, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0729, dtype=torch.float64)   实验回归误差 tensor(0.0566, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.0050, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1099, dtype=torch.float64)   实验回归误差 tensor(0.0683, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################ 1 50 绝对误差 tensor(0.0143, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0373, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2286, dtype=torch.float64)   实验回归误差 tensor(0.1003, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################### 1 50 绝对误差 tensor(0.0235, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0864, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3188, dtype=torch.float64)   实验回归误差 tensor(0.1290, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(0.0227, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1040, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4464, dtype=torch.float64)   实验回归误差 tensor(0.1581, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3618, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 48   条件数 1.0
# ############################ 1 50 绝对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0124, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1891, dtype=torch.float64)   实验回归误差 tensor(0.1039, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0046, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0038, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0724, dtype=torch.float64)   实验回归误差 tensor(0.0601, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ##################################################### 2 50 绝对误差 tensor(0.9086, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1514, dtype=torch.float64)   实验回归误差 tensor(0.1671, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1957624983199093
# ###################################### 2 50 绝对误差 tensor(1.1832, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4134, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1156, dtype=torch.float64)   实验回归误差 tensor(0.2731, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.084231323704948
# ######################################################################################### 2 50 绝对误差 tensor(0.0203, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0131, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0916, dtype=torch.float64)   实验回归误差 tensor(0.0543, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2203523672545122
# ################################################# 2 50 绝对误差 tensor(1.5656, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8162, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0471, dtype=torch.float64)   实验回归误差 tensor(0.1363, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2007969911906025
# ############################################ 2 50 绝对误差 tensor(0.9235, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8292, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0939, dtype=torch.float64)   实验回归误差 tensor(0.2754, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1012762512089336
# ########################################################## 2 50 绝对误差 tensor(0.0828, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0575, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0641, dtype=torch.float64)   实验回归误差 tensor(0.0680, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1998627142753913
# ################################################################################## 2 50 绝对误差 tensor(1.8562, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5878, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0985, dtype=torch.float64)   实验回归误差 tensor(0.1962, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1416772689322574
# ################################################## 2 50 绝对误差 tensor(0.0480, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0287, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0567, dtype=torch.float64)   实验回归误差 tensor(0.0444, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2665920463313647
# ############################### 2 50 绝对误差 tensor(0.4166, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1949, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2640, dtype=torch.float64)   实验回归误差 tensor(0.2080, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0604959974924215
# ############################## 2 50 绝对误差 tensor(1.7370, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2858, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0922, dtype=torch.float64)   实验回归误差 tensor(0.2852, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1712751537994026
# ############################################################################################################################### 3 50 绝对误差 tensor(1.3468, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7304, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0794, dtype=torch.float64)   实验回归误差 tensor(0.1295, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4405535111308923
# ##################################################### 3 50 绝对误差 tensor(0.1078, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0661, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0642, dtype=torch.float64)   实验回归误差 tensor(0.0494, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4623979472896385
# ######################################################## 3 50 绝对误差 tensor(2.0899, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3496, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0530, dtype=torch.float64)   实验回归误差 tensor(0.2036, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3233266251564233
# ############################ 3 50 绝对误差 tensor(1.4943, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7420, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0502, dtype=torch.float64)   实验回归误差 tensor(0.1540, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2036366329628119
# ################################################################################################################################################################## 3 50 绝对误差 tensor(5.3299, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9535, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0332, dtype=torch.float64)   实验回归误差 tensor(0.1776, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.437549192923588
# ################################################################# 3 50 绝对误差 tensor(1.1288, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0072, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0718, dtype=torch.float64)   实验回归误差 tensor(0.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2960077661245781
# ################################################################################################################################################## 3 50 绝对误差 tensor(0.0265, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0149, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0513, dtype=torch.float64)   实验回归误差 tensor(0.0378, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9592, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4101082900339095
# ################################################### 3 50 绝对误差 tensor(0.7205, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6595, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1044, dtype=torch.float64)   实验回归误差 tensor(0.1417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.381543312720941
# ############################################## 3 50 绝对误差 tensor(3.4939, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2242, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0380, dtype=torch.float64)   实验回归误差 tensor(0.2363, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1661979130538083
# ############################### 3 50 绝对误差 tensor(0.7629, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6592, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0913, dtype=torch.float64)   实验回归误差 tensor(0.1705, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.229854111694127
# ########################### 1 50 绝对误差 tensor(0.0232, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0771, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3194, dtype=torch.float64)   实验回归误差 tensor(0.1268, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################### 1 50 绝对误差 tensor(0.0135, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0221, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1677, dtype=torch.float64)   实验回归误差 tensor(0.0870, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.0038, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0103, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2621, dtype=torch.float64)   实验回归误差 tensor(0.1290, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(0.0205, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0302, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1474, dtype=torch.float64)   实验回归误差 tensor(0.0843, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.0355, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0219, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0601, dtype=torch.float64)   实验回归误差 tensor(0.0448, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0188, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0206, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1141, dtype=torch.float64)   实验回归误差 tensor(0.0599, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################ 1 50 绝对误差 tensor(0.0186, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0227, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1297, dtype=torch.float64)   实验回归误差 tensor(0.0827, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(0.0214, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0233, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0916, dtype=torch.float64)   实验回归误差 tensor(0.0591, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(0.0034, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0029, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0950, dtype=torch.float64)   实验回归误差 tensor(0.0716, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0114, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0065, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0551, dtype=torch.float64)   实验回归误差 tensor(0.0475, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################################################################################### 2 50 绝对误差 tensor(0.0216, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0102, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0386, dtype=torch.float64)   实验回归误差 tensor(0.0344, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8485, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.304243427447693
# #################################### 2 50 绝对误差 tensor(0.6043, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8641, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1123, dtype=torch.float64)   实验回归误差 tensor(0.1642, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0721821895263715
# ######################################################## 2 50 绝对误差 tensor(2.1583, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2829, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0591, dtype=torch.float64)   实验回归误差 tensor(0.1548, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1980543926099263
# ########################################################### 2 50 绝对误差 tensor(0.7281, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4370, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0796, dtype=torch.float64)   实验回归误差 tensor(0.1094, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1743786698354337
# ######################################### 2 50 绝对误差 tensor(2.0334, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0107, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0660, dtype=torch.float64)   实验回归误差 tensor(0.2571, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4659417481186061
# ############################################################## 2 50 绝对误差 tensor(0.0069, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0607, dtype=torch.float64)   实验回归误差 tensor(0.0418, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1341587444598218
# ########################################################################################## 2 50 绝对误差 tensor(0.6194, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.8727, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2974, dtype=torch.float64)   实验回归误差 tensor(0.1023, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0542059360262002
# ############################################################################################## 2 50 绝对误差 tensor(0.0209, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0119, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0494, dtype=torch.float64)   实验回归误差 tensor(0.0314, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1973134804374863
# ############################################################################## 2 50 绝对误差 tensor(0.0481, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0574, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1053, dtype=torch.float64)   实验回归误差 tensor(0.0711, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.624829095115656
# ########################################## 2 50 绝对误差 tensor(0.0233, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0097, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0322, dtype=torch.float64)   实验回归误差 tensor(0.0280, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9798, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0860321877885075
# ############################################################################################ 3 50 绝对误差 tensor(0.7938, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5993, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0801, dtype=torch.float64)   实验回归误差 tensor(0.0974, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2976107457800354
# ############################################################### 3 50 绝对误差 tensor(0.8784, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1498, dtype=torch.float64)   实验回归误差 tensor(0.1677, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2263855181149876
# ################################################################### 3 50 绝对误差 tensor(3.7102, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1376, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0270, dtype=torch.float64)   实验回归误差 tensor(0.2068, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3475891856612854
# ###################################################### 3 50 绝对误差 tensor(0.0354, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0165, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0469, dtype=torch.float64)   实验回归误差 tensor(0.0425, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2723695305017073
# ############################################################################ 3 50 绝对误差 tensor(1.1886, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9937, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0785, dtype=torch.float64)   实验回归误差 tensor(0.3037, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2420187322371872
# ################################################ 3 50 绝对误差 tensor(1.3676, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6993, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0404, dtype=torch.float64)   实验回归误差 tensor(0.1501, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.5212155444629112
# ######################################################################### 3 50 绝对误差 tensor(0.1618, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3932, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2366, dtype=torch.float64)   实验回归误差 tensor(0.0889, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3964216921535622
# ############################################################## 3 50 绝对误差 tensor(0.0153, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0085, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0456, dtype=torch.float64)   实验回归误差 tensor(0.0375, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8718, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1569214934312522
# ######################################################################### 3 50 绝对误差 tensor(1.7346, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3406, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0809, dtype=torch.float64)   实验回归误差 tensor(0.1374, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2876883497018161
# ############################################################################################### 3 50 绝对误差 tensor(2.9925, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9905, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0344, dtype=torch.float64)   实验回归误差 tensor(0.1064, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.267655106546513
# ############################################ 1 50 绝对误差 tensor(0.0294, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0547, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1970, dtype=torch.float64)   实验回归误差 tensor(0.1162, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0240, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0884, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3086, dtype=torch.float64)   实验回归误差 tensor(0.1413, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0274, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1590, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4473, dtype=torch.float64)   实验回归误差 tensor(0.1844, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2953, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 48   条件数 1.0
# #################################### 1 50 绝对误差 tensor(0.0412, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1461, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3266, dtype=torch.float64)   实验回归误差 tensor(0.1493, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.0090, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0195, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2135, dtype=torch.float64)   实验回归误差 tensor(0.0973, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.1166, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(5.2655, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9652, dtype=torch.float64)   实验回归误差 tensor(0.2720, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4138, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################## 1 50 绝对误差 tensor(0.0383, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2689, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4597, dtype=torch.float64)   实验回归误差 tensor(0.1362, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(0.0145, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0194, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1364, dtype=torch.float64)   实验回归误差 tensor(0.0850, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0087, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1632, dtype=torch.float64)   实验回归误差 tensor(0.0898, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0209, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0277, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1045, dtype=torch.float64)   实验回归误差 tensor(0.0712, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ###################################### 2 50 绝对误差 tensor(0.0625, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1871, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2800, dtype=torch.float64)   实验回归误差 tensor(0.1324, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.024834431216454
# ################################################################################ 2 50 绝对误差 tensor(0.0322, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0303, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0764, dtype=torch.float64)   实验回归误差 tensor(0.0527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2100055098363598
# ################################# 2 50 绝对误差 tensor(1.2903, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3414, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1241, dtype=torch.float64)   实验回归误差 tensor(0.2570, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2097954465865408
# ######################################################################################################### 2 50 绝对误差 tensor(0.6817, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8399, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1281, dtype=torch.float64)   实验回归误差 tensor(0.1888, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4529518105761696
# ###################################### 2 50 绝对误差 tensor(0.9847, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6031, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0667, dtype=torch.float64)   实验回归误差 tensor(0.1391, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.152444701322521
# ################################## 2 50 绝对误差 tensor(0.0125, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0119, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0688, dtype=torch.float64)   实验回归误差 tensor(0.0421, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2833774824163326
# ######################### 2 50 绝对误差 tensor(0.5664, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4984, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0841, dtype=torch.float64)   实验回归误差 tensor(0.2034, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2227360104241636
# ########################## 2 50 绝对误差 tensor(1.2754, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9964, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0921, dtype=torch.float64)   实验回归误差 tensor(0.2820, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.448181523232513
# ############################# 2 50 绝对误差 tensor(0.0295, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0425, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1311, dtype=torch.float64)   实验回归误差 tensor(0.0619, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2323237089251249
# ################################## 2 50 绝对误差 tensor(1.1353, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5763, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0523, dtype=torch.float64)   实验回归误差 tensor(0.1607, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.110357620640127
# ################################# 3 50 绝对误差 tensor(0.6274, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3587, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0638, dtype=torch.float64)   实验回归误差 tensor(0.1571, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.202674699451814
# ######################################################## 3 50 绝对误差 tensor(0.0447, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0167, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0418, dtype=torch.float64)   实验回归误差 tensor(0.0365, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8718, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1539154749443405
# ##################################################################################### 3 50 绝对误差 tensor(2.0788, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0354, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0479, dtype=torch.float64)   实验回归误差 tensor(0.1281, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2338320854662763
# ############################################################################################################################################################################################## 3 50 绝对误差 tensor(2.1368, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7505, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0746, dtype=torch.float64)   实验回归误差 tensor(0.1413, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.368406664415822
# ####################################### 3 50 绝对误差 tensor(2.9302, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8890, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0215, dtype=torch.float64)   实验回归误差 tensor(0.1670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4348260849022865
# ############################################################## 3 50 绝对误差 tensor(0.6188, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2847, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0456, dtype=torch.float64)   实验回归误差 tensor(0.0914, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0751979887564982
# ##################################################################### 3 50 绝对误差 tensor(0.1138, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1462, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1362, dtype=torch.float64)   实验回归误差 tensor(0.0864, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.577267083730565
# ############################################################################### 3 50 绝对误差 tensor(0.4581, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2295, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0396, dtype=torch.float64)   实验回归误差 tensor(0.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4206291802777578
# ######################################################################################################################### 3 50 绝对误差 tensor(0.3945, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2611, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0688, dtype=torch.float64)   实验回归误差 tensor(0.0671, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.395520276894407
# #################################################################### 3 50 绝对误差 tensor(0.4582, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4144, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0913, dtype=torch.float64)   实验回归误差 tensor(0.1308, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.458167268885795
# ######################################### 1 50 绝对误差 tensor(0.0011, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0769, dtype=torch.float64)   实验回归误差 tensor(0.0626, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# #################################### 1 50 绝对误差 tensor(0.0048, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0029, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0604, dtype=torch.float64)   实验回归误差 tensor(0.0493, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9592, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################## 1 50 绝对误差 tensor(0.0235, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0782, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2696, dtype=torch.float64)   实验回归误差 tensor(0.1550, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################################### 1 50 绝对误差 tensor(0.0191, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0205, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1418, dtype=torch.float64)   实验回归误差 tensor(0.0946, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################## 1 50 绝对误差 tensor(0.0021, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0009, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0363, dtype=torch.float64)   实验回归误差 tensor(0.0311, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8246, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################## 1 50 绝对误差 tensor(0.0280, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0131, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0479, dtype=torch.float64)   实验回归误差 tensor(0.0408, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(0.0109, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0082, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0722, dtype=torch.float64)   实验回归误差 tensor(0.0474, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################ 1 50 绝对误差 tensor(0.0169, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1187, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6004, dtype=torch.float64)   实验回归误差 tensor(0.2206, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################################ 1 50 绝对误差 tensor(0.0122, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0116, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1345, dtype=torch.float64)   实验回归误差 tensor(0.0774, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0337, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2293, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5655, dtype=torch.float64)   实验回归误差 tensor(0.2679, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################################################################################################################## 2 50 绝对误差 tensor(0.0335, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0353, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0829, dtype=torch.float64)   实验回归误差 tensor(0.0562, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3274014084150918
# ############################################################################### 2 50 绝对误差 tensor(0.0138, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0137, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0899, dtype=torch.float64)   实验回归误差 tensor(0.0567, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.22082694119409
# ############################################ 2 50 绝对误差 tensor(0.3438, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2738, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0928, dtype=torch.float64)   实验回归误差 tensor(0.1026, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0872800929640034
# ############################ 2 50 绝对误差 tensor(2.1961, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2976, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0659, dtype=torch.float64)   实验回归误差 tensor(0.2156, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0937912314351013
# ########################################################################### 2 50 绝对误差 tensor(0.0329, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0158, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0535, dtype=torch.float64)   实验回归误差 tensor(0.0436, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.7746, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.06747164538145
# ################################################################### 2 50 绝对误差 tensor(1.1449, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1520, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1318, dtype=torch.float64)   实验回归误差 tensor(0.1648, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4229988986789956
# ############################################################################################################################################################### 2 50 绝对误差 tensor(0.0190, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0190, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1215, dtype=torch.float64)   实验回归误差 tensor(0.0781, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1143904976400156
# ############################################################## 2 50 绝对误差 tensor(0.0307, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0182, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0482, dtype=torch.float64)   实验回归误差 tensor(0.0375, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9798, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0239905920332957
# ################################### 3 50 绝对误差 tensor(2.5337, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1159, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0460, dtype=torch.float64)   实验回归误差 tensor(0.1603, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3199137117770556
# #################################################### 3 50 绝对误差 tensor(1.0074, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1405, dtype=torch.float64)   实验回归误差 tensor(0.1311, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2522562099226757
# ############################################################################################################################################################################################## 3 50 绝对误差 tensor(0.3559, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4489, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1458, dtype=torch.float64)   实验回归误差 tensor(0.1375, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3049397097202764
# #################################################################################################################### 3 50 绝对误差 tensor(0.0237, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0104, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0402, dtype=torch.float64)   实验回归误差 tensor(0.0318, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9163, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1831930476912405
# ##################################### 3 50 绝对误差 tensor(0.7005, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1400, dtype=torch.float64)   实验回归误差 tensor(0.1618, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.118324947364318
# ################################################################################################# 3 50 绝对误差 tensor(3.3809, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0493, dtype=torch.float64)   实验回归误差 tensor(0.1372, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4596577455850661
# ##################### 3 50 绝对误差 tensor(0.8860, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2415, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1473, dtype=torch.float64)   实验回归误差 tensor(0.2827, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3005609891535623
# ################################## 3 50 绝对误差 tensor(3.3576, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5733, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0366, dtype=torch.float64)   实验回归误差 tensor(0.2317, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2868155467227584
# ############################################ 3 50 绝对误差 tensor(2.1116, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7814, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0799, dtype=torch.float64)   实验回归误差 tensor(0.2589, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.6349879051063316
# ############################################################################### 3 50 绝对误差 tensor(0.6956, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6284, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0782, dtype=torch.float64)   实验回归误差 tensor(0.1484, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2911926584154123
