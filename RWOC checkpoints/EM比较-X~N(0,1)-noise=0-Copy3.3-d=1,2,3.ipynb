# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(150,151,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.3)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.002
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############ 1 150 绝对误差 tensor(0.0315, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0514, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4125, dtype=torch.float64)   实验回归误差 tensor(0.1098, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0156, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0089, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1381, dtype=torch.float64)   实验回归误差 tensor(0.0544, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0571, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0828, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4234, dtype=torch.float64)   实验回归误差 tensor(0.1061, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0533, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0754, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3894, dtype=torch.float64)   实验回归误差 tensor(0.0985, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0487, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0582, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3567, dtype=torch.float64)   实验回归误差 tensor(0.0986, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0280, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0143, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1322, dtype=torch.float64)   实验回归误差 tensor(0.0536, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0817, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1963, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5354, dtype=torch.float64)   实验回归误差 tensor(0.1107, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3885, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 142   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.1061, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7792, dtype=torch.float64)   实验回归误差 tensor(0.0903, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0694, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0371, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1682, dtype=torch.float64)   实验回归误差 tensor(0.0599, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3317, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0866, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1945, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5502, dtype=torch.float64)   实验回归误差 tensor(0.1000, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3949, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################################################## 2 150 绝对误差 tensor(0.0882, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1019, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2799, dtype=torch.float64)   实验回归误差 tensor(0.0671, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0871779249593256
# ##################################################################################### 2 150 绝对误差 tensor(0.0560, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0450, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2628, dtype=torch.float64)   实验回归误差 tensor(0.0843, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0457688139292478
# ############## 2 150 绝对误差 tensor(3.2084, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9451, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0887, dtype=torch.float64)   实验回归误差 tensor(0.1444, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1050313176994158
# ############################################## 2 150 绝对误差 tensor(0.5945, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7816, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3837, dtype=torch.float64)   实验回归误差 tensor(0.1344, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1000073537008606
# ################## 2 150 绝对误差 tensor(0.1418, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6095, dtype=torch.float64)   实验回归误差 tensor(0.1491, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4046, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0282628474623088
# ######################################################################### 2 150 绝对误差 tensor(0.0479, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0420, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2042, dtype=torch.float64)   实验回归误差 tensor(0.0679, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1127625368985226
# ############################ 2 150 绝对误差 tensor(0.0786, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0464, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1883, dtype=torch.float64)   实验回归误差 tensor(0.0606, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3466, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0787023531614586
# ############################################################################### 2 150 绝对误差 tensor(0.2103, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6834, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7793, dtype=torch.float64)   实验回归误差 tensor(0.1669, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4065, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.032720024025231
# ########################################################## 2 150 绝对误差 tensor(0.2458, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2774, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3217, dtype=torch.float64)   实验回归误差 tensor(0.0889, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1377766774212026
# ############################################ 2 150 绝对误差 tensor(0.4494, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5239, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3058, dtype=torch.float64)   实验回归误差 tensor(0.0935, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.045040151431874
# ###################################### 3 150 绝对误差 tensor(1.7036, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7811, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1372, dtype=torch.float64)   实验回归误差 tensor(0.0633, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2383522581901845
# ############################################################################################# 3 150 绝对误差 tensor(3.4707, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7444, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1558, dtype=torch.float64)   实验回归误差 tensor(0.1771, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1675934653611981
# ####################################### 3 150 绝对误差 tensor(0.6274, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4764, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2267, dtype=torch.float64)   实验回归误差 tensor(0.0738, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1805943271686428
# ########################## 3 150 绝对误差 tensor(1.4944, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5472, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1269, dtype=torch.float64)   实验回归误差 tensor(0.0590, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.173889748881953
# ################################## 3 150 绝对误差 tensor(1.9146, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1421, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1675, dtype=torch.float64)   实验回归误差 tensor(0.1507, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.11277124048648
# ############################################################################# 3 150 绝对误差 tensor(0.1082, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1521, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3918, dtype=torch.float64)   实验回归误差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.3413861946602939
# ################################################################################################################ 3 150 绝对误差 tensor(4.0157, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4707, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1087, dtype=torch.float64)   实验回归误差 tensor(0.1475, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2226082373501324
# ######################################################## 3 150 绝对误差 tensor(1.6386, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3155, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2326, dtype=torch.float64)   实验回归误差 tensor(0.1405, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1496028141387395
# ##################### 3 150 绝对误差 tensor(0.6654, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3277, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1280, dtype=torch.float64)   实验回归误差 tensor(0.0811, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1214659791582295
# ################################################################################################## 3 150 绝对误差 tensor(1.3966, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7712, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1740, dtype=torch.float64)   实验回归误差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1916033021891221
# ############### 1 150 绝对误差 tensor(0.0056, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2405, dtype=torch.float64)   实验回归误差 tensor(0.0820, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3515, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.3026, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(17.6020, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9961, dtype=torch.float64)   实验回归误差 tensor(0.1118, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0892, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0986, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3450, dtype=torch.float64)   实验回归误差 tensor(0.0981, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.1059, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4422, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8310, dtype=torch.float64)   实验回归误差 tensor(0.1415, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0158, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0097, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2016, dtype=torch.float64)   实验回归误差 tensor(0.0922, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.4666, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.4116, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9596, dtype=torch.float64)   实验回归误差 tensor(0.0901, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4093, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.1521, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2751, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4737, dtype=torch.float64)   实验回归误差 tensor(0.0760, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0496, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2588, dtype=torch.float64)   实验回归误差 tensor(0.0997, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0217, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0246, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3619, dtype=torch.float64)   实验回归误差 tensor(0.0880, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# #################################### 2 150 绝对误差 tensor(1.7314, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0372, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1724, dtype=torch.float64)   实验回归误差 tensor(0.1381, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1087567706309565
# ################################### 2 150 绝对误差 tensor(2.6702, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2604, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1391, dtype=torch.float64)   实验回归误差 tensor(0.0908, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.093213530562614
# ############################################ 2 150 绝对误差 tensor(0.1650, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2893, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4437, dtype=torch.float64)   实验回归误差 tensor(0.0731, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.180906179536743
# #################################################### 2 150 绝对误差 tensor(0.7321, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0103, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3675, dtype=torch.float64)   实验回归误差 tensor(0.1665, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.104300831989062
# ######################## 2 150 绝对误差 tensor(0.0838, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1726, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4987, dtype=torch.float64)   实验回归误差 tensor(0.0816, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.2104029101896883
# ###################################### 2 150 绝对误差 tensor(1.7952, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1207, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1881, dtype=torch.float64)   实验回归误差 tensor(0.1334, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.082907062080338
# ###################################################### 2 150 绝对误差 tensor(0.9054, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.2506, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6165, dtype=torch.float64)   实验回归误差 tensor(0.1017, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1212337539857955
# ########################################################## 2 150 绝对误差 tensor(1.5727, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4547, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0852, dtype=torch.float64)   实验回归误差 tensor(0.0781, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1156997067110017
# ############## 2 150 绝对误差 tensor(0.7615, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3627, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5004, dtype=torch.float64)   实验回归误差 tensor(0.1280, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0677374435149292
# ############################## 2 150 绝对误差 tensor(0.7289, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0194, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3856, dtype=torch.float64)   实验回归误差 tensor(0.1556, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1293230346758365
# ############################################################################################################################## 3 150 绝对误差 tensor(4.5807, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4238, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0981, dtype=torch.float64)   实验回归误差 tensor(0.1041, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1608648040743808
# ################################################### 3 150 绝对误差 tensor(0.7402, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8604, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3328, dtype=torch.float64)   实验回归误差 tensor(0.1403, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1968685308651787
# ####################################################### 3 150 绝对误差 tensor(1.0315, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2027, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3284, dtype=torch.float64)   实验回归误差 tensor(0.1641, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1171493161514985
# ############################################################################################################################ 3 150 绝对误差 tensor(1.2527, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6964, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1504, dtype=torch.float64)   实验回归误差 tensor(0.0774, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.056584455023971
# ######################################################################################################################### 3 150 绝对误差 tensor(2.9973, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2535, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1245, dtype=torch.float64)   实验回归误差 tensor(0.0810, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.3342703301424719
# ##################################################################################################################################### 3 150 绝对误差 tensor(0.4917, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2871, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1949, dtype=torch.float64)   实验回归误差 tensor(0.0835, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1369048914717728
# ########################### 3 150 绝对误差 tensor(0.7171, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9349, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3648, dtype=torch.float64)   实验回归误差 tensor(0.1290, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0841197473835091
# ################ 3 150 绝对误差 tensor(0.3140, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3685, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3844, dtype=torch.float64)   实验回归误差 tensor(0.1139, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1968216061384191
# ############################################################################## 3 150 绝对误差 tensor(0.7268, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3132, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1340, dtype=torch.float64)   实验回归误差 tensor(0.0755, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1258846792151576
# ########################### 3 150 绝对误差 tensor(1.7642, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9775, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1489, dtype=torch.float64)   实验回归误差 tensor(0.0880, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.143134743373538
# ################ 1 150 绝对误差 tensor(0.0289, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0155, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1725, dtype=torch.float64)   实验回归误差 tensor(0.0783, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.8388, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.2316, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6982, dtype=torch.float64)   实验回归误差 tensor(0.1092, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4094, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.1130, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3017, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6752, dtype=torch.float64)   实验回归误差 tensor(0.1083, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3897, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0749, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2719, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7467, dtype=torch.float64)   实验回归误差 tensor(0.1094, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.1694, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1608, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8942, dtype=torch.float64)   实验回归误差 tensor(0.1520, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3983, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.1646, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2230, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8999, dtype=torch.float64)   实验回归误差 tensor(0.1189, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 143   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.2882, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(56.1639, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9982, dtype=torch.float64)   实验回归误差 tensor(0.2590, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4119, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.1226, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3758, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6970, dtype=torch.float64)   实验回归误差 tensor(0.1144, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4084, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0589, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1090, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4840, dtype=torch.float64)   实验回归误差 tensor(0.0959, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0752, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2060, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6544, dtype=torch.float64)   实验回归误差 tensor(0.1198, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.0
# ################################################################################################################ 2 150 绝对误差 tensor(0.1707, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0933, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1522, dtype=torch.float64)   实验回归误差 tensor(0.0617, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1294889922638303
# ######################################################################################################## 2 150 绝对误差 tensor(0.0266, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0136, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1478, dtype=torch.float64)   实验回归误差 tensor(0.0649, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.234587915419843
# ############### 2 150 绝对误差 tensor(1.0098, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5003, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4058, dtype=torch.float64)   实验回归误差 tensor(0.1443, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.022779620286011
# ######################### 2 150 绝对误差 tensor(0.1243, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1297, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2959, dtype=torch.float64)   实验回归误差 tensor(0.0833, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0474742502665322
# ################################# 2 150 绝对误差 tensor(1.2417, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5781, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1275, dtype=torch.float64)   实验回归误差 tensor(0.0986, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.220334520819947
# ####################### 2 150 绝对误差 tensor(2.0673, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1692, dtype=torch.float64)   实验回归误差 tensor(0.0882, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0328533812504688
# ##################### 2 150 绝对误差 tensor(1.2005, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4465, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3361, dtype=torch.float64)   实验回归误差 tensor(0.1009, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4089, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1816078033229573
# ############################ 2 150 绝对误差 tensor(1.1459, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1805, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2795, dtype=torch.float64)   实验回归误差 tensor(0.1717, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0428032546576467
# ########################################################################################################################################################################################################超过迭代上限
#  2 150 绝对误差 tensor(0.2115, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2474, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3521, dtype=torch.float64)   实验回归误差 tensor(0.0867, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1447398697623647
# ########################## 2 150 绝对误差 tensor(0.2887, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5643, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5683, dtype=torch.float64)   实验回归误差 tensor(0.1320, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4037, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.170408306063759
# ################################################################################### 3 150 绝对误差 tensor(1.5301, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4393, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0936, dtype=torch.float64)   实验回归误差 tensor(0.0911, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2517803301183748
# ################################# 3 150 绝对误差 tensor(1.9884, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8767, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1285, dtype=torch.float64)   实验回归误差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2891066870154078
# ################# 3 150 绝对误差 tensor(0.9100, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6207, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1938, dtype=torch.float64)   实验回归误差 tensor(0.1301, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1665026386128081
# ###################################### 3 150 绝对误差 tensor(1.5327, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8815, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1695, dtype=torch.float64)   实验回归误差 tensor(0.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2321465344431601
# ############################################## 3 150 绝对误差 tensor(0.1104, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0259, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0748, dtype=torch.float64)   实验回归误差 tensor(0.0365, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2754, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1498807231510846
# #################################################################################################################################################################################### 3 150 绝对误差 tensor(0.1987, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1787, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2462, dtype=torch.float64)   实验回归误差 tensor(0.0697, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2003250808489476
# ############################################ 3 150 绝对误差 tensor(1.7086, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9466, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1652, dtype=torch.float64)   实验回归误差 tensor(0.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1503734792116307
# ################################################### 3 150 绝对误差 tensor(1.3203, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6083, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1369, dtype=torch.float64)   实验回归误差 tensor(0.1045, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2048465485484774
# #################################################################### 3 150 绝对误差 tensor(0.3576, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5539, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3576, dtype=torch.float64)   实验回归误差 tensor(0.1027, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.021889246696667
# ########################################## 3 150 绝对误差 tensor(0.8636, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8535, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2820, dtype=torch.float64)   实验回归误差 tensor(0.1615, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4094, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2460770278768956
# ############## 1 150 绝对误差 tensor(0.1488, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7027, dtype=torch.float64)   实验回归误差 tensor(0.1478, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4089, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0050, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0026, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1561, dtype=torch.float64)   实验回归误差 tensor(0.0439, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.1173, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3324, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6032, dtype=torch.float64)   实验回归误差 tensor(0.1169, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3976, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0687, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1241, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4462, dtype=torch.float64)   实验回归误差 tensor(0.1255, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0755, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0594, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2233, dtype=torch.float64)   实验回归误差 tensor(0.0824, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.1542, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5769, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7238, dtype=torch.float64)   实验回归误差 tensor(0.1116, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4073, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0588, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0952, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4832, dtype=torch.float64)   实验回归误差 tensor(0.1041, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0549, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0917, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4533, dtype=torch.float64)   实验回归误差 tensor(0.1403, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.0801, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1756, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5813, dtype=torch.float64)   实验回归误差 tensor(0.1247, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0275, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0171, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1831, dtype=torch.float64)   实验回归误差 tensor(0.0716, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3515, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########################################### 2 150 绝对误差 tensor(1.9978, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0975, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1584, dtype=torch.float64)   实验回归误差 tensor(0.1003, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0278874372113973
# ################### 2 150 绝对误差 tensor(0.4428, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4219, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2845, dtype=torch.float64)   实验回归误差 tensor(0.1029, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.187521936388045
# ####################################### 2 150 绝对误差 tensor(0.3732, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3646, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2812, dtype=torch.float64)   实验回归误差 tensor(0.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3941, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1167978368763143
# ################## 2 150 绝对误差 tensor(0.5919, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3624, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2013, dtype=torch.float64)   实验回归误差 tensor(0.0778, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1097841759618103
# ########################################################################## 2 150 绝对误差 tensor(1.0708, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0199, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2751, dtype=torch.float64)   实验回归误差 tensor(0.1456, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1503156454299963
# ########################### 2 150 绝对误差 tensor(1.1436, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.8541, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4300, dtype=torch.float64)   实验回归误差 tensor(0.1106, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1072986189704115
# ############################################################## 2 150 绝对误差 tensor(0.7428, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1415, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3521, dtype=torch.float64)   实验回归误差 tensor(0.1376, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0551011680082243
# ######################################################################################################### 2 150 绝对误差 tensor(0.3850, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2263, dtype=torch.float64)   实验回归误差 tensor(0.0943, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3838, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1520504495442012
# ############################### 2 150 绝对误差 tensor(0.0623, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0797, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3843, dtype=torch.float64)   实验回归误差 tensor(0.0835, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3800, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.284727432997294
# ############################################################ 2 150 绝对误差 tensor(0.1471, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2338, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4197, dtype=torch.float64)   实验回归误差 tensor(0.1085, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.082017408026987
# ################ 3 150 绝对误差 tensor(0.5154, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2634, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1367, dtype=torch.float64)   实验回归误差 tensor(0.0762, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3466, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.183229781319899
# ################################################################################ 3 150 绝对误差 tensor(0.2196, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1372, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1605, dtype=torch.float64)   实验回归误差 tensor(0.0586, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2514253404491524
# ######################################################## 3 150 绝对误差 tensor(1.5627, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6986, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1300, dtype=torch.float64)   实验回归误差 tensor(0.1077, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.278423360833872
# ##################### 3 150 绝对误差 tensor(0.2180, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0666, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0858, dtype=torch.float64)   实验回归误差 tensor(0.0478, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3216, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1470980994332627
# ####################################### 3 150 绝对误差 tensor(2.1278, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9523, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1251, dtype=torch.float64)   实验回归误差 tensor(0.1312, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1235512359005828
# ########################################################### 3 150 绝对误差 tensor(1.2224, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2233, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2819, dtype=torch.float64)   实验回归误差 tensor(0.1203, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2287747198810544
# ######################################## 3 150 绝对误差 tensor(1.8461, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0374, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1664, dtype=torch.float64)   实验回归误差 tensor(0.1243, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1896892064299687
# ######################## 3 150 绝对误差 tensor(0.4162, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9365, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5775, dtype=torch.float64)   实验回归误差 tensor(0.1822, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1343641267505844
# ################################ 3 150 绝对误差 tensor(1.0259, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3353, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3934, dtype=torch.float64)   实验回归误差 tensor(0.1025, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1375867066284122
# ####################################################################### 3 150 绝对误差 tensor(1.5876, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2541, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2357, dtype=torch.float64)   实验回归误差 tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1500408226719434
# ############### 1 150 绝对误差 tensor(0.1871, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3340, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8514, dtype=torch.float64)   实验回归误差 tensor(0.1251, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0158, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0129, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2411, dtype=torch.float64)   实验回归误差 tensor(0.0715, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.3754, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(5.2846, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9856, dtype=torch.float64)   实验回归误差 tensor(0.1775, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4079, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0241, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0211, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2422, dtype=torch.float64)   实验回归误差 tensor(0.0936, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0933, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2439, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6344, dtype=torch.float64)   实验回归误差 tensor(0.0990, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0767, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1375, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4864, dtype=torch.float64)   实验回归误差 tensor(0.1208, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3868, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0517, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0353, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2190, dtype=torch.float64)   实验回归误差 tensor(0.0831, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########## 1 150 绝对误差 tensor(0.0672, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1302, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4715, dtype=torch.float64)   实验回归误差 tensor(0.1088, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0833, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2215, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6090, dtype=torch.float64)   实验回归误差 tensor(0.1453, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0600, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1125, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4768, dtype=torch.float64)   实验回归误差 tensor(0.1165, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4075, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################################################################### 2 150 绝对误差 tensor(0.0952, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0798, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2368, dtype=torch.float64)   实验回归误差 tensor(0.0721, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0932128176707654
# ######################## 2 150 绝对误差 tensor(0.8667, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5078, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2007, dtype=torch.float64)   实验回归误差 tensor(0.0890, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1132977854161163
# ##################### 2 150 绝对误差 tensor(0.6379, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4407, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1846, dtype=torch.float64)   实验回归误差 tensor(0.0845, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0690928902763566
# #################################### 2 150 绝对误差 tensor(0.4236, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3180, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1987, dtype=torch.float64)   实验回归误差 tensor(0.0624, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.079855069133926
# ########################### 2 150 绝对误差 tensor(1.1789, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6129, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3780, dtype=torch.float64)   实验回归误差 tensor(0.0975, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0496720419177987
# ######################################### 2 150 绝对误差 tensor(0.2277, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7999, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9158, dtype=torch.float64)   实验回归误差 tensor(0.1364, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4073, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.264501893874507
# ################################## 2 150 绝对误差 tensor(1.3849, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2948, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2745, dtype=torch.float64)   实验回归误差 tensor(0.1107, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0370914458940406
# ########### 2 150 绝对误差 tensor(0.5400, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4735, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5943, dtype=torch.float64)   实验回归误差 tensor(0.2284, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1225268270236701
# ############################################################################################ 2 150 绝对误差 tensor(1.3692, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2367, dtype=torch.float64)   实验回归误差 tensor(0.1338, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.042356166526347
# ############################## 2 150 绝对误差 tensor(0.1757, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0876, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1667, dtype=torch.float64)   实验回归误差 tensor(0.0690, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3515, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1347778067505732
# ########################################################################################################################################################################################## 3 150 绝对误差 tensor(0.2833, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6055, dtype=torch.float64)   实验回归误差 tensor(0.0979, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1890707987273117
# ######################################################### 3 150 绝对误差 tensor(0.5040, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9226, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4884, dtype=torch.float64)   实验回归误差 tensor(0.0857, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4027, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1543867625998192
# ################################### 3 150 绝对误差 tensor(1.3193, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6805, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1480, dtype=torch.float64)   实验回归误差 tensor(0.0970, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2711701885012439
# ################################################################################### 3 150 绝对误差 tensor(5.3831, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3877, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0729, dtype=torch.float64)   实验回归误差 tensor(0.1141, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.101457283090988
# ########################################################## 3 150 绝对误差 tensor(1.5256, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1893, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2484, dtype=torch.float64)   实验回归误差 tensor(0.1202, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0894103058067086
# ################################################################################################ 3 150 绝对误差 tensor(1.0982, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8505, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2101, dtype=torch.float64)   实验回归误差 tensor(0.0944, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.134463992072375
# ############################################## 3 150 绝对误差 tensor(0.8887, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4839, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1636, dtype=torch.float64)   实验回归误差 tensor(0.0731, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2439337793733187
# ################################################ 3 150 绝对误差 tensor(1.7464, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.8518, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3042, dtype=torch.float64)   实验回归误差 tensor(0.1416, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.238973896184244
# ################################### 3 150 绝对误差 tensor(1.3201, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8810, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1863, dtype=torch.float64)   实验回归误差 tensor(0.1309, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.117054900429473
# ################################################################ 3 150 绝对误差 tensor(2.5663, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0548, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1244, dtype=torch.float64)   实验回归误差 tensor(0.1064, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.3627540555951108
