# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(2):
    for num_example in range(140,141,100): 
        for num_X2feature in [4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############################### 4 140 w绝对误差 tensor(1.4093, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5481, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0364, dtype=torch.float64)   实验回归残差 tensor(0.1141, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0371, dtype=torch.float64)   测试集实验回归残差 tensor(0.1472, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3058068197014072
# ############################################ 4 140 w绝对误差 tensor(0.3672, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3286, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0925, dtype=torch.float64)   实验回归残差 tensor(0.0725, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0923, dtype=torch.float64)   测试集实验回归残差 tensor(0.1236, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3680, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2356382244268773
# ################################ 4 140 w绝对误差 tensor(1.4625, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0123, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0633, dtype=torch.float64)   实验回归残差 tensor(0.0901, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0678, dtype=torch.float64)   测试集实验回归残差 tensor(0.1992, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2778332618281119
# ####################### 4 140 w绝对误差 tensor(2.3962, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1072, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0475, dtype=torch.float64)   实验回归残差 tensor(0.0863, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0531, dtype=torch.float64)   测试集实验回归残差 tensor(0.1709, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1950083439063115
# ################################### 4 140 w绝对误差 tensor(0.6332, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7120, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1123, dtype=torch.float64)   实验回归残差 tensor(0.1037, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1169, dtype=torch.float64)   测试集实验回归残差 tensor(0.1677, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1749802149739716
# ############################## 4 140 w绝对误差 tensor(1.9388, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0960, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0607, dtype=torch.float64)   实验回归残差 tensor(0.1496, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0570, dtype=torch.float64)   测试集实验回归残差 tensor(0.2702, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2715431149939034
# ################################## 4 140 w绝对误差 tensor(3.1906, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3098, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0382, dtype=torch.float64)   实验回归残差 tensor(0.1206, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0359, dtype=torch.float64)   测试集实验回归残差 tensor(0.2132, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3456552688482835
# #################################### 4 140 w绝对误差 tensor(3.8152, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2518, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0330, dtype=torch.float64)   实验回归残差 tensor(0.0815, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0381, dtype=torch.float64)   测试集实验回归残差 tensor(0.2504, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3697766232139286
# ################################################################################################## 4 140 w绝对误差 tensor(3.6160, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8069, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0546, dtype=torch.float64)   实验回归残差 tensor(0.0977, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0498, dtype=torch.float64)   测试集实验回归残差 tensor(0.2207, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2439385075279292
# ################################### 4 140 w绝对误差 tensor(0.8199, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5870, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0740, dtype=torch.float64)   实验回归残差 tensor(0.1010, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0827, dtype=torch.float64)   测试集实验回归残差 tensor(0.1634, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.229455055079092
# ###################################################################################################### 5 140 w绝对误差 tensor(0.3191, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1601, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0538, dtype=torch.float64)   实验回归残差 tensor(0.0506, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0518, dtype=torch.float64)   测试集实验回归残差 tensor(0.0568, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3522, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3363, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2895838901539425
# ############################################### 5 140 w绝对误差 tensor(2.2615, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6173, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0677, dtype=torch.float64)   实验回归残差 tensor(0.1083, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0675, dtype=torch.float64)   测试集实验回归残差 tensor(0.2183, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4082, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2512164409512248
# ############################ 5 140 w绝对误差 tensor(2.7423, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0426, dtype=torch.float64)   实验回归残差 tensor(0.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0390, dtype=torch.float64)   测试集实验回归残差 tensor(0.1226, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.142567660840466
# ########################################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(2.4321, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7916, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0316, dtype=torch.float64)   实验回归残差 tensor(0.2279, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0294, dtype=torch.float64)   测试集实验回归残差 tensor(0.1863, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3846583210170993
# ########################################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(2.5314, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3442, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0461, dtype=torch.float64)   实验回归残差 tensor(0.0921, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0575, dtype=torch.float64)   测试集实验回归残差 tensor(0.2600, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3836570195673252
# ############################################################# 5 140 w绝对误差 tensor(3.7241, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5261, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0354, dtype=torch.float64)   实验回归残差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0403, dtype=torch.float64)   测试集实验回归残差 tensor(0.3425, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2934877984190907
# ################################################################## 5 140 w绝对误差 tensor(2.1588, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1683, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0537, dtype=torch.float64)   实验回归残差 tensor(0.1184, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0566, dtype=torch.float64)   测试集实验回归残差 tensor(0.1118, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3890889455573587
# ######################################################################### 5 140 w绝对误差 tensor(0.1617, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1411, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0826, dtype=torch.float64)   实验回归残差 tensor(0.0511, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0795, dtype=torch.float64)   测试集实验回归残差 tensor(0.0763, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3522, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3363, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4194364371330495
# ############################################## 5 140 w绝对误差 tensor(2.0190, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5861, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0281, dtype=torch.float64)   实验回归残差 tensor(0.0883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0302, dtype=torch.float64)   测试集实验回归残差 tensor(0.1491, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.340825513031239
# ######################## 5 140 w绝对误差 tensor(3.6252, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4552, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0404, dtype=torch.float64)   实验回归残差 tensor(0.1323, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0365, dtype=torch.float64)   测试集实验回归残差 tensor(0.1185, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3809662806984733
# ########################################################################################################################################################################################################超过迭代上限
#  6 140 w绝对误差 tensor(0.4079, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3347, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0767, dtype=torch.float64)   实验回归残差 tensor(0.0608, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0866, dtype=torch.float64)   测试集实验回归残差 tensor(0.0973, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3885, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3142659336603029
# ################################### 6 140 w绝对误差 tensor(3.6704, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1569, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0321, dtype=torch.float64)   实验回归残差 tensor(0.0955, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0321, dtype=torch.float64)   测试集实验回归残差 tensor(0.1722, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2672728863474867
# ################################### 6 140 w绝对误差 tensor(3.0414, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9744, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0306, dtype=torch.float64)   实验回归残差 tensor(0.1566, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0349, dtype=torch.float64)   测试集实验回归残差 tensor(0.2322, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3824087257697906
# ####################################################################### 6 140 w绝对误差 tensor(3.9830, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3141, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0371, dtype=torch.float64)   实验回归残差 tensor(0.1041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0303, dtype=torch.float64)   测试集实验回归残差 tensor(0.1663, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3878947854557104
# ########################################################################################################################################################################################################超过迭代上限
#  6 140 w绝对误差 tensor(1.4509, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9916, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0620, dtype=torch.float64)   实验回归残差 tensor(0.0621, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0693, dtype=torch.float64)   测试集实验回归残差 tensor(0.2192, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3338358268667823
# ########################################################################################################## 6 140 w绝对误差 tensor(5.0141, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6882, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0345, dtype=torch.float64)   实验回归残差 tensor(0.1215, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0335, dtype=torch.float64)   测试集实验回归残差 tensor(0.2695, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3697982482048974
# ########################################## 6 140 w绝对误差 tensor(2.9625, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4435, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0578, dtype=torch.float64)   实验回归残差 tensor(0.1528, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0421, dtype=torch.float64)   测试集实验回归残差 tensor(0.2842, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.404334032586309
# ################################ 6 140 w绝对误差 tensor(3.7506, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5531, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0430, dtype=torch.float64)   实验回归残差 tensor(0.0712, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0348, dtype=torch.float64)   测试集实验回归残差 tensor(0.1986, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4142761314805918
# ################################################################################################## 6 140 w绝对误差 tensor(2.8600, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0228, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0353, dtype=torch.float64)   实验回归残差 tensor(0.0976, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0422, dtype=torch.float64)   测试集实验回归残差 tensor(0.1637, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3971, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.3020039806151442
# ########################################## 6 140 w绝对误差 tensor(3.5293, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3810, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0362, dtype=torch.float64)   实验回归残差 tensor(0.1073, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0420, dtype=torch.float64)   测试集实验回归残差 tensor(0.2221, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3029834028126124
# ##################################### 4 140 w绝对误差 tensor(3.0272, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1157, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0440, dtype=torch.float64)   实验回归残差 tensor(0.1417, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0387, dtype=torch.float64)   测试集实验回归残差 tensor(0.1895, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4084, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2594800114132931
# #################################### 4 140 w绝对误差 tensor(1.5914, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0297, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0689, dtype=torch.float64)   实验回归残差 tensor(0.2154, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0678, dtype=torch.float64)   测试集实验回归残差 tensor(0.1755, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4081, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.244450339734662
# ############################################################### 4 140 w绝对误差 tensor(2.1508, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7981, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0366, dtype=torch.float64)   实验回归残差 tensor(0.0982, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0425, dtype=torch.float64)   测试集实验回归残差 tensor(0.1661, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1742252230321453
# ################## 4 140 w绝对误差 tensor(1.7319, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0505, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0606, dtype=torch.float64)   实验回归残差 tensor(0.1602, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0639, dtype=torch.float64)   测试集实验回归残差 tensor(0.1320, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2091438032377415
# ### 4 140 w绝对误差 tensor(1.5356, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2597, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0802, dtype=torch.float64)   实验回归残差 tensor(0.1778, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0910, dtype=torch.float64)   测试集实验回归残差 tensor(0.1311, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1721257557987772
# ###################################### 4 140 w绝对误差 tensor(1.3497, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7619, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0549, dtype=torch.float64)   实验回归残差 tensor(0.1375, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0527, dtype=torch.float64)   测试集实验回归残差 tensor(0.1868, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.146673756249909
# ##################### 4 140 w绝对误差 tensor(1.2144, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0137, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0934, dtype=torch.float64)   实验回归残差 tensor(0.1897, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0922, dtype=torch.float64)   测试集实验回归残差 tensor(0.1585, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2706704883250635
# #################################### 4 140 w绝对误差 tensor(2.7368, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9722, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0331, dtype=torch.float64)   实验回归残差 tensor(0.1022, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0361, dtype=torch.float64)   测试集实验回归残差 tensor(0.1886, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1188530211419907
# ############################ 4 140 w绝对误差 tensor(1.8993, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3826, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0789, dtype=torch.float64)   实验回归残差 tensor(0.1858, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0747, dtype=torch.float64)   测试集实验回归残差 tensor(0.1611, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3364952750896704
# ############################################## 4 140 w绝对误差 tensor(1.6275, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3533, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0751, dtype=torch.float64)   实验回归残差 tensor(0.0965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0852, dtype=torch.float64)   测试集实验回归残差 tensor(0.1669, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2345280685852558
# ############################ 5 140 w绝对误差 tensor(5.4824, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3947, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0289, dtype=torch.float64)   实验回归残差 tensor(0.1473, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0237, dtype=torch.float64)   测试集实验回归残差 tensor(0.3528, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3350623732533486
# ########################################################## 5 140 w绝对误差 tensor(1.1505, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0237, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0968, dtype=torch.float64)   实验回归残差 tensor(0.1560, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0851, dtype=torch.float64)   测试集实验回归残差 tensor(0.1672, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.542585748250685
# ####################### 5 140 w绝对误差 tensor(2.1684, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0188, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0515, dtype=torch.float64)   实验回归残差 tensor(0.1157, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0422, dtype=torch.float64)   测试集实验回归残差 tensor(0.1762, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2461134749504368
# ####################################################### 5 140 w绝对误差 tensor(3.4223, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0383, dtype=torch.float64)   实验回归残差 tensor(0.1093, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0351, dtype=torch.float64)   测试集实验回归残差 tensor(0.1997, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.231671933389523
# ###################################### 5 140 w绝对误差 tensor(0.7436, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3035, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0403, dtype=torch.float64)   实验回归残差 tensor(0.0646, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0433, dtype=torch.float64)   测试集实验回归残差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.205215904315799
# ########################################################################################################################################################################################################超过迭代上限
#  5 140 w绝对误差 tensor(4.5019, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8190, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0423, dtype=torch.float64)   实验回归残差 tensor(0.0903, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0428, dtype=torch.float64)   测试集实验回归残差 tensor(0.2533, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3638118883473813
# ####################################################### 5 140 w绝对误差 tensor(3.0163, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6480, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0642, dtype=torch.float64)   实验回归残差 tensor(0.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0545, dtype=torch.float64)   测试集实验回归残差 tensor(0.3912, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3261825352168846
# ########################### 5 140 w绝对误差 tensor(1.5019, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2578, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0868, dtype=torch.float64)   实验回归残差 tensor(0.1237, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0956, dtype=torch.float64)   测试集实验回归残差 tensor(0.3063, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3981, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2905551493662324
# ############################################ 5 140 w绝对误差 tensor(1.7050, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1606, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0709, dtype=torch.float64)   实验回归残差 tensor(0.1332, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0717, dtype=torch.float64)   测试集实验回归残差 tensor(0.1632, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2236506530851892
# ################################################################################## 5 140 w绝对误差 tensor(4.4320, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7347, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0402, dtype=torch.float64)   实验回归残差 tensor(0.1153, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0387, dtype=torch.float64)   测试集实验回归残差 tensor(0.1528, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3462335145267
# ############################################### 6 140 w绝对误差 tensor(2.0756, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8520, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0465, dtype=torch.float64)   实验回归残差 tensor(0.1171, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0409, dtype=torch.float64)   测试集实验回归残差 tensor(0.1592, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3871565805217012
# ########################################################################################### 6 140 w绝对误差 tensor(3.0777, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0453, dtype=torch.float64)   实验回归残差 tensor(0.0562, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0458, dtype=torch.float64)   测试集实验回归残差 tensor(0.2474, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3711177554426364
# ############################################################################################################## 6 140 w绝对误差 tensor(2.8235, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0695, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0350, dtype=torch.float64)   实验回归残差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0345, dtype=torch.float64)   测试集实验回归残差 tensor(0.1751, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4272089718769148
# ################################################ 6 140 w绝对误差 tensor(3.1843, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6026, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0450, dtype=torch.float64)   实验回归残差 tensor(0.1392, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0574, dtype=torch.float64)   测试集实验回归残差 tensor(0.2186, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.353641823022169
# ################################################################## 6 140 w绝对误差 tensor(2.9260, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5830, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0534, dtype=torch.float64)   实验回归残差 tensor(0.0853, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0587, dtype=torch.float64)   测试集实验回归残差 tensor(0.2843, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2539690141945141
# ########################### 6 140 w绝对误差 tensor(3.1643, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1864, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0369, dtype=torch.float64)   实验回归残差 tensor(0.1482, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0347, dtype=torch.float64)   测试集实验回归残差 tensor(0.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3010470461696544
# ######################## 6 140 w绝对误差 tensor(3.2914, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1632, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0327, dtype=torch.float64)   实验回归残差 tensor(0.2071, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0331, dtype=torch.float64)   测试集实验回归残差 tensor(0.2287, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.4448291167693752
# ######################################################## 6 140 w绝对误差 tensor(2.4702, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0388, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0422, dtype=torch.float64)   实验回归残差 tensor(0.1020, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0435, dtype=torch.float64)   测试集实验回归残差 tensor(0.2249, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3897018946784494
# ######################################## 6 140 w绝对误差 tensor(3.1467, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3106, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0462, dtype=torch.float64)   实验回归残差 tensor(0.1047, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0388, dtype=torch.float64)   测试集实验回归残差 tensor(0.2293, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.357481378709448
# ################################### 6 140 w绝对误差 tensor(1.0175, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4844, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0471, dtype=torch.float64)   实验回归残差 tensor(0.1052, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0506, dtype=torch.float64)   测试集实验回归残差 tensor(0.1499, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4040, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.335234874395804
