# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.3)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ######## 1 100 绝对误差 tensor(0.0453, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0525, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2869, dtype=torch.float64)   实验回归误差 tensor(0.0821, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ######### 1 100 绝对误差 tensor(0.8945, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0889, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5704, dtype=torch.float64)   实验回归误差 tensor(0.2013, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0765, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0700, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2757, dtype=torch.float64)   实验回归误差 tensor(0.0788, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0905, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3958, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8315, dtype=torch.float64)   实验回归误差 tensor(0.2041, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0004, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0002, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1203, dtype=torch.float64)   实验回归误差 tensor(0.0666, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0631, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0566, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2690, dtype=torch.float64)   实验回归误差 tensor(0.1100, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0290, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0224, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1954, dtype=torch.float64)   实验回归误差 tensor(0.0602, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################## 1 100 绝对误差 tensor(0.0418, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0344, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2670, dtype=torch.float64)   实验回归误差 tensor(0.0970, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3636, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.1189, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3143, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6158, dtype=torch.float64)   实验回归误差 tensor(0.1539, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0867, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1293, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4155, dtype=torch.float64)   实验回归误差 tensor(0.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ######################################################### 2 100 绝对误差 tensor(1.1660, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3676, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3165, dtype=torch.float64)   实验回归误差 tensor(0.1490, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1045095512007639
# ###################### 2 100 绝对误差 tensor(2.0725, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3441, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1647, dtype=torch.float64)   实验回归误差 tensor(0.2954, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.169840573465738
# ################## 2 100 绝对误差 tensor(1.3962, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2381, dtype=torch.float64)   实验回归误差 tensor(0.1281, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.076464327889366
# ######################## 2 100 绝对误差 tensor(0.8922, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0631, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3257, dtype=torch.float64)   实验回归误差 tensor(0.1621, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.03512989868084
# ######################################### 2 100 绝对误差 tensor(1.3119, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9207, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4216, dtype=torch.float64)   实验回归误差 tensor(0.2783, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3999, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0611943871543736
# ############################################# 2 100 绝对误差 tensor(0.8736, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5888, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1674, dtype=torch.float64)   实验回归误差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1528133757798102
# ################################################################# 2 100 绝对误差 tensor(0.6001, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7294, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6369, dtype=torch.float64)   实验回归误差 tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.193145345838001
# ################ 2 100 绝对误差 tensor(1.5626, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7161, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3876, dtype=torch.float64)   实验回归误差 tensor(0.1469, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2177366518355555
# ################################################## 3 100 绝对误差 tensor(1.5005, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9122, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1747, dtype=torch.float64)   实验回归误差 tensor(0.1096, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1800857055240437
# ################# 3 100 绝对误差 tensor(2.3880, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9519, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1473, dtype=torch.float64)   实验回归误差 tensor(0.1404, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2489755161559488
# ############################################################# 3 100 绝对误差 tensor(0.2415, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1570, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1585, dtype=torch.float64)   实验回归误差 tensor(0.0574, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2488347030584057
# ############# 3 100 绝对误差 tensor(1.7286, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1546, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2040, dtype=torch.float64)   实验回归误差 tensor(0.2995, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2649239186757708
# ################################### 3 100 绝对误差 tensor(0.6726, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4857, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1813, dtype=torch.float64)   实验回归误差 tensor(0.0908, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.4118762334501105
# ################### 3 100 绝对误差 tensor(2.0103, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2277, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1697, dtype=torch.float64)   实验回归误差 tensor(0.1479, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1579149903600283
# ############################################################# 3 100 绝对误差 tensor(3.8709, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1054, dtype=torch.float64)   实验回归误差 tensor(0.1294, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.267042803548208
# ############################################### 3 100 绝对误差 tensor(3.4079, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3314, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1208, dtype=torch.float64)   实验回归误差 tensor(0.2135, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2643001252896602
# ############################################################## 3 100 绝对误差 tensor(2.9794, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2831, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1284, dtype=torch.float64)   实验回归误差 tensor(0.0809, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.27658036405457
# ####################################################### 3 100 绝对误差 tensor(0.1143, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0809, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1763, dtype=torch.float64)   实验回归误差 tensor(0.0630, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2969013467826631
# ############### 1 100 绝对误差 tensor(0.0776, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0659, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2323, dtype=torch.float64)   实验回归误差 tensor(0.1036, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(2.8753, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0062, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2454, dtype=torch.float64)   实验回归误差 tensor(0.2431, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# #################### 1 100 绝对误差 tensor(0.0283, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0233, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2584, dtype=torch.float64)   实验回归误差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.2485, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(5.1361, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9619, dtype=torch.float64)   实验回归误差 tensor(0.1722, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3918, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0
# ######## 1 100 绝对误差 tensor(0.1274, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6384, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7402, dtype=torch.float64)   实验回归误差 tensor(0.1365, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0773, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1686, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5948, dtype=torch.float64)   实验回归误差 tensor(0.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.0848, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1888, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5859, dtype=torch.float64)   实验回归误差 tensor(0.1381, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0311, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0225, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1823, dtype=torch.float64)   实验回归误差 tensor(0.0635, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.0135, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0061, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1395, dtype=torch.float64)   实验回归误差 tensor(0.0609, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.1465, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8605, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8482, dtype=torch.float64)   实验回归误差 tensor(0.1466, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ####################################################### 2 100 绝对误差 tensor(0.7614, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8350, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3887, dtype=torch.float64)   实验回归误差 tensor(0.1870, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2559602486744281
# ################################ 2 100 绝对误差 tensor(0.2006, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1995, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2846, dtype=torch.float64)   实验回归误差 tensor(0.1182, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1349346583341018
# ############## 2 100 绝对误差 tensor(0.5671, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4305, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2156, dtype=torch.float64)   实验回归误差 tensor(0.1163, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2106443412358276
# ##################### 2 100 绝对误差 tensor(1.0192, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4288, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1321, dtype=torch.float64)   实验回归误差 tensor(0.1269, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.172169735315196
# ###################### 2 100 绝对误差 tensor(0.7403, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7032, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2612, dtype=torch.float64)   实验回归误差 tensor(0.1646, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1678673699717352
# ############ 2 100 绝对误差 tensor(0.7475, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5957, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2217, dtype=torch.float64)   实验回归误差 tensor(0.1046, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.063287734295372
# ########################################## 2 100 绝对误差 tensor(0.2427, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9604, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7338, dtype=torch.float64)   实验回归误差 tensor(0.1663, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4070, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1464754550743648
# ################################################################################################ 2 100 绝对误差 tensor(2.6128, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9263, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2576, dtype=torch.float64)   实验回归误差 tensor(0.1233, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.186166157747158
# ##################### 2 100 绝对误差 tensor(0.2385, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4996, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4684, dtype=torch.float64)   实验回归误差 tensor(0.1199, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3891, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0391661764773596
# ############################################################################################################ 2 100 绝对误差 tensor(0.1369, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1383, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2807, dtype=torch.float64)   实验回归误差 tensor(0.1058, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3191, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0237483149102853
# ############################## 3 100 绝对误差 tensor(0.4686, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5770, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3729, dtype=torch.float64)   实验回归误差 tensor(0.1048, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1331884920377489
# ########################################## 3 100 绝对误差 tensor(0.7643, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1725, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3973, dtype=torch.float64)   实验回归误差 tensor(0.2386, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0818992292675507
# ######################################################################################################## 3 100 绝对误差 tensor(1.8194, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6875, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1079, dtype=torch.float64)   实验回归误差 tensor(0.1259, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2952598316502508
# ################################################ 3 100 绝对误差 tensor(2.4960, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8956, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0926, dtype=torch.float64)   实验回归误差 tensor(0.1029, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1933719851357574
# ####################################################### 3 100 绝对误差 tensor(0.2412, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1160, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1280, dtype=torch.float64)   实验回归误差 tensor(0.0634, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3191, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.299039536267474
# ####################################################################################################### 3 100 绝对误差 tensor(1.4869, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2183, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2392, dtype=torch.float64)   实验回归误差 tensor(0.1001, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.332814133525532
# ################################################## 3 100 绝对误差 tensor(1.0641, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0463, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2524, dtype=torch.float64)   实验回归误差 tensor(0.0982, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.364369380615176
# ############################### 3 100 绝对误差 tensor(0.4384, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7927, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4635, dtype=torch.float64)   实验回归误差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3004629060797332
# ###################################################### 3 100 绝对误差 tensor(0.9401, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0122, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2992, dtype=torch.float64)   实验回归误差 tensor(0.1264, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0626448939181243
# ################################################## 3 100 绝对误差 tensor(0.7960, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4789, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1824, dtype=torch.float64)   实验回归误差 tensor(0.0837, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3065389707219877
# ############### 1 100 绝对误差 tensor(0.0229, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0336, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4661, dtype=torch.float64)   实验回归误差 tensor(0.1078, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0848, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1106, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4029, dtype=torch.float64)   实验回归误差 tensor(0.1350, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0455, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0337, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2049, dtype=torch.float64)   实验回归误差 tensor(0.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########## 1 100 绝对误差 tensor(0.0447, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0627, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3714, dtype=torch.float64)   实验回归误差 tensor(0.1371, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ###################### 1 100 绝对误差 tensor(0.5671, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.2800, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9361, dtype=torch.float64)   实验回归误差 tensor(0.1958, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0803, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0696, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2834, dtype=torch.float64)   实验回归误差 tensor(0.1062, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0277, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0375, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3934, dtype=torch.float64)   实验回归误差 tensor(0.1440, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.1045, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3204, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6075, dtype=torch.float64)   实验回归误差 tensor(0.1389, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.3093, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(11.4111, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9880, dtype=torch.float64)   实验回归误差 tensor(0.1247, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4129, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 96   条件数 1.0
# ################## 1 100 绝对误差 tensor(0.3486, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(12.3547, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0061, dtype=torch.float64)   实验回归误差 tensor(0.1721, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ##################################################### 2 100 绝对误差 tensor(0.1442, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0795, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1587, dtype=torch.float64)   实验回归误差 tensor(0.0613, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0174558535339153
# ############################################################################# 2 100 绝对误差 tensor(0.1942, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1917, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2218, dtype=torch.float64)   实验回归误差 tensor(0.0845, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1455430223315541
# ######################################### 2 100 绝对误差 tensor(1.2470, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0333, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2406, dtype=torch.float64)   实验回归误差 tensor(0.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0672255308931924
# ####################################################### 2 100 绝对误差 tensor(0.5357, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.1244, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8820, dtype=torch.float64)   实验回归误差 tensor(0.2113, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1422980338363606
# ################ 2 100 绝对误差 tensor(1.9862, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3384, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2079, dtype=torch.float64)   实验回归误差 tensor(0.1803, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1642569018449018
# ######################### 2 100 绝对误差 tensor(0.0791, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0791, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2530, dtype=torch.float64)   实验回归误差 tensor(0.1162, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1119483835938875
# ##################################################################### 2 100 绝对误差 tensor(0.4685, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9688, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4910, dtype=torch.float64)   实验回归误差 tensor(0.1783, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3820, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.1620518257634271
# ##################################################################################### 2 100 绝对误差 tensor(1.9635, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9276, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2804, dtype=torch.float64)   实验回归误差 tensor(0.1809, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0259780458351873
# ######################################################################################## 2 100 绝对误差 tensor(1.2150, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2155, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2606, dtype=torch.float64)   实验回归误差 tensor(0.1140, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.078816108186164
# ###################### 3 100 绝对误差 tensor(2.2620, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1157, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1330, dtype=torch.float64)   实验回归误差 tensor(0.1304, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3098459681815844
# ######################### 3 100 绝对误差 tensor(3.2142, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4111, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1356, dtype=torch.float64)   实验回归误差 tensor(0.2052, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2198870097989591
# ##################### 3 100 绝对误差 tensor(1.8233, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9092, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1434, dtype=torch.float64)   实验回归误差 tensor(0.1315, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1368660592269113
# ############################### 3 100 绝对误差 tensor(2.1849, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2208, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1754, dtype=torch.float64)   实验回归误差 tensor(0.1512, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2303077423716446
# ###################################################################################################### 3 100 绝对误差 tensor(2.1943, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2393, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1591, dtype=torch.float64)   实验回归误差 tensor(0.1474, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3584883241867534
# ######################################################################################################### 3 100 绝对误差 tensor(3.9243, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5162, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1308, dtype=torch.float64)   实验回归误差 tensor(0.1293, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1920359632322108
# #################################### 3 100 绝对误差 tensor(2.4917, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1562, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1402, dtype=torch.float64)   实验回归误差 tensor(0.1218, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0925197025143147
# ########################################### 3 100 绝对误差 tensor(1.9201, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0658, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1477, dtype=torch.float64)   实验回归误差 tensor(0.1908, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2204105526301654
# ############################################################################################### 3 100 绝对误差 tensor(1.4715, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2958, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3279, dtype=torch.float64)   实验回归误差 tensor(0.1641, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3078762948998015
# #################### 3 100 绝对误差 tensor(3.1972, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3086, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1331, dtype=torch.float64)   实验回归误差 tensor(0.1536, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1527109174395338
# ############ 1 100 绝对误差 tensor(0.0364, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0231, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1704, dtype=torch.float64)   实验回归误差 tensor(0.0793, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3342, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0362, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0345, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2959, dtype=torch.float64)   实验回归误差 tensor(0.1137, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0907, dtype=torch.float64)   实验回归误差 tensor(0.0471, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2410, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.1042, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5307, dtype=torch.float64)   实验回归误差 tensor(0.1517, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.2288, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0754, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9214, dtype=torch.float64)   实验回归误差 tensor(0.1793, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.2768, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(5.6435, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9876, dtype=torch.float64)   实验回归误差 tensor(0.1595, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0838, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0594, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1706, dtype=torch.float64)   实验回归误差 tensor(0.0658, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.1139, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1609, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3684, dtype=torch.float64)   实验回归误差 tensor(0.1543, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0398, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0606, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4023, dtype=torch.float64)   实验回归误差 tensor(0.1399, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0571, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0298, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1482, dtype=torch.float64)   实验回归误差 tensor(0.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 2 100 绝对误差 tensor(0.9634, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2476, dtype=torch.float64)   实验回归误差 tensor(0.1230, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0882442435771578
# ######################## 2 100 绝对误差 tensor(0.4795, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7779, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4364, dtype=torch.float64)   实验回归误差 tensor(0.1713, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1566198014558957
# ############################################################### 2 100 绝对误差 tensor(0.5977, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7553, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3281, dtype=torch.float64)   实验回归误差 tensor(0.2098, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1098819620281635
# ############### 2 100 绝对误差 tensor(0.1141, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2380, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5011, dtype=torch.float64)   实验回归误差 tensor(0.1270, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1040011493019628
# ############################ 2 100 绝对误差 tensor(0.4597, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3292, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2035, dtype=torch.float64)   实验回归误差 tensor(0.1181, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2143702438509294
# ############## 2 100 绝对误差 tensor(0.5142, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5722, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3071, dtype=torch.float64)   实验回归误差 tensor(0.1320, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1002565907931874
# ######################################################## 2 100 绝对误差 tensor(0.6590, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4560, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2814, dtype=torch.float64)   实验回归误差 tensor(0.1146, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2858041889502954
# #################################### 2 100 绝对误差 tensor(0.0245, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0117, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1408, dtype=torch.float64)   实验回归误差 tensor(0.0479, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3191, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.100146687177259
# ########################################### 2 100 绝对误差 tensor(1.2144, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1450, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2564, dtype=torch.float64)   实验回归误差 tensor(0.1153, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1417871114929161
# ######################################################### 2 100 绝对误差 tensor(0.2629, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(6.3328, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0128, dtype=torch.float64)   实验回归误差 tensor(0.1903, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0497482463470422
# ########################## 3 100 绝对误差 tensor(1.5355, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9519, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1633, dtype=torch.float64)   实验回归误差 tensor(0.1315, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.249555079284102
# ################################################################################# 3 100 绝对误差 tensor(0.7949, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6438, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2057, dtype=torch.float64)   实验回归误差 tensor(0.1152, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1697915977227638
# ############################################# 3 100 绝对误差 tensor(0.5539, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9863, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4916, dtype=torch.float64)   实验回归误差 tensor(0.0883, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.132119164388728
# ################################################################# 3 100 绝对误差 tensor(1.2158, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8150, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1914, dtype=torch.float64)   实验回归误差 tensor(0.1152, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1493609322753637
# ####################################### 3 100 绝对误差 tensor(2.6720, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8840, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0912, dtype=torch.float64)   实验回归误差 tensor(0.1117, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1281261598779355
# ################################################## 3 100 绝对误差 tensor(1.7656, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1040, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2063, dtype=torch.float64)   实验回归误差 tensor(0.1328, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2824651623246486
# ################################################# 3 100 绝对误差 tensor(1.6421, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1332, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1845, dtype=torch.float64)   实验回归误差 tensor(0.1624, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.340957956678178
# ###################################################### 3 100 绝对误差 tensor(0.2259, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0812, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1050, dtype=torch.float64)   实验回归误差 tensor(0.0728, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1913126431820675
# ################### 3 100 绝对误差 tensor(2.1103, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0469, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1452, dtype=torch.float64)   实验回归误差 tensor(0.1200, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3482120541282736
# ######################################################## 3 100 绝对误差 tensor(1.3190, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6989, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1517, dtype=torch.float64)   实验回归误差 tensor(0.1225, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1333711536480828
# ######### 1 100 绝对误差 tensor(0.0686, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1593, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5350, dtype=torch.float64)   实验回归误差 tensor(0.1361, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0017, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1263, dtype=torch.float64)   实验回归误差 tensor(0.0522, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.2765, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(25.6346, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0001, dtype=torch.float64)   实验回归误差 tensor(0.2861, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4111, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0
# ########### 1 100 绝对误差 tensor(0.1209, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5453, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8011, dtype=torch.float64)   实验回归误差 tensor(0.1852, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0883, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2203, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5565, dtype=torch.float64)   实验回归误差 tensor(0.1369, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ######### 1 100 绝对误差 tensor(0.1063, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5267, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8041, dtype=torch.float64)   实验回归误差 tensor(0.1320, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3840, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2753, dtype=torch.float64)   实验回归误差 tensor(0.0733, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0688, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1305, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4914, dtype=torch.float64)   实验回归误差 tensor(0.1069, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########### 1 100 绝对误差 tensor(0.1500, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4052, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9282, dtype=torch.float64)   实验回归误差 tensor(0.1967, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########### 1 100 绝对误差 tensor(0.0425, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0393, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2387, dtype=torch.float64)   实验回归误差 tensor(0.0903, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########################### 2 100 绝对误差 tensor(1.1092, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3255, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3175, dtype=torch.float64)   实验回归误差 tensor(0.1754, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0831695364369034
# ################################### 2 100 绝对误差 tensor(0.2101, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0513, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8167, dtype=torch.float64)   实验回归误差 tensor(0.1993, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.108761473437905
# ############################################################## 2 100 绝对误差 tensor(0.0243, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0086, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1012, dtype=torch.float64)   实验回归误差 tensor(0.0510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0485899419282063
# #################################################### 2 100 绝对误差 tensor(2.6801, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2583, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1262, dtype=torch.float64)   实验回归误差 tensor(0.1757, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1818601656577055
# #################################### 2 100 绝对误差 tensor(0.7693, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8792, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3900, dtype=torch.float64)   实验回归误差 tensor(0.1090, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.105623704932543
# ################### 2 100 绝对误差 tensor(1.2979, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0556, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2356, dtype=torch.float64)   实验回归误差 tensor(0.1665, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2372157351955828
# ########### 2 100 绝对误差 tensor(0.9087, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7798, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4861, dtype=torch.float64)   实验回归误差 tensor(0.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0814037734981363
# ###################################################### 2 100 绝对误差 tensor(0.3597, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2707, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2031, dtype=torch.float64)   实验回归误差 tensor(0.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1027331732939838
# ################## 2 100 绝对误差 tensor(0.0695, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0596, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2455, dtype=torch.float64)   实验回归误差 tensor(0.0925, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1740602340723163
# #################### 2 100 绝对误差 tensor(2.6403, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2778, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1497, dtype=torch.float64)   实验回归误差 tensor(0.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1807452174978448
# ############################################### 3 100 绝对误差 tensor(0.2207, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2100, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2288, dtype=torch.float64)   实验回归误差 tensor(0.0803, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3244455335971306
# ############################################## 3 100 绝对误差 tensor(0.9044, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6058, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1693, dtype=torch.float64)   实验回归误差 tensor(0.1494, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.253875892667079
# ################################################################ 3 100 绝对误差 tensor(0.9120, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9590, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5008, dtype=torch.float64)   实验回归误差 tensor(0.0962, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2078396795891306
# ########################################## 3 100 绝对误差 tensor(0.9404, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8231, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3024, dtype=torch.float64)   实验回归误差 tensor(0.1661, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2587986239005335
# ############################## 3 100 绝对误差 tensor(1.7610, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8887, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1567, dtype=torch.float64)   实验回归误差 tensor(0.1228, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2123004518136062
# ######################################################################################################### 3 100 绝对误差 tensor(0.1061, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0722, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1845, dtype=torch.float64)   实验回归误差 tensor(0.0856, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.158303735617275
# ############## 3 100 绝对误差 tensor(2.0448, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1361, dtype=torch.float64)   实验回归误差 tensor(0.1954, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.206882935161195
# ############# 3 100 绝对误差 tensor(3.5338, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0938, dtype=torch.float64)   实验回归误差 tensor(0.2138, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2865163041097132
# ############################################################ 3 100 绝对误差 tensor(0.3417, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1236, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1008, dtype=torch.float64)   实验回归误差 tensor(0.0601, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2106596869329613
# ######################################## 3 100 绝对误差 tensor(1.0003, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5767, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1980, dtype=torch.float64)   实验回归误差 tensor(0.1316, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.300573479019908
