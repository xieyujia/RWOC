# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############# 1 100 绝对误差 tensor(0.0018, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0025, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1416, dtype=torch.float64)   实验回归误差 tensor(0.0663, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0488, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5651, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7363, dtype=torch.float64)   实验回归误差 tensor(0.1732, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########### 1 100 绝对误差 tensor(0.0122, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0266, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1986, dtype=torch.float64)   实验回归误差 tensor(0.0736, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2884, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.0012, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2070, dtype=torch.float64)   实验回归误差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0530, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4046, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5583, dtype=torch.float64)   实验回归误差 tensor(0.1441, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ####################### 1 100 绝对误差 tensor(0.0146, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0094, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0808, dtype=torch.float64)   实验回归误差 tensor(0.0504, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0131, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0424, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3032, dtype=torch.float64)   实验回归误差 tensor(0.1102, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.3277, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.1663, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6260, dtype=torch.float64)   实验回归误差 tensor(0.1016, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0799, dtype=torch.float64)   实验回归误差 tensor(0.0511, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0047, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0040, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0810, dtype=torch.float64)   实验回归误差 tensor(0.0531, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ######################################################################################################### 2 100 绝对误差 tensor(0.0292, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0211, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0769, dtype=torch.float64)   实验回归误差 tensor(0.0390, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1160447743287083
# ###################################################### 2 100 绝对误差 tensor(0.9446, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0647, dtype=torch.float64)   实验回归误差 tensor(0.0912, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1521530015009471
# ############################## 2 100 绝对误差 tensor(0.2049, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2809, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1437, dtype=torch.float64)   实验回归误差 tensor(0.0798, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.206740593627838
# ######################################################### 2 100 绝对误差 tensor(0.6427, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5176, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0762, dtype=torch.float64)   实验回归误差 tensor(0.0957, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0783675538439967
# ################################################################## 2 100 绝对误差 tensor(0.4586, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5378, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1066, dtype=torch.float64)   实验回归误差 tensor(0.1288, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.08693463496577
# ################### 2 100 绝对误差 tensor(0.0309, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0213, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0704, dtype=torch.float64)   实验回归误差 tensor(0.0432, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1576, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1782207163767597
# ############### 2 100 绝对误差 tensor(1.6123, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0845, dtype=torch.float64)   实验回归误差 tensor(0.2782, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0789069720184596
# ######################### 2 100 绝对误差 tensor(0.5270, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2801, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2094, dtype=torch.float64)   实验回归误差 tensor(0.1836, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0793668217408203
# ################################################################# 3 100 绝对误差 tensor(1.9821, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0499, dtype=torch.float64)   实验回归误差 tensor(0.1312, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2034351473923561
# ########################## 3 100 绝对误差 tensor(1.4445, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8444, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0644, dtype=torch.float64)   实验回归误差 tensor(0.1258, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1755329675128423
# ################################################################################################################## 3 100 绝对误差 tensor(2.7338, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5394, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0594, dtype=torch.float64)   实验回归误差 tensor(0.1370, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2273076876912168
# ############################################### 3 100 绝对误差 tensor(0.0132, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0784, dtype=torch.float64)   实验回归误差 tensor(0.0463, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1530459149568666
# ############################## 3 100 绝对误差 tensor(2.4870, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0375, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0349, dtype=torch.float64)   实验回归误差 tensor(0.1485, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3285182513477507
# ################################# 3 100 绝对误差 tensor(0.8162, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8205, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0950, dtype=torch.float64)   实验回归误差 tensor(0.1139, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3400719662028233
# ######################################################################################### 3 100 绝对误差 tensor(0.7790, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1727, dtype=torch.float64)   实验回归误差 tensor(0.1868, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3851, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.2429767905670186
# ########################################################################################################### 3 100 绝对误差 tensor(1.6868, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6797, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0871, dtype=torch.float64)   实验回归误差 tensor(0.1700, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2186906665392698
# ########################################### 3 100 绝对误差 tensor(3.1858, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8212, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0242, dtype=torch.float64)   实验回归误差 tensor(0.1680, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2584841190826666
# #################################################################################################### 3 100 绝对误差 tensor(3.0906, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1399, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0342, dtype=torch.float64)   实验回归误差 tensor(0.1416, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2350108029191296
# ################ 1 100 绝对误差 tensor(0.0009, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0011, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1262, dtype=torch.float64)   实验回归误差 tensor(0.0708, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0241, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1341, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5413, dtype=torch.float64)   实验回归误差 tensor(0.1924, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(2.5121, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9588, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0748, dtype=torch.float64)   实验回归误差 tensor(0.2677, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ######### 1 100 绝对误差 tensor(0.0014, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0028, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1869, dtype=torch.float64)   实验回归误差 tensor(0.0872, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0155, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0319, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2046, dtype=torch.float64)   实验回归误差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3546, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0025, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0458, dtype=torch.float64)   实验回归误差 tensor(0.0334, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0075, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0049, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0639, dtype=torch.float64)   实验回归误差 tensor(0.0373, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0141, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1619, dtype=torch.float64)   实验回归误差 tensor(0.0720, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0568, dtype=torch.float64)   实验回归误差 tensor(0.0412, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0092, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0078, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0877, dtype=torch.float64)   实验回归误差 tensor(0.0512, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3114, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########################### 2 100 绝对误差 tensor(1.1105, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0391, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0858, dtype=torch.float64)   实验回归误差 tensor(0.1228, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2339165364153677
# ###################################################################### 2 100 绝对误差 tensor(0.0417, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0319, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0631, dtype=torch.float64)   实验回归误差 tensor(0.0427, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2235, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.1950702086706768
# ################################################################# 2 100 绝对误差 tensor(0.1567, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1859, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1351, dtype=torch.float64)   实验回归误差 tensor(0.0832, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1752042977584907
# ############ 2 100 绝对误差 tensor(0.5383, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6887, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2912, dtype=torch.float64)   实验回归误差 tensor(0.2136, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1296778385827408
# ############################################################################## 2 100 绝对误差 tensor(0.0850, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0857, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0870, dtype=torch.float64)   实验回归误差 tensor(0.0495, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3335, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.168519925628992
# ################### 2 100 绝对误差 tensor(2.0630, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8594, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0424, dtype=torch.float64)   实验回归误差 tensor(0.1249, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0548627349720772
# ####################################################################### 2 100 绝对误差 tensor(0.0677, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4706, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5311, dtype=torch.float64)   实验回归误差 tensor(0.1007, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1100596073464521
# ################## 2 100 绝对误差 tensor(2.1742, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4183, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0652, dtype=torch.float64)   实验回归误差 tensor(0.1941, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0925646674280705
# ######################################################################### 2 100 绝对误差 tensor(3.5330, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6210, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0481, dtype=torch.float64)   实验回归误差 tensor(0.1601, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2177007709065795
# ################### 2 100 绝对误差 tensor(0.6205, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9473, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1626, dtype=torch.float64)   实验回归误差 tensor(0.1629, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0835131892663812
# ############################################################## 3 100 绝对误差 tensor(1.4940, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6464, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0517, dtype=torch.float64)   实验回归误差 tensor(0.0824, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2785041364808785
# ################################################################ 3 100 绝对误差 tensor(1.3906, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7524, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0544, dtype=torch.float64)   实验回归误差 tensor(0.1300, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2503343174625703
# ############################################################################ 3 100 绝对误差 tensor(0.9160, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7800, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2072, dtype=torch.float64)   实验回归误差 tensor(0.2020, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2449641453670317
# ########################## 3 100 绝对误差 tensor(1.0201, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5778, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0631, dtype=torch.float64)   实验回归误差 tensor(0.1200, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3917238892866057
# ################################################ 3 100 绝对误差 tensor(0.4332, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8126, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1955, dtype=torch.float64)   实验回归误差 tensor(0.1523, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2597397691603678
# ########################################################## 3 100 绝对误差 tensor(0.7997, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4323, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0453, dtype=torch.float64)   实验回归误差 tensor(0.1001, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2135101966820439
# ###################################################################### 3 100 绝对误差 tensor(1.0486, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6363, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0604, dtype=torch.float64)   实验回归误差 tensor(0.0995, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3408662018953414
# ###################################### 3 100 绝对误差 tensor(0.9089, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9611, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1022, dtype=torch.float64)   实验回归误差 tensor(0.0844, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2195046438791142
# ####################### 3 100 绝对误差 tensor(1.3201, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7217, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0556, dtype=torch.float64)   实验回归误差 tensor(0.1304, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1738904689945207
# ##################################################################### 3 100 绝对误差 tensor(0.0394, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0219, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0520, dtype=torch.float64)   实验回归误差 tensor(0.0302, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2570, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1066562890092047
# ################ 1 100 绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0608, dtype=torch.float64)   实验回归误差 tensor(0.0368, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0106, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0128, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1275, dtype=torch.float64)   实验回归误差 tensor(0.0625, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.0077, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0513, dtype=torch.float64)   实验回归误差 tensor(0.0344, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1916, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0726, dtype=torch.float64)   实验回归误差 tensor(0.0434, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2410, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0052, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0167, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3312, dtype=torch.float64)   实验回归误差 tensor(0.1145, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################ 1 100 绝对误差 tensor(0.0380, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2064, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4927, dtype=torch.float64)   实验回归误差 tensor(0.1065, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3918, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0672, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5278, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8805, dtype=torch.float64)   实验回归误差 tensor(0.1863, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4093, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 96   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0161, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0250, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1481, dtype=torch.float64)   实验回归误差 tensor(0.0744, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.0047, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0031, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0702, dtype=torch.float64)   实验回归误差 tensor(0.0410, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1916, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0151, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0092, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0571, dtype=torch.float64)   实验回归误差 tensor(0.0374, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1916, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 2 100 绝对误差 tensor(0.4709, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6621, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1297, dtype=torch.float64)   实验回归误差 tensor(0.1424, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1593544849627981
# #################### 2 100 绝对误差 tensor(0.8948, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7429, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0829, dtype=torch.float64)   实验回归误差 tensor(0.1059, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0747290986147455
# #################################################### 2 100 绝对误差 tensor(0.2281, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3287, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1173, dtype=torch.float64)   实验回归误差 tensor(0.0846, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.4003107555972856
# ############# 2 100 绝对误差 tensor(2.6707, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0752, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0375, dtype=torch.float64)   实验回归误差 tensor(0.1263, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0388802496733904
# ############################################### 2 100 绝对误差 tensor(0.8228, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0549, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1519, dtype=torch.float64)   实验回归误差 tensor(0.2918, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1325311620499179
# ############################## 2 100 绝对误差 tensor(0.6365, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0688, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2186, dtype=torch.float64)   实验回归误差 tensor(0.1577, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.166798913933921
# ################## 2 100 绝对误差 tensor(0.4008, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2289, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0535, dtype=torch.float64)   实验回归误差 tensor(0.0817, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0974077904980537
# ######################################### 2 100 绝对误差 tensor(3.0835, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3779, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0492, dtype=torch.float64)   实验回归误差 tensor(0.2087, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1815429431235265
# ########################## 2 100 绝对误差 tensor(0.0141, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0528, dtype=torch.float64)   实验回归误差 tensor(0.0351, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1958731408132492
# ##################################################################################### 3 100 绝对误差 tensor(1.7719, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1810, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0674, dtype=torch.float64)   实验回归误差 tensor(0.1446, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2983875742875544
# ####################################################### 3 100 绝对误差 tensor(0.8267, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6613, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0672, dtype=torch.float64)   实验回归误差 tensor(0.1000, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2499703329593463
# ########################### 3 100 绝对误差 tensor(1.7046, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2095, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0674, dtype=torch.float64)   实验回归误差 tensor(0.1429, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2042455545808273
# ####################################################### 3 100 绝对误差 tensor(3.7986, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3411, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0369, dtype=torch.float64)   实验回归误差 tensor(0.1712, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.468937883800197
# #################################### 3 100 绝对误差 tensor(0.1831, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1448, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0795, dtype=torch.float64)   实验回归误差 tensor(0.0624, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2154236708291273
# ################################################################################################################# 3 100 绝对误差 tensor(0.6552, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3365, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0587, dtype=torch.float64)   实验回归误差 tensor(0.0834, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2761268716371303
# ############### 3 100 绝对误差 tensor(0.6991, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2870, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1847, dtype=torch.float64)   实验回归误差 tensor(0.2180, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3982, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.1938461889380565
# ######################### 3 100 绝对误差 tensor(1.3324, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9637, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0649, dtype=torch.float64)   实验回归误差 tensor(0.0849, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2026533432794817
# ########################### 3 100 绝对误差 tensor(0.4655, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5393, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1179, dtype=torch.float64)   实验回归误差 tensor(0.0975, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1707963514446789
# ################################# 3 100 绝对误差 tensor(0.7798, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0177, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1311, dtype=torch.float64)   实验回归误差 tensor(0.1032, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1159010150981492
# ########### 1 100 绝对误差 tensor(0.0105, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0447, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3577, dtype=torch.float64)   实验回归误差 tensor(0.1095, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########## 1 100 绝对误差 tensor(0.0266, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1179, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3600, dtype=torch.float64)   实验回归误差 tensor(0.1097, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3345, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 96   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0015, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1429, dtype=torch.float64)   实验回归误差 tensor(0.0683, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2884, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0324, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1108, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3375, dtype=torch.float64)   实验回归误差 tensor(0.1247, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0822, dtype=torch.float64)   实验回归误差 tensor(0.0466, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2083, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1101, dtype=torch.float64)   实验回归误差 tensor(0.0503, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0034, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0018, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0481, dtype=torch.float64)   实验回归误差 tensor(0.0316, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0048, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0974, dtype=torch.float64)   实验回归误差 tensor(0.0492, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0001, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(6.9503e-05, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0477, dtype=torch.float64)   实验回归误差 tensor(0.0308, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 1 100 绝对误差 tensor(0.0097, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1676, dtype=torch.float64)   实验回归误差 tensor(0.0704, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3342, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############### 2 100 绝对误差 tensor(0.6925, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1776, dtype=torch.float64)   实验回归误差 tensor(0.1135, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.110543992890399
# ################################################# 2 100 绝对误差 tensor(0.0460, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0235, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0460, dtype=torch.float64)   实验回归误差 tensor(0.0316, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1916, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1118798915960608
# ############ 2 100 绝对误差 tensor(0.1671, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4679, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2555, dtype=torch.float64)   实验回归误差 tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1362663359565568
# ############################################ 2 100 绝对误差 tensor(0.0580, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2955, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4498, dtype=torch.float64)   实验回归误差 tensor(0.1078, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.102337651487521
# ############### 2 100 绝对误差 tensor(1.2325, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1329, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0895, dtype=torch.float64)   实验回归误差 tensor(0.2438, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.069577714006727
# ##################################### 2 100 绝对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0723, dtype=torch.float64)   实验回归误差 tensor(0.0421, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2570, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0663846503585193
# ####################################################### 2 100 绝对误差 tensor(0.4204, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2974, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0674, dtype=torch.float64)   实验回归误差 tensor(0.0726, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1955832443942687
# ###################################################################################################################### 2 100 绝对误差 tensor(0.4363, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6150, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1587, dtype=torch.float64)   实验回归误差 tensor(0.1653, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1565855534698106
# ################### 2 100 绝对误差 tensor(1.0876, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1707, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0981, dtype=torch.float64)   实验回归误差 tensor(0.1651, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0577965745212128
# ############### 2 100 绝对误差 tensor(0.2101, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2268, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1214, dtype=torch.float64)   实验回归误差 tensor(0.0815, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0416670085922144
# ############# 3 100 绝对误差 tensor(0.6917, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0885, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1806, dtype=torch.float64)   实验回归误差 tensor(0.1393, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2000344589495944
# ############### 3 100 绝对误差 tensor(1.1665, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9378, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0714, dtype=torch.float64)   实验回归误差 tensor(0.1511, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.121534338177543
# #################################################################### 3 100 绝对误差 tensor(2.1333, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4214, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0634, dtype=torch.float64)   实验回归误差 tensor(0.1533, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1846075701260974
# ######################################## 3 100 绝对误差 tensor(1.6458, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3418, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0710, dtype=torch.float64)   实验回归误差 tensor(0.1170, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.3472884716207427
# ####################### 3 100 绝对误差 tensor(2.6820, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3373, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0551, dtype=torch.float64)   实验回归误差 tensor(0.1938, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0608528434617475
# ######################### 3 100 绝对误差 tensor(0.0118, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0532, dtype=torch.float64)   实验回归误差 tensor(0.0338, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2083, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.4174615385899405
# ########################################################### 3 100 绝对误差 tensor(0.2024, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1014, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0573, dtype=torch.float64)   实验回归误差 tensor(0.0495, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2884, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1256133946513964
# ############################################ 3 100 绝对误差 tensor(0.3251, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1360, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0393, dtype=torch.float64)   实验回归误差 tensor(0.0470, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2951361346983292
# ######################################################################################## 3 100 绝对误差 tensor(0.2480, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1990, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0768, dtype=torch.float64)   实验回归误差 tensor(0.0708, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1774883836598355
# ######################### 3 100 绝对误差 tensor(2.6584, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0895, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0509, dtype=torch.float64)   实验回归误差 tensor(0.2226, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1642782487482657
# ############## 1 100 绝对误差 tensor(0.0138, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0668, dtype=torch.float64)   实验回归误差 tensor(0.0475, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ######## 1 100 绝对误差 tensor(0.0156, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0061, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0316, dtype=torch.float64)   实验回归误差 tensor(0.0243, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0296, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ##################### 1 100 绝对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0030, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0606, dtype=torch.float64)   实验回归误差 tensor(0.0388, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################### 1 100 绝对误差 tensor(0.0058, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1727, dtype=torch.float64)   实验回归误差 tensor(0.0693, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2884, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ################# 1 100 绝对误差 tensor(0.0088, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0125, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1498, dtype=torch.float64)   实验回归误差 tensor(0.0780, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0030, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0020, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0613, dtype=torch.float64)   实验回归误差 tensor(0.0418, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ############ 1 100 绝对误差 tensor(0.0020, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2178, dtype=torch.float64)   实验回归误差 tensor(0.0792, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3342, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# #### 1 100 绝对误差 tensor(0.0796, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(12.8022, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0010, dtype=torch.float64)   实验回归误差 tensor(0.1017, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4003, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 92   条件数 1.0
# ############## 1 100 绝对误差 tensor(0.0571, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5004, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6504, dtype=torch.float64)   实验回归误差 tensor(0.1439, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3772, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98   条件数 1.0
# ############# 1 100 绝对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0074, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0920, dtype=torch.float64)   实验回归误差 tensor(0.0495, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2884, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0
# ########################################################################### 2 100 绝对误差 tensor(0.0172, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0131, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0697, dtype=torch.float64)   实验回归误差 tensor(0.0460, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0841246726367662
# ######################################### 2 100 绝对误差 tensor(1.2744, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9982, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0529, dtype=torch.float64)   实验回归误差 tensor(0.1434, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2528064065596802
# ###################################### 2 100 绝对误差 tensor(0.0162, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0155, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0922, dtype=torch.float64)   实验回归误差 tensor(0.0489, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2315046228937034
# ################################################################################################## 2 100 绝对误差 tensor(1.2967, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9633, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0828, dtype=torch.float64)   实验回归误差 tensor(0.1531, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1938389517621912
# ########################## 2 100 绝对误差 tensor(0.3660, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3632, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1034, dtype=torch.float64)   实验回归误差 tensor(0.0928, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.204958620685606
# ######################################################### 2 100 绝对误差 tensor(1.7025, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5362, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0765, dtype=torch.float64)   实验回归误差 tensor(0.1347, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.150357736069846
# ############################################## 2 100 绝对误差 tensor(5.0230, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4732, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0327, dtype=torch.float64)   实验回归误差 tensor(0.2067, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.024653835602049
# ########################## 2 100 绝对误差 tensor(2.0945, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3552, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0686, dtype=torch.float64)   实验回归误差 tensor(0.1330, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.4363326378318984
# ############### 2 100 绝对误差 tensor(0.0457, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0464, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0964, dtype=torch.float64)   实验回归误差 tensor(0.0520, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.0623672224578922
# #################### 2 100 绝对误差 tensor(0.0215, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0095, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0371, dtype=torch.float64)   实验回归误差 tensor(0.0254, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1267865635226075
# ################################################################################################################################ 3 100 绝对误差 tensor(0.0480, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0504, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1076, dtype=torch.float64)   实验回归误差 tensor(0.0478, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.203475591027283
# ############################################################################################### 3 100 绝对误差 tensor(0.0317, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0214, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0598, dtype=torch.float64)   实验回归误差 tensor(0.0337, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2014553747966843
# ######################### 3 100 绝对误差 tensor(0.2910, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3929, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1297, dtype=torch.float64)   实验回归误差 tensor(0.1112, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.131703250942833
# ######################################################################### 3 100 绝对误差 tensor(0.4444, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5972, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1600, dtype=torch.float64)   实验回归误差 tensor(0.0824, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1468419739924907
# ############################################################### 3 100 绝对误差 tensor(0.7360, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9310, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1187, dtype=torch.float64)   实验回归误差 tensor(0.1565, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2996390846182546
# ############################ 3 100 绝对误差 tensor(2.5537, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3298, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0511, dtype=torch.float64)   实验回归误差 tensor(0.1255, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1186671555567125
# ########################################################################################################### 3 100 绝对误差 tensor(1.5724, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8350, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0560, dtype=torch.float64)   实验回归误差 tensor(0.1729, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1927195433827942
# ########################## 3 100 绝对误差 tensor(0.1973, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1350, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0679, dtype=torch.float64)   实验回归误差 tensor(0.0647, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.2194995714330799
# ################### 3 100 绝对误差 tensor(1.8262, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6704, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0428, dtype=torch.float64)   实验回归误差 tensor(0.1061, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1966924633428166
# ##################################################################################################################################### 3 100 绝对误差 tensor(3.3947, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9254, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0650, dtype=torch.float64)   实验回归误差 tensor(0.1443, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100   条件数 1.1957360116013178
