# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(150,151,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.002
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############### 1 150 绝对误差 tensor(0.0111, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0669, dtype=torch.float64)   实验回归误差 tensor(0.0348, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2754, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0104, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0151, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1513, dtype=torch.float64)   实验回归误差 tensor(0.0527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3515, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0027, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0039, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1347, dtype=torch.float64)   实验回归误差 tensor(0.0493, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0231, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0623, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2646, dtype=torch.float64)   实验回归误差 tensor(0.0857, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0001, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0001, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0899, dtype=torch.float64)   实验回归误差 tensor(0.0451, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3317, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################### 1 150 绝对误差 tensor(0.0159, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0080, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0542, dtype=torch.float64)   实验回归误差 tensor(0.0303, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0144, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0271, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1807, dtype=torch.float64)   实验回归误差 tensor(0.0632, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0059, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0054, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0969, dtype=torch.float64)   实验回归误差 tensor(0.0436, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0040, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1593, dtype=torch.float64)   实验回归误差 tensor(0.0545, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3652, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0139, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0641, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4279, dtype=torch.float64)   实验回归误差 tensor(0.1042, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3895, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.0
# ################################################ 2 150 绝对误差 tensor(0.0443, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0594, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1133, dtype=torch.float64)   实验回归误差 tensor(0.0510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3661, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0522278222209676
# ####################### 2 150 绝对误差 tensor(1.5413, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0903, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0691, dtype=torch.float64)   实验回归误差 tensor(0.1082, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1939577129759542
# ################################## 2 150 绝对误差 tensor(0.2161, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6962, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2697, dtype=torch.float64)   实验回归误差 tensor(0.0970, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4080, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0890869387259143
# ############################################################################################################# 2 150 绝对误差 tensor(0.0584, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0598, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0914, dtype=torch.float64)   实验回归误差 tensor(0.0468, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.11231282606443
# ############################# 2 150 绝对误差 tensor(0.1198, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3264, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3006, dtype=torch.float64)   实验回归误差 tensor(0.0873, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0954012612503676
# ################### 2 150 绝对误差 tensor(2.8326, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4075, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0508, dtype=torch.float64)   实验回归误差 tensor(0.1171, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.118169011751377
# ####################################################################################################### 2 150 绝对误差 tensor(0.0620, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0696, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1288, dtype=torch.float64)   实验回归误差 tensor(0.0548, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3466, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1900179037381333
# ############################################ 2 150 绝对误差 tensor(0.0112, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0611, dtype=torch.float64)   实验回归误差 tensor(0.0335, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1133869224838975
# ################################################################################################################################################## 2 150 绝对误差 tensor(2.3963, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6722, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0267, dtype=torch.float64)   实验回归误差 tensor(0.0957, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0746663275212607
# ################################################## 2 150 绝对误差 tensor(1.5039, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5086, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1058, dtype=torch.float64)   实验回归误差 tensor(0.1580, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.031860426400992
# ################# 3 150 绝对误差 tensor(0.6336, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6792, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1165, dtype=torch.float64)   实验回归误差 tensor(0.1427, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2046808110676894
# ############################################################# 3 150 绝对误差 tensor(0.7985, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7218, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0936, dtype=torch.float64)   实验回归误差 tensor(0.1081, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1840360679376691
# ############################################################################# 3 150 绝对误差 tensor(1.3472, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9360, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0628, dtype=torch.float64)   实验回归误差 tensor(0.0873, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1363005102802914
# ########################################################################################### 3 150 绝对误差 tensor(1.7641, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6546, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1017, dtype=torch.float64)   实验回归误差 tensor(0.1333, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2790419714248331
# ################################################################# 3 150 绝对误差 tensor(3.3357, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9930, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0390, dtype=torch.float64)   实验回归误差 tensor(0.1619, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.304059824614537
# ########################################### 3 150 绝对误差 tensor(0.9603, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6932, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0746, dtype=torch.float64)   实验回归误差 tensor(0.1157, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0917352460837928
# ########################################################### 3 150 绝对误差 tensor(0.0585, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0593, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1150, dtype=torch.float64)   实验回归误差 tensor(0.0480, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1749386411187157
# ######################################################################################## 3 150 绝对误差 tensor(1.2588, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0145, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0821, dtype=torch.float64)   实验回归误差 tensor(0.1461, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.175574950277244
# ######################################################################################################### 3 150 绝对误差 tensor(1.9361, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3792, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0634, dtype=torch.float64)   实验回归误差 tensor(0.1132, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1590393116769953
# ############################################################################################################## 3 150 绝对误差 tensor(2.2508, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2876, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0703, dtype=torch.float64)   实验回归误差 tensor(0.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2392640669622461
# ############# 1 150 绝对误差 tensor(0.0084, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0052, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0596, dtype=torch.float64)   实验回归误差 tensor(0.0354, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2702, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0015, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2787, dtype=torch.float64)   实验回归误差 tensor(0.0829, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0014, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1411, dtype=torch.float64)   实验回归误差 tensor(0.0627, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0127, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0197, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1342, dtype=torch.float64)   实验回归误差 tensor(0.0497, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0638, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1767, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8823, dtype=torch.float64)   实验回归误差 tensor(0.2150, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3971, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0182, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2601, dtype=torch.float64)   实验回归误差 tensor(0.0869, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0305, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1294, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3905, dtype=torch.float64)   实验回归误差 tensor(0.0893, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.7174, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2565, dtype=torch.float64)   实验回归误差 tensor(0.1010, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4096, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0298, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1533, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4931, dtype=torch.float64)   实验回归误差 tensor(0.1227, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.1380, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.8339, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9571, dtype=torch.float64)   实验回归误差 tensor(0.1856, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4072, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 142   条件数 1.0
# ################################### 2 150 绝对误差 tensor(0.0133, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0036, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0255, dtype=torch.float64)   实验回归误差 tensor(0.0180, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.103904545051949
# ########################################################### 2 150 绝对误差 tensor(1.4852, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6946, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0491, dtype=torch.float64)   实验回归误差 tensor(0.1244, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0645920707914462
# ################################################################################################################################# 2 150 绝对误差 tensor(0.2385, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1998, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0773, dtype=torch.float64)   实验回归误差 tensor(0.0593, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0316149921594138
# ############################################ 2 150 绝对误差 tensor(0.0196, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0113, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0577, dtype=torch.float64)   实验回归误差 tensor(0.0311, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1412127948225446
# ######################### 2 150 绝对误差 tensor(0.1724, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3756, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2084, dtype=torch.float64)   实验回归误差 tensor(0.1133, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.066998377654489
# ################################### 2 150 绝对误差 tensor(0.2507, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4103, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4920, dtype=torch.float64)   实验回归误差 tensor(0.2134, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4011, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.065541868570244
# ##################################################################################################### 2 150 绝对误差 tensor(0.0024, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1800, dtype=torch.float64)   实验回归误差 tensor(0.0552, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3805, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0420152625454817
# ############################################ 2 150 绝对误差 tensor(0.8820, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5219, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0586, dtype=torch.float64)   实验回归误差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0868776959447213
# ################################################################################################ 2 150 绝对误差 tensor(1.2440, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6265, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0539, dtype=torch.float64)   实验回归误差 tensor(0.1380, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.093202484912315
# ############################### 2 150 绝对误差 tensor(2.6628, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2945, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0502, dtype=torch.float64)   实验回归误差 tensor(0.1811, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1014988135388866
# ################################################################ 3 150 绝对误差 tensor(1.3154, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1206, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0835, dtype=torch.float64)   实验回归误差 tensor(0.0936, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1084081709074693
# ######################################### 3 150 绝对误差 tensor(2.6651, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9297, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0347, dtype=torch.float64)   实验回归误差 tensor(0.1102, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2899837609004354
# #################################################################################### 3 150 绝对误差 tensor(0.0580, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0410, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0642, dtype=torch.float64)   实验回归误差 tensor(0.0373, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3216, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0940693576585003
# ######################################################################## 3 150 绝对误差 tensor(2.0394, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1185, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0504, dtype=torch.float64)   实验回归误差 tensor(0.1014, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2552230925373025
# ############################################################ 3 150 绝对误差 tensor(2.6767, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9461, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0383, dtype=torch.float64)   实验回归误差 tensor(0.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3788, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1903343805786881
# ################################################### 3 150 绝对误差 tensor(2.0500, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0560, dtype=torch.float64)   实验回归误差 tensor(0.1493, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1100147001653167
# ################################################################## 3 150 绝对误差 tensor(0.0102, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0046, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0484, dtype=torch.float64)   实验回归误差 tensor(0.0289, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2147875279784304
# ################################################ 3 150 绝对误差 tensor(3.3331, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9661, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0302, dtype=torch.float64)   实验回归误差 tensor(0.1733, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.242275265779741
# ################################################################################################# 3 150 绝对误差 tensor(0.9936, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4450, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0421, dtype=torch.float64)   实验回归误差 tensor(0.0927, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1507730445039481
# ################################################### 3 150 绝对误差 tensor(1.8846, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6816, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0330, dtype=torch.float64)   实验回归误差 tensor(0.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.17525860803184
# ############## 1 150 绝对误差 tensor(0.0188, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0380, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1934, dtype=torch.float64)   实验回归误差 tensor(0.0680, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0047, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0064, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1295, dtype=torch.float64)   实验回归误差 tensor(0.0506, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0127, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0141, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1150, dtype=torch.float64)   实验回归误差 tensor(0.0554, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2858, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0188, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0998, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4453, dtype=torch.float64)   实验回归误差 tensor(0.0850, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3930, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0378, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4049, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7492, dtype=torch.float64)   实验回归误差 tensor(0.1443, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3974, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 142   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0138, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0146, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0988, dtype=torch.float64)   实验回归误差 tensor(0.0524, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0092, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0106, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1180, dtype=torch.float64)   实验回归误差 tensor(0.0501, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0017, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0031, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1913, dtype=torch.float64)   实验回归误差 tensor(0.0553, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3544, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0017, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0563, dtype=torch.float64)   实验回归误差 tensor(0.0316, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2437, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0264, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1812, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5743, dtype=torch.float64)   实验回归误差 tensor(0.1229, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3607, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############################# 2 150 绝对误差 tensor(1.0550, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8174, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0765, dtype=torch.float64)   实验回归误差 tensor(0.1161, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1691044729422728
# ####################### 2 150 绝对误差 tensor(1.4588, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6857, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0469, dtype=torch.float64)   实验回归误差 tensor(0.1393, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0374854505545645
# ############################### 2 150 绝对误差 tensor(0.0128, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0184, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1376, dtype=torch.float64)   实验回归误差 tensor(0.0542, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1529710781804103
# ###################################################################### 2 150 绝对误差 tensor(2.0795, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4434, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0722, dtype=torch.float64)   实验回归误差 tensor(0.1453, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1254543534022687
# ########################################## 2 150 绝对误差 tensor(0.2698, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2284, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0790, dtype=torch.float64)   实验回归误差 tensor(0.0693, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3709, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1256846481604468
# ############## 2 150 绝对误差 tensor(0.0154, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0113, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0680, dtype=torch.float64)   实验回归误差 tensor(0.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2034358107207894
# ############################################################## 2 150 绝对误差 tensor(0.6085, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5164, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0892, dtype=torch.float64)   实验回归误差 tensor(0.0952, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1775372873077288
# ##################################################################################################################### 2 150 绝对误差 tensor(2.1387, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9863, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0434, dtype=torch.float64)   实验回归误差 tensor(0.1002, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1138318574653034
# ################################### 2 150 绝对误差 tensor(0.8625, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9535, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1095, dtype=torch.float64)   实验回归误差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.169377162346737
# ############################ 2 150 绝对误差 tensor(1.7826, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6428, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0420, dtype=torch.float64)   实验回归误差 tensor(0.1507, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1267402038534489
# #################################### 3 150 绝对误差 tensor(2.5155, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0040, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0401, dtype=torch.float64)   实验回归误差 tensor(0.0867, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1467764644983212
# ####################################### 3 150 绝对误差 tensor(0.0203, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0127, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0653, dtype=torch.float64)   实验回归误差 tensor(0.0355, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2776349178133088
# ####################################################### 3 150 绝对误差 tensor(1.2382, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7207, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0567, dtype=torch.float64)   实验回归误差 tensor(0.0974, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0759168026975254
# ############################################################ 3 150 绝对误差 tensor(1.5668, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9031, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0528, dtype=torch.float64)   实验回归误差 tensor(0.0755, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1365170389901194
# ########################################################################### 3 150 绝对误差 tensor(0.5890, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0758, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1728, dtype=torch.float64)   实验回归误差 tensor(0.1233, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.16725061196769
# ################################################################################################# 3 150 绝对误差 tensor(1.1606, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6138, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0520, dtype=torch.float64)   实验回归误差 tensor(0.0977, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1123880758547626
# ###################################################### 3 150 绝对误差 tensor(0.2231, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1799, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0883, dtype=torch.float64)   实验回归误差 tensor(0.0725, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.1615091273707963
# ###################################################### 3 150 绝对误差 tensor(0.2490, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5109, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1988, dtype=torch.float64)   实验回归误差 tensor(0.0948, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1531044727256214
# ############################################## 3 150 绝对误差 tensor(0.3691, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5049, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1528, dtype=torch.float64)   实验回归误差 tensor(0.0955, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2146401691537354
# ################################################################################### 3 150 绝对误差 tensor(0.4671, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2518, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0549, dtype=torch.float64)   实验回归误差 tensor(0.0600, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1691707650748706
# ################# 1 150 绝对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0007, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0972, dtype=torch.float64)   实验回归误差 tensor(0.0484, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3009, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0097, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0121, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1207, dtype=torch.float64)   实验回归误差 tensor(0.0499, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0179, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0094, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0502, dtype=torch.float64)   实验回归误差 tensor(0.0275, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2437, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0029, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0024, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0842, dtype=torch.float64)   实验回归误差 tensor(0.0366, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3064, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0184, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0734, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3628, dtype=torch.float64)   实验回归误差 tensor(0.0844, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0277, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0545, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2087, dtype=torch.float64)   实验回归误差 tensor(0.0736, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3748, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0093, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0089, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0997, dtype=torch.float64)   实验回归误差 tensor(0.0486, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0374, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3106, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6446, dtype=torch.float64)   实验回归误差 tensor(0.1182, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4006, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 142   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0013, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0017, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1242, dtype=torch.float64)   实验回归误差 tensor(0.0582, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ######### 1 150 绝对误差 tensor(0.0070, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0084, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1025, dtype=torch.float64)   实验回归误差 tensor(0.0501, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ###################################################################################################### 2 150 绝对误差 tensor(0.0149, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0074, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0487, dtype=torch.float64)   实验回归误差 tensor(0.0292, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2275, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1519201597052633
# ############################################################################# 2 150 绝对误差 tensor(0.8213, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8446, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1244, dtype=torch.float64)   实验回归误差 tensor(0.1033, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4047, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0981992599980275
# ################################################################################ 2 150 绝对误差 tensor(0.6437, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3127, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2079, dtype=torch.float64)   实验回归误差 tensor(0.1137, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0394386995659937
# ############################### 2 150 绝对误差 tensor(0.2913, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2081, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0664, dtype=torch.float64)   实验回归误差 tensor(0.0616, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.081553458574958
# ############################################################################################################################################### 2 150 绝对误差 tensor(0.3839, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5354, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1404, dtype=torch.float64)   实验回归误差 tensor(0.1410, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.11162723263734
# ############################################################################# 2 150 绝对误差 tensor(0.4968, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9757, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1977, dtype=torch.float64)   实验回归误差 tensor(0.1173, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0211234126206685
# #################################################### 2 150 绝对误差 tensor(0.2190, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7391, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2604, dtype=torch.float64)   实验回归误差 tensor(0.0853, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2214736311992795
# ############# 2 150 绝对误差 tensor(0.1234, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0745, dtype=torch.float64)   实验回归误差 tensor(0.0492, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.017096794499776
# ################ 2 150 绝对误差 tensor(0.8218, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0515, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1201, dtype=torch.float64)   实验回归误差 tensor(0.1270, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2068566827020446
# ######################################################### 2 150 绝对误差 tensor(0.1109, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1604, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8153, dtype=torch.float64)   实验回归误差 tensor(0.1289, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3930, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   条件数 1.029851383396001
# ######################################## 3 150 绝对误差 tensor(2.4806, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1094, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0421, dtype=torch.float64)   实验回归误差 tensor(0.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2163578434434874
# ######################### 3 150 绝对误差 tensor(0.8124, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7001, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0960, dtype=torch.float64)   实验回归误差 tensor(0.0759, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1402376556055327
# ################################# 3 150 绝对误差 tensor(0.6226, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0936, dtype=torch.float64)   实验回归误差 tensor(0.0745, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1533589669489954
# ###################################################################################################################################################################### 3 150 绝对误差 tensor(1.9432, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1516, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0601, dtype=torch.float64)   实验回归误差 tensor(0.1205, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2249551402836396
# ####################################################### 3 150 绝对误差 tensor(2.7090, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5185, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0560, dtype=torch.float64)   实验回归误差 tensor(0.1614, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1977633511861117
# ##################################################### 3 150 绝对误差 tensor(2.5535, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2962, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0565, dtype=torch.float64)   实验回归误差 tensor(0.1537, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1620048711455957
# ############################################################################################################################################################## 3 150 绝对误差 tensor(1.8474, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5815, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0884, dtype=torch.float64)   实验回归误差 tensor(0.1205, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0987236204418487
# ############################################################################################### 3 150 绝对误差 tensor(1.1664, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8495, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0752, dtype=torch.float64)   实验回归误差 tensor(0.0883, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0883809581603354
# ############################################################################################################################################ 3 150 绝对误差 tensor(0.6770, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3480, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0529, dtype=torch.float64)   实验回归误差 tensor(0.0863, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.3559232367301297
# ##################### 3 150 绝对误差 tensor(0.5391, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9726, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1923, dtype=torch.float64)   实验回归误差 tensor(0.1142, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2198307018774872
# ############ 1 150 绝对误差 tensor(0.0035, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0103, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2984, dtype=torch.float64)   实验回归误差 tensor(0.0896, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.0163, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0353, dtype=torch.float64)   实验回归误差 tensor(0.0200, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2220, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0086, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0153, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1809, dtype=torch.float64)   实验回归误差 tensor(0.0584, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0058, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0515, dtype=torch.float64)   实验回归误差 tensor(0.0324, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1688, dtype=torch.float64)   实验回归误差 tensor(0.0553, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0056, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1207, dtype=torch.float64)   实验回归误差 tensor(0.0537, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3317, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0110, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0249, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2024, dtype=torch.float64)   实验回归误差 tensor(0.0592, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.0255, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0911, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3742, dtype=torch.float64)   实验回归误差 tensor(0.1006, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0029, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1617, dtype=torch.float64)   实验回归误差 tensor(0.0824, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(1.4651, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0193, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1251, dtype=torch.float64)   实验回归误差 tensor(0.1163, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############################################################################################ 2 150 绝对误差 tensor(3.6721, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4427, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0445, dtype=torch.float64)   实验回归误差 tensor(0.1243, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1280466040031099
# ################################################################################################################## 2 150 绝对误差 tensor(0.0530, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0566, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1053, dtype=torch.float64)   实验回归误差 tensor(0.0495, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3216, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2676166551527386
# ################################################### 2 150 绝对误差 tensor(0.5864, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5397, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0939, dtype=torch.float64)   实验回归误差 tensor(0.0719, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0559699973824546
# ################################# 2 150 绝对误差 tensor(0.0034, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0839, dtype=torch.float64)   实验回归误差 tensor(0.0423, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2910, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1615809921283804
# ############### 2 150 绝对误差 tensor(1.2967, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1605, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0923, dtype=torch.float64)   实验回归误差 tensor(0.1144, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0561937748502621
# ################# 2 150 绝对误差 tensor(0.1837, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4074, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2222, dtype=torch.float64)   实验回归误差 tensor(0.0783, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0608753465935388
# ################### 2 150 绝对误差 tensor(1.0335, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6332, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0619, dtype=torch.float64)   实验回归误差 tensor(0.0997, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.049634784303163
# ########################################### 2 150 绝对误差 tensor(0.0119, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0206, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1970, dtype=torch.float64)   实验回归误差 tensor(0.0739, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3754, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0977690200776549
# ########################### 2 150 绝对误差 tensor(1.5007, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0456, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0678, dtype=torch.float64)   实验回归误差 tensor(0.1318, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1353493352178987
# ############################################################################### 2 150 绝对误差 tensor(1.3577, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3305, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0874, dtype=torch.float64)   实验回归误差 tensor(0.1083, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1072565728630956
# ###################################################################### 3 150 绝对误差 tensor(3.2716, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2520, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0391, dtype=torch.float64)   实验回归误差 tensor(0.1209, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0853588952883364
# ############################################################## 3 150 绝对误差 tensor(1.5417, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8766, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0568, dtype=torch.float64)   实验回归误差 tensor(0.1000, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4125, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1900613500785102
# ########################################################################################################################################### 3 150 绝对误差 tensor(0.5138, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4662, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0951, dtype=torch.float64)   实验回归误差 tensor(0.1049, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1393358460132916
# ################################################## 3 150 绝对误差 tensor(2.6736, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3108, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0520, dtype=torch.float64)   实验回归误差 tensor(0.1518, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0818423672788375
# ########################################## 3 150 绝对误差 tensor(1.4162, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0376, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0724, dtype=torch.float64)   实验回归误差 tensor(0.1504, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0390640312633148
# ################################################################# 3 150 绝对误差 tensor(1.9777, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1623, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0563, dtype=torch.float64)   实验回归误差 tensor(0.1129, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.230272282967299
# ############################################################# 3 150 绝对误差 tensor(1.8817, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1152, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0552, dtype=torch.float64)   实验回归误差 tensor(0.1508, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4086, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1301889386697488
# ########################################################### 3 150 绝对误差 tensor(0.5052, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3188, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0651, dtype=torch.float64)   实验回归误差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1377222194144307
# ############################################### 3 150 绝对误差 tensor(0.3446, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1986, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0529, dtype=torch.float64)   实验回归误差 tensor(0.0483, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3466, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1240548074078032
# ################################################################# 3 150 绝对误差 tensor(0.4709, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2980, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0619, dtype=torch.float64)   实验回归误差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1065046525166091
