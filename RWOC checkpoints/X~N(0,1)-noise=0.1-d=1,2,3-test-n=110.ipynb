# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(2):
    for num_example in range(110,111,100): 
        for num_X2feature in [3,2,1]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ################ 3 110 w绝对误差 tensor(0.8636, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9900, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1209, dtype=torch.float64)   实验回归残差 tensor(0.1334, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1095, dtype=torch.float64)   测试集实验回归残差 tensor(0.2526, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.146813143145421
# ############### 3 110 w绝对误差 tensor(0.9058, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7042, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0998, dtype=torch.float64)   实验回归残差 tensor(0.1617, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0727, dtype=torch.float64)   测试集实验回归残差 tensor(0.1445, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.245563821943674
# ######################## 3 110 w绝对误差 tensor(0.6249, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4076, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0646, dtype=torch.float64)   实验回归残差 tensor(0.1046, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0688, dtype=torch.float64)   测试集实验回归残差 tensor(0.1407, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.200846293450642
# ################################# 3 110 w绝对误差 tensor(1.2945, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6609, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0501, dtype=torch.float64)   实验回归残差 tensor(0.1307, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0458, dtype=torch.float64)   测试集实验回归残差 tensor(0.1775, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2222802358098177
# ########## 3 110 w绝对误差 tensor(2.0969, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0812, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0536, dtype=torch.float64)   实验回归残差 tensor(0.1756, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0595, dtype=torch.float64)   测试集实验回归残差 tensor(0.2542, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2312781145007343
# #################### 3 110 w绝对误差 tensor(2.1236, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0481, dtype=torch.float64)   实验回归残差 tensor(0.1712, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0510, dtype=torch.float64)   测试集实验回归残差 tensor(0.1389, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1780868420521817
# ################# 3 110 w绝对误差 tensor(1.2236, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6145, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1208, dtype=torch.float64)   实验回归残差 tensor(0.1704, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1307, dtype=torch.float64)   测试集实验回归残差 tensor(0.3131, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1996817447484895
# ############################################### 3 110 w绝对误差 tensor(0.0442, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0149, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0336, dtype=torch.float64)   实验回归残差 tensor(0.0243, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0412, dtype=torch.float64)   测试集实验回归残差 tensor(0.0325, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1909, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3108726337074146
# ############################# 3 110 w绝对误差 tensor(0.2408, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2053, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0802, dtype=torch.float64)   实验回归残差 tensor(0.0687, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0931, dtype=torch.float64)   测试集实验回归残差 tensor(0.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.2385039754407718
# ########### 3 110 w绝对误差 tensor(3.9299, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3938, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0372, dtype=torch.float64)   实验回归残差 tensor(0.1257, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0360, dtype=torch.float64)   测试集实验回归残差 tensor(0.2951, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2228854749997726
# ################################ 2 110 w绝对误差 tensor(1.9363, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0483, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0576, dtype=torch.float64)   实验回归残差 tensor(0.1209, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0640, dtype=torch.float64)   测试集实验回归残差 tensor(0.3561, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0891096339413886
# ################################################# 2 110 w绝对误差 tensor(0.0568, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0371, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0698, dtype=torch.float64)   实验回归残差 tensor(0.0465, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0608, dtype=torch.float64)   测试集实验回归残差 tensor(0.0449, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2721, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1985, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0901739311209742
# ############################### 2 110 w绝对误差 tensor(0.0168, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0248, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1305, dtype=torch.float64)   实验回归残差 tensor(0.0529, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1394, dtype=torch.float64)   测试集实验回归残差 tensor(0.0688, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3073, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0578438416257419
# ########################################################################################################################################################################################################超过迭代上限
#  2 110 w绝对误差 tensor(0.2831, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3987, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1145, dtype=torch.float64)   实验回归残差 tensor(0.0976, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1230, dtype=torch.float64)   测试集实验回归残差 tensor(0.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3348, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.351850732576597
# ####################################################### 2 110 w绝对误差 tensor(0.6369, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1918, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0302, dtype=torch.float64)   实验回归残差 tensor(0.0685, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.0729, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3280, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3212, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1350289465928074
# ######################## 2 110 w绝对误差 tensor(1.7109, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7167, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0391, dtype=torch.float64)   实验回归残差 tensor(0.1251, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0375, dtype=torch.float64)   测试集实验回归残差 tensor(0.1616, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.234778453990713
# ############## 2 110 w绝对误差 tensor(0.0047, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0044, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0853, dtype=torch.float64)   实验回归残差 tensor(0.0422, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0889, dtype=torch.float64)   测试集实验回归残差 tensor(0.0519, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2136, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3073, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0747571446224542
# ############### 2 110 w绝对误差 tensor(0.3780, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1329, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0360, dtype=torch.float64)   实验回归残差 tensor(0.0536, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0308, dtype=torch.float64)   测试集实验回归残差 tensor(0.0542, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3073, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0624436960620312
# ####################### 2 110 w绝对误差 tensor(0.9265, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4885, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0492, dtype=torch.float64)   实验回归残差 tensor(0.1113, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0630, dtype=torch.float64)   测试集实验回归残差 tensor(0.1759, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3685, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1038453871550247
# ################ 2 110 w绝对误差 tensor(1.5985, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7747, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0440, dtype=torch.float64)   实验回归残差 tensor(0.1344, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0551, dtype=torch.float64)   测试集实验回归残差 tensor(0.1233, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.203058069731917
# ################################ 1 110 w绝对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0023, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0379, dtype=torch.float64)   实验回归残差 tensor(0.0253, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0434, dtype=torch.float64)   测试集实验回归残差 tensor(0.0280, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1037, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2060, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ########################## 1 110 w绝对误差 tensor(0.0014, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2734, dtype=torch.float64)   实验回归残差 tensor(0.1068, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3158, dtype=torch.float64)   测试集实验回归残差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3938, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.0
# ############### 1 110 w绝对误差 tensor(0.0086, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2135, dtype=torch.float64)   实验回归残差 tensor(0.0802, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2143, dtype=torch.float64)   测试集实验回归残差 tensor(0.0735, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3606, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 108   测试集置换矩阵误差 tensor(1.3685, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# #################### 1 110 w绝对误差 tensor(0.0029, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0638, dtype=torch.float64)   实验回归残差 tensor(0.0417, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0814, dtype=torch.float64)   测试集实验回归残差 tensor(0.0512, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1909, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3073, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ####### 1 110 w绝对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0048, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0479, dtype=torch.float64)   实验回归残差 tensor(0.0328, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0478, dtype=torch.float64)   测试集实验回归残差 tensor(0.0333, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1201, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1442, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ########### 1 110 w绝对误差 tensor(0.0181, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0083, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0480, dtype=torch.float64)   实验回归残差 tensor(0.0305, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0424, dtype=torch.float64)   测试集实验回归残差 tensor(0.0300, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1755, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1599, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ######### 1 110 w绝对误差 tensor(0.0155, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0699, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4150, dtype=torch.float64)   实验回归残差 tensor(0.1361, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4833, dtype=torch.float64)   测试集实验回归残差 tensor(0.1269, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4068, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.0
# ############## 1 110 w绝对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0013, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1109, dtype=torch.float64)   实验回归残差 tensor(0.0499, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1317, dtype=torch.float64)   测试集实验回归残差 tensor(0.0634, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3212, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ########## 1 110 w绝对误差 tensor(0.1559, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(3.5491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.8950, dtype=torch.float64)   实验回归残差 tensor(0.1831, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.9373, dtype=torch.float64)   测试集实验回归残差 tensor(0.2732, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4061, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 102   测试集置换矩阵误差 tensor(1.4011, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# #### 1 110 w绝对误差 tensor(0.0347, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1354, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3811, dtype=torch.float64)   实验回归残差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4008, dtype=torch.float64)   测试集实验回归残差 tensor(0.1434, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ################################## 3 110 w绝对误差 tensor(1.7052, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7340, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1072, dtype=torch.float64)   实验回归残差 tensor(0.1867, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0961, dtype=torch.float64)   测试集实验回归残差 tensor(0.2251, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1503407746834333
# ########################################################################### 3 110 w绝对误差 tensor(0.0325, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0273, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0972, dtype=torch.float64)   实验回归残差 tensor(0.0499, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0731, dtype=torch.float64)   测试集实验回归残差 tensor(0.0549, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3003, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2358, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2330692468115847
# ##################### 3 110 w绝对误差 tensor(2.6625, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2177, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0449, dtype=torch.float64)   实验回归残差 tensor(0.1289, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0360, dtype=torch.float64)   测试集实验回归残差 tensor(0.1993, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.194857293463803
# #################### 3 110 w绝对误差 tensor(0.5319, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1866, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0348, dtype=torch.float64)   实验回归残差 tensor(0.0541, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0353, dtype=torch.float64)   测试集实验回归残差 tensor(0.0772, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3003, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3618, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.17203698734239
# ################################################# 3 110 w绝对误差 tensor(0.8764, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6338, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0820, dtype=torch.float64)   实验回归残差 tensor(0.0995, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0589, dtype=torch.float64)   测试集实验回归残差 tensor(0.1434, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.167638773854208
# ############## 3 110 w绝对误差 tensor(1.7512, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0774, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0613, dtype=torch.float64)   实验回归残差 tensor(0.1033, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0647, dtype=torch.float64)   测试集实验回归残差 tensor(0.1355, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3257417375566738
# ############################### 3 110 w绝对误差 tensor(2.5274, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1214, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0436, dtype=torch.float64)   实验回归残差 tensor(0.1032, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0425, dtype=torch.float64)   测试集实验回归残差 tensor(0.2279, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1651922702861754
# ################################ 3 110 w绝对误差 tensor(1.1862, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2689, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1141, dtype=torch.float64)   实验回归残差 tensor(0.1358, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0952, dtype=torch.float64)   测试集实验回归残差 tensor(0.1918, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1047937868409747
# ########################## 3 110 w绝对误差 tensor(1.1127, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8970, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0773, dtype=torch.float64)   实验回归残差 tensor(0.1090, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0817, dtype=torch.float64)   测试集实验回归残差 tensor(0.1745, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.147245377994572
# #################### 3 110 w绝对误差 tensor(0.7528, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4819, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0582, dtype=torch.float64)   实验回归残差 tensor(0.0940, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0578, dtype=torch.float64)   测试集实验回归残差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3618, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.169167783438193
# ############# 2 110 w绝对误差 tensor(1.5151, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5083, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0355, dtype=torch.float64)   实验回归残差 tensor(0.1544, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0377, dtype=torch.float64)   测试集实验回归残差 tensor(0.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1333187752620286
# ####################################### 2 110 w绝对误差 tensor(0.0272, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0272, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0966, dtype=torch.float64)   实验回归残差 tensor(0.0496, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0869, dtype=torch.float64)   测试集实验回归残差 tensor(0.0520, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3143, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2285, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0613591622672094
# ############# 2 110 w绝对误差 tensor(0.0169, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0362, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2096, dtype=torch.float64)   实验回归残差 tensor(0.0763, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2165, dtype=torch.float64)   测试集实验回归残差 tensor(0.1144, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3484, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1613533793914301
# ######################### 2 110 w绝对误差 tensor(0.0042, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0024, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0484, dtype=torch.float64)   实验回归残差 tensor(0.0318, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0545, dtype=torch.float64)   测试集实验回归残差 tensor(0.0345, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1442, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1755, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1289412485801193
# ############################ 2 110 w绝对误差 tensor(0.0112, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0465, dtype=torch.float64)   实验回归残差 tensor(0.0295, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0540, dtype=torch.float64)   测试集实验回归残差 tensor(0.0312, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1599, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1734983417174305
# ################################################ 2 110 w绝对误差 tensor(0.5030, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1840, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2288, dtype=torch.float64)   实验回归残差 tensor(0.1132, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2149, dtype=torch.float64)   测试集实验回归残差 tensor(0.1027, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4047, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.2821355779816805
# #################################################### 2 110 w绝对误差 tensor(0.4725, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4383, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0858, dtype=torch.float64)   实验回归残差 tensor(0.1103, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0761, dtype=torch.float64)   测试集实验回归残差 tensor(0.1069, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3412, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.1587656045248895
# ##################### 2 110 w绝对误差 tensor(0.0080, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0407, dtype=torch.float64)   实验回归残差 tensor(0.0251, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0395, dtype=torch.float64)   测试集实验回归残差 tensor(0.0300, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1677, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.0445, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.112419679595129
# ######################### 2 110 w绝对误差 tensor(2.3181, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8691, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0340, dtype=torch.float64)   实验回归残差 tensor(0.1536, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0401, dtype=torch.float64)   测试集实验回归残差 tensor(0.1577, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0689340293373133
# ######################################### 2 110 w绝对误差 tensor(0.0308, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0297, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0993, dtype=torch.float64)   实验回归残差 tensor(0.0409, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0907, dtype=torch.float64)   测试集实验回归残差 tensor(0.0479, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2863, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2792, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0921828405106375
# ########### 1 110 w绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0189, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1760, dtype=torch.float64)   实验回归残差 tensor(0.0571, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1769, dtype=torch.float64)   测试集实验回归残差 tensor(0.0779, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3348, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ####### 1 110 w绝对误差 tensor(0.0101, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0484, dtype=torch.float64)   实验回归残差 tensor(0.0316, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0441, dtype=torch.float64)   测试集实验回归残差 tensor(0.0325, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2060, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1755, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ######## 1 110 w绝对误差 tensor(0.0015, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0659, dtype=torch.float64)   实验回归残差 tensor(0.0428, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0630, dtype=torch.float64)   测试集实验回归残差 tensor(0.0367, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1677, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1362, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ########### 1 110 w绝对误差 tensor(0.0031, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0018, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0595, dtype=torch.float64)   实验回归残差 tensor(0.0356, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0549, dtype=torch.float64)   测试集实验回归残差 tensor(0.0355, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2136, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.1985, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ########## 1 110 w绝对误差 tensor(0.0265, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0508, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1615, dtype=torch.float64)   实验回归残差 tensor(0.0749, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2353, dtype=torch.float64)   测试集实验回归残差 tensor(0.0752, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3212, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3618, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ######### 1 110 w绝对误差 tensor(0.0169, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0664, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3678, dtype=torch.float64)   实验回归残差 tensor(0.1185, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4016, dtype=torch.float64)   测试集实验回归残差 tensor(0.1177, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3733, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 108   测试集置换矩阵误差 tensor(1.3543, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.0
# ####### 1 110 w绝对误差 tensor(0.0542, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6540, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.8409, dtype=torch.float64)   实验回归残差 tensor(0.1410, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7033, dtype=torch.float64)   测试集实验回归残差 tensor(0.1697, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3803, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 104   条件数 1.0
# ################# 1 110 w绝对误差 tensor(0.0217, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0694, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2887, dtype=torch.float64)   实验回归残差 tensor(0.0718, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3623, dtype=torch.float64)   测试集实验回归残差 tensor(0.1022, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3685, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.0
# ########### 1 110 w绝对误差 tensor(0.0739, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.2582, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9487, dtype=torch.float64)   实验回归残差 tensor(0.1229, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.9621, dtype=torch.float64)   测试集实验回归残差 tensor(0.2205, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 108   测试集置换矩阵误差 tensor(1.3918, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 100   条件数 1.0
# ######## 1 110 w绝对误差 tensor(0.1005, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(9.1347, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9983, dtype=torch.float64)   实验回归残差 tensor(0.1863, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.9867, dtype=torch.float64)   测试集实验回归残差 tensor(0.2307, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 108   测试集置换矩阵误差 tensor(1.4003, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.0
