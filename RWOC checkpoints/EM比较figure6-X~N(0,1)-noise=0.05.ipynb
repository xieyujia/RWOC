# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [2,5,10,20]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1)=generatedata(noise=0.05)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    results_error.append(error_each)
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')

                #print('真实置换矩阵为：',true_P)
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print(num_X2feature,num_example,'置换矩阵误差：',error_P,end='   ')
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# #################################################### 2 100 平均相对误差2： tensor(1.1604, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0211, dtype=torch.float64)   实验回归误差 tensor(0.1013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################# 2 100 平均相对误差2： tensor(1.6049, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0318, dtype=torch.float64)   实验回归误差 tensor(0.2151, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(1.0776, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0412, dtype=torch.float64)   实验回归误差 tensor(0.1347, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################### 2 100 平均相对误差2： tensor(0.9660, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0235, dtype=torch.float64)   实验回归误差 tensor(0.0913, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################## 2 100 平均相对误差2： tensor(0.9283, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0388, dtype=torch.float64)   实验回归误差 tensor(0.1172, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################ 2 100 平均相对误差2： tensor(1.0495, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0414, dtype=torch.float64)   实验回归误差 tensor(0.1795, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 2 100 平均相对误差2： tensor(0.0105, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0336, dtype=torch.float64)   实验回归误差 tensor(0.0225, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 2 100 平均相对误差2： tensor(0.0070, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2570, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1393, dtype=torch.float64)   实验回归误差 tensor(0.0590, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 2 100 平均相对误差2： tensor(0.7451, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0599, dtype=torch.float64)   实验回归误差 tensor(0.1419, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 5 100 平均相对误差2： tensor(0.5102, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0295, dtype=torch.float64)   实验回归误差 tensor(0.0618, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 5 100 平均相对误差2： tensor(3.0517, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0188, dtype=torch.float64)   实验回归误差 tensor(0.1698, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################### 5 100 平均相对误差2： tensor(3.3148, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0165, dtype=torch.float64)   实验回归误差 tensor(0.1921, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################# 5 100 平均相对误差2： tensor(0.2453, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0760, dtype=torch.float64)   实验回归误差 tensor(0.0617, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################################################################################### 5 100 平均相对误差2： tensor(2.4604, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0293, dtype=torch.float64)   实验回归误差 tensor(0.1347, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 5 100 平均相对误差2： tensor(1.7494, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0205, dtype=torch.float64)   实验回归误差 tensor(0.0837, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 5 100 平均相对误差2： tensor(3.1303, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0210, dtype=torch.float64)   实验回归误差 tensor(0.1346, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################### 5 100 平均相对误差2： tensor(2.0800, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0182, dtype=torch.float64)   实验回归误差 tensor(0.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################### 5 100 平均相对误差2： tensor(1.9809, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0276, dtype=torch.float64)   实验回归误差 tensor(0.0951, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################ 5 100 平均相对误差2： tensor(0.6540, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0681, dtype=torch.float64)   实验回归误差 tensor(0.1526, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################################################################################################################################### 10 100 平均相对误差2： tensor(4.3943, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0133, dtype=torch.float64)   实验回归误差 tensor(0.0587, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################### 10 100 平均相对误差2： tensor(3.5425, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0143, dtype=torch.float64)   实验回归误差 tensor(0.0964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################### 10 100 平均相对误差2： tensor(3.8578, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0118, dtype=torch.float64)   实验回归误差 tensor(0.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################################################## 10 100 平均相对误差2： tensor(3.7481, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0162, dtype=torch.float64)   实验回归误差 tensor(0.0886, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################## 10 100 平均相对误差2： tensor(3.9543, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0198, dtype=torch.float64)   实验回归误差 tensor(0.1167, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################### 10 100 平均相对误差2： tensor(6.1149, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0095, dtype=torch.float64)   实验回归误差 tensor(0.0939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################################################## 10 100 平均相对误差2： tensor(3.1776, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0145, dtype=torch.float64)   实验回归误差 tensor(0.0662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################################################################### 10 100 平均相对误差2： tensor(3.0843, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0177, dtype=torch.float64)   实验回归误差 tensor(0.0932, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################################################################### 10 100 平均相对误差2： tensor(2.8084, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0162, dtype=torch.float64)   实验回归误差 tensor(0.0896, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################### 10 100 平均相对误差2： tensor(2.2300, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0253, dtype=torch.float64)   实验回归误差 tensor(0.0944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 20 100 平均相对误差2： tensor(4.4508, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0163, dtype=torch.float64)   实验回归误差 tensor(0.0634, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 20 100 平均相对误差2： tensor(7.4910, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0101, dtype=torch.float64)   实验回归误差 tensor(0.0911, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 20 100 平均相对误差2： tensor(5.0131, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0086, dtype=torch.float64)   实验回归误差 tensor(0.0878, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################################################################################################### 20 100 平均相对误差2： tensor(4.3488, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0133, dtype=torch.float64)   实验回归误差 tensor(0.0628, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################ 20 100 平均相对误差2： tensor(4.4306, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0126, dtype=torch.float64)   实验回归误差 tensor(0.0748, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################### 20 100 平均相对误差2： tensor(5.5962, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0145, dtype=torch.float64)   实验回归误差 tensor(0.0680, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 20 100 平均相对误差2： tensor(5.2646, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0120, dtype=torch.float64)   实验回归误差 tensor(0.0641, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 20 100 平均相对误差2： tensor(6.0342, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0101, dtype=torch.float64)   实验回归误差 tensor(0.0939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################## 20 100 平均相对误差2： tensor(5.8118, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0128, dtype=torch.float64)   实验回归误差 tensor(0.0731, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################## 20 100 平均相对误差2： tensor(3.6828, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0166, dtype=torch.float64)   实验回归误差 tensor(0.0532, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################### 2 100 平均相对误差2： tensor(0.0113, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.9798, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0247, dtype=torch.float64)   实验回归误差 tensor(0.0185, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################### 2 100 平均相对误差2： tensor(1.3771, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0414, dtype=torch.float64)   实验回归误差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 2 100 平均相对误差2： tensor(2.7093, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0247, dtype=torch.float64)   实验回归误差 tensor(0.1322, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################### 2 100 平均相对误差2： tensor(0.1800, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0708, dtype=torch.float64)   实验回归误差 tensor(0.0703, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 2 100 平均相对误差2： tensor(0.2524, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1605, dtype=torch.float64)   实验回归误差 tensor(0.0849, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################### 2 100 平均相对误差2： tensor(0.0078, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2317, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0993, dtype=torch.float64)   实验回归误差 tensor(0.0470, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ################ 2 100 平均相对误差2： tensor(1.5589, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0326, dtype=torch.float64)   实验回归误差 tensor(0.2040, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################## 2 100 平均相对误差2： tensor(0.5367, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3820, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0550, dtype=torch.float64)   实验回归误差 tensor(0.1000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ########## 2 100 平均相对误差2： tensor(0.7334, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0759, dtype=torch.float64)   实验回归误差 tensor(0.1597, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################### 2 100 平均相对误差2： tensor(0.0077, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0543, dtype=torch.float64)   实验回归误差 tensor(0.0383, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################# 5 100 平均相对误差2： tensor(3.2705, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0223, dtype=torch.float64)   实验回归误差 tensor(0.1213, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################## 5 100 平均相对误差2： tensor(2.2679, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0191, dtype=torch.float64)   实验回归误差 tensor(0.0947, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 5 100 平均相对误差2： tensor(1.6484, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0245, dtype=torch.float64)   实验回归误差 tensor(0.1476, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################################################################################################超过迭代上限
#  5 100 平均相对误差2： tensor(0.9899, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0254, dtype=torch.float64)   实验回归误差 tensor(0.1165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 5 100 平均相对误差2： tensor(0.0110, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(0.8602, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0156, dtype=torch.float64)   实验回归误差 tensor(0.0122, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################## 5 100 平均相对误差2： tensor(2.6236, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0138, dtype=torch.float64)   实验回归误差 tensor(0.1141, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################### 5 100 平均相对误差2： tensor(2.6822, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0202, dtype=torch.float64)   实验回归误差 tensor(0.1084, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 5 100 平均相对误差2： tensor(1.9818, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0172, dtype=torch.float64)   实验回归误差 tensor(0.0761, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 5 100 平均相对误差2： tensor(1.0673, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0348, dtype=torch.float64)   实验回归误差 tensor(0.0867, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 5 100 平均相对误差2： tensor(3.8628, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0159, dtype=torch.float64)   实验回归误差 tensor(0.2007, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################### 10 100 平均相对误差2： tensor(2.4755, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0199, dtype=torch.float64)   实验回归误差 tensor(0.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################### 10 100 平均相对误差2： tensor(4.4301, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0177, dtype=torch.float64)   实验回归误差 tensor(0.0790, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################################## 10 100 平均相对误差2： tensor(5.2459, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0130, dtype=torch.float64)   实验回归误差 tensor(0.0749, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################### 10 100 平均相对误差2： tensor(3.8714, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0136, dtype=torch.float64)   实验回归误差 tensor(0.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################################ 10 100 平均相对误差2： tensor(4.2508, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0199, dtype=torch.float64)   实验回归误差 tensor(0.0937, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################### 10 100 平均相对误差2： tensor(5.4368, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0158, dtype=torch.float64)   实验回归误差 tensor(0.1067, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################################### 10 100 平均相对误差2： tensor(2.6780, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0215, dtype=torch.float64)   实验回归误差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 10 100 平均相对误差2： tensor(1.9429, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0203, dtype=torch.float64)   实验回归误差 tensor(0.1029, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################# 10 100 平均相对误差2： tensor(3.0106, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0145, dtype=torch.float64)   实验回归误差 tensor(0.0889, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################## 10 100 平均相对误差2： tensor(4.5090, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0100, dtype=torch.float64)   实验回归误差 tensor(0.1407, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################## 20 100 平均相对误差2： tensor(5.8816, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0092, dtype=torch.float64)   实验回归误差 tensor(0.0763, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 20 100 平均相对误差2： tensor(6.6782, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0094, dtype=torch.float64)   实验回归误差 tensor(0.0773, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################################### 20 100 平均相对误差2： tensor(7.1940, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0101, dtype=torch.float64)   实验回归误差 tensor(0.0835, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################## 20 100 平均相对误差2： tensor(6.1606, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0114, dtype=torch.float64)   实验回归误差 tensor(0.0540, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 20 100 平均相对误差2： tensor(5.8464, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0149, dtype=torch.float64)   实验回归误差 tensor(0.1048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 20 100 平均相对误差2： tensor(4.1420, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0165, dtype=torch.float64)   实验回归误差 tensor(0.0435, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################ 20 100 平均相对误差2： tensor(7.1775, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0098, dtype=torch.float64)   实验回归误差 tensor(0.0538, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 20 100 平均相对误差2： tensor(4.2975, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0142, dtype=torch.float64)   实验回归误差 tensor(0.0710, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 20 100 平均相对误差2： tensor(4.4130, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0127, dtype=torch.float64)   实验回归误差 tensor(0.0720, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 20 100 平均相对误差2： tensor(6.4867, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0089, dtype=torch.float64)   实验回归误差 tensor(0.0691, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################### 2 100 平均相对误差2： tensor(0.0089, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(0.8246, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0151, dtype=torch.float64)   实验回归误差 tensor(0.0129, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 2 100 平均相对误差2： tensor(1.1443, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4056, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0569, dtype=torch.float64)   实验回归误差 tensor(0.1928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ################ 2 100 平均相对误差2： tensor(1.1966, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0407, dtype=torch.float64)   实验回归误差 tensor(0.1441, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################### 2 100 平均相对误差2： tensor(1.0004, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0523, dtype=torch.float64)   实验回归误差 tensor(0.1710, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################### 2 100 平均相对误差2： tensor(1.0948, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0557, dtype=torch.float64)   实验回归误差 tensor(0.1438, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################### 2 100 平均相对误差2： tensor(0.0097, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0953, dtype=torch.float64)   实验回归误差 tensor(0.0464, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 2 100 平均相对误差2： tensor(2.6933, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0253, dtype=torch.float64)   实验回归误差 tensor(0.1504, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################ 2 100 平均相对误差2： tensor(0.0256, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1203, dtype=torch.float64)   实验回归误差 tensor(0.0454, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 2 100 平均相对误差2： tensor(1.5276, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0295, dtype=torch.float64)   实验回归误差 tensor(0.1696, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(0.3932, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0740, dtype=torch.float64)   实验回归误差 tensor(0.1109, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################### 5 100 平均相对误差2： tensor(1.8586, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0458, dtype=torch.float64)   实验回归误差 tensor(0.1228, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################## 5 100 平均相对误差2： tensor(2.3577, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0211, dtype=torch.float64)   实验回归误差 tensor(0.1956, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 5 100 平均相对误差2： tensor(1.3210, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0230, dtype=torch.float64)   实验回归误差 tensor(0.1225, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################### 5 100 平均相对误差2： tensor(4.7727, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0133, dtype=torch.float64)   实验回归误差 tensor(0.1651, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 5 100 平均相对误差2： tensor(2.7029, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0225, dtype=torch.float64)   实验回归误差 tensor(0.1444, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################################################### 5 100 平均相对误差2： tensor(4.7797, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0184, dtype=torch.float64)   实验回归误差 tensor(0.1400, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 5 100 平均相对误差2： tensor(2.5086, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0293, dtype=torch.float64)   实验回归误差 tensor(0.1075, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################################################################### 5 100 平均相对误差2： tensor(2.3440, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0213, dtype=torch.float64)   实验回归误差 tensor(0.1025, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 5 100 平均相对误差2： tensor(2.3182, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0341, dtype=torch.float64)   实验回归误差 tensor(0.1562, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 5 100 平均相对误差2： tensor(1.9622, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0305, dtype=torch.float64)   实验回归误差 tensor(0.1052, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################ 10 100 平均相对误差2： tensor(2.1369, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3998, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0313, dtype=torch.float64)   实验回归误差 tensor(0.0981, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################ 10 100 平均相对误差2： tensor(3.6101, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0195, dtype=torch.float64)   实验回归误差 tensor(0.0862, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 10 100 平均相对误差2： tensor(3.5820, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0202, dtype=torch.float64)   实验回归误差 tensor(0.1343, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 10 100 平均相对误差2： tensor(4.6958, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0156, dtype=torch.float64)   实验回归误差 tensor(0.1338, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################## 10 100 平均相对误差2： tensor(2.6955, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0168, dtype=torch.float64)   实验回归误差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 10 100 平均相对误差2： tensor(6.1051, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0119, dtype=torch.float64)   实验回归误差 tensor(0.0659, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################ 10 100 平均相对误差2： tensor(3.8763, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0149, dtype=torch.float64)   实验回归误差 tensor(0.0968, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################ 10 100 平均相对误差2： tensor(3.9268, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0192, dtype=torch.float64)   实验回归误差 tensor(0.0859, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 10 100 平均相对误差2： tensor(1.8707, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0257, dtype=torch.float64)   实验回归误差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 10 100 平均相对误差2： tensor(3.2161, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0168, dtype=torch.float64)   实验回归误差 tensor(0.1356, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 20 100 平均相对误差2： tensor(5.6500, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0124, dtype=torch.float64)   实验回归误差 tensor(0.0518, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################## 20 100 平均相对误差2： tensor(7.6391, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0100, dtype=torch.float64)   实验回归误差 tensor(0.0823, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################# 20 100 平均相对误差2： tensor(5.1687, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0125, dtype=torch.float64)   实验回归误差 tensor(0.1245, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 20 100 平均相对误差2： tensor(7.0863, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0093, dtype=torch.float64)   实验回归误差 tensor(0.0541, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################ 20 100 平均相对误差2： tensor(8.4802, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0079, dtype=torch.float64)   实验回归误差 tensor(0.0513, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 20 100 平均相对误差2： tensor(5.1953, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0116, dtype=torch.float64)   实验回归误差 tensor(0.0684, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################### 20 100 平均相对误差2： tensor(5.7441, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0094, dtype=torch.float64)   实验回归误差 tensor(0.0676, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################################################################### 20 100 平均相对误差2： tensor(5.5400, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0105, dtype=torch.float64)   实验回归误差 tensor(0.0831, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################# 20 100 平均相对误差2： tensor(5.5620, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0099, dtype=torch.float64)   实验回归误差 tensor(0.0479, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################# 20 100 平均相对误差2： tensor(6.5149, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0094, dtype=torch.float64)   实验回归误差 tensor(0.0799, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################### 2 100 平均相对误差2： tensor(1.1554, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0612, dtype=torch.float64)   实验回归误差 tensor(0.1772, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(0.9473, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0694, dtype=torch.float64)   实验回归误差 tensor(0.2127, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################ 2 100 平均相对误差2： tensor(0.5231, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0503, dtype=torch.float64)   实验回归误差 tensor(0.1146, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################## 2 100 平均相对误差2： tensor(2.3337, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0428, dtype=torch.float64)   实验回归误差 tensor(0.1409, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################### 2 100 平均相对误差2： tensor(1.5331, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0406, dtype=torch.float64)   实验回归误差 tensor(0.1727, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################### 2 100 平均相对误差2： tensor(0.1997, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0832, dtype=torch.float64)   实验回归误差 tensor(0.0828, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################### 2 100 平均相对误差2： tensor(0.1493, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3191, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0458, dtype=torch.float64)   实验回归误差 tensor(0.0525, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################### 2 100 平均相对误差2： tensor(0.0418, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0318, dtype=torch.float64)   实验回归误差 tensor(0.0245, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################### 2 100 平均相对误差2： tensor(1.0583, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3972, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0518, dtype=torch.float64)   实验回归误差 tensor(0.1142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ################################ 2 100 平均相对误差2： tensor(1.1014, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0493, dtype=torch.float64)   实验回归误差 tensor(0.1088, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################### 5 100 平均相对误差2： tensor(1.8195, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0250, dtype=torch.float64)   实验回归误差 tensor(0.1036, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################## 5 100 平均相对误差2： tensor(3.1026, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0190, dtype=torch.float64)   实验回归误差 tensor(0.1475, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################## 5 100 平均相对误差2： tensor(1.0236, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0319, dtype=torch.float64)   实验回归误差 tensor(0.1081, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################### 5 100 平均相对误差2： tensor(1.4359, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0251, dtype=torch.float64)   实验回归误差 tensor(0.1033, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 5 100 平均相对误差2： tensor(1.3914, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0162, dtype=torch.float64)   实验回归误差 tensor(0.0708, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################## 5 100 平均相对误差2： tensor(3.8759, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0183, dtype=torch.float64)   实验回归误差 tensor(0.1502, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 5 100 平均相对误差2： tensor(4.4621, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0142, dtype=torch.float64)   实验回归误差 tensor(0.1377, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################### 5 100 平均相对误差2： tensor(1.3967, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0420, dtype=torch.float64)   实验回归误差 tensor(0.0828, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################### 5 100 平均相对误差2： tensor(1.4921, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0327, dtype=torch.float64)   实验回归误差 tensor(0.1229, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################# 5 100 平均相对误差2： tensor(1.9665, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0316, dtype=torch.float64)   实验回归误差 tensor(0.1454, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 10 100 平均相对误差2： tensor(4.0291, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0152, dtype=torch.float64)   实验回归误差 tensor(0.1067, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################### 10 100 平均相对误差2： tensor(2.9180, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0195, dtype=torch.float64)   实验回归误差 tensor(0.1469, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################### 10 100 平均相对误差2： tensor(6.1283, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0115, dtype=torch.float64)   实验回归误差 tensor(0.0475, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################### 10 100 平均相对误差2： tensor(2.3767, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0200, dtype=torch.float64)   实验回归误差 tensor(0.0600, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################################################################### 10 100 平均相对误差2： tensor(4.5862, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0152, dtype=torch.float64)   实验回归误差 tensor(0.0743, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 10 100 平均相对误差2： tensor(2.4487, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0272, dtype=torch.float64)   实验回归误差 tensor(0.1140, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################## 10 100 平均相对误差2： tensor(4.8248, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0130, dtype=torch.float64)   实验回归误差 tensor(0.1710, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################### 10 100 平均相对误差2： tensor(2.2137, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0165, dtype=torch.float64)   实验回归误差 tensor(0.0715, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################## 10 100 平均相对误差2： tensor(3.2990, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0162, dtype=torch.float64)   实验回归误差 tensor(0.1141, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################ 10 100 平均相对误差2： tensor(4.6836, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0164, dtype=torch.float64)   实验回归误差 tensor(0.1509, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-53c62e4c3a70> in <module>()
#      37                         for i in range(num_example):
#      38                             for j in range(num_example):
# ---> 39                                 C[i][j]=(Y1[i]-Y2[j])**2
#      40
#      41                         #S=SinkhornIPOT(C)
#
# KeyboardInterrupt:
