# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(50,51,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.3)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ################################## 1 50 绝对误差 tensor(0.0404, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0658, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4686, dtype=torch.float64)   实验回归误差 tensor(0.1958, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################ 1 50 绝对误差 tensor(0.0259, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0168, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2002, dtype=torch.float64)   实验回归误差 tensor(0.0946, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################## 1 50 绝对误差 tensor(0.1018, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1243, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3629, dtype=torch.float64)   实验回归误差 tensor(0.1625, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################### 1 50 绝对误差 tensor(2.1031, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0325, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2572, dtype=torch.float64)   实验回归误差 tensor(0.2059, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ####################### 1 50 绝对误差 tensor(0.0852, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3956, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8171, dtype=torch.float64)   实验回归误差 tensor(0.2529, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################################### 1 50 绝对误差 tensor(0.6543, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.3452, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8992, dtype=torch.float64)   实验回归误差 tensor(0.2885, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################### 1 50 绝对误差 tensor(0.0207, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0384, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5289, dtype=torch.float64)   实验回归误差 tensor(0.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################################### 1 50 绝对误差 tensor(0.4025, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(9.9226, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9712, dtype=torch.float64)   实验回归误差 tensor(0.1580, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################ 1 50 绝对误差 tensor(0.1011, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5777, dtype=torch.float64)   实验回归误差 tensor(0.1535, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ##################################### 1 50 绝对误差 tensor(0.0309, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0415, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4758, dtype=torch.float64)   实验回归误差 tensor(0.1581, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################################### 2 50 绝对误差 tensor(0.1770, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7526, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6788, dtype=torch.float64)   实验回归误差 tensor(0.1780, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1803531451212959
# ######################################################## 2 50 绝对误差 tensor(0.0907, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0329, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1029, dtype=torch.float64)   实验回归误差 tensor(0.0568, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1560937682247798
# ###################################### 2 50 绝对误差 tensor(0.2411, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2110, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2169, dtype=torch.float64)   实验回归误差 tensor(0.1444, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3754841897208085
# ##################################################################### 2 50 绝对误差 tensor(0.0423, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0417, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2772, dtype=torch.float64)   实验回归误差 tensor(0.1600, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1248073125413782
# ######################################################## 2 50 绝对误差 tensor(6.3334, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4720, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0780, dtype=torch.float64)   实验回归误差 tensor(0.1780, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3321515375164916
# ################################# 2 50 绝对误差 tensor(0.2374, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2545, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2732, dtype=torch.float64)   实验回归误差 tensor(0.0766, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1208688757581653
# #################################################### 2 50 绝对误差 tensor(1.1875, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4493, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4248, dtype=torch.float64)   实验回归误差 tensor(0.2118, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1470644087939068
# ########################################################## 2 50 绝对误差 tensor(0.1533, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2273, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3587, dtype=torch.float64)   实验回归误差 tensor(0.1427, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1454827922973165
# ################################# 2 50 绝对误差 tensor(0.6804, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0990, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4488, dtype=torch.float64)   实验回归误差 tensor(0.2133, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2629537289966297
# ################################### 2 50 绝对误差 tensor(2.9290, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9609, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2318, dtype=torch.float64)   实验回归误差 tensor(0.1535, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0574746794247356
# ###################################### 3 50 绝对误差 tensor(1.0208, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7138, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1933, dtype=torch.float64)   实验回归误差 tensor(0.1920, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2856729654713932
# ################################################################################################################## 3 50 绝对误差 tensor(1.0226, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4071, dtype=torch.float64)   实验回归误差 tensor(0.1363, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.205804515641686
# ############################################################### 3 50 绝对误差 tensor(3.7511, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2780, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1119, dtype=torch.float64)   实验回归误差 tensor(0.1212, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3387949608275374
# ######################## 3 50 绝对误差 tensor(2.5092, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0562, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1198, dtype=torch.float64)   实验回归误差 tensor(0.1856, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.262481105115065
# ############################################## 3 50 绝对误差 tensor(1.1994, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6729, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1384, dtype=torch.float64)   实验回归误差 tensor(0.1698, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4792130625494322
# ############################################### 3 50 绝对误差 tensor(1.5808, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1533, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1833, dtype=torch.float64)   实验回归误差 tensor(0.1012, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.327742125357439
# ######################################### 3 50 绝对误差 tensor(0.2470, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5188, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4023, dtype=torch.float64)   实验回归误差 tensor(0.1246, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3261044392736647
# ################################################################# 3 50 绝对误差 tensor(2.3377, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0120, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1858, dtype=torch.float64)   实验回归误差 tensor(0.1828, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.6106093894269664
# ######################################################################## 3 50 绝对误差 tensor(1.3501, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9161, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1813, dtype=torch.float64)   实验回归误差 tensor(0.1601, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3991628044444107
# ############################## 1 50 绝对误差 tensor(0.0979, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1217, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3526, dtype=torch.float64)   实验回归误差 tensor(0.1382, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################### 1 50 绝对误差 tensor(0.0506, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0269, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1776, dtype=torch.float64)   实验回归误差 tensor(0.0912, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################### 1 50 绝对误差 tensor(0.2606, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(10.2133, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0221, dtype=torch.float64)   实验回归误差 tensor(0.1492, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################### 1 50 绝对误差 tensor(0.1628, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0067, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8051, dtype=torch.float64)   实验回归误差 tensor(0.2958, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(0.0163, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0177, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3145, dtype=torch.float64)   实验回归误差 tensor(0.1332, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################################# 1 50 绝对误差 tensor(0.2289, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2347, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8698, dtype=torch.float64)   实验回归误差 tensor(0.2319, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(2.9461, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9867, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2133, dtype=torch.float64)   实验回归误差 tensor(0.2300, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.1021, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1104, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2753, dtype=torch.float64)   实验回归误差 tensor(0.1174, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ##################################### 1 50 绝对误差 tensor(0.0852, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0406, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1715, dtype=torch.float64)   实验回归误差 tensor(0.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0066, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2516, dtype=torch.float64)   实验回归误差 tensor(0.0921, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################################### 2 50 绝对误差 tensor(0.1881, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1660, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2260, dtype=torch.float64)   实验回归误差 tensor(0.0993, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2436941542289592
# ################################################## 2 50 绝对误差 tensor(0.1978, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2234, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2576, dtype=torch.float64)   实验回归误差 tensor(0.1215, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.342820863839853
# ######################################## 2 50 绝对误差 tensor(0.3581, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2196, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2098, dtype=torch.float64)   实验回归误差 tensor(0.0884, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.260487778059467
# ##################################################################################################### 2 50 绝对误差 tensor(0.2276, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.4156, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9423, dtype=torch.float64)   实验回归误差 tensor(0.1621, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2209015456931536
# ########################################### 2 50 绝对误差 tensor(0.2731, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3186, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3415, dtype=torch.float64)   实验回归误差 tensor(0.1295, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1180062600786402
# ########################################################### 2 50 绝对误差 tensor(1.2512, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1706, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2437, dtype=torch.float64)   实验回归误差 tensor(0.1907, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2292459960254434
# ########################### 2 50 绝对误差 tensor(2.4051, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6045, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0738, dtype=torch.float64)   实验回归误差 tensor(0.1451, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2529766557975757
# #################################################################### 2 50 绝对误差 tensor(0.3997, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.1798, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9299, dtype=torch.float64)   实验回归误差 tensor(0.1898, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3009600766858593
# ############################################ 2 50 绝对误差 tensor(0.0574, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0514, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2497, dtype=torch.float64)   实验回归误差 tensor(0.1074, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.285424977846414
# ###################### 2 50 绝对误差 tensor(0.8363, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0899, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5914, dtype=torch.float64)   实验回归误差 tensor(0.2015, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1288619955627337
# ############################################################################################################# 3 50 绝对误差 tensor(2.2547, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2719, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1813, dtype=torch.float64)   实验回归误差 tensor(0.2039, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1364119118046792
# ############################################## 3 50 绝对误差 tensor(0.9079, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8119, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2416, dtype=torch.float64)   实验回归误差 tensor(0.2013, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4059127838460437
# ################################################################ 3 50 绝对误差 tensor(0.2667, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7327, dtype=torch.float64)   实验回归误差 tensor(0.2275, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2497180659081844
# ################################################################ 3 50 绝对误差 tensor(2.5581, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2502, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1631, dtype=torch.float64)   实验回归误差 tensor(0.2104, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1591108460879678
# ####################################################### 3 50 绝对误差 tensor(0.4907, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5309, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3247, dtype=torch.float64)   实验回归误差 tensor(0.1139, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2382690722988823
# ################################################## 3 50 绝对误差 tensor(1.7137, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0844, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1594, dtype=torch.float64)   实验回归误差 tensor(0.1226, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.7037974506773417
# ############################################################################ 3 50 绝对误差 tensor(2.3640, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3621, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1825, dtype=torch.float64)   实验回归误差 tensor(0.2393, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.106577790310248
# ############################################################################################################################# 3 50 绝对误差 tensor(0.1000, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2132, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4873, dtype=torch.float64)   实验回归误差 tensor(0.1536, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3273157667246795
# ############################# 3 50 绝对误差 tensor(1.3620, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1533, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2945, dtype=torch.float64)   实验回归误差 tensor(0.1983, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2844256076866976
# ############################################# 3 50 绝对误差 tensor(0.2631, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2473, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3007, dtype=torch.float64)   实验回归误差 tensor(0.1572, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3080129663031816
# #################### 1 50 绝对误差 tensor(0.1464, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6227, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6567, dtype=torch.float64)   实验回归误差 tensor(0.1986, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################################################## 1 50 绝对误差 tensor(0.1468, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0875, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2506, dtype=torch.float64)   实验回归误差 tensor(0.1247, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################# 1 50 绝对误差 tensor(0.0211, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0190, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3060, dtype=torch.float64)   实验回归误差 tensor(0.1332, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(0.1525, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2338, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4083, dtype=torch.float64)   实验回归误差 tensor(0.1639, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0676, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0504, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2378, dtype=torch.float64)   实验回归误差 tensor(0.1191, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################################## 1 50 绝对误差 tensor(0.0123, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0056, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1780, dtype=torch.float64)   实验回归误差 tensor(0.0781, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.1722, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1067, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7983, dtype=torch.float64)   实验回归误差 tensor(0.1957, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ##################################### 1 50 绝对误差 tensor(0.2261, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1745, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8374, dtype=torch.float64)   实验回归误差 tensor(0.1643, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################### 1 50 绝对误差 tensor(0.0658, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0483, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2545, dtype=torch.float64)   实验回归误差 tensor(0.1222, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0673, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0499, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1991, dtype=torch.float64)   实验回归误差 tensor(0.1011, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ########################################### 2 50 绝对误差 tensor(0.9705, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8934, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2692, dtype=torch.float64)   实验回归误差 tensor(0.1465, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2162159302660072
# ########################################### 2 50 绝对误差 tensor(0.0383, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0390, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3484, dtype=torch.float64)   实验回归误差 tensor(0.1327, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2481072931155077
# ################################################################################################## 2 50 绝对误差 tensor(3.4833, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1777, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1219, dtype=torch.float64)   实验回归误差 tensor(0.1882, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2706622368031932
# #################################### 2 50 绝对误差 tensor(1.1697, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9803, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2542, dtype=torch.float64)   实验回归误差 tensor(0.1609, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1567657089079841
# ################################# 2 50 绝对误差 tensor(1.5837, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1011, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1697, dtype=torch.float64)   实验回归误差 tensor(0.2236, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.100010969029941
# ############################################## 2 50 绝对误差 tensor(1.3849, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5864, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1134, dtype=torch.float64)   实验回归误差 tensor(0.1358, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.198522266067309
# ################################################################## 2 50 绝对误差 tensor(2.8421, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2295, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1412, dtype=torch.float64)   实验回归误差 tensor(0.2622, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3509934487001334
# ############################### 2 50 绝对误差 tensor(1.1223, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4562, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4151, dtype=torch.float64)   实验回归误差 tensor(0.1555, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0664737986453114
# ########################### 2 50 绝对误差 tensor(0.1510, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1222, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2063, dtype=torch.float64)   实验回归误差 tensor(0.0956, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3639142349428517
# ################################################ 2 50 绝对误差 tensor(0.0300, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0332, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3399, dtype=torch.float64)   实验回归误差 tensor(0.0900, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.158157418056688
# ############################### 3 50 绝对误差 tensor(1.6620, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8687, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1596, dtype=torch.float64)   实验回归误差 tensor(0.1981, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.5613702979668171
# ################################################################################### 3 50 绝对误差 tensor(0.5501, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5252, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2343, dtype=torch.float64)   实验回归误差 tensor(0.1248, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.6442258525604645
# ####################### 3 50 绝对误差 tensor(1.3401, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0394, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1750, dtype=torch.float64)   实验回归误差 tensor(0.1894, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2826923232714795
# ################################################################################################################################################################## 3 50 绝对误差 tensor(0.1104, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0599, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1625, dtype=torch.float64)   实验回归误差 tensor(0.0834, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2332520726692873
# ########################################################## 3 50 绝对误差 tensor(0.5040, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5899, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2862, dtype=torch.float64)   实验回归误差 tensor(0.1058, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.5796048972632206
# ########################################### 3 50 绝对误差 tensor(0.4975, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1742, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6078, dtype=torch.float64)   实验回归误差 tensor(0.1932, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3066640053958736
# ############################################################################### 3 50 绝对误差 tensor(4.7417, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1040, dtype=torch.float64)   实验回归误差 tensor(0.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.24408307820375
# ######################################################################### 3 50 绝对误差 tensor(2.7367, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9898, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1152, dtype=torch.float64)   实验回归误差 tensor(0.2037, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3460207504801345
# ############################################ 3 50 绝对误差 tensor(1.2589, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8692, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1820, dtype=torch.float64)   实验回归误差 tensor(0.1212, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.297204578969143
# ############################################################## 3 50 绝对误差 tensor(2.3238, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9363, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1192, dtype=torch.float64)   实验回归误差 tensor(0.2288, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2407088332722198
# ######################## 1 50 绝对误差 tensor(0.0205, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0456, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6631, dtype=torch.float64)   实验回归误差 tensor(0.2332, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0250, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0223, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2511, dtype=torch.float64)   实验回归误差 tensor(0.1524, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(1.6422, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0054, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3471, dtype=torch.float64)   实验回归误差 tensor(0.1881, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################################## 1 50 绝对误差 tensor(0.1004, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1800, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6178, dtype=torch.float64)   实验回归误差 tensor(0.1791, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################### 1 50 绝对误差 tensor(0.0637, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1108, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4912, dtype=torch.float64)   实验回归误差 tensor(0.2029, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################### 1 50 绝对误差 tensor(1.4705, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0211, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4007, dtype=torch.float64)   实验回归误差 tensor(0.1920, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ######################## 1 50 绝对误差 tensor(0.0121, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0144, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2687, dtype=torch.float64)   实验回归误差 tensor(0.1174, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################### 1 50 绝对误差 tensor(0.1082, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1388, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3721, dtype=torch.float64)   实验回归误差 tensor(0.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################ 1 50 绝对误差 tensor(0.0950, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1431, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3952, dtype=torch.float64)   实验回归误差 tensor(0.1414, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################################ 1 50 绝对误差 tensor(0.1143, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1378, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3947, dtype=torch.float64)   实验回归误差 tensor(0.1675, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# #################################################################################################### 2 50 绝对误差 tensor(2.9310, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4395, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1270, dtype=torch.float64)   实验回归误差 tensor(0.2214, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1246240877623053
# #################################################### 2 50 绝对误差 tensor(0.1061, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0421, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1030, dtype=torch.float64)   实验回归误差 tensor(0.0546, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1521602683707066
# ########################################## 2 50 绝对误差 tensor(0.3690, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3520, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2994, dtype=torch.float64)   实验回归误差 tensor(0.1309, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.365333470655441
# ################################ 2 50 绝对误差 tensor(1.7689, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7761, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1502, dtype=torch.float64)   实验回归误差 tensor(0.1904, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2243300139563815
# ############################################################################### 2 50 绝对误差 tensor(0.2599, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3296, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3193, dtype=torch.float64)   实验回归误差 tensor(0.0609, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0926850916046567
# ############################################ 2 50 绝对误差 tensor(1.1169, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9655, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2139, dtype=torch.float64)   实验回归误差 tensor(0.2008, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1349687392276002
# ######################################################################### 2 50 绝对误差 tensor(0.9775, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5943, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4569, dtype=torch.float64)   实验回归误差 tensor(0.2512, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1559071340213434
# ############################################################ 2 50 绝对误差 tensor(0.7052, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6783, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2471, dtype=torch.float64)   实验回归误差 tensor(0.1903, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.082737316733825
# ######################## 2 50 绝对误差 tensor(0.0466, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0160, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0740, dtype=torch.float64)   实验回归误差 tensor(0.0589, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0477202477876473
# ############################################ 2 50 绝对误差 tensor(0.5503, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0686, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5049, dtype=torch.float64)   实验回归误差 tensor(0.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1968647306631104
# ########################################################## 3 50 绝对误差 tensor(1.4613, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9145, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2278, dtype=torch.float64)   实验回归误差 tensor(0.1835, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2506204875137965
# ############################################################## 3 50 绝对误差 tensor(0.4657, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2587, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1766, dtype=torch.float64)   实验回归误差 tensor(0.0936, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2999274846311195
# ################################################################################################################################### 3 50 绝对误差 tensor(0.0700, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0953, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3644, dtype=torch.float64)   实验回归误差 tensor(0.1025, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2037465656784805
# ################################################################################### 3 50 绝对误差 tensor(1.4690, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1207, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2342, dtype=torch.float64)   实验回归误差 tensor(0.1758, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2788819642440996
# ################################### 3 50 绝对误差 tensor(2.2207, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4361, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1700, dtype=torch.float64)   实验回归误差 tensor(0.1458, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2679025358295086
# ####################################################################################################################################################### 3 50 绝对误差 tensor(0.3196, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4354, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3681, dtype=torch.float64)   实验回归误差 tensor(0.0797, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.5223494093301047
# ###################################################### 3 50 绝对误差 tensor(0.8245, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2989, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4896, dtype=torch.float64)   实验回归误差 tensor(0.1945, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3324332967942762
# ######################################################## 3 50 绝对误差 tensor(2.5665, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1150, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1401, dtype=torch.float64)   实验回归误差 tensor(0.1344, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3871175925284953
# ##################################################################### 3 50 绝对误差 tensor(2.3186, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5450, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1838, dtype=torch.float64)   实验回归误差 tensor(0.2003, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2685827029371248
# ####################################### 3 50 绝对误差 tensor(1.9811, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7858, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1263, dtype=torch.float64)   实验回归误差 tensor(0.1250, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3242969067034234
# ####################### 1 50 绝对误差 tensor(2.3401, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9939, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2211, dtype=torch.float64)   实验回归误差 tensor(0.3844, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################### 1 50 绝对误差 tensor(1.3711, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0775, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4304, dtype=torch.float64)   实验回归误差 tensor(0.1924, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0913, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3349, dtype=torch.float64)   实验回归误差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ###################### 1 50 绝对误差 tensor(0.0131, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0256, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4486, dtype=torch.float64)   实验回归误差 tensor(0.1479, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################## 1 50 绝对误差 tensor(0.0771, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0639, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2538, dtype=torch.float64)   实验回归误差 tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################## 1 50 绝对误差 tensor(0.0296, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0343, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3765, dtype=torch.float64)   实验回归误差 tensor(0.1424, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ###################### 1 50 绝对误差 tensor(0.1238, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4515, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6199, dtype=torch.float64)   实验回归误差 tensor(0.2092, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ############################# 1 50 绝对误差 tensor(0.0404, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0412, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3104, dtype=torch.float64)   实验回归误差 tensor(0.1217, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3414, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################### 1 50 绝对误差 tensor(0.0900, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2422, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6101, dtype=torch.float64)   实验回归误差 tensor(0.2282, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ####################### 1 50 绝对误差 tensor(0.2119, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.4909, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9306, dtype=torch.float64)   实验回归误差 tensor(0.1996, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.0
# ################################ 2 50 绝对误差 tensor(1.1602, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7718, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4118, dtype=torch.float64)   实验回归误差 tensor(0.1766, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2125688991460464
# ######################################### 2 50 绝对误差 tensor(0.4517, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7820, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7155, dtype=torch.float64)   实验回归误差 tensor(0.1869, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3989, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 48   条件数 1.1205414911279339
# ############################################# 2 50 绝对误差 tensor(1.3314, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1835, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2343, dtype=torch.float64)   实验回归误差 tensor(0.2160, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.523761909612243
# ##################################################################################################### 2 50 绝对误差 tensor(0.3655, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2808, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2152, dtype=torch.float64)   实验回归误差 tensor(0.1051, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2706864127262678
# ########################################## 2 50 绝对误差 tensor(3.3500, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5182, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1271, dtype=torch.float64)   实验回归误差 tensor(0.2276, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1429672017215549
# ############################################################### 2 50 绝对误差 tensor(2.8099, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3653, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1551, dtype=torch.float64)   实验回归误差 tensor(0.1724, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3130754459604959
# #################################################### 2 50 绝对误差 tensor(0.1120, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0684, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1723, dtype=torch.float64)   实验回归误差 tensor(0.1019, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2095795160813019
# ########################### 2 50 绝对误差 tensor(0.0941, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0915, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2660, dtype=torch.float64)   实验回归误差 tensor(0.1083, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.1699949215310415
# ################################################################################################################ 2 50 绝对误差 tensor(0.1118, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0404, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0795, dtype=torch.float64)   实验回归误差 tensor(0.0559, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.5957848761870814
# ############################################################################ 3 50 绝对误差 tensor(0.5738, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5409, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2494, dtype=torch.float64)   实验回归误差 tensor(0.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2887626261158058
# ########################################################################################################################################################################################################超过迭代上限
#  3 50 绝对误差 tensor(0.4052, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5831, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4714, dtype=torch.float64)   实验回归误差 tensor(0.1342, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.6031734140004053
# ########################## 3 50 绝对误差 tensor(1.5189, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0550, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1758, dtype=torch.float64)   实验回归误差 tensor(0.1942, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.2541889866656937
# ################################################################################################# 3 50 绝对误差 tensor(1.6101, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0788, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1886, dtype=torch.float64)   实验回归误差 tensor(0.1491, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4022020727382851
# ################################################################################################# 3 50 绝对误差 tensor(2.1713, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2180, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1581, dtype=torch.float64)   实验回归误差 tensor(0.2105, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3529059390136333
# ############################################################################################# 3 50 绝对误差 tensor(2.5730, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6644, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1802, dtype=torch.float64)   实验回归误差 tensor(0.2179, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3228234322878214
# ########################################### 3 50 绝对误差 tensor(0.7363, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5252, dtype=torch.float64)   实验回归误差 tensor(0.2426, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.3213151630575315
# ########################################## 3 50 绝对误差 tensor(0.1626, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3741, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5514, dtype=torch.float64)   实验回归误差 tensor(0.1560, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4798521216344322
# ################################################# 3 50 绝对误差 tensor(1.8336, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0632, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1640, dtype=torch.float64)   实验回归误差 tensor(0.2001, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.4975696250004764
# ################################## 3 50 绝对误差 tensor(0.7388, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3782, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1083, dtype=torch.float64)   实验回归误差 tensor(0.1383, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   条件数 1.431932300637961
