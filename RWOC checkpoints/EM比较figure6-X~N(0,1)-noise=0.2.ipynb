# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(100,101,100): 
        for num_X2feature in [2,5,10,20]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1)=generatedata(noise=0.2)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.003
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    results_error.append(error_each)
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')

                #print('真实置换矩阵为：',true_P)
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print(num_X2feature,num_example,'置换矩阵误差：',error_P,end='   ')
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# #################################################### 2 100 平均相对误差2： tensor(0.9886, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4036, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3111, dtype=torch.float64)   实验回归误差 tensor(0.1400, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# #################### 2 100 平均相对误差2： tensor(1.1071, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2487, dtype=torch.float64)   实验回归误差 tensor(0.1748, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 2 100 平均相对误差2： tensor(1.0486, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1281, dtype=torch.float64)   实验回归误差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################## 2 100 平均相对误差2： tensor(0.1128, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2888, dtype=torch.float64)   实验回归误差 tensor(0.0942, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(1.4469, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1289, dtype=torch.float64)   实验回归误差 tensor(0.1211, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################## 2 100 平均相对误差2： tensor(2.9354, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1218, dtype=torch.float64)   实验回归误差 tensor(0.1392, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################## 2 100 平均相对误差2： tensor(0.8984, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0932, dtype=torch.float64)   实验回归误差 tensor(0.1125, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################ 2 100 平均相对误差2： tensor(2.8962, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1074, dtype=torch.float64)   实验回归误差 tensor(0.1631, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################ 2 100 平均相对误差2： tensor(1.5126, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0931, dtype=torch.float64)   实验回归误差 tensor(0.1376, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################### 2 100 平均相对误差2： tensor(1.3697, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0953, dtype=torch.float64)   实验回归误差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################# 5 100 平均相对误差2： tensor(2.8725, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0580, dtype=torch.float64)   实验回归误差 tensor(0.0737, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################### 5 100 平均相对误差2： tensor(1.6561, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1293, dtype=torch.float64)   实验回归误差 tensor(0.0933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################ 5 100 平均相对误差2： tensor(1.4591, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1286, dtype=torch.float64)   实验回归误差 tensor(0.1818, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 5 100 平均相对误差2： tensor(2.0097, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1166, dtype=torch.float64)   实验回归误差 tensor(0.1335, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 5 100 平均相对误差2： tensor(4.7698, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0566, dtype=torch.float64)   实验回归误差 tensor(0.1355, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################ 5 100 平均相对误差2： tensor(1.5786, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0959, dtype=torch.float64)   实验回归误差 tensor(0.1176, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################################################### 5 100 平均相对误差2： tensor(1.4755, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1024, dtype=torch.float64)   实验回归误差 tensor(0.1338, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################## 5 100 平均相对误差2： tensor(2.1338, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0981, dtype=torch.float64)   实验回归误差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################### 5 100 平均相对误差2： tensor(0.9425, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0795, dtype=torch.float64)   实验回归误差 tensor(0.0789, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 5 100 平均相对误差2： tensor(2.9526, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1237, dtype=torch.float64)   实验回归误差 tensor(0.1331, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################### 10 100 平均相对误差2： tensor(3.5097, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0694, dtype=torch.float64)   实验回归误差 tensor(0.1162, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################## 10 100 平均相对误差2： tensor(2.8995, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0524, dtype=torch.float64)   实验回归误差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 10 100 平均相对误差2： tensor(2.1007, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0587, dtype=torch.float64)   实验回归误差 tensor(0.1183, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################# 10 100 平均相对误差2： tensor(3.1429, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4107, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0775, dtype=torch.float64)   实验回归误差 tensor(0.0686, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ########################################################## 10 100 平均相对误差2： tensor(3.5393, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0728, dtype=torch.float64)   实验回归误差 tensor(0.0926, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################### 10 100 平均相对误差2： tensor(2.3768, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0823, dtype=torch.float64)   实验回归误差 tensor(0.0729, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################################################### 10 100 平均相对误差2： tensor(2.6037, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0691, dtype=torch.float64)   实验回归误差 tensor(0.0764, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################# 10 100 平均相对误差2： tensor(2.1593, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1022, dtype=torch.float64)   实验回归误差 tensor(0.1038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 10 100 平均相对误差2： tensor(6.1415, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0534, dtype=torch.float64)   实验回归误差 tensor(0.1156, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################## 10 100 平均相对误差2： tensor(3.0939, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0716, dtype=torch.float64)   实验回归误差 tensor(0.1007, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################### 20 100 平均相对误差2： tensor(7.2598, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0318, dtype=torch.float64)   实验回归误差 tensor(0.0817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################# 20 100 平均相对误差2： tensor(5.4409, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0476, dtype=torch.float64)   实验回归误差 tensor(0.0695, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 20 100 平均相对误差2： tensor(5.8761, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0520, dtype=torch.float64)   实验回归误差 tensor(0.0555, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 20 100 平均相对误差2： tensor(4.4387, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0444, dtype=torch.float64)   实验回归误差 tensor(0.0739, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################ 20 100 平均相对误差2： tensor(8.2981, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0383, dtype=torch.float64)   实验回归误差 tensor(0.0773, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################## 20 100 平均相对误差2： tensor(8.4033, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0370, dtype=torch.float64)   实验回归误差 tensor(0.0706, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 20 100 平均相对误差2： tensor(5.4564, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0428, dtype=torch.float64)   实验回归误差 tensor(0.0913, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################# 20 100 平均相对误差2： tensor(4.1408, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0348, dtype=torch.float64)   实验回归误差 tensor(0.0787, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################ 20 100 平均相对误差2： tensor(6.2447, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0433, dtype=torch.float64)   实验回归误差 tensor(0.0622, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################### 20 100 平均相对误差2： tensor(4.9590, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0422, dtype=torch.float64)   实验回归误差 tensor(0.0461, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################# 2 100 平均相对误差2： tensor(0.1921, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4675, dtype=torch.float64)   实验回归误差 tensor(0.1389, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################### 2 100 平均相对误差2： tensor(0.6176, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3544, dtype=torch.float64)   实验回归误差 tensor(0.1719, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################### 2 100 平均相对误差2： tensor(1.5983, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1267, dtype=torch.float64)   实验回归误差 tensor(0.1085, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################### 2 100 平均相对误差2： tensor(0.7986, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3027, dtype=torch.float64)   实验回归误差 tensor(0.0997, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################### 2 100 平均相对误差2： tensor(0.0353, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1703, dtype=torch.float64)   实验回归误差 tensor(0.0752, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################### 2 100 平均相对误差2： tensor(1.0293, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0680, dtype=torch.float64)   实验回归误差 tensor(0.0775, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 2 100 平均相对误差2： tensor(0.5464, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0970, dtype=torch.float64)   实验回归误差 tensor(0.0885, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################### 2 100 平均相对误差2： tensor(0.0506, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1580, dtype=torch.float64)   实验回归误差 tensor(0.0649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################### 2 100 平均相对误差2： tensor(1.4476, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1041, dtype=torch.float64)   实验回归误差 tensor(0.1028, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################# 2 100 平均相对误差2： tensor(1.1125, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1040, dtype=torch.float64)   实验回归误差 tensor(0.1425, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################### 5 100 平均相对误差2： tensor(1.9361, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1504, dtype=torch.float64)   实验回归误差 tensor(0.2265, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 5 100 平均相对误差2： tensor(0.2152, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2800, dtype=torch.float64)   实验回归误差 tensor(0.0824, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################## 5 100 平均相对误差2： tensor(1.4688, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1369, dtype=torch.float64)   实验回归误差 tensor(0.1378, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 5 100 平均相对误差2： tensor(2.7804, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1127, dtype=torch.float64)   实验回归误差 tensor(0.1050, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################## 5 100 平均相对误差2： tensor(1.0566, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4042, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2189, dtype=torch.float64)   实验回归误差 tensor(0.1040, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ############################################################################################### 5 100 平均相对误差2： tensor(0.8939, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3824, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1460, dtype=torch.float64)   实验回归误差 tensor(0.1512, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ################################################################# 5 100 平均相对误差2： tensor(3.5103, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0998, dtype=torch.float64)   实验回归误差 tensor(0.1807, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 5 100 平均相对误差2： tensor(1.0369, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2370, dtype=torch.float64)   实验回归误差 tensor(0.1095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 5 100 平均相对误差2： tensor(1.8304, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1250, dtype=torch.float64)   实验回归误差 tensor(0.1842, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################################### 5 100 平均相对误差2： tensor(2.3345, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1017, dtype=torch.float64)   实验回归误差 tensor(0.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################ 10 100 平均相对误差2： tensor(4.0019, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0717, dtype=torch.float64)   实验回归误差 tensor(0.1107, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################################### 10 100 平均相对误差2： tensor(3.0667, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0580, dtype=torch.float64)   实验回归误差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################## 10 100 平均相对误差2： tensor(2.5368, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0682, dtype=torch.float64)   实验回归误差 tensor(0.0676, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################## 10 100 平均相对误差2： tensor(3.8426, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0635, dtype=torch.float64)   实验回归误差 tensor(0.1275, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 10 100 平均相对误差2： tensor(3.4438, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0522, dtype=torch.float64)   实验回归误差 tensor(0.0712, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################################################################### 10 100 平均相对误差2： tensor(5.0462, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0504, dtype=torch.float64)   实验回归误差 tensor(0.1282, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################## 10 100 平均相对误差2： tensor(1.8171, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1605, dtype=torch.float64)   实验回归误差 tensor(0.1522, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################### 10 100 平均相对误差2： tensor(2.8768, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0597, dtype=torch.float64)   实验回归误差 tensor(0.1326, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 10 100 平均相对误差2： tensor(3.2635, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0903, dtype=torch.float64)   实验回归误差 tensor(0.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################## 10 100 平均相对误差2： tensor(3.2658, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3992, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0917, dtype=torch.float64)   实验回归误差 tensor(0.0963, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 98
# ################################################################# 20 100 平均相对误差2： tensor(4.7690, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0520, dtype=torch.float64)   实验回归误差 tensor(0.0470, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################ 20 100 平均相对误差2： tensor(6.4132, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0439, dtype=torch.float64)   实验回归误差 tensor(0.0906, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 20 100 平均相对误差2： tensor(6.4064, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0467, dtype=torch.float64)   实验回归误差 tensor(0.0555, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################### 20 100 平均相对误差2： tensor(5.2067, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0509, dtype=torch.float64)   实验回归误差 tensor(0.0841, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 20 100 平均相对误差2： tensor(4.6901, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0474, dtype=torch.float64)   实验回归误差 tensor(0.0711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 20 100 平均相对误差2： tensor(6.9350, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0368, dtype=torch.float64)   实验回归误差 tensor(0.0601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################## 20 100 平均相对误差2： tensor(3.5666, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0504, dtype=torch.float64)   实验回归误差 tensor(0.1031, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################## 20 100 平均相对误差2： tensor(6.6454, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0393, dtype=torch.float64)   实验回归误差 tensor(0.0702, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################### 20 100 平均相对误差2： tensor(5.0917, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0362, dtype=torch.float64)   实验回归误差 tensor(0.0660, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################### 20 100 平均相对误差2： tensor(4.7703, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0410, dtype=torch.float64)   实验回归误差 tensor(0.0725, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################### 2 100 平均相对误差2： tensor(1.0200, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1308, dtype=torch.float64)   实验回归误差 tensor(0.0922, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################### 2 100 平均相对误差2： tensor(0.0875, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2410, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1453, dtype=torch.float64)   实验回归误差 tensor(0.0543, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(1.0525, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1000, dtype=torch.float64)   实验回归误差 tensor(0.1616, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################### 2 100 平均相对误差2： tensor(0.2190, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1871, dtype=torch.float64)   实验回归误差 tensor(0.0799, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################### 2 100 平均相对误差2： tensor(1.2650, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1913, dtype=torch.float64)   实验回归误差 tensor(0.1473, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############### 2 100 平均相对误差2： tensor(0.4840, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2621, dtype=torch.float64)   实验回归误差 tensor(0.1372, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################## 2 100 平均相对误差2： tensor(2.2691, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1071, dtype=torch.float64)   实验回归误差 tensor(0.2345, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############## 2 100 平均相对误差2： tensor(1.9738, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0813, dtype=torch.float64)   实验回归误差 tensor(0.0876, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################ 2 100 平均相对误差2： tensor(0.5258, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1615, dtype=torch.float64)   实验回归误差 tensor(0.0843, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 2 100 平均相对误差2： tensor(0.4260, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1694, dtype=torch.float64)   实验回归误差 tensor(0.0807, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 5 100 平均相对误差2： tensor(2.8367, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0806, dtype=torch.float64)   实验回归误差 tensor(0.0988, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################### 5 100 平均相对误差2： tensor(2.3967, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0910, dtype=torch.float64)   实验回归误差 tensor(0.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################### 5 100 平均相对误差2： tensor(1.8907, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1225, dtype=torch.float64)   实验回归误差 tensor(0.1310, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################### 5 100 平均相对误差2： tensor(2.0271, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0953, dtype=torch.float64)   实验回归误差 tensor(0.1378, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# #################################################################################### 5 100 平均相对误差2： tensor(3.2861, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1129, dtype=torch.float64)   实验回归误差 tensor(0.1368, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 5 100 平均相对误差2： tensor(1.7054, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1026, dtype=torch.float64)   实验回归误差 tensor(0.1458, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 5 100 平均相对误差2： tensor(1.5494, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1371, dtype=torch.float64)   实验回归误差 tensor(0.0912, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################ 5 100 平均相对误差2： tensor(3.3850, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0683, dtype=torch.float64)   实验回归误差 tensor(0.1310, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################## 5 100 平均相对误差2： tensor(3.0548, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0654, dtype=torch.float64)   实验回归误差 tensor(0.1241, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################# 5 100 平均相对误差2： tensor(1.1403, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2108, dtype=torch.float64)   实验回归误差 tensor(0.1480, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################################### 10 100 平均相对误差2： tensor(4.6703, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0777, dtype=torch.float64)   实验回归误差 tensor(0.1061, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################ 10 100 平均相对误差2： tensor(2.2806, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1019, dtype=torch.float64)   实验回归误差 tensor(0.0993, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################## 10 100 平均相对误差2： tensor(4.0296, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0626, dtype=torch.float64)   实验回归误差 tensor(0.0768, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################## 10 100 平均相对误差2： tensor(3.3423, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0837, dtype=torch.float64)   实验回归误差 tensor(0.1715, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################### 10 100 平均相对误差2： tensor(3.1790, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0873, dtype=torch.float64)   实验回归误差 tensor(0.0626, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ####################################################################################################### 10 100 平均相对误差2： tensor(5.0214, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0701, dtype=torch.float64)   实验回归误差 tensor(0.0962, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 10 100 平均相对误差2： tensor(1.6636, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0984, dtype=torch.float64)   实验回归误差 tensor(0.1015, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################ 10 100 平均相对误差2： tensor(2.9115, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0679, dtype=torch.float64)   实验回归误差 tensor(0.0648, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################################################################################## 10 100 平均相对误差2： tensor(5.3553, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0575, dtype=torch.float64)   实验回归误差 tensor(0.0942, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################## 10 100 平均相对误差2： tensor(4.1230, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0409, dtype=torch.float64)   实验回归误差 tensor(0.1471, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################################## 20 100 平均相对误差2： tensor(5.5320, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0469, dtype=torch.float64)   实验回归误差 tensor(0.0715, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 20 100 平均相对误差2： tensor(7.3852, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0374, dtype=torch.float64)   实验回归误差 tensor(0.0941, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################ 20 100 平均相对误差2： tensor(6.6259, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0351, dtype=torch.float64)   实验回归误差 tensor(0.1028, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################ 20 100 平均相对误差2： tensor(4.1294, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0739, dtype=torch.float64)   实验回归误差 tensor(0.0531, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################### 20 100 平均相对误差2： tensor(7.6635, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0317, dtype=torch.float64)   实验回归误差 tensor(0.0841, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 20 100 平均相对误差2： tensor(5.3213, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0510, dtype=torch.float64)   实验回归误差 tensor(0.0973, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################### 20 100 平均相对误差2： tensor(5.3197, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0473, dtype=torch.float64)   实验回归误差 tensor(0.0578, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################################################### 20 100 平均相对误差2： tensor(6.0195, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0304, dtype=torch.float64)   实验回归误差 tensor(0.0634, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ###################################################################################### 20 100 平均相对误差2： tensor(6.4139, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0397, dtype=torch.float64)   实验回归误差 tensor(0.0758, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################ 20 100 平均相对误差2： tensor(8.2188, dtype=torch.float64, grad_fn=<NormBackward0>)   20 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0381, dtype=torch.float64)   实验回归误差 tensor(0.0713, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################# 2 100 平均相对误差2： tensor(0.0371, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3342, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1750, dtype=torch.float64)   实验回归误差 tensor(0.0693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 2 100 平均相对误差2： tensor(0.1374, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0873, dtype=torch.float64)   实验回归误差 tensor(0.0426, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################# 2 100 平均相对误差2： tensor(0.6641, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3184, dtype=torch.float64)   实验回归误差 tensor(0.1652, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################## 2 100 平均相对误差2： tensor(1.3942, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2083, dtype=torch.float64)   实验回归误差 tensor(0.1050, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################# 2 100 平均相对误差2： tensor(2.4162, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0467, dtype=torch.float64)   实验回归误差 tensor(0.1114, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################### 2 100 平均相对误差2： tensor(0.0435, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1665, dtype=torch.float64)   实验回归误差 tensor(0.0604, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################### 2 100 平均相对误差2： tensor(2.1584, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1201, dtype=torch.float64)   实验回归误差 tensor(0.1487, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############ 2 100 平均相对误差2： tensor(0.0286, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1287, dtype=torch.float64)   实验回归误差 tensor(0.0635, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################## 2 100 平均相对误差2： tensor(1.1713, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1141, dtype=torch.float64)   实验回归误差 tensor(0.1091, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################## 2 100 平均相对误差2： tensor(3.6858, dtype=torch.float64, grad_fn=<NormBackward0>)   2 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0687, dtype=torch.float64)   实验回归误差 tensor(0.1573, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################################################### 5 100 平均相对误差2： tensor(1.4136, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0998, dtype=torch.float64)   实验回归误差 tensor(0.0887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################## 5 100 平均相对误差2： tensor(0.5755, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2749, dtype=torch.float64)   实验回归误差 tensor(0.1189, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################## 5 100 平均相对误差2： tensor(0.7957, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1300, dtype=torch.float64)   实验回归误差 tensor(0.1009, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################## 5 100 平均相对误差2： tensor(2.3986, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0928, dtype=torch.float64)   实验回归误差 tensor(0.1030, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################### 5 100 平均相对误差2： tensor(1.0225, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1158, dtype=torch.float64)   实验回归误差 tensor(0.1468, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################## 5 100 平均相对误差2： tensor(1.6390, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1571, dtype=torch.float64)   实验回归误差 tensor(0.1889, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ##################################################################################################################### 5 100 平均相对误差2： tensor(2.8340, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0911, dtype=torch.float64)   实验回归误差 tensor(0.1960, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################## 5 100 平均相对误差2： tensor(1.4915, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1899, dtype=torch.float64)   实验回归误差 tensor(0.1299, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################# 5 100 平均相对误差2： tensor(1.2669, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0717, dtype=torch.float64)   实验回归误差 tensor(0.0962, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ######################################################################### 5 100 平均相对误差2： tensor(1.8811, dtype=torch.float64, grad_fn=<NormBackward0>)   5 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0960, dtype=torch.float64)   实验回归误差 tensor(0.1141, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################ 10 100 平均相对误差2： tensor(4.0293, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0502, dtype=torch.float64)   实验回归误差 tensor(0.0815, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################################################# 10 100 平均相对误差2： tensor(2.8700, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0591, dtype=torch.float64)   实验回归误差 tensor(0.1246, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################################ 10 100 平均相对误差2： tensor(7.1035, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0489, dtype=torch.float64)   实验回归误差 tensor(0.0856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################################# 10 100 平均相对误差2： tensor(6.4950, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0422, dtype=torch.float64)   实验回归误差 tensor(0.1020, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################ 10 100 平均相对误差2： tensor(2.9968, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0636, dtype=torch.float64)   实验回归误差 tensor(0.1391, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################### 10 100 平均相对误差2： tensor(6.1450, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.3928, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0498, dtype=torch.float64)   实验回归误差 tensor(0.0937, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ################################################################################ 10 100 平均相对误差2： tensor(3.1417, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0669, dtype=torch.float64)   实验回归误差 tensor(0.1178, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########################################################################################### 10 100 平均相对误差2： tensor(2.6918, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0803, dtype=torch.float64)   实验回归误差 tensor(0.0486, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ############################################################################################################ 10 100 平均相对误差2： tensor(2.7928, dtype=torch.float64, grad_fn=<NormBackward0>)   10 100 置换矩阵误差： tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0885, dtype=torch.float64)   实验回归误差 tensor(0.1025, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 100
# ########
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3cab0e4ee7fa> in <module>()
#      51                         if Loss<1e-2:
#      52                             break
# ---> 53                         Loss.backward()
#      54     #                         results_Loss.append(Loss)
#      55     #                         for i_ in range(num_X1features):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:
