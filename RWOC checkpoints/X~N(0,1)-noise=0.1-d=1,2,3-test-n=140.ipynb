# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(2):
    for num_example in range(140,141,100): 
        for num_X2feature in [3,2,1]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ################################################## 3 140 w绝对误差 tensor(2.6672, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4761, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0592, dtype=torch.float64)   实验回归残差 tensor(0.0875, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0575, dtype=torch.float64)   测试集实验回归残差 tensor(0.2407, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1938291801658079
# ################################################################### 3 140 w绝对误差 tensor(1.7835, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1251, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0669, dtype=torch.float64)   实验回归残差 tensor(0.0807, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0553, dtype=torch.float64)   测试集实验回归残差 tensor(0.2285, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1086809608796042
# ################################ 3 140 w绝对误差 tensor(0.4548, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2745, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0631, dtype=torch.float64)   实验回归残差 tensor(0.0677, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0484, dtype=torch.float64)   测试集实验回归残差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3512, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2591725170002175
# ###################### 3 140 w绝对误差 tensor(1.0448, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0686, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1037, dtype=torch.float64)   实验回归残差 tensor(0.1181, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1042, dtype=torch.float64)   测试集实验回归残差 tensor(0.1390, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4117, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2100360276735624
# ################################ 3 140 w绝对误差 tensor(1.2302, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9952, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0826, dtype=torch.float64)   实验回归残差 tensor(0.0941, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0741, dtype=torch.float64)   测试集实验回归残差 tensor(0.1658, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2881888723691142
# ################################################ 3 140 w绝对误差 tensor(0.4858, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0514, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2257, dtype=torch.float64)   实验回归残差 tensor(0.1166, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2286, dtype=torch.float64)   测试集实验回归残差 tensor(0.2112, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 134   条件数 1.1565325400227109
# ####################### 3 140 w绝对误差 tensor(0.5913, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5198, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0880, dtype=torch.float64)   实验回归残差 tensor(0.0915, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0770, dtype=torch.float64)   测试集实验回归残差 tensor(0.1137, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3864, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4134, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.1275974113376022
# #################### 3 140 w绝对误差 tensor(2.1524, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1890, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0560, dtype=torch.float64)   实验回归残差 tensor(0.1329, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0523, dtype=torch.float64)   测试集实验回归残差 tensor(0.3357, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1718980164356845
# ##################### 3 140 w绝对误差 tensor(1.2095, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6479, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0511, dtype=torch.float64)   实验回归残差 tensor(0.1034, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0641, dtype=torch.float64)   测试集实验回归残差 tensor(0.1630, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1175567025472972
# ############################### 3 140 w绝对误差 tensor(3.7422, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4729, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0390, dtype=torch.float64)   实验回归残差 tensor(0.1266, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0339, dtype=torch.float64)   测试集实验回归残差 tensor(0.1664, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.133098494453396
# ##################################### 2 140 w绝对误差 tensor(2.6609, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8298, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0573, dtype=torch.float64)   实验回归残差 tensor(0.1477, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0702, dtype=torch.float64)   测试集实验回归残差 tensor(0.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.117920142110091
# ################## 2 140 w绝对误差 tensor(1.4639, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2494, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0788, dtype=torch.float64)   实验回归残差 tensor(0.1195, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0861, dtype=torch.float64)   测试集实验回归残差 tensor(0.2337, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1689878741396453
# ##################################### 2 140 w绝对误差 tensor(0.3366, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5544, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3869, dtype=torch.float64)   实验回归残差 tensor(0.1542, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4531, dtype=torch.float64)   测试集实验回归残差 tensor(0.2528, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4131, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.1359864925099146
# ######################### 2 140 w绝对误差 tensor(0.3224, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3348, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4100, dtype=torch.float64)   实验回归残差 tensor(0.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3859, dtype=torch.float64)   测试集实验回归残差 tensor(0.2204, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4015, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4118, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.3210700124738977
# ########################################## 2 140 w绝对误差 tensor(0.0361, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0523, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1432, dtype=torch.float64)   实验回归残差 tensor(0.0563, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1409, dtype=torch.float64)   测试集实验回归残差 tensor(0.0566, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3363, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3408, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 136   条件数 1.1239423249051286
# ######################### 2 140 w绝对误差 tensor(1.7214, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0942, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0562, dtype=torch.float64)   实验回归残差 tensor(0.1711, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0633, dtype=torch.float64)   测试集实验回归残差 tensor(0.1719, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.155509212114617
# ###################### 2 140 w绝对误差 tensor(0.8008, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4275, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1580, dtype=torch.float64)   实验回归残差 tensor(0.1592, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1826, dtype=torch.float64)   测试集实验回归残差 tensor(0.3213, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1366102033097105
# ########################### 2 140 w绝对误差 tensor(0.5404, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5129, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2495, dtype=torch.float64)   实验回归残差 tensor(0.0976, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2628, dtype=torch.float64)   测试集实验回归残差 tensor(0.2060, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4079, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4090, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1253606362853514
# #################### 2 140 w绝对误差 tensor(1.6659, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1201, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0694, dtype=torch.float64)   实验回归残差 tensor(0.1026, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0585, dtype=torch.float64)   测试集实验回归残差 tensor(0.1748, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1198955610938717
# #################################################################### 2 140 w绝对误差 tensor(1.5458, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5774, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0351, dtype=torch.float64)   实验回归残差 tensor(0.0835, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0396, dtype=torch.float64)   测试集实验回归残差 tensor(0.1239, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0755476048745576
# ############# 1 140 w绝对误差 tensor(0.0577, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6798, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.7693, dtype=torch.float64)   实验回归残差 tensor(0.1706, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7322, dtype=torch.float64)   测试集实验回归残差 tensor(0.2179, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3979, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 132   测试集置换矩阵误差 tensor(1.3965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 134   条件数 1.0
# ############################## 1 140 w绝对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0011, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1050, dtype=torch.float64)   实验回归残差 tensor(0.0447, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1142, dtype=torch.float64)   测试集实验回归残差 tensor(0.0563, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3202, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3148, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ##################################################################### 1 140 w绝对误差 tensor(0.4148, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.1268, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4185, dtype=torch.float64)   实验回归残差 tensor(0.0977, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4562, dtype=torch.float64)   测试集实验回归残差 tensor(0.2487, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4042, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.4139, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ####################################################### 1 140 w绝对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0135, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1291, dtype=torch.float64)   实验回归残差 tensor(0.0711, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1581, dtype=torch.float64)   测试集实验回归残差 tensor(0.0681, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3363, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3510, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ################# 1 140 w绝对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0080, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1506, dtype=torch.float64)   实验回归残差 tensor(0.0676, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1652, dtype=torch.float64)   测试集实验回归残差 tensor(0.0796, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3575, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3310, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################################ 1 140 w绝对误差 tensor(0.0121, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0085, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0685, dtype=torch.float64)   实验回归残差 tensor(0.0362, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0835, dtype=torch.float64)   测试集实验回归残差 tensor(0.0417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ########################################################################################################### 1 140 w绝对误差 tensor(0.0088, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0055, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0557, dtype=torch.float64)   实验回归残差 tensor(0.0368, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0602, dtype=torch.float64)   测试集实验回归残差 tensor(0.0351, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2479, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ############### 1 140 w绝对误差 tensor(0.6024, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0776, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3435, dtype=torch.float64)   实验回归残差 tensor(0.1177, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3125, dtype=torch.float64)   测试集实验回归残差 tensor(0.0771, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4117, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4089, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################################ 1 140 w绝对误差 tensor(0.0061, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0106, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1817, dtype=torch.float64)   实验回归残差 tensor(0.0540, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1716, dtype=torch.float64)   测试集实验回归残差 tensor(0.0586, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3680, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3575, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################################# 1 140 w绝对误差 tensor(0.1348, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(4.1243, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9269, dtype=torch.float64)   实验回归残差 tensor(0.2469, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.9298, dtype=torch.float64)   测试集实验回归残差 tensor(0.2494, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4035, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 134   测试集置换矩阵误差 tensor(1.4002, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 129   条件数 1.0
# ###################### 3 140 w绝对误差 tensor(2.0188, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4212, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0690, dtype=torch.float64)   实验回归残差 tensor(0.0759, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0645, dtype=torch.float64)   测试集实验回归残差 tensor(0.1641, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.199799658643495
# ############################### 3 140 w绝对误差 tensor(0.2699, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5716, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2132, dtype=torch.float64)   实验回归残差 tensor(0.0855, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1975, dtype=torch.float64)   测试集实验回归残差 tensor(0.1497, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3972, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2341439651992907
# ############################ 3 140 w绝对误差 tensor(3.5479, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2747, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0350, dtype=torch.float64)   实验回归残差 tensor(0.1022, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0374, dtype=torch.float64)   测试集实验回归残差 tensor(0.1516, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1209829467019614
# ################# 3 140 w绝对误差 tensor(0.9463, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2690, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1400, dtype=torch.float64)   实验回归残差 tensor(0.1601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1310, dtype=torch.float64)   测试集实验回归残差 tensor(0.1193, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.269771070676022
# ################################## 3 140 w绝对误差 tensor(1.3575, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6451, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1224, dtype=torch.float64)   实验回归残差 tensor(0.1030, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1110, dtype=torch.float64)   测试集实验回归残差 tensor(0.1733, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1586332481770207
# ########################################################################################### 3 140 w绝对误差 tensor(0.9831, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4963, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0522, dtype=torch.float64)   实验回归残差 tensor(0.0679, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0490, dtype=torch.float64)   测试集实验回归残差 tensor(0.1430, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3814, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2471011139986412
# ############################################ 3 140 w绝对误差 tensor(2.0181, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7628, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0345, dtype=torch.float64)   实验回归残差 tensor(0.0965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0391, dtype=torch.float64)   测试集实验回归残差 tensor(0.2111, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.321897433764972
# ##################################### 3 140 w绝对误差 tensor(2.5194, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0396, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0417, dtype=torch.float64)   实验回归残差 tensor(0.1379, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0402, dtype=torch.float64)   测试集实验回归残差 tensor(0.2067, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.111369615090226
# ############################## 3 140 w绝对误差 tensor(1.3506, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3637, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1103, dtype=torch.float64)   实验回归残差 tensor(0.1653, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1070, dtype=torch.float64)   测试集实验回归残差 tensor(0.1831, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1376461355990863
# #################################### 2 140 w绝对误差 tensor(0.0021, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0007, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0363, dtype=torch.float64)   实验回归残差 tensor(0.0230, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0327, dtype=torch.float64)   测试集实验回归残差 tensor(0.0241, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1772, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.1339, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0603402925316372
# ################################################# 2 140 w绝对误差 tensor(1.1837, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3279, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1034, dtype=torch.float64)   实验回归残差 tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1168, dtype=torch.float64)   测试集实验回归残差 tensor(0.2562, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0487645735184616
# ######################### 2 140 w绝对误差 tensor(1.3120, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8116, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0586, dtype=torch.float64)   实验回归残差 tensor(0.1305, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0599, dtype=torch.float64)   测试集实验回归残差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.092225960111905
# ############################################################################################## 2 140 w绝对误差 tensor(0.0062, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0031, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0518, dtype=torch.float64)   实验回归残差 tensor(0.0329, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0500, dtype=torch.float64)   测试集实验回归残差 tensor(0.0326, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.1650, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1629649888240765
# ########################################################################################## 2 140 w绝对误差 tensor(0.0255, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0176, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0659, dtype=torch.float64)   实验回归残差 tensor(0.0358, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0603, dtype=torch.float64)   测试集实验回归残差 tensor(0.0391, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0722383214260314
# ############################################ 2 140 w绝对误差 tensor(1.0793, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0096, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1086, dtype=torch.float64)   实验回归残差 tensor(0.1159, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0804, dtype=torch.float64)   测试集实验回归残差 tensor(0.1881, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1920943616341522
# ############################################# 2 140 w绝对误差 tensor(2.0228, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9559, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0480, dtype=torch.float64)   实验回归残差 tensor(0.0913, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0464, dtype=torch.float64)   测试集实验回归残差 tensor(0.1924, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0490582066212428
# ################ 2 140 w绝对误差 tensor(0.7991, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9712, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1077, dtype=torch.float64)   实验回归残差 tensor(0.1417, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1115, dtype=torch.float64)   测试集实验回归残差 tensor(0.2298, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.236818873050854
# ############################ 2 140 w绝对误差 tensor(0.0183, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0160, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0902, dtype=torch.float64)   实验回归残差 tensor(0.0462, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0895, dtype=torch.float64)   测试集实验回归残差 tensor(0.0455, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2025428273843741
# ####################################################### 2 140 w绝对误差 tensor(1.6804, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4124, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0883, dtype=torch.float64)   实验回归残差 tensor(0.0893, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0730, dtype=torch.float64)   测试集实验回归残差 tensor(0.5078, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1372826654859303
# ##################### 1 140 w绝对误差 tensor(0.0055, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0026, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0457, dtype=torch.float64)   实验回归残差 tensor(0.0293, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0454, dtype=torch.float64)   测试集实验回归残差 tensor(0.0289, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2012, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ########## 1 140 w绝对误差 tensor(0.0024, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0024, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1014, dtype=torch.float64)   实验回归残差 tensor(0.0458, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0890, dtype=torch.float64)   测试集实验回归残差 tensor(0.0392, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# #################################################### 1 140 w绝对误差 tensor(0.0090, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0073, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0857, dtype=torch.float64)   实验回归残差 tensor(0.0575, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0817, dtype=torch.float64)   测试集实验回归残差 tensor(0.0450, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2762, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################# 1 140 w绝对误差 tensor(1.0782, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0052, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1867, dtype=torch.float64)   实验回归残差 tensor(0.1635, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1746, dtype=torch.float64)   测试集实验回归残差 tensor(0.4951, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4072, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 134   条件数 1.0
# ##################### 1 140 w绝对误差 tensor(0.0123, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0062, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0521, dtype=torch.float64)   实验回归残差 tensor(0.0322, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0555, dtype=torch.float64)   测试集实验回归残差 tensor(0.0364, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2299, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ################## 1 140 w绝对误差 tensor(0.0079, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0235, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2875, dtype=torch.float64)   实验回归残差 tensor(0.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3081, dtype=torch.float64)   测试集实验回归残差 tensor(0.0788, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3627, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ############## 1 140 w绝对误差 tensor(0.0314, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1074, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3379, dtype=torch.float64)   实验回归残差 tensor(0.0969, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3448, dtype=torch.float64)   测试集实验回归残差 tensor(0.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3779, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3612, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ############################################ 1 140 w绝对误差 tensor(0.0126, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0136, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0974, dtype=torch.float64)   实验回归残差 tensor(0.0462, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1067, dtype=torch.float64)   测试集实验回归残差 tensor(0.0444, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3093, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2928, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ############################# 1 140 w绝对误差 tensor(0.0127, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0129, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1032, dtype=torch.float64)   实验回归残差 tensor(0.0513, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0968, dtype=torch.float64)   测试集实验回归残差 tensor(0.0493, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################ 1 140 w绝对误差 tensor(0.0570, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7386, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.7922, dtype=torch.float64)   实验回归残差 tensor(0.1531, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.8258, dtype=torch.float64)   测试集实验回归残差 tensor(0.1467, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3924, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 136   条件数 1.0
