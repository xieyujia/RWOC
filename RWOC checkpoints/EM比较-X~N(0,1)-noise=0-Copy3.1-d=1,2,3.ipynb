# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(150,151,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.002
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############### 1 150 绝对误差 tensor(2.0357, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9834, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1083, dtype=torch.float64)   实验回归误差 tensor(0.2342, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################### 1 150 绝对误差 tensor(0.0110, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0148, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1183, dtype=torch.float64)   实验回归误差 tensor(0.0475, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0205, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0102, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0533, dtype=torch.float64)   实验回归误差 tensor(0.0320, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2383, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0123, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0125, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0966, dtype=torch.float64)   实验回归误差 tensor(0.0417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3064, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0262, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1858, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5685, dtype=torch.float64)   实验回归误差 tensor(0.1455, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3976, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ############## 1 150 绝对误差 tensor(1.4618e-05, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(9.7218e-06, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0650, dtype=torch.float64)   实验回归误差 tensor(0.0380, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# # 1 150 绝对误差 tensor(0.0347, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3498, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6711, dtype=torch.float64)   实验回归误差 tensor(0.8305, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9950, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 0   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0227, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0612, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2505, dtype=torch.float64)   实验回归误差 tensor(0.0778, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0194, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0999, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4856, dtype=torch.float64)   实验回归误差 tensor(0.1222, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3880, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################################# 2 150 绝对误差 tensor(0.0561, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0260, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0491, dtype=torch.float64)   实验回归误差 tensor(0.0297, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2702, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0577471080343048
# ################################################################################ 2 150 绝对误差 tensor(0.2895, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1844, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0562, dtype=torch.float64)   实验回归误差 tensor(0.0717, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.055069230784614
# ################# 2 150 绝对误差 tensor(0.0072, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0146, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2031, dtype=torch.float64)   实验回归误差 tensor(0.0659, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1150762714873446
# ######################### 2 150 绝对误差 tensor(1.2959, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0723, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0700, dtype=torch.float64)   实验回归误差 tensor(0.1201, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4090, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0126687554935963
# ################################################################## 2 150 绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0044, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0396, dtype=torch.float64)   实验回归误差 tensor(0.0231, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.116102783080556
# ################################################################################################################################## 2 150 绝对误差 tensor(0.0238, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0093, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0396, dtype=torch.float64)   实验回归误差 tensor(0.0231, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2055, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0430008016454873
# ############################################################################################ 2 150 绝对误差 tensor(0.2332, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5272, dtype=torch.float64)   实验回归误差 tensor(0.1410, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4088, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0570827964601177
# ####################################################################################### 2 150 绝对误差 tensor(0.0102, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0094, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0893, dtype=torch.float64)   实验回归误差 tensor(0.0403, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.29566724679964
# ############################################ 2 150 绝对误差 tensor(1.0534, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1144, dtype=torch.float64)   实验回归误差 tensor(0.1482, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1267146522404878
# #################################################################### 2 150 绝对误差 tensor(0.8064, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0700, dtype=torch.float64)   实验回归误差 tensor(0.0976, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.074750892094729
# ############################### 3 150 绝对误差 tensor(0.6688, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3180, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0546, dtype=torch.float64)   实验回归误差 tensor(0.0774, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2502528030274034
# #################################################################################################### 3 150 绝对误差 tensor(2.2223, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7210, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0718, dtype=torch.float64)   实验回归误差 tensor(0.1570, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4137, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1131676905979915
# ################################################################################################################################################# 3 150 绝对误差 tensor(1.8174, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6164, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0892, dtype=torch.float64)   实验回归误差 tensor(0.1200, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1381610986048842
# ############################## 3 150 绝对误差 tensor(1.1370, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7920, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0732, dtype=torch.float64)   实验回归误差 tensor(0.1457, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2211867516771924
# ################################################################################################ 3 150 绝对误差 tensor(1.3026, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5661, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0499, dtype=torch.float64)   实验回归误差 tensor(0.0929, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0901425007884724
# ###################################################################################################################################################### 3 150 绝对误差 tensor(1.5478, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7356, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0473, dtype=torch.float64)   实验回归误差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2714231160658236
# ########################### 3 150 绝对误差 tensor(1.0903, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9246, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0921, dtype=torch.float64)   实验回归误差 tensor(0.1436, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.120236632033928
# ######################################################################################################################################################################### 3 150 绝对误差 tensor(0.0383, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0189, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0436, dtype=torch.float64)   实验回归误差 tensor(0.0301, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1776, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.3205685035659425
# ############################################## 3 150 绝对误差 tensor(1.1442, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9189, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0756, dtype=torch.float64)   实验回归误差 tensor(0.0961, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2025121193433315
# ##################################################### 3 150 绝对误差 tensor(0.8308, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2527, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1826, dtype=torch.float64)   实验回归误差 tensor(0.1532, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2500762065390205
# ################ 1 150 绝对误差 tensor(0.0132, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0266, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1956, dtype=torch.float64)   实验回归误差 tensor(0.0659, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3553, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0288, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0997, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3444, dtype=torch.float64)   实验回归误差 tensor(0.0895, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3896, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0136, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0316, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2599, dtype=torch.float64)   实验回归误差 tensor(0.0792, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.2902, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.3934, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5491, dtype=torch.float64)   实验回归误差 tensor(0.1078, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4044, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0498, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7985, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8454, dtype=torch.float64)   实验回归误差 tensor(0.1153, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0045, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0141, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3431, dtype=torch.float64)   实验回归误差 tensor(0.0811, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3564, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0004, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0004, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1028, dtype=torch.float64)   实验回归误差 tensor(0.0451, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0507, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5084, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6810, dtype=torch.float64)   实验回归误差 tensor(0.1699, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ################ 1 150 绝对误差 tensor(1.1336, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9945, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1936, dtype=torch.float64)   实验回归误差 tensor(0.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4128, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 146   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0103, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0340, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3160, dtype=torch.float64)   实验回归误差 tensor(0.0718, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3564, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############################################################################################## 2 150 绝对误差 tensor(0.0085, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0046, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0567, dtype=torch.float64)   实验回归误差 tensor(0.0337, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2543, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0147547397885444
# ############################ 2 150 绝对误差 tensor(0.7884, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4919, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0590, dtype=torch.float64)   实验回归误差 tensor(0.0934, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2005500775023086
# ########################################################################################################################################################################################################超过迭代上限
#  2 150 绝对误差 tensor(0.0600, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0506, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0829, dtype=torch.float64)   实验回归误差 tensor(0.0458, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.048624704306101
# ############################################## 2 150 绝对误差 tensor(0.7880, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7311, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0926, dtype=torch.float64)   实验回归误差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4047, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0959976222240184
# ########################################### 2 150 绝对误差 tensor(0.5177, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2750, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0606, dtype=torch.float64)   实验回归误差 tensor(0.0681, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0830860707423113
# ##################################################### 2 150 绝对误差 tensor(0.2328, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2075, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0911, dtype=torch.float64)   实验回归误差 tensor(0.0769, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1506475107101362
# ###################################################### 2 150 绝对误差 tensor(0.0271, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0261, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0959, dtype=torch.float64)   实验回归误差 tensor(0.0435, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3064, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.013420061130522
# ##################################################################################### 2 150 绝对误差 tensor(0.0331, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0259, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0699, dtype=torch.float64)   实验回归误差 tensor(0.0332, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2754, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1267589581290292
# ################################ 2 150 绝对误差 tensor(1.5498, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0590, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0686, dtype=torch.float64)   实验回归误差 tensor(0.1651, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1159411125550773
# ################# 2 150 绝对误差 tensor(0.4376, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7386, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2017, dtype=torch.float64)   实验回归误差 tensor(0.1203, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0408092161176772
# ########################### 3 150 绝对误差 tensor(1.5265, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0090, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0737, dtype=torch.float64)   实验回归误差 tensor(0.1506, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2096603248553457
# ############ 3 150 绝对误差 tensor(1.9104, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1895, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0585, dtype=torch.float64)   实验回归误差 tensor(0.2030, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1202186701610728
# ######################### 3 150 绝对误差 tensor(1.1697, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9423, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0798, dtype=torch.float64)   实验回归误差 tensor(0.1065, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.130903092387515
# ################################################# 3 150 绝对误差 tensor(2.9030, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.6076, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0509, dtype=torch.float64)   实验回归误差 tensor(0.1507, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1792663420897438
# ######################################################################################################################## 3 150 绝对误差 tensor(1.8835, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7845, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0442, dtype=torch.float64)   实验回归误差 tensor(0.0743, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1151017629906796
# #################################################################################### 3 150 绝对误差 tensor(2.1895, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4185, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0756, dtype=torch.float64)   实验回归误差 tensor(0.0818, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1911145222627832
# ################################### 3 150 绝对误差 tensor(2.1129, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0782, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0561, dtype=torch.float64)   实验回归误差 tensor(0.1371, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1457652712084532
# #################### 3 150 绝对误差 tensor(2.7062, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2396, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0432, dtype=torch.float64)   实验回归误差 tensor(0.1112, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0705036617629131
# ################### 3 150 绝对误差 tensor(1.1890, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2274, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0937, dtype=torch.float64)   实验回归误差 tensor(0.1905, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4094, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1702837760140692
# #################################### 3 150 绝对误差 tensor(1.4584, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9976, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0666, dtype=torch.float64)   实验回归误差 tensor(0.1219, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.295221956813418
# ############ 1 150 绝对误差 tensor(0.0074, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0085, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1090, dtype=torch.float64)   实验回归误差 tensor(0.0422, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3006, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0082, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0150, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1921, dtype=torch.float64)   实验回归误差 tensor(0.0615, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3509, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0658, dtype=torch.float64)   实验回归误差 tensor(0.0353, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2697, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0011, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0693, dtype=torch.float64)   实验回归误差 tensor(0.0414, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0274, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1959, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4812, dtype=torch.float64)   实验回归误差 tensor(0.0956, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3982, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0078, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0092, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1104, dtype=torch.float64)   实验回归误差 tensor(0.0480, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0167, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0591, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3465, dtype=torch.float64)   实验回归误差 tensor(0.1131, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0088, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0173, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1898, dtype=torch.float64)   实验回归误差 tensor(0.0622, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.1071, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(94.7700, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0000, dtype=torch.float64)   实验回归误差 tensor(0.1809, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3955, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0129, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0132, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1089, dtype=torch.float64)   实验回归误差 tensor(0.0473, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3314, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ######################################################################## 2 150 绝对误差 tensor(1.2001, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9190, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0806, dtype=torch.float64)   实验回归误差 tensor(0.1178, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.057757076186065
# ###################################################################### 2 150 绝对误差 tensor(0.2098, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2474, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1062, dtype=torch.float64)   实验回归误差 tensor(0.0835, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2474641745573316
# ##################################################################### 2 150 绝对误差 tensor(0.4166, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4573, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3121, dtype=torch.float64)   实验回归误差 tensor(0.1651, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.171991240570137
# ################## 2 150 绝对误差 tensor(0.5288, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8302, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1508, dtype=torch.float64)   实验回归误差 tensor(0.1453, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2088677293414896
# ################### 2 150 绝对误差 tensor(0.7119, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4621, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0585, dtype=torch.float64)   实验回归误差 tensor(0.0908, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0747667284100093
# ################### 2 150 绝对误差 tensor(2.1601, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1100, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0539, dtype=torch.float64)   实验回归误差 tensor(0.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1260734442622704
# ###################################################################################### 2 150 绝对误差 tensor(0.0248, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0246, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0952, dtype=torch.float64)   实验回归误差 tensor(0.0441, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2646, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.3795210572466794
# ################ 2 150 绝对误差 tensor(1.9192, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9275, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0487, dtype=torch.float64)   实验回归误差 tensor(0.1078, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1907079220549635
# ################################################################################### 2 150 绝对误差 tensor(0.0135, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0579, dtype=torch.float64)   实验回归误差 tensor(0.0374, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0654000630006537
# ###################### 2 150 绝对误差 tensor(0.0292, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0120, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0449, dtype=torch.float64)   实验回归误差 tensor(0.0304, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0669865371423197
# ########################################################################## 3 150 绝对误差 tensor(0.0195, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0132, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0625, dtype=torch.float64)   实验回归误差 tensor(0.0356, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1067457729175711
# ################### 3 150 绝对误差 tensor(2.2262, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3662, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0604, dtype=torch.float64)   实验回归误差 tensor(0.1683, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2277893721914739
# ######################################## 3 150 绝对误差 tensor(0.3641, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4293, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1098, dtype=torch.float64)   实验回归误差 tensor(0.0707, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3978, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.3361809205602655
# #################################################################################### 3 150 绝对误差 tensor(0.4230, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3772, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0975, dtype=torch.float64)   实验回归误差 tensor(0.0717, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1974253335149907
# ############################################## 3 150 绝对误差 tensor(2.4674, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0040, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0381, dtype=torch.float64)   实验回归误差 tensor(0.1419, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1546722038034307
# ###################################################################### 3 150 绝对误差 tensor(1.8274, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8677, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0526, dtype=torch.float64)   实验回归误差 tensor(0.1123, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1974191129148328
# ################################################################################################################################################ 3 150 绝对误差 tensor(1.5901, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1353, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0729, dtype=torch.float64)   实验回归误差 tensor(0.1230, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2770239656283981
# ################################ 3 150 绝对误差 tensor(1.1762, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0559, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0909, dtype=torch.float64)   实验回归误差 tensor(0.1250, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.183303320435636
# ##################### 3 150 绝对误差 tensor(2.6550, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0200, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0377, dtype=torch.float64)   实验回归误差 tensor(0.1225, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1462009267462059
# ######################################################### 3 150 绝对误差 tensor(0.4750, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4468, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1026, dtype=torch.float64)   实验回归误差 tensor(0.0873, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.141787443795102
# ################### 1 150 绝对误差 tensor(0.0106, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0071, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0660, dtype=torch.float64)   实验回归误差 tensor(0.0380, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.8582, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9923, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2006, dtype=torch.float64)   实验回归误差 tensor(0.1286, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4130, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.0018, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0017, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1032, dtype=torch.float64)   实验回归误差 tensor(0.0366, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0170, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0349, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2010, dtype=torch.float64)   实验回归误差 tensor(0.0741, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0547, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8797, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7976, dtype=torch.float64)   实验回归误差 tensor(0.1244, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3882, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1263, dtype=torch.float64)   实验回归误差 tensor(0.0564, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0074, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0147, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1965, dtype=torch.float64)   实验回归误差 tensor(0.0754, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0119, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0126, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0996, dtype=torch.float64)   实验回归误差 tensor(0.0494, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.0070, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0114, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1610, dtype=torch.float64)   实验回归误差 tensor(0.0538, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########## 1 150 绝对误差 tensor(0.0035, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0028, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0708, dtype=torch.float64)   实验回归误差 tensor(0.0333, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2543, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ######################################################################## 2 150 绝对误差 tensor(0.0113, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0038, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0336, dtype=torch.float64)   实验回归误差 tensor(0.0206, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.068731832297845
# ######################## 2 150 绝对误差 tensor(0.4471, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4886, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1054, dtype=torch.float64)   实验回归误差 tensor(0.1038, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1694295627332112
# ##################### 2 150 绝对误差 tensor(0.3526, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6042, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1553, dtype=torch.float64)   实验回归误差 tensor(0.1550, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.09168937518814
# ##################################### 2 150 绝对误差 tensor(0.8461, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3598, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1663, dtype=torch.float64)   实验回归误差 tensor(0.1533, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4120, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0689104395006404
# #################################################################### 2 150 绝对误差 tensor(0.0267, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0427, dtype=torch.float64)   实验回归误差 tensor(0.0283, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1431, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0750481127011973
# ######################################## 2 150 绝对误差 tensor(0.0544, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2029, dtype=torch.float64)   实验回归误差 tensor(0.0627, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3710, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0829542149498101
# ########################################################################################################### 2 150 绝对误差 tensor(0.1962, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2787, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1353, dtype=torch.float64)   实验回归误差 tensor(0.0744, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0447543020937415
# ############################################# 2 150 绝对误差 tensor(0.7851, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5250, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0671, dtype=torch.float64)   实验回归误差 tensor(0.0916, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0182818503837747
# ################################### 2 150 绝对误差 tensor(0.7107, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3666, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0580, dtype=torch.float64)   实验回归误差 tensor(0.0630, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0253104604096757
# ############################## 2 150 绝对误差 tensor(1.6960, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1749, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0678, dtype=torch.float64)   实验回归误差 tensor(0.1755, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0683438528163212
# ########################################################################### 3 150 绝对误差 tensor(2.1955, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1843, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0553, dtype=torch.float64)   实验回归误差 tensor(0.1075, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2854840143324167
# #################################### 3 150 绝对误差 tensor(1.7310, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2718, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0704, dtype=torch.float64)   实验回归误差 tensor(0.1096, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.169535321681157
# ########################################################################################################################################################################## 3 150 绝对误差 tensor(1.2897, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3893, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0282, dtype=torch.float64)   实验回归误差 tensor(0.0798, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2401030845820296
# ################################################## 3 150 绝对误差 tensor(0.4909, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8635, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2042, dtype=torch.float64)   实验回归误差 tensor(0.1487, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1605498838990702
# ############################################################### 3 150 绝对误差 tensor(0.0381, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0321, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0803, dtype=torch.float64)   实验回归误差 tensor(0.0419, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2858, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1401314330639427
# ################################### 3 150 绝对误差 tensor(2.2949, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1844, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0470, dtype=torch.float64)   实验回归误差 tensor(0.1807, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1403722347942384
# ######################################################### 3 150 绝对误差 tensor(0.1805, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5965, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3195, dtype=torch.float64)   实验回归误差 tensor(0.0883, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.066940575402262
# ####################################### 3 150 绝对误差 tensor(1.1332, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5077, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0409, dtype=torch.float64)   实验回归误差 tensor(0.0793, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1951624142817698
# ################################################################################################################################ 3 150 绝对误差 tensor(1.5530, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7744, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0436, dtype=torch.float64)   实验回归误差 tensor(0.1265, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4029, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.240339375095536
# ################################################################ 3 150 绝对误差 tensor(0.7801, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6575, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0773, dtype=torch.float64)   实验回归误差 tensor(0.0946, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1364602572141775
# ############## 1 150 绝对误差 tensor(0.0745, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.5203, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9552, dtype=torch.float64)   实验回归误差 tensor(0.1370, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4052, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0175, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0516, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2519, dtype=torch.float64)   实验回归误差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3612, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0098, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0215, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2344, dtype=torch.float64)   实验回归误差 tensor(0.0689, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3515, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0126, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0096, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0814, dtype=torch.float64)   实验回归误差 tensor(0.0402, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0082, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0741, dtype=torch.float64)   实验回归误差 tensor(0.0349, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2702, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0028, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0069, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2278, dtype=torch.float64)   实验回归误差 tensor(0.0760, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0304, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3447, dtype=torch.float64)   实验回归误差 tensor(0.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3903, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0196, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0321, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1602, dtype=torch.float64)   实验回归误差 tensor(0.0532, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3515, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0511, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5855, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7445, dtype=torch.float64)   实验回归误差 tensor(0.1523, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3950, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0041, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0018, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0439, dtype=torch.float64)   实验回归误差 tensor(0.0241, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2596, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################################################################################################## 2 150 绝对误差 tensor(0.7966, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6288, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0872, dtype=torch.float64)   实验回归误差 tensor(0.1053, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0653696665900667
# ################################################### 2 150 绝对误差 tensor(0.0108, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0126, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1247, dtype=torch.float64)   实验回归误差 tensor(0.0490, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3466, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0905741172850936
# ###################################################################### 2 150 绝对误差 tensor(0.1242, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6455, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4474, dtype=torch.float64)   实验回归误差 tensor(0.0725, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3934, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0870137470647712
# ############################################## 2 150 绝对误差 tensor(0.7110, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4469, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0578, dtype=torch.float64)   实验回归误差 tensor(0.1027, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0884891167762172
# ########################################################################################################################################## 2 150 绝对误差 tensor(0.0151, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0089, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0581, dtype=torch.float64)   实验回归误差 tensor(0.0314, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2383, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.166108000718047
# ################################ 2 150 绝对误差 tensor(1.8412, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1637, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0672, dtype=torch.float64)   实验回归误差 tensor(0.1444, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0602339102154166
# ################################################################################################# 2 150 绝对误差 tensor(1.2401, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5626, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1308, dtype=torch.float64)   实验回归误差 tensor(0.2064, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1367633184613035
# ######################################################## 2 150 绝对误差 tensor(1.1636, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3449, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1105, dtype=torch.float64)   实验回归误差 tensor(0.1012, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0400574637315434
# ############################ 2 150 绝对误差 tensor(1.5021, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7175, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0483, dtype=torch.float64)   实验回归误差 tensor(0.1238, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0833454604620607
# ################################################################## 2 150 绝对误差 tensor(0.0226, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0254, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1156, dtype=torch.float64)   实验回归误差 tensor(0.0463, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1344009136605346
# ################################################################ 3 150 绝对误差 tensor(0.4978, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7495, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1272, dtype=torch.float64)   实验回归误差 tensor(0.1221, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.255176607049807
# ####################################################################################################### 3 150 绝对误差 tensor(2.0581, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4814, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0712, dtype=torch.float64)   实验回归误差 tensor(0.1510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1659540523157559
# ########################################### 3 150 绝对误差 tensor(0.0090, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0037, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0326, dtype=torch.float64)   实验回归误差 tensor(0.0218, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.326353316776683
# ######################################################################################### 3 150 绝对误差 tensor(2.5911, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1710, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0444, dtype=torch.float64)   实验回归误差 tensor(0.1105, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1601665035112003
# ################################################################################################################################################################ 3 150 绝对误差 tensor(1.9552, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8761, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0400, dtype=torch.float64)   实验回归误差 tensor(0.1138, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.3132119411705374
# ##################################################################################### 3 150 绝对误差 tensor(0.0624, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0650, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1023, dtype=torch.float64)   实验回归误差 tensor(0.0589, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3360, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.211831347107147
# ######################################################################################################################################### 3 150 绝对误差 tensor(0.3356, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2448, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.0707, dtype=torch.float64)   实验回归误差 tensor(0.0652, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1471892858080455
# ####################################### 3 150 绝对误差 tensor(0.5208, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5627, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1209, dtype=torch.float64)   实验回归误差 tensor(0.0994, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1837756264354955
# ############################################################################################################################################### 3 150 绝对误差 tensor(0.0466, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2185, dtype=torch.float64)   实验回归误差 tensor(0.0742, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2904586959927777
# ####################################### 3 150 绝对误差 tensor(0.2516, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5095, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1682, dtype=torch.float64)   实验回归误差 tensor(0.1168, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3929, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1230627320877604
