# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(50,51,100): 
        for num_X2feature in [3,2,1]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.008
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-5:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############ 3 50 w绝对误差 tensor(0.3355, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7180, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2284, dtype=torch.float64)   实验回归残差 tensor(0.1287, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1846, dtype=torch.float64)   测试集实验回归残差 tensor(0.2330, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.454413581936682
# ###################################### 3 50 w绝对误差 tensor(2.0780, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4236, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0740, dtype=torch.float64)   实验回归残差 tensor(0.1043, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0744, dtype=torch.float64)   测试集实验回归残差 tensor(0.2416, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1376230059753045
# ############################# 3 50 w绝对误差 tensor(0.0693, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0964, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1496, dtype=torch.float64)   实验回归残差 tensor(0.0871, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1257, dtype=torch.float64)   测试集实验回归残差 tensor(0.0899, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3483710374557052
# ############## 3 50 w绝对误差 tensor(1.9895, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2778, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0575, dtype=torch.float64)   实验回归残差 tensor(0.2055, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0747, dtype=torch.float64)   测试集实验回归残差 tensor(0.2726, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2220628885487679
# ################# 3 50 w绝对误差 tensor(1.7623, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0335, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0713, dtype=torch.float64)   实验回归残差 tensor(0.1810, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0682, dtype=torch.float64)   测试集实验回归残差 tensor(0.2991, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4401486947578173
# ############################# 3 50 w绝对误差 tensor(0.4546, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2646, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0583, dtype=torch.float64)   实验回归残差 tensor(0.1128, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0633, dtype=torch.float64)   测试集实验回归残差 tensor(0.2132, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1975522722735499
# ############################################## 3 50 w绝对误差 tensor(4.0047, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9631, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0490, dtype=torch.float64)   实验回归残差 tensor(0.1382, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0371, dtype=torch.float64)   测试集实验回归残差 tensor(0.2981, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2531181969907494
# #################### 3 50 w绝对误差 tensor(0.3668, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4122, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1401, dtype=torch.float64)   实验回归残差 tensor(0.1536, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0966, dtype=torch.float64)   测试集实验回归残差 tensor(0.1502, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4973869760821605
# ####### 3 50 w绝对误差 tensor(0.6567, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6027, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0898, dtype=torch.float64)   实验回归残差 tensor(0.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0914, dtype=torch.float64)   测试集实验回归残差 tensor(0.2295, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2763834335712418
# ############################################### 3 50 w绝对误差 tensor(0.0295, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0124, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0416, dtype=torch.float64)   实验回归残差 tensor(0.0317, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0431, dtype=torch.float64)   测试集实验回归残差 tensor(0.0381, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2210624280917475
# #################################### 2 50 w绝对误差 tensor(0.0347, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0334, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0685, dtype=torch.float64)   实验回归残差 tensor(0.0500, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1162, dtype=torch.float64)   测试集实验回归残差 tensor(0.0704, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2640654236744282
# ######################################## 2 50 w绝对误差 tensor(2.9075, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4799, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0490, dtype=torch.float64)   实验回归残差 tensor(0.1229, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0585, dtype=torch.float64)   测试集实验回归残差 tensor(0.3228, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.189127584311316
# ########## 2 50 w绝对误差 tensor(0.0351, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0232, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0632, dtype=torch.float64)   实验回归残差 tensor(0.0483, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0583, dtype=torch.float64)   测试集实验回归残差 tensor(0.0539, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9592, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4787071471205144
# #################### 2 50 w绝对误差 tensor(0.0061, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0066, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0989, dtype=torch.float64)   实验回归残差 tensor(0.0685, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1261, dtype=torch.float64)   测试集实验回归残差 tensor(0.0781, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.096388688614851
# ######### 2 50 w绝对误差 tensor(0.8523, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8004, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0949, dtype=torch.float64)   实验回归残差 tensor(0.1238, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0969, dtype=torch.float64)   测试集实验回归残差 tensor(0.2905, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.297381601033538
# ################ 2 50 w绝对误差 tensor(1.4603, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1604, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0928, dtype=torch.float64)   实验回归残差 tensor(0.2563, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0867, dtype=torch.float64)   测试集实验回归残差 tensor(0.2986, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2062533996967606
# ########## 2 50 w绝对误差 tensor(0.9528, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2301, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1306, dtype=torch.float64)   实验回归残差 tensor(0.1539, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1673, dtype=torch.float64)   测试集实验回归残差 tensor(0.4713, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3252260553706572
# ####################### 2 50 w绝对误差 tensor(0.0164, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0097, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0471, dtype=torch.float64)   实验回归残差 tensor(0.0394, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0661, dtype=torch.float64)   测试集实验回归残差 tensor(0.0528, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.226760519748351
# ######################################### 2 50 w绝对误差 tensor(0.3379, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3103, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1106, dtype=torch.float64)   实验回归残差 tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0819, dtype=torch.float64)   测试集实验回归残差 tensor(0.2143, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3244259713182962
# ####### 2 50 w绝对误差 tensor(0.5588, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7105, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1063, dtype=torch.float64)   实验回归残差 tensor(0.1631, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1067, dtype=torch.float64)   测试集实验回归残差 tensor(0.3384, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0468080619053728
# ###### 1 50 w绝对误差 tensor(0.0049, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0528, dtype=torch.float64)   实验回归残差 tensor(0.0443, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0615, dtype=torch.float64)   测试集实验回归残差 tensor(0.0519, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ########### 1 50 w绝对误差 tensor(0.0013, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0026, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2102, dtype=torch.float64)   实验回归残差 tensor(0.1038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1839, dtype=torch.float64)   测试集实验回归残差 tensor(0.1128, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ##### 1 50 w绝对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0669, dtype=torch.float64)   实验回归残差 tensor(0.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1013, dtype=torch.float64)   测试集实验回归残差 tensor(0.0698, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ########### 1 50 w绝对误差 tensor(0.0167, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0147, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0848, dtype=torch.float64)   实验回归残差 tensor(0.0573, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0946, dtype=torch.float64)   测试集实验回归残差 tensor(0.0561, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ####### 1 50 w绝对误差 tensor(0.0042, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0143, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3588, dtype=torch.float64)   实验回归残差 tensor(0.1356, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2999, dtype=torch.float64)   测试集实验回归残差 tensor(0.1460, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######### 1 50 w绝对误差 tensor(0.0066, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0077, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1222, dtype=torch.float64)   实验回归残差 tensor(0.0796, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1116, dtype=torch.float64)   测试集实验回归残差 tensor(0.0831, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ################ 1 50 w绝对误差 tensor(0.0182, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0343, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2022, dtype=torch.float64)   实验回归残差 tensor(0.1230, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2095, dtype=torch.float64)   测试集实验回归残差 tensor(0.1438, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ###### 1 50 w绝对误差 tensor(0.0315, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1961, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.5175, dtype=torch.float64)   实验回归残差 tensor(0.1321, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.5906, dtype=torch.float64)   测试集实验回归残差 tensor(0.2821, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ###### 1 50 w绝对误差 tensor(0.0037, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1337, dtype=torch.float64)   实验回归残差 tensor(0.0923, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1491, dtype=torch.float64)   测试集实验回归残差 tensor(0.1022, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ####### 1 50 w绝对误差 tensor(0.3722, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0853, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.5289, dtype=torch.float64)   实验回归残差 tensor(0.1504, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4425, dtype=torch.float64)   测试集实验回归残差 tensor(0.2345, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ########################## 3 50 w绝对误差 tensor(0.0145, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0049, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0280, dtype=torch.float64)   实验回归残差 tensor(0.0248, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0369, dtype=torch.float64)   测试集实验回归残差 tensor(0.0309, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9381, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(0.9381, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4774033265825488
# ######################## 3 50 w绝对误差 tensor(0.8385, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8163, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1191, dtype=torch.float64)   实验回归残差 tensor(0.1182, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1481, dtype=torch.float64)   测试集实验回归残差 tensor(0.3983, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.7292779922601442
# ################ 3 50 w绝对误差 tensor(1.0384, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8985, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0691, dtype=torch.float64)   实验回归残差 tensor(0.2048, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0850, dtype=torch.float64)   测试集实验回归残差 tensor(0.1704, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2321338385030052
# ############# 3 50 w绝对误差 tensor(0.8974, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6125, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0763, dtype=torch.float64)   实验回归残差 tensor(0.1366, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0639, dtype=torch.float64)   测试集实验回归残差 tensor(0.2626, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.459411056133898
# ##################### 3 50 w绝对误差 tensor(1.9671, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1144, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0508, dtype=torch.float64)   实验回归残差 tensor(0.2245, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0598, dtype=torch.float64)   测试集实验回归残差 tensor(0.1711, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3642204051181517
# ########## 3 50 w绝对误差 tensor(1.8948, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3063, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0718, dtype=torch.float64)   实验回归残差 tensor(0.1891, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0662, dtype=torch.float64)   测试集实验回归残差 tensor(0.2539, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2261007769473553
# #################### 3 50 w绝对误差 tensor(1.3231, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9087, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0542, dtype=torch.float64)   实验回归残差 tensor(0.1894, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0791, dtype=torch.float64)   测试集实验回归残差 tensor(0.1573, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2439765596189174
# ############ 3 50 w绝对误差 tensor(0.8246, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3638, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0409, dtype=torch.float64)   实验回归残差 tensor(0.0878, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0468, dtype=torch.float64)   测试集实验回归残差 tensor(0.1609, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2479323722540447
# ####################### 3 50 w绝对误差 tensor(0.0570, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0408, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0581, dtype=torch.float64)   实验回归残差 tensor(0.0448, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0704, dtype=torch.float64)   测试集实验回归残差 tensor(0.0635, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9798, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.34376114039524
# ############################ 3 50 w绝对误差 tensor(0.0345, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0159, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0444, dtype=torch.float64)   实验回归残差 tensor(0.0330, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0404, dtype=torch.float64)   测试集实验回归残差 tensor(0.0360, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(0.9381, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.227472703417406
# ########### 2 50 w绝对误差 tensor(1.2836, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2302, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0915, dtype=torch.float64)   实验回归残差 tensor(0.2738, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0875, dtype=torch.float64)   测试集实验回归残差 tensor(0.2213, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1495682057617655
# ###################### 2 50 w绝对误差 tensor(0.3138, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1388, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0414, dtype=torch.float64)   实验回归残差 tensor(0.0490, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0630, dtype=torch.float64)   测试集实验回归残差 tensor(0.0936, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1498675622795473
# ########## 2 50 w绝对误差 tensor(1.0123, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7163, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1533, dtype=torch.float64)   实验回归残差 tensor(0.3062, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1891, dtype=torch.float64)   测试集实验回归残差 tensor(0.3485, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.183091255914001
# ##################################### 2 50 w绝对误差 tensor(0.1898, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2060, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0924, dtype=torch.float64)   实验回归残差 tensor(0.1006, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1147, dtype=torch.float64)   测试集实验回归残差 tensor(0.1142, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.132347717815733
# ############### 2 50 w绝对误差 tensor(2.3173, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0822, dtype=torch.float64)   实验回归残差 tensor(0.1889, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0578, dtype=torch.float64)   测试集实验回归残差 tensor(0.3578, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3292997073984931
# ########## 2 50 w绝对误差 tensor(0.0634, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0575, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0938, dtype=torch.float64)   实验回归残差 tensor(0.0632, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0760, dtype=torch.float64)   测试集实验回归残差 tensor(0.0636, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3125179586506135
# ############################## 2 50 w绝对误差 tensor(1.9182, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0412, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0562, dtype=torch.float64)   实验回归残差 tensor(0.1332, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0434, dtype=torch.float64)   测试集实验回归残差 tensor(0.3220, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1642723505059842
# ######## 2 50 w绝对误差 tensor(0.1898, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3356, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1579, dtype=torch.float64)   实验回归残差 tensor(0.1240, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1928, dtype=torch.float64)   测试集实验回归残差 tensor(0.1816, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1091263178206205
# ################################# 2 50 w绝对误差 tensor(0.0451, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0338, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0692, dtype=torch.float64)   实验回归残差 tensor(0.0497, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0907, dtype=torch.float64)   测试集实验回归残差 tensor(0.0743, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2639061237266722
# ########### 2 50 w绝对误差 tensor(0.1497, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1440, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0888, dtype=torch.float64)   实验回归残差 tensor(0.0892, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1080, dtype=torch.float64)   测试集实验回归残差 tensor(0.1512, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2807030395256196
# ######## 1 50 w绝对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0138, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1194, dtype=torch.float64)   实验回归残差 tensor(0.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1325, dtype=torch.float64)   测试集实验回归残差 tensor(0.0884, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ###### 1 50 w绝对误差 tensor(0.0150, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0309, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1586, dtype=torch.float64)   实验回归残差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2028, dtype=torch.float64)   测试集实验回归残差 tensor(0.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# #### 1 50 w绝对误差 tensor(0.0165, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0469, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2375, dtype=torch.float64)   实验回归残差 tensor(0.1086, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2983, dtype=torch.float64)   测试集实验回归残差 tensor(0.1592, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ####### 1 50 w绝对误差 tensor(0.0012, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0015, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1205, dtype=torch.float64)   实验回归残差 tensor(0.0841, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1322, dtype=torch.float64)   测试集实验回归残差 tensor(0.0823, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######## 1 50 w绝对误差 tensor(0.0350, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0199, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0637, dtype=torch.float64)   实验回归残差 tensor(0.0416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0488, dtype=torch.float64)   测试集实验回归残差 tensor(0.0377, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######## 1 50 w绝对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0078, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0999, dtype=torch.float64)   实验回归残差 tensor(0.0699, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0737, dtype=torch.float64)   测试集实验回归残差 tensor(0.0524, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ###### 1 50 w绝对误差 tensor(0.0390, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1366, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3117, dtype=torch.float64)   实验回归残差 tensor(0.1344, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2903, dtype=torch.float64)   测试集实验回归残差 tensor(0.1628, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ########### 1 50 w绝对误差 tensor(0.0095, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1035, dtype=torch.float64)   实验回归残差 tensor(0.0638, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1122, dtype=torch.float64)   测试集实验回归残差 tensor(0.0778, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######## 1 50 w绝对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0039, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0720, dtype=torch.float64)   实验回归残差 tensor(0.0545, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0699, dtype=torch.float64)   测试集实验回归残差 tensor(0.0568, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0770, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ####### 1 50 w绝对误差 tensor(1.8265, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9851, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1099, dtype=torch.float64)   实验回归残差 tensor(0.2153, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1025, dtype=torch.float64)   测试集实验回归残差 tensor(0.5042, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ################# 3 50 w绝对误差 tensor(0.0025, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0357, dtype=torch.float64)   实验回归残差 tensor(0.0323, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0311, dtype=torch.float64)   测试集实验回归残差 tensor(0.0250, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.7211, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.275475351105275
# ################## 3 50 w绝对误差 tensor(1.8956, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9261, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0403, dtype=torch.float64)   实验回归残差 tensor(0.2531, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0606, dtype=torch.float64)   测试集实验回归残差 tensor(0.3347, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4493609189520713
# ############## 3 50 w绝对误差 tensor(2.3695, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3746, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0593, dtype=torch.float64)   实验回归残差 tensor(0.2656, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0477, dtype=torch.float64)   测试集实验回归残差 tensor(0.3000, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3216192028522775
# ##################### 3 50 w绝对误差 tensor(2.0878, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0786, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0523, dtype=torch.float64)   实验回归残差 tensor(0.1497, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0452, dtype=torch.float64)   测试集实验回归残差 tensor(0.2522, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2108919276179715
# ############# 3 50 w绝对误差 tensor(1.6563, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0284, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0621, dtype=torch.float64)   实验回归残差 tensor(0.1592, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0678, dtype=torch.float64)   测试集实验回归残差 tensor(0.2259, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3429921318137648
# ################################## 3 50 w绝对误差 tensor(2.8723, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3117, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0481, dtype=torch.float64)   实验回归残差 tensor(0.1163, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0511, dtype=torch.float64)   测试集实验回归残差 tensor(0.3474, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.5722762643136505
# ############# 3 50 w绝对误差 tensor(0.6577, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4853, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0745, dtype=torch.float64)   实验回归残差 tensor(0.1047, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0715, dtype=torch.float64)   测试集实验回归残差 tensor(0.1984, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3582331803319208
# ######### 3 50 w绝对误差 tensor(2.0223, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9618, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0541, dtype=torch.float64)   实验回归残差 tensor(0.1461, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0477, dtype=torch.float64)   测试集实验回归残差 tensor(0.1708, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4668476930171133
# ########################### 3 50 w绝对误差 tensor(0.1640, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1463, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0652, dtype=torch.float64)   实验回归残差 tensor(0.0733, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0778, dtype=torch.float64)   测试集实验回归残差 tensor(0.1010, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3668092212592582
# ####################### 3 50 w绝对误差 tensor(2.2859, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5865, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0773, dtype=torch.float64)   实验回归残差 tensor(0.1139, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0678, dtype=torch.float64)   测试集实验回归残差 tensor(0.3854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2158419474051632
# ############### 2 50 w绝对误差 tensor(0.7261, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7345, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1159, dtype=torch.float64)   实验回归残差 tensor(0.1803, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0970, dtype=torch.float64)   测试集实验回归残差 tensor(0.2786, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.3051925341819786
# ################ 2 50 w绝对误差 tensor(0.8032, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6811, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1413, dtype=torch.float64)   实验回归残差 tensor(0.2405, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2121, dtype=torch.float64)   测试集实验回归残差 tensor(0.2266, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2634308431228503
# ############ 2 50 w绝对误差 tensor(0.0311, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0401, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0951, dtype=torch.float64)   实验回归残差 tensor(0.0695, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1162, dtype=torch.float64)   测试集实验回归残差 tensor(0.0777, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2558386919718192
# ####################### 2 50 w绝对误差 tensor(0.0307, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0560, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1372, dtype=torch.float64)   实验回归残差 tensor(0.0810, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1813, dtype=torch.float64)   测试集实验回归残差 tensor(0.1118, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4573601799808884
# ###################################### 2 50 w绝对误差 tensor(1.4775, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5556, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1164, dtype=torch.float64)   实验回归残差 tensor(0.1586, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0859, dtype=torch.float64)   测试集实验回归残差 tensor(0.3600, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.5495499726877608
# ########## 2 50 w绝对误差 tensor(0.0451, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0715, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1249, dtype=torch.float64)   实验回归残差 tensor(0.0771, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1425, dtype=torch.float64)   测试集实验回归残差 tensor(0.0839, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0734280939392036
# ############ 2 50 w绝对误差 tensor(2.8015, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3214, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0322, dtype=torch.float64)   实验回归残差 tensor(0.2794, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0517, dtype=torch.float64)   测试集实验回归残差 tensor(0.4659, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.35120206828539
# ############# 2 50 w绝对误差 tensor(0.7088, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1880, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1716, dtype=torch.float64)   实验回归残差 tensor(0.1918, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1401, dtype=torch.float64)   测试集实验回归残差 tensor(0.3044, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2193409468966516
# ###### 2 50 w绝对误差 tensor(2.2809, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4080, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0707, dtype=torch.float64)   实验回归残差 tensor(0.2578, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0644, dtype=torch.float64)   测试集实验回归残差 tensor(0.1860, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1495393660821103
# ######## 2 50 w绝对误差 tensor(0.0427, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0959, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2381, dtype=torch.float64)   实验回归残差 tensor(0.1146, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2202, dtype=torch.float64)   测试集实验回归残差 tensor(0.1369, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1810118477675065
# ######### 1 50 w绝对误差 tensor(0.0046, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0082, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1777, dtype=torch.float64)   实验回归残差 tensor(0.0963, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1741, dtype=torch.float64)   测试集实验回归残差 tensor(0.1164, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ###### 1 50 w绝对误差 tensor(0.0970, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(6.6138, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9878, dtype=torch.float64)   实验回归残差 tensor(0.2682, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.9712, dtype=torch.float64)   测试集实验回归残差 tensor(0.2898, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ...
# ############ 3 50 w绝对误差 tensor(1.6332, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7872, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0483, dtype=torch.float64)   实验回归残差 tensor(0.2152, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0614, dtype=torch.float64)   测试集实验回归残差 tensor(0.3300, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4517237184957583
# ###################### 3 50 w绝对误差 tensor(0.0095, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0039, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0461, dtype=torch.float64)   实验回归残差 tensor(0.0367, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0394, dtype=torch.float64)   测试集实验回归残差 tensor(0.0344, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0583, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(0.8485, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4813100049679608
# ########### 3 50 w绝对误差 tensor(1.6504, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9399, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0736, dtype=torch.float64)   实验回归残差 tensor(0.2364, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0554, dtype=torch.float64)   测试集实验回归残差 tensor(0.3819, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2435941593378301
# ########################## 3 50 w绝对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0551, dtype=torch.float64)   实验回归残差 tensor(0.0445, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0660, dtype=torch.float64)   测试集实验回归残差 tensor(0.0483, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.5903089332958675
# ######### 3 50 w绝对误差 tensor(0.1666, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9309, dtype=torch.float64)   实验回归残差 tensor(0.1931, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7358, dtype=torch.float64)   测试集实验回归残差 tensor(0.2609, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2748995348576926
# ############ 3 50 w绝对误差 tensor(0.6125, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7077, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1134, dtype=torch.float64)   实验回归残差 tensor(0.1665, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1362, dtype=torch.float64)   测试集实验回归残差 tensor(0.2683, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.287110601716765
# ############################## 3 50 w绝对误差 tensor(0.5589, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1096, dtype=torch.float64)   实验回归残差 tensor(0.1075, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0765, dtype=torch.float64)   测试集实验回归残差 tensor(0.1759, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.236018003148212
# ########################### 2 50 w绝对误差 tensor(0.1174, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0665, dtype=torch.float64)   实验回归残差 tensor(0.0570, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0632, dtype=torch.float64)   测试集实验回归残差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.371874415862877
# ########################### 2 50 w绝对误差 tensor(0.2167, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6581, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3265, dtype=torch.float64)   实验回归残差 tensor(0.1736, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2892, dtype=torch.float64)   测试集实验回归残差 tensor(0.1521, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3266, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.4445339220185687
# ############## 2 50 w绝对误差 tensor(1.3555, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7616, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0445, dtype=torch.float64)   实验回归残差 tensor(0.1798, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0613, dtype=torch.float64)   测试集实验回归残差 tensor(0.1161, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0895742563642667
# ############ 2 50 w绝对误差 tensor(2.9853, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0587, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0323, dtype=torch.float64)   实验回归残差 tensor(0.2550, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0399, dtype=torch.float64)   测试集实验回归残差 tensor(0.2306, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.194167630090109
# ################################### 2 50 w绝对误差 tensor(0.0862, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1064, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1780, dtype=torch.float64)   实验回归残差 tensor(0.1047, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1488, dtype=torch.float64)   测试集实验回归残差 tensor(0.1406, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0774365859453718
# ###### 2 50 w绝对误差 tensor(0.9042, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1234, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1248, dtype=torch.float64)   实验回归残差 tensor(0.2440, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1253, dtype=torch.float64)   测试集实验回归残差 tensor(0.1758, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0427168774906672
# ##################### 2 50 w绝对误差 tensor(0.0499, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0418, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0708, dtype=torch.float64)   实验回归残差 tensor(0.0537, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1013, dtype=torch.float64)   测试集实验回归残差 tensor(0.0703, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1314, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.1217787590308403
# ############### 2 50 w绝对误差 tensor(0.0296, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0205, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0569, dtype=torch.float64)   实验回归残差 tensor(0.0359, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0742, dtype=torch.float64)   测试集实验回归残差 tensor(0.0558, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0198, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(0.9165, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.2083863181389494
# ####### 2 50 w绝对误差 tensor(1.0351, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0498, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0956, dtype=torch.float64)   实验回归残差 tensor(0.3298, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1396, dtype=torch.float64)   测试集实验回归残差 tensor(0.2567, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.140202086640844
# ###################### 2 50 w绝对误差 tensor(2.4446, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6352, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0587, dtype=torch.float64)   实验回归残差 tensor(0.1506, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0729, dtype=torch.float64)   测试集实验回归残差 tensor(0.3295, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.6189616119340358
# ######### 1 50 w绝对误差 tensor(0.0115, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0184, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1627, dtype=torch.float64)   实验回归残差 tensor(0.1097, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1663, dtype=torch.float64)   测试集实验回归残差 tensor(0.0947, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2166, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ################ 1 50 w绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1356, dtype=torch.float64)   实验回归残差 tensor(0.0885, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0867, dtype=torch.float64)   测试集实验回归残差 tensor(0.0585, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2490, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ###### 1 50 w绝对误差 tensor(0.0040, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0069, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1519, dtype=torch.float64)   实验回归残差 tensor(0.0916, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1693, dtype=torch.float64)   测试集实验回归残差 tensor(0.0802, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ####### 1 50 w绝对误差 tensor(0.0236, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0379, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1537, dtype=torch.float64)   实验回归残差 tensor(0.0826, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1768, dtype=torch.float64)   测试集实验回归残差 tensor(0.0971, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2329, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ##### 1 50 w绝对误差 tensor(0.0076, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0390, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4575, dtype=torch.float64)   实验回归残差 tensor(0.1530, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3830, dtype=torch.float64)   测试集实验回归残差 tensor(0.2349, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3115, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ##### 1 50 w绝对误差 tensor(0.0129, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0270, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2262, dtype=torch.float64)   实验回归残差 tensor(0.1046, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1952, dtype=torch.float64)   测试集实验回归残差 tensor(0.0957, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######## 1 50 w绝对误差 tensor(0.9130, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0523, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2359, dtype=torch.float64)   实验回归残差 tensor(0.1601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3225, dtype=torch.float64)   测试集实验回归残差 tensor(0.2301, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######### 1 50 w绝对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0186, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2035, dtype=torch.float64)   实验回归残差 tensor(0.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1651, dtype=torch.float64)   测试集实验回归残差 tensor(0.1165, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.1489, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ############# 1 50 w绝对误差 tensor(0.0140, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0109, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0891, dtype=torch.float64)   实验回归残差 tensor(0.0632, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0785, dtype=torch.float64)   测试集实验回归残差 tensor(0.0525, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
# ######### 1 50 w绝对误差 tensor(0.0728, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2034, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.8598, dtype=torch.float64)   实验回归残差 tensor(0.1708, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.8628, dtype=torch.float64)   测试集实验回归残差 tensor(0.4587, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 50   测试集置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 50   条件数 1.0
