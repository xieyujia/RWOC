# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(80,81,100): 
        for num_X2feature in [4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.008
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# #################### 4 80 w绝对误差 tensor(4.0883, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3757, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0321, dtype=torch.float64)   实验回归残差 tensor(0.1429, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0351, dtype=torch.float64)   测试集实验回归残差 tensor(0.2895, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2907692627477738
# ######################################################################################################################################################################################################超过迭代上限
#  4 80 w绝对误差 tensor(3.2927, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3340, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0459, dtype=torch.float64)   实验回归残差 tensor(0.1161, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0442, dtype=torch.float64)   测试集实验回归残差 tensor(0.3667, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6077627205571836
# ################# 4 80 w绝对误差 tensor(0.4531, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2109, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0489, dtype=torch.float64)   实验回归残差 tensor(0.0713, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0537, dtype=torch.float64)   测试集实验回归残差 tensor(0.1268, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3766496794527743
# ################### 4 80 w绝对误差 tensor(1.9529, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0467, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0596, dtype=torch.float64)   实验回归残差 tensor(0.1350, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0693, dtype=torch.float64)   测试集实验回归残差 tensor(0.1128, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2957231721184965
# ################################### 4 80 w绝对误差 tensor(1.6596, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0559, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0808, dtype=torch.float64)   实验回归残差 tensor(0.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0601, dtype=torch.float64)   测试集实验回归残差 tensor(0.2181, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.265970230434092
# ################# 4 80 w绝对误差 tensor(1.7875, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3034, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0673, dtype=torch.float64)   实验回归残差 tensor(0.2108, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0880, dtype=torch.float64)   测试集实验回归残差 tensor(0.2597, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.454884743170497
# ############## 4 80 w绝对误差 tensor(0.6279, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3463, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2202, dtype=torch.float64)   实验回归残差 tensor(0.1894, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1816, dtype=torch.float64)   测试集实验回归残差 tensor(0.2631, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.284738912648843
# ########################################### 4 80 w绝对误差 tensor(2.5606, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3785, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0528, dtype=torch.float64)   实验回归残差 tensor(0.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0575, dtype=torch.float64)   测试集实验回归残差 tensor(0.3438, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3213173726304508
# ####################### 4 80 w绝对误差 tensor(3.5756, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3934, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0425, dtype=torch.float64)   实验回归残差 tensor(0.1931, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0394, dtype=torch.float64)   测试集实验回归残差 tensor(0.3660, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3757683782081123
# ########################### 4 80 w绝对误差 tensor(1.9286, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2551, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0644, dtype=torch.float64)   实验回归残差 tensor(0.1222, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0576, dtype=torch.float64)   测试集实验回归残差 tensor(0.2426, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3963, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3045624542890444
# ################################# 5 80 w绝对误差 tensor(0.1040, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1301, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1148, dtype=torch.float64)   实验回归残差 tensor(0.0538, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1284, dtype=torch.float64)   测试集实验回归残差 tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3229, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3323, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3928546399768182
# ######################################## 5 80 w绝对误差 tensor(2.3110, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0473, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0446, dtype=torch.float64)   实验回归残差 tensor(0.1441, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0414, dtype=torch.float64)   测试集实验回归残差 tensor(0.2760, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.7009904042595256
# ################################################################## 5 80 w绝对误差 tensor(1.9300, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8320, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0426, dtype=torch.float64)   实验回归残差 tensor(0.1192, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0495, dtype=torch.float64)   测试集实验回归残差 tensor(0.3236, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5432528429845471
# ########################################## 5 80 w绝对误差 tensor(4.4407, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6886, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0376, dtype=torch.float64)   实验回归残差 tensor(0.0797, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0351, dtype=torch.float64)   测试集实验回归残差 tensor(0.3278, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.488263783491099
# ################# 5 80 w绝对误差 tensor(3.1488, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0284, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0293, dtype=torch.float64)   实验回归残差 tensor(0.1835, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0348, dtype=torch.float64)   测试集实验回归残差 tensor(0.2173, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4256339375399742
# ############################### 5 80 w绝对误差 tensor(2.8023, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0671, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0402, dtype=torch.float64)   实验回归残差 tensor(0.1923, dtype=torch.float64, grad_fn=<DivBackward0>)   ########### 5 80 w绝对误差 tensor(1.6680, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8203, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0550, dtype=torch.float64)   实验回归残差 tensor(0.2355, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0490, dtype=torch.float64)   测试集实验回归残差 tensor(0.2417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2878688109241199
# ####################### 5 80 w绝对误差 tensor(2.0440, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9967, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0424, dtype=torch.float64)   实验回归残差 tensor(0.1348, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0451, dtype=torch.float64)   测试集实验回归残差 tensor(0.1967, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4150839757875802
# #################### 5 80 w绝对误差 tensor(1.9968, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2173, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0682, dtype=torch.float64)   实验回归残差 tensor(0.2312, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0704, dtype=torch.float64)   测试集实验回归残差 tensor(0.3033, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4003202281524747
# ######################################### 6 80 w绝对误差 tensor(2.1845, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0572, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0481, dtype=torch.float64)   实验回归残差 tensor(0.1784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0394, dtype=torch.float64)   测试集实验回归残差 tensor(0.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4729585659019342
# #################################################################### 6 80 w绝对误差 tensor(5.4342, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5969, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0317, dtype=torch.float64)   实验回归残差 tensor(0.1064, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0318, dtype=torch.float64)   测试集实验回归残差 tensor(0.2628, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5838890902474074
# ################# 6 80 w绝对误差 tensor(2.4476, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7838, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0288, dtype=torch.float64)   实验回归残差 tensor(0.1430, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0279, dtype=torch.float64)   测试集实验回归残差 tensor(0.1324, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3804364467328125
# ############################# 6 80 w绝对误差 tensor(1.3546, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0658, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0753, dtype=torch.float64)   实验回归残差 tensor(0.1108, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0715, dtype=torch.float64)   测试集实验回归残差 tensor(0.1977, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5622537496845343
# ##################### 6 80 w绝对误差 tensor(2.1936, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7961, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0324, dtype=torch.float64)   实验回归残差 tensor(0.1076, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0383, dtype=torch.float64)   测试集实验回归残差 tensor(0.1534, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4566084577798666
# ############## 6 80 w绝对误差 tensor(2.5015, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9751, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0387, dtype=torch.float64)   实验回归残差 tensor(0.1422, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0422, dtype=torch.float64)   测试集实验回归残差 tensor(0.1291, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.43219590761793
# ############################### 6 80 w绝对误差 tensor(1.4572, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0344, dtype=torch.float64)   实验回归残差 tensor(0.0759, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0299, dtype=torch.float64)   测试集实验回归残差 tensor(0.1866, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5220196855145682
# ################### 6 80 w绝对误差 tensor(1.0765, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3641, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0392, dtype=torch.float64)   实验回归残差 tensor(0.1037, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0314, dtype=torch.float64)   测试集实验回归残差 tensor(0.1560, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4582141022796797
# ###################### 6 80 w绝对误差 tensor(1.2507, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8715, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0673, dtype=torch.float64)   实验回归残差 tensor(0.1071, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0883, dtype=torch.float64)   测试集实验回归残差 tensor(0.3725, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6146743462735862
# ##################################### 6 80 w绝对误差 tensor(4.4158, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3582, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0304, dtype=torch.float64)   实验回归残差 tensor(0.1049, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0342, dtype=torch.float64)   测试集实验回归残差 tensor(0.1359, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.572077305013592
# ##################### 4 80 w绝对误差 tensor(3.0576, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9203, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0615, dtype=torch.float64)   实验回归残差 tensor(0.1872, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0688, dtype=torch.float64)   测试集实验回归残差 tensor(0.2173, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3526735987087992
# ################ 4 80 w绝对误差 tensor(1.7345, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1708, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0726, dtype=torch.float64)   实验回归残差 tensor(0.2272, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0639, dtype=torch.float64)   测试集实验回归残差 tensor(0.3564, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4168030552579824
# ################ 4 80 w绝对误差 tensor(3.5528, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8464, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0257, dtype=torch.float64)   实验回归残差 tensor(0.1261, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0217, dtype=torch.float64)   测试集实验回归残差 tensor(0.2577, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5910610884047214
# ################################# 4 80 w绝对误差 tensor(4.6757, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4575, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0320, dtype=torch.float64)   实验回归残差 tensor(0.1689, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0321, dtype=torch.float64)   测试集实验回归残差 tensor(0.3020, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5515015125086253
# ####################### 4 80 w绝对误差 tensor(2.0084, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4180, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0861, dtype=torch.float64)   实验回归残差 tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0602, dtype=torch.float64)   测试集实验回归残差 tensor(0.1728, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4728984369543094
# ############### 4 80 w绝对误差 tensor(1.9071, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8811, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0449, dtype=torch.float64)   实验回归残差 tensor(0.1630, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0422, dtype=torch.float64)   测试集实验回归残差 tensor(0.1204, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3334033381769759
# ############# 4 80 w绝对误差 tensor(2.5396, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0384, dtype=torch.float64)   实验回归残差 tensor(0.2272, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0401, dtype=torch.float64)   测试集实验回归残差 tensor(0.1958, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2130977026102934
# ################## 4 80 w绝对误差 tensor(0.8737, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1672, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1287, dtype=torch.float64)   实验回归残差 tensor(0.1526, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1568, dtype=torch.float64)   测试集实验回归残差 tensor(0.3494, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.436211889205574
# #################################### 4 80 w绝对误差 tensor(0.0295, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0162, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0472, dtype=torch.float64)   实验回归残差 tensor(0.0296, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0604, dtype=torch.float64)   测试集实验回归残差 tensor(0.0468, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(0.9874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2686354278483292
# ##################### 4 80 w绝对误差 tensor(1.0691, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6965, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0694, dtype=torch.float64)   实验回归残差 tensor(0.1233, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0597, dtype=torch.float64)   测试集实验回归残差 tensor(0.2173, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.260756704294925
# ###################### 5 80 w绝对误差 tensor(2.5282, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2263, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0474, dtype=torch.float64)   实验回归残差 tensor(0.1784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0502, dtype=torch.float64)   测试集实验回归残差 tensor(0.3699, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4654407008105086
# ######################################### 5 80 w绝对误差 tensor(2.3392, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2151, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0508, dtype=torch.float64)   实验回归残差 tensor(0.1448, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0424, dtype=torch.float64)   测试集实验回归残差 tensor(0.2129, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5701505727112348
# ############################# 5 80 w绝对误差 tensor(3.0119, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0396, dtype=torch.float64)   实验回归残差 tensor(0.1598, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0472, dtype=torch.float64)   测试集实验回归残差 tensor(0.2481, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3788383883395567
# ############################## 5 80 w绝对误差 tensor(1.6834, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9706, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0608, dtype=torch.float64)   实验回归残差 tensor(0.1141, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0682, dtype=torch.float64)   测试集实验回归残差 tensor(0.1738, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.310303258009902
# ########################################################################################################################################################################################################超过迭代上限
#  5 80 w绝对误差 tensor(3.8756, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1425, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0271, dtype=torch.float64)   实验回归残差 tensor(0.1537, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0378, dtype=torch.float64)   测试集实验回归残差 tensor(0.3530, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4694556482627923
# ######################################## 5 80 w绝对误差 tensor(3.7181, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4748, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0429, dtype=torch.float64)   实验回归残差 tensor(0.1323, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0415, dtype=torch.float64)   测试集实验回归残差 tensor(0.2364, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3574260569893448
# ################################# 5 80 w绝对误差 tensor(4.0943, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4447, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0410, dtype=torch.float64)   实验回归残差 tensor(0.1154, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0408, dtype=torch.float64)   测试集实验回归残差 tensor(0.2330, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4233518635095221
# ################################################ 5 80 w绝对误差 tensor(3.2556, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2382, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0351, dtype=torch.float64)   实验回归残差 tensor(0.1103, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0413, dtype=torch.float64)   测试集实验回归残差 tensor(0.2637, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3173177918528631
# ############################## 5 80 w绝对误差 tensor(4.2261, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2779, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0338, dtype=torch.float64)   实验回归残差 tensor(0.1732, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0279, dtype=torch.float64)   测试集实验回归残差 tensor(0.1818, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4391160876595348
# ################################################################################## 5 80 w绝对误差 tensor(2.9808, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2865, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0384, dtype=torch.float64)   实验回归残差 tensor(0.1237, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0435, dtype=torch.float64)   测试集实验回归残差 tensor(0.2756, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5995646183560528
# ############################################################ 6 80 w绝对误差 tensor(2.9428, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4226, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0531, dtype=torch.float64)   实验回归残差 tensor(0.0746, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0411, dtype=torch.float64)   测试集实验回归残差 tensor(0.1952, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4152094587137896
# ############################# 6 80 w绝对误差 tensor(2.2561, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1786, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0607, dtype=torch.float64)   实验回归残差 tensor(0.0870, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0607, dtype=torch.float64)   测试集实验回归残差 tensor(0.3052, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4639476554109143
# ###################################### 6 80 w绝对误差 tensor(2.8270, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0576, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0297, dtype=torch.float64)   实验回归残差 tensor(0.1932, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0308, dtype=torch.float64)   测试集实验回归残差 tensor(0.1523, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4993053652123516
# ################################# 6 80 w绝对误差 tensor(3.3886, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3375, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0327, dtype=torch.float64)   实验回归残差 tensor(0.1511, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0384, dtype=torch.float64)   测试集实验回归残差 tensor(0.3278, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6647579252120832
# ########################################################## 6 80 w绝对误差 tensor(2.8598, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2165, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0491, dtype=torch.float64)   实验回归残差 tensor(0.0933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0434, dtype=torch.float64)   测试集实验回归残差 tensor(0.1508, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6293959078292073
# ################################################### 6 80 w绝对误差 tensor(5.2388, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4810, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0254, dtype=torch.float64)   实验回归残差 tensor(0.1218, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0253, dtype=torch.float64)   测试集实验回归残差 tensor(0.2830, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5136887286712135
# ############################ 6 80 w绝对误差 tensor(1.4238, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2986, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0884, dtype=torch.float64)   实验回归残差 tensor(0.1418, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0957, dtype=torch.float64)   测试集实验回归残差 tensor(0.2456, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3000315869175998
# ########################################################################################################################################################################################################超过迭代上限
#  6 80 w绝对误差 tensor(4.5201, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7873, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0350, dtype=torch.float64)   实验回归残差 tensor(0.1554, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0417, dtype=torch.float64)   测试集实验回归残差 tensor(0.4311, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.408573913801058
# ############################# 6 80 w绝对误差 tensor(0.8834, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5643, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0739, dtype=torch.float64)   实验回归残差 tensor(0.1145, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0733, dtype=torch.float64)   测试集实验回归残差 tensor(0.1847, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3513655898141566
# ##################################################################### 6 80 w绝对误差 tensor(2.9653, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0696, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0405, dtype=torch.float64)   实验回归残差 tensor(0.1108, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0322, dtype=torch.float64)   测试集实验回归残差 tensor(0.3030, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6812412577134122
# ############################ 4 80 w绝对误差 tensor(1.2437, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0034, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1000, dtype=torch.float64)   实验回归残差 tensor(0.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0825, dtype=torch.float64)   测试集实验回归残差 tensor(0.2585, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.229024280952659
# ############################ 4 80 w绝对误差 tensor(3.8116, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0266, dtype=torch.float64)   实验回归残差 tensor(0.0867, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0329, dtype=torch.float64)   测试集实验回归残差 tensor(0.1754, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3785355158906842
# ############## 4 80 w绝对误差 tensor(3.5410, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3807, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0393, dtype=torch.float64)   实验回归残差 tensor(0.1800, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0351, dtype=torch.float64)   测试集实验回归残差 tensor(0.2341, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2099321344422582
# ######################################## 4 80 w绝对误差 tensor(0.5577, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3179, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0678, dtype=torch.float64)   实验回归残差 tensor(0.0803, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0542, dtype=torch.float64)   测试集实验回归残差 tensor(0.1553, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3229, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2205352588691043
# ############ 4 80 w绝对误差 tensor(1.6826, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9492, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0562, dtype=torch.float64)   实验回归残差 tensor(0.1610, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0519, dtype=torch.float64)   测试集实验回归残差 tensor(0.2227, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3339824827418871
# ################################################################# 4 80 w绝对误差 tensor(4.7483, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6773, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0327, dtype=torch.float64)   实验回归残差 tensor(0.1392, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0377, dtype=torch.float64)   测试集实验回归残差 tensor(0.2810, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.490984756422414
# #################### 4 80 w绝对误差 tensor(1.3023, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1582, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0904, dtype=torch.float64)   实验回归残差 tensor(0.2266, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0908, dtype=torch.float64)   测试集实验回归残差 tensor(0.3829, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4502098125863632
# #################### 4 80 w绝对误差 tensor(1.6203, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0536, dtype=torch.float64)   实验回归残差 tensor(0.1380, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0609, dtype=torch.float64)   测试集实验回归残差 tensor(0.2806, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3608552287203701
# ####################### 4 80 w绝对误差 tensor(1.6113, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9803, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0639, dtype=torch.float64)   实验回归残差 tensor(0.1823, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0540, dtype=torch.float64)   测试集实验回归残差 tensor(0.1723, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3056776042377511
# ########################################################################################################################################################################################################超过迭代上限
#  4 80 w绝对误差 tensor(3.0954, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0784, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0636, dtype=torch.float64)   实验回归残差 tensor(0.1311, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0668, dtype=torch.float64)   测试集实验回归残差 tensor(0.3210, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5351550119646022
# #################### 5 80 w绝对误差 tensor(1.9334, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2737, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0671, dtype=torch.float64)   实验回归残差 tensor(0.1583, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0529, dtype=torch.float64)   测试集实验回归残差 tensor(0.2278, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.386259605160449
# ############################# 5 80 w绝对误差 tensor(1.4216, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6072, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0403, dtype=torch.float64)   实验回归残差 tensor(0.0982, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0404, dtype=torch.float64)   测试集实验回归残差 tensor(0.1398, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.309730571207308
# ############################ 5 80 w绝对误差 tensor(1.4641, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6411, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0399, dtype=torch.float64)   实验回归残差 tensor(0.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0376, dtype=torch.float64)   测试集实验回归残差 tensor(0.1617, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5091328077778448
# ################################ 5 80 w绝对误差 tensor(3.2881, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3148, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0437, dtype=torch.float64)   实验回归残差 tensor(0.2878, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0424, dtype=torch.float64)   测试集实验回归残差 tensor(0.2862, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2605889676004232
# ############### 5 80 w绝对误差 tensor(3.0228, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3111, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0418, dtype=torch.float64)   实验回归残差 tensor(0.2078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0486, dtype=torch.float64)   测试集实验回归残差 tensor(0.2903, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5284399414881409
# ################################### 5 80 w绝对误差 tensor(1.8723, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1587, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0578, dtype=torch.float64)   实验回归残差 tensor(0.1513, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0704, dtype=torch.float64)   测试集实验回归残差 tensor(0.1804, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6118653929372513
# ##################################### 5 80 w绝对误差 tensor(3.0342, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6209, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0558, dtype=torch.float64)   实验回归残差 tensor(0.1606, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0649, dtype=torch.float64)   测试集实验回归残差 tensor(0.3827, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3371556937810523
# ########################################################################################################################################################################################################超过迭代上限
#  5 80 w绝对误差 tensor(3.5782, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0283, dtype=torch.float64)   实验回归残差 tensor(0.1285, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0328, dtype=torch.float64)   测试集实验回归残差 tensor(0.2727, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.621573943298228
# ######################################################## 5 80 w绝对误差 tensor(2.3962, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3892, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0520, dtype=torch.float64)   实验回归残差 tensor(0.1748, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0521, dtype=torch.float64)   测试集实验回归残差 tensor(0.1614, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5866947582895177
# ...
# ############################### 4 80 w绝对误差 tensor(1.0060, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4256, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0475, dtype=torch.float64)   实验回归残差 tensor(0.1164, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0483, dtype=torch.float64)   测试集实验回归残差 tensor(0.1178, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.400176975740611
# ############################## 4 80 w绝对误差 tensor(1.8491, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6404, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0373, dtype=torch.float64)   实验回归残差 tensor(0.0916, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0363, dtype=torch.float64)   测试集实验回归残差 tensor(0.2221, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.423572058676345
# ###################### 4 80 w绝对误差 tensor(0.9684, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8971, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0933, dtype=torch.float64)   实验回归残差 tensor(0.1203, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0872, dtype=torch.float64)   测试集实验回归残差 tensor(0.2427, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4292506584751006
# ############################ 4 80 w绝对误差 tensor(0.1994, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1387, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0722, dtype=torch.float64)   实验回归残差 tensor(0.0604, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0795, dtype=torch.float64)   测试集实验回归残差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2942, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4521760668085797
# ############################################# 4 80 w绝对误差 tensor(3.2923, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8787, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0677, dtype=torch.float64)   实验回归残差 tensor(0.1809, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0441, dtype=torch.float64)   测试集实验回归残差 tensor(0.1580, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4471037766934418
# ##################### 4 80 w绝对误差 tensor(2.1818, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1715, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0541, dtype=torch.float64)   实验回归残差 tensor(0.2026, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0476, dtype=torch.float64)   测试集实验回归残差 tensor(0.2411, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3823793843898184
# ############################################ 4 80 w绝对误差 tensor(1.9448, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1113, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0439, dtype=torch.float64)   实验回归残差 tensor(0.1695, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0665, dtype=torch.float64)   测试集实验回归残差 tensor(0.3246, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3753127892561388
# ########################### 5 80 w绝对误差 tensor(2.6844, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2580, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0415, dtype=torch.float64)   实验回归残差 tensor(0.1472, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0449, dtype=torch.float64)   测试集实验回归残差 tensor(0.2206, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.405177169085035
# ############################# 5 80 w绝对误差 tensor(1.3988, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5347, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0441, dtype=torch.float64)   实验回归残差 tensor(0.1369, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0374, dtype=torch.float64)   测试集实验回归残差 tensor(0.1364, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3570018681514897
# ########################## 5 80 w绝对误差 tensor(2.1992, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7373, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0363, dtype=torch.float64)   实验回归残差 tensor(0.1325, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0377, dtype=torch.float64)   测试集实验回归残差 tensor(0.1506, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.537908906295831
# ###################################################### 5 80 w绝对误差 tensor(2.9106, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2870, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0535, dtype=torch.float64)   实验回归残差 tensor(0.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0487, dtype=torch.float64)   测试集实验回归残差 tensor(0.3235, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6103210015955596
# ############################################################# 5 80 w绝对误差 tensor(2.9583, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5097, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0463, dtype=torch.float64)   实验回归残差 tensor(0.1306, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0583, dtype=torch.float64)   测试集实验回归残差 tensor(0.2832, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.463111254345387
# ############### 5 80 w绝对误差 tensor(1.3008, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9215, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0845, dtype=torch.float64)   实验回归残差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0779, dtype=torch.float64)   测试集实验回归残差 tensor(0.1830, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2621711375479565
# ########################################### 5 80 w绝对误差 tensor(2.9001, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4149, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0439, dtype=torch.float64)   实验回归残差 tensor(0.1284, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0459, dtype=torch.float64)   测试集实验回归残差 tensor(0.1392, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.346757944555288
# ################################################## 5 80 w绝对误差 tensor(2.9988, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7808, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0251, dtype=torch.float64)   实验回归残差 tensor(0.0975, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0316, dtype=torch.float64)   测试集实验回归残差 tensor(0.2054, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4437197812752096
# ##################### 5 80 w绝对误差 tensor(1.2357, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6970, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0551, dtype=torch.float64)   实验回归残差 tensor(0.1047, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0511, dtype=torch.float64)   测试集实验回归残差 tensor(0.1356, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2939761576438198
# ######################## 5 80 w绝对误差 tensor(2.9572, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1073, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0363, dtype=torch.float64)   实验回归残差 tensor(0.1963, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.2810, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.460510700151968
# ########################################### 6 80 w绝对误差 tensor(2.5876, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9245, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0311, dtype=torch.float64)   实验回归残差 tensor(0.1321, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0388, dtype=torch.float64)   测试集实验回归残差 tensor(0.1890, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3957738680554082
# #################################### 6 80 w绝对误差 tensor(2.5651, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0106, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0394, dtype=torch.float64)   实验回归残差 tensor(0.1499, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0385, dtype=torch.float64)   测试集实验回归残差 tensor(0.2158, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5314251819440394
# ############################# 6 80 w绝对误差 tensor(2.6763, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0270, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0351, dtype=torch.float64)   实验回归残差 tensor(0.2395, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0416, dtype=torch.float64)   测试集实验回归残差 tensor(0.3249, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5266863822930004
# ####################################### 6 80 w绝对误差 tensor(1.6978, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8969, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0530, dtype=torch.float64)   实验回归残差 tensor(0.1385, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0469, dtype=torch.float64)   测试集实验回归残差 tensor(0.2731, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5915409900573716
# #################### 6 80 w绝对误差 tensor(2.3478, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2710, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0630, dtype=torch.float64)   实验回归残差 tensor(0.1477, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0554, dtype=torch.float64)   测试集实验回归残差 tensor(0.1707, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4664877245133332
# ############################################### 6 80 w绝对误差 tensor(3.7213, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5139, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0487, dtype=torch.float64)   实验回归残差 tensor(0.1076, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0427, dtype=torch.float64)   测试集实验回归残差 tensor(0.4555, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5593967493486163
# ########################## 6 80 w绝对误差 tensor(2.6656, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3897, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0515, dtype=torch.float64)   实验回归残差 tensor(0.2212, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0543, dtype=torch.float64)   测试集实验回归残差 tensor(0.2536, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.7787667342423457
# ################################################################################## 6 80 w绝对误差 tensor(3.7909, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4288, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0351, dtype=torch.float64)   实验回归残差 tensor(0.1105, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0399, dtype=torch.float64)   测试集实验回归残差 tensor(0.2077, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.6968738661547218
# ################################## 6 80 w绝对误差 tensor(0.9596, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4179, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0396, dtype=torch.float64)   实验回归残差 tensor(0.1129, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0443, dtype=torch.float64)   测试集实验回归残差 tensor(0.2089, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3509, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.697540269781078
