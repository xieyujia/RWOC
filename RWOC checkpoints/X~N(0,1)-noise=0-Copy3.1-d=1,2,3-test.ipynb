# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(20,21,100): 
        for num_X2feature in [3,2,1]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ###################################################### 3 20 w绝对误差 tensor(1.1707, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2641, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2159, dtype=torch.float64)   实验回归残差 tensor(0.2990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1450, dtype=torch.float64)   测试集实验回归残差 tensor(0.5002, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.785204070803601
# ################################################################## 3 20 w绝对误差 tensor(0.3289, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1740, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0250, dtype=torch.float64)   实验回归残差 tensor(0.0470, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0686, dtype=torch.float64)   测试集实验回归残差 tensor(0.1469, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8367, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.946121834847154
# ############################################################################### 3 20 w绝对误差 tensor(0.0351, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0135, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0340, dtype=torch.float64)   实验回归残差 tensor(0.0298, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0622, dtype=torch.float64)   测试集实验回归残差 tensor(0.0672, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.4472, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5847776821402884
# ######################################## 3 20 w绝对误差 tensor(1.1681, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7760, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0587, dtype=torch.float64)   实验回归残差 tensor(0.2513, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0697, dtype=torch.float64)   测试集实验回归残差 tensor(0.3091, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4108274397115703
# ################################################################################# 3 20 w绝对误差 tensor(0.0154, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0062, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0358, dtype=torch.float64)   实验回归残差 tensor(0.0309, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0366, dtype=torch.float64)   测试集实验回归残差 tensor(0.0376, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.7071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.6325, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4744102937507504
# ########################################################################## 3 20 w绝对误差 tensor(1.3872, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4579, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0327, dtype=torch.float64)   实验回归残差 tensor(0.1647, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0563, dtype=torch.float64)   测试集实验回归残差 tensor(0.3510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.87304802973136
# ############################################################################################ 3 20 w绝对误差 tensor(3.8204, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2013, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0338, dtype=torch.float64)   实验回归残差 tensor(0.2237, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0388, dtype=torch.float64)   测试集实验回归残差 tensor(0.2368, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5429194705460074
# ############################## 3 20 w绝对误差 tensor(1.0520, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4259, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1343, dtype=torch.float64)   实验回归残差 tensor(0.2796, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2327, dtype=torch.float64)   测试集实验回归残差 tensor(0.4003, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4192024858338952
# ############################################### 3 20 w绝对误差 tensor(1.6156, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4196, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0834, dtype=torch.float64)   实验回归残差 tensor(0.1885, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1220, dtype=torch.float64)   测试集实验回归残差 tensor(0.5192, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4567702795978013
# ################################################################################## 3 20 w绝对误差 tensor(1.5931, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0457, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0677, dtype=torch.float64)   实验回归残差 tensor(0.1961, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0825, dtype=torch.float64)   测试集实验回归残差 tensor(0.3432, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 2.2011188970784485
# ############################## 2 20 w绝对误差 tensor(1.8135, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9783, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0374, dtype=torch.float64)   实验回归残差 tensor(0.3014, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0620, dtype=torch.float64)   测试集实验回归残差 tensor(0.3707, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3248802020400647
# ######################################## 2 20 w绝对误差 tensor(0.0775, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1538, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2121, dtype=torch.float64)   实验回归残差 tensor(0.1643, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2386, dtype=torch.float64)   测试集实验回归残差 tensor(0.1877, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3953859807313957
# ########################### 2 20 w绝对误差 tensor(1.3215, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7437, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0547, dtype=torch.float64)   实验回归残差 tensor(0.2851, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0632, dtype=torch.float64)   测试集实验回归残差 tensor(0.2692, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0960348026495428
# ################################################################## 2 20 w绝对误差 tensor(0.0906, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0631, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0581, dtype=torch.float64)   实验回归残差 tensor(0.0585, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0592, dtype=torch.float64)   测试集实验回归残差 tensor(0.0655, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.790276816474267
# ####################################################### 2 20 w绝对误差 tensor(0.6124, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6224, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1207, dtype=torch.float64)   实验回归残差 tensor(0.2257, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1153, dtype=torch.float64)   测试集实验回归残差 tensor(0.2982, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5584006941364812
# ######################################################## 2 20 w绝对误差 tensor(0.0190, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0273, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1732, dtype=torch.float64)   实验回归残差 tensor(0.0988, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1111, dtype=torch.float64)   测试集实验回归残差 tensor(0.0890, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.225614362650706
# ####################################################### 2 20 w绝对误差 tensor(1.9460, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3298, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0865, dtype=torch.float64)   实验回归残差 tensor(0.2768, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0457, dtype=torch.float64)   测试集实验回归残差 tensor(0.3841, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3473202313217616
# ############################################################### 2 20 w绝对误差 tensor(0.1961, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1312, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0999, dtype=torch.float64)   实验回归残差 tensor(0.1005, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0699, dtype=torch.float64)   测试集实验回归残差 tensor(0.1049, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.2312746025939671
# ################################################ 2 20 w绝对误差 tensor(0.1196, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2566, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2484, dtype=torch.float64)   实验回归残差 tensor(0.1581, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1512, dtype=torch.float64)   测试集实验回归残差 tensor(0.2922, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3322359371657784
# ###################################################### 2 20 w绝对误差 tensor(2.1907, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2331, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0543, dtype=torch.float64)   实验回归残差 tensor(0.3876, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0674, dtype=torch.float64)   测试集实验回归残差 tensor(0.5026, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1709962308110475
# ########################### 1 20 w绝对误差 tensor(0.0236, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0310, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1386, dtype=torch.float64)   实验回归残差 tensor(0.0965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1434, dtype=torch.float64)   测试集实验回归残差 tensor(0.1391, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################################ 1 20 w绝对误差 tensor(0.0477, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6863, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9183, dtype=torch.float64)   实验回归残差 tensor(0.3347, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7934, dtype=torch.float64)   测试集实验回归残差 tensor(0.2934, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################## 1 20 w绝对误差 tensor(0.0007, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0009, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0924, dtype=torch.float64)   实验回归残差 tensor(0.0841, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1178, dtype=torch.float64)   测试集实验回归残差 tensor(0.1027, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.7746, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################# 1 20 w绝对误差 tensor(0.0269, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2661, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.6631, dtype=torch.float64)   实验回归残差 tensor(0.3686, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7908, dtype=torch.float64)   测试集实验回归残差 tensor(0.2552, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3292, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 18   条件数 1.0
# ################################ 1 20 w绝对误差 tensor(0.0227, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0368, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1707, dtype=torch.float64)   实验回归残差 tensor(0.1424, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1632, dtype=torch.float64)   测试集实验回归残差 tensor(0.1264, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ########################### 1 20 w绝对误差 tensor(0.0267, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1595, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4763, dtype=torch.float64)   实验回归残差 tensor(0.2401, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4872, dtype=torch.float64)   测试集实验回归残差 tensor(0.2010, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################## 1 20 w绝对误差 tensor(0.0098, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0046, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0461, dtype=torch.float64)   实验回归残差 tensor(0.0373, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0451, dtype=torch.float64)   测试集实验回归残差 tensor(0.0395, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.4472, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.6325, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ########################################## 1 20 w绝对误差 tensor(0.0009, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1589, dtype=torch.float64)   实验回归残差 tensor(0.1303, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1307, dtype=torch.float64)   测试集实验回归残差 tensor(0.0862, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.6325, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ######################################### 1 20 w绝对误差 tensor(0.0165, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0380, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2646, dtype=torch.float64)   实验回归残差 tensor(0.1639, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2563, dtype=torch.float64)   测试集实验回归残差 tensor(0.1434, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################## 1 20 w绝对误差 tensor(0.0362, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2841, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.6191, dtype=torch.float64)   实验回归残差 tensor(0.2522, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.5851, dtype=torch.float64)   测试集实验回归残差 tensor(0.3104, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################################# 3 20 w绝对误差 tensor(1.9217, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5479, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0578, dtype=torch.float64)   实验回归残差 tensor(0.1936, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0687, dtype=torch.float64)   测试集实验回归残差 tensor(0.4547, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6699816854836556
# ################################ 3 20 w绝对误差 tensor(0.6298, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9610, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1343, dtype=torch.float64)   实验回归残差 tensor(0.3111, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1937, dtype=torch.float64)   测试集实验回归残差 tensor(0.3417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.2241058492277983
# ############################################## 3 20 w绝对误差 tensor(0.5659, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8785, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1569, dtype=torch.float64)   实验回归残差 tensor(0.2111, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1316, dtype=torch.float64)   测试集实验回归残差 tensor(0.4843, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5442759580962806
# ################################################### 3 20 w绝对误差 tensor(0.8982, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2891, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0329, dtype=torch.float64)   实验回归残差 tensor(0.1184, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0464, dtype=torch.float64)   测试集实验回归残差 tensor(0.1461, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.7810539222209345
# ########################################################################## 3 20 w绝对误差 tensor(0.5428, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6477, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1392, dtype=torch.float64)   实验回归残差 tensor(0.2279, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1064, dtype=torch.float64)   测试集实验回归残差 tensor(0.4594, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.9128326354523904
# ######################################################## 3 20 w绝对误差 tensor(0.0220, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0216, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0659, dtype=torch.float64)   实验回归残差 tensor(0.0595, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0800, dtype=torch.float64)   测试集实验回归残差 tensor(0.0635, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.5477, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.7071, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.7912467469960933
# ############################ 3 20 w绝对误差 tensor(0.6582, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4336, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0571, dtype=torch.float64)   实验回归残差 tensor(0.1780, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0583, dtype=torch.float64)   测试集实验回归残差 tensor(0.2554, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5273513813658715
# ##################################################################### 3 20 w绝对误差 tensor(2.7314, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5586, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1063, dtype=torch.float64)   实验回归残差 tensor(0.2449, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0670, dtype=torch.float64)   测试集实验回归残差 tensor(0.2871, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4314222308244755
# ################################ 3 20 w绝对误差 tensor(0.7543, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6769, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0628, dtype=torch.float64)   实验回归残差 tensor(0.2878, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1373, dtype=torch.float64)   测试集实验回归残差 tensor(0.3103, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.510779956658281
# ########################################################### 3 20 w绝对误差 tensor(0.9617, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6422, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0867, dtype=torch.float64)   实验回归残差 tensor(0.2299, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0668, dtype=torch.float64)   测试集实验回归残差 tensor(0.3319, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4147114572492494
# ################################################ 2 20 w绝对误差 tensor(0.0224, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0154, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0665, dtype=torch.float64)   实验回归残差 tensor(0.0573, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0652, dtype=torch.float64)   测试集实验回归残差 tensor(0.0451, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.7071, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3929302441413873
# ##################################################################################################### 2 20 w绝对误差 tensor(0.4552, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3480, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0889, dtype=torch.float64)   实验回归残差 tensor(0.1836, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0632, dtype=torch.float64)   测试集实验回归残差 tensor(0.1875, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.335868448015086
# ####################################################### 2 20 w绝对误差 tensor(0.0173, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0381, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2713, dtype=torch.float64)   实验回归残差 tensor(0.1284, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1632, dtype=torch.float64)   测试集实验回归残差 tensor(0.1320, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.2093170703746225
# ########################################################### 2 20 w绝对误差 tensor(0.4030, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4220, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3147, dtype=torch.float64)   实验回归残差 tensor(0.3735, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3012, dtype=torch.float64)   测试集实验回归残差 tensor(0.5547, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3561524557039166
# ######################################################################################## 2 20 w绝对误差 tensor(1.3449, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9520, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2012, dtype=torch.float64)   实验回归残差 tensor(0.1686, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1732, dtype=torch.float64)   测试集实验回归残差 tensor(0.1944, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.2538088717554265
# ################################################## 2 20 w绝对误差 tensor(1.9285, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9054, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0634, dtype=torch.float64)   实验回归残差 tensor(0.1949, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0595, dtype=torch.float64)   测试集实验回归残差 tensor(0.4743, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1573540191237994
# ################################## 2 20 w绝对误差 tensor(0.1570, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7084, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3929, dtype=torch.float64)   实验回归残差 tensor(0.2485, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2924, dtype=torch.float64)   测试集实验回归残差 tensor(0.3356, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.242531709447447
# ############################################ 2 20 w绝对误差 tensor(0.0326, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0219, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0681, dtype=torch.float64)   实验回归残差 tensor(0.0596, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0691, dtype=torch.float64)   测试集实验回归残差 tensor(0.0694, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.5477, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.7071, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.240240888665032
# ################################################## 2 20 w绝对误差 tensor(2.3524, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7048, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0826, dtype=torch.float64)   实验回归残差 tensor(0.2438, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0510, dtype=torch.float64)   测试集实验回归残差 tensor(0.4510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1712961059844529
# ######################################## 2 20 w绝对误差 tensor(2.6044, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6850, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0528, dtype=torch.float64)   实验回归残差 tensor(0.3113, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0728, dtype=torch.float64)   测试集实验回归残差 tensor(0.3932, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0771724592562233
# ##################################### 1 20 w绝对误差 tensor(0.0150, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0101, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0658, dtype=torch.float64)   实验回归残差 tensor(0.0608, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0946, dtype=torch.float64)   测试集实验回归残差 tensor(0.0879, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ######################## 1 20 w绝对误差 tensor(0.2927, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.2076, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.5350, dtype=torch.float64)   实验回归残差 tensor(0.3647, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7237, dtype=torch.float64)   测试集实验回归残差 tensor(0.6290, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ##################################### 1 20 w绝对误差 tensor(0.0062, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0070, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1274, dtype=torch.float64)   实验回归残差 tensor(0.0697, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1176, dtype=torch.float64)   测试集实验回归残差 tensor(0.1027, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ######################################################## 1 20 w绝对误差 tensor(3.3034, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9317, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0846, dtype=torch.float64)   实验回归残差 tensor(0.3535, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0454, dtype=torch.float64)   测试集实验回归残差 tensor(0.3703, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ###################### 1 20 w绝对误差 tensor(0.0108, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0342, dtype=torch.float64)   实验回归残差 tensor(0.0331, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0705, dtype=torch.float64)   测试集实验回归残差 tensor(0.0654, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.4472, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.7746, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################## 1 20 w绝对误差 tensor(0.5218, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8905, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2273, dtype=torch.float64)   实验回归残差 tensor(0.4016, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4313, dtype=torch.float64)   测试集实验回归残差 tensor(0.5912, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################################ 1 20 w绝对误差 tensor(0.0235, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0373, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1475, dtype=torch.float64)   实验回归残差 tensor(0.1051, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1300, dtype=torch.float64)   测试集实验回归残差 tensor(0.0994, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################# 1 20 w绝对误差 tensor(0.0004, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0003, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0675, dtype=torch.float64)   实验回归残差 tensor(0.0648, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0786, dtype=torch.float64)   测试集实验回归残差 tensor(0.0677, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.7746, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.7746, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ######################### 1 20 w绝对误差 tensor(0.0222, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0375, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1441, dtype=torch.float64)   实验回归残差 tensor(0.1166, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1588, dtype=torch.float64)   测试集实验回归残差 tensor(0.1253, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################ 1 20 w绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0065, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0578, dtype=torch.float64)   实验回归残差 tensor(0.0534, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0648, dtype=torch.float64)   测试集实验回归残差 tensor(0.0619, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.6325, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################################################################################################ 3 20 w绝对误差 tensor(1.0354, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6812, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0582, dtype=torch.float64)   实验回归残差 tensor(0.1587, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0570, dtype=torch.float64)   测试集实验回归残差 tensor(0.3223, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.9441987995089343
# ############################################################# 3 20 w绝对误差 tensor(2.0857, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3089, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0817, dtype=torch.float64)   实验回归残差 tensor(0.2980, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0698, dtype=torch.float64)   测试集实验回归残差 tensor(0.4154, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.516823795988448
# ########################################################## 3 20 w绝对误差 tensor(0.5605, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4581, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2665, dtype=torch.float64)   实验回归残差 tensor(0.4526, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4532, dtype=torch.float64)   测试集实验回归残差 tensor(0.6071, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5054469268286124
# ###################################### 3 20 w绝对误差 tensor(1.4683, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0529, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0597, dtype=torch.float64)   实验回归残差 tensor(0.2581, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0728, dtype=torch.float64)   测试集实验回归残差 tensor(0.1955, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5312013075379571
# ################################################### 3 20 w绝对误差 tensor(0.7043, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7894, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0912, dtype=torch.float64)   实验回归残差 tensor(0.0947, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1748, dtype=torch.float64)   测试集实验回归残差 tensor(0.6845, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3743233862820767
# ############################ 3 20 w绝对误差 tensor(4.3765, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5800, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0307, dtype=torch.float64)   实验回归残差 tensor(0.2013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0318, dtype=torch.float64)   测试集实验回归残差 tensor(0.6302, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3749275389931845
# ############################## 3 20 w绝对误差 tensor(1.8434, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9915, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0406, dtype=torch.float64)   实验回归残差 tensor(0.3336, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0754, dtype=torch.float64)   测试集实验回归残差 tensor(0.4082, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.713427357938655
# ################################################# 3 20 w绝对误差 tensor(1.6758, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9797, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0541, dtype=torch.float64)   实验回归残差 tensor(0.3609, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0402, dtype=torch.float64)   测试集实验回归残差 tensor(0.4207, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6952293086476589
# ######################################################################################## 3 20 w绝对误差 tensor(0.3406, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2732, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0892, dtype=torch.float64)   实验回归残差 tensor(0.1079, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0756, dtype=torch.float64)   测试集实验回归残差 tensor(0.1218, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6360951183245507
# ################################################################ 3 20 w绝对误差 tensor(2.3798, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1398, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0714, dtype=torch.float64)   实验回归残差 tensor(0.3602, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0550, dtype=torch.float64)   测试集实验回归残差 tensor(0.3518, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.796459684126099
# ######################################### 2 20 w绝对误差 tensor(0.9722, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9529, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1024, dtype=torch.float64)   实验回归残差 tensor(0.3508, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0905, dtype=torch.float64)   测试集实验回归残差 tensor(0.2849, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.2683970651806762
# ############################################################### 2 20 w绝对误差 tensor(0.1606, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2786, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1435, dtype=torch.float64)   实验回归残差 tensor(0.1388, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1334, dtype=torch.float64)   测试集实验回归残差 tensor(0.1271, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3572820088622308
# ############################ 2 20 w绝对误差 tensor(1.0906, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7709, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0748, dtype=torch.float64)   实验回归残差 tensor(0.2312, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0615, dtype=torch.float64)   测试集实验回归残差 tensor(0.4849, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6117151707707391
# ################################################# 2 20 w绝对误差 tensor(2.0947, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7673, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0430, dtype=torch.float64)   实验回归残差 tensor(0.3993, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0312, dtype=torch.float64)   测试集实验回归残差 tensor(0.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4238856638405026
# ################################### 2 20 w绝对误差 tensor(0.8259, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6860, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0955, dtype=torch.float64)   实验回归残差 tensor(0.3289, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1547, dtype=torch.float64)   测试集实验回归残差 tensor(0.5022, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1048540240870994
# ####################################### 2 20 w绝对误差 tensor(0.0182, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0274, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1144, dtype=torch.float64)   实验回归残差 tensor(0.1032, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1648, dtype=torch.float64)   测试集实验回归残差 tensor(0.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.38141130235176
# ############################## 2 20 w绝对误差 tensor(0.0189, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0236, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1555, dtype=torch.float64)   实验回归残差 tensor(0.1433, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1297, dtype=torch.float64)   测试集实验回归残差 tensor(0.1067, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.3286710576552545
# ######################################## 2 20 w绝对误差 tensor(0.0274, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0152, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0526, dtype=torch.float64)   实验回归残差 tensor(0.0398, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0604, dtype=torch.float64)   测试集实验回归残差 tensor(0.0449, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.7071, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.6325, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.294524865554268
# ...
# #################################### 3 20 w绝对误差 tensor(2.4959, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2608, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0408, dtype=torch.float64)   实验回归残差 tensor(0.2043, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0425, dtype=torch.float64)   测试集实验回归残差 tensor(0.3561, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6670158785724039
# ################################# 3 20 w绝对误差 tensor(1.1187, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9676, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0706, dtype=torch.float64)   实验回归残差 tensor(0.1679, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0963, dtype=torch.float64)   测试集实验回归残差 tensor(0.3757, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.5097863987500624
# ########################################################################################################## 3 20 w绝对误差 tensor(0.0495, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0267, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0382, dtype=torch.float64)   实验回归残差 tensor(0.0367, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0400, dtype=torch.float64)   测试集实验回归残差 tensor(0.0448, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.4472, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.4472, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 2.114059406046709
# ############################################################################################ 3 20 w绝对误差 tensor(1.1205, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5762, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0371, dtype=torch.float64)   实验回归残差 tensor(0.1631, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0500, dtype=torch.float64)   测试集实验回归残差 tensor(0.3422, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6856842508560104
# ##################################################################################################################### 3 20 w绝对误差 tensor(3.5655, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5176, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0501, dtype=torch.float64)   实验回归残差 tensor(0.2052, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0416, dtype=torch.float64)   测试集实验回归残差 tensor(0.8290, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6921790271241854
# ############################################################################# 3 20 w绝对误差 tensor(1.6676, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6056, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0372, dtype=torch.float64)   实验回归残差 tensor(0.1606, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0351, dtype=torch.float64)   测试集实验回归残差 tensor(0.1898, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.7811180034171643
# #################################### 2 20 w绝对误差 tensor(0.9584, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5747, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0530, dtype=torch.float64)   实验回归残差 tensor(0.1749, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0761, dtype=torch.float64)   测试集实验回归残差 tensor(0.2699, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.198540202148618
# ################################## 2 20 w绝对误差 tensor(2.1413, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7255, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0661, dtype=torch.float64)   实验回归残差 tensor(0.4822, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0936, dtype=torch.float64)   测试集实验回归残差 tensor(0.2780, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0774618710319457
# ################################################### 2 20 w绝对误差 tensor(3.1004, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0950, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0433, dtype=torch.float64)   实验回归残差 tensor(0.2613, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0485, dtype=torch.float64)   测试集实验回归残差 tensor(0.6695, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 2.0292416882662048
# ######################################################## 2 20 w绝对误差 tensor(0.4360, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6718, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1554, dtype=torch.float64)   实验回归残差 tensor(0.3127, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1471, dtype=torch.float64)   测试集实验回归残差 tensor(0.3669, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.6887345334437183
# ########################################## 2 20 w绝对误差 tensor(0.0480, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0299, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0675, dtype=torch.float64)   实验回归残差 tensor(0.0443, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0656, dtype=torch.float64)   测试集实验回归残差 tensor(0.0613, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1048364248611289
# ############################################################## 2 20 w绝对误差 tensor(0.0256, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0279, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1123, dtype=torch.float64)   实验回归残差 tensor(0.0941, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0785, dtype=torch.float64)   测试集实验回归残差 tensor(0.0670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.4466774791937775
# ############################ 2 20 w绝对误差 tensor(0.6892, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8907, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0752, dtype=torch.float64)   实验回归残差 tensor(0.2929, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1282, dtype=torch.float64)   测试集实验回归残差 tensor(0.3518, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1131219961826904
# ################################################################################# 2 20 w绝对误差 tensor(2.6009, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5314, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0700, dtype=torch.float64)   实验回归残差 tensor(0.2640, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0622, dtype=torch.float64)   测试集实验回归残差 tensor(0.5100, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.2956993668323529
# ############################################# 2 20 w绝对误差 tensor(2.5348, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3867, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0590, dtype=torch.float64)   实验回归残差 tensor(0.3310, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0478, dtype=torch.float64)   测试集实验回归残差 tensor(0.5237, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.104384859588116
# ################################# 2 20 w绝对误差 tensor(0.5811, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8449, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1216, dtype=torch.float64)   实验回归残差 tensor(0.1125, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1258, dtype=torch.float64)   测试集实验回归残差 tensor(0.2010, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.1142862869774788
# ########################## 1 20 w绝对误差 tensor(0.0332, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0712, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2015, dtype=torch.float64)   实验回归残差 tensor(0.1468, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1874, dtype=torch.float64)   测试集实验回归残差 tensor(0.1469, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################################ 1 20 w绝对误差 tensor(0.0042, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0090, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1693, dtype=torch.float64)   实验回归残差 tensor(0.1211, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2028, dtype=torch.float64)   测试集实验回归残差 tensor(0.1529, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################################# 1 20 w绝对误差 tensor(0.0197, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0340, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1835, dtype=torch.float64)   实验回归残差 tensor(0.0932, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2323, dtype=torch.float64)   测试集实验回归残差 tensor(0.1674, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################################################## 1 20 w绝对误差 tensor(0.0339, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0452, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1366, dtype=torch.float64)   实验回归残差 tensor(0.1054, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1232, dtype=torch.float64)   测试集实验回归残差 tensor(0.1140, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################## 1 20 w绝对误差 tensor(0.3924, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0009, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4177, dtype=torch.float64)   实验回归残差 tensor(0.4001, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.5072, dtype=torch.float64)   测试集实验回归残差 tensor(0.8440, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################################################## 1 20 w绝对误差 tensor(0.0116, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0189, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1985, dtype=torch.float64)   实验回归残差 tensor(0.1194, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1394, dtype=torch.float64)   测试集实验回归残差 tensor(0.1001, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ############################## 1 20 w绝对误差 tensor(0.0217, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1589, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.5874, dtype=torch.float64)   实验回归残差 tensor(0.2404, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4768, dtype=torch.float64)   测试集实验回归残差 tensor(0.1626, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# #################################################### 1 20 w绝对误差 tensor(0.0080, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0058, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0855, dtype=torch.float64)   实验回归残差 tensor(0.0737, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0623, dtype=torch.float64)   测试集实验回归残差 tensor(0.0509, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.8944, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################## 1 20 w绝对误差 tensor(0.0045, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1082, dtype=torch.float64)   实验回归残差 tensor(0.0889, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1862, dtype=torch.float64)   测试集实验回归残差 tensor(0.1177, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
# ################################ 1 20 w绝对误差 tensor(0.0192, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0386, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1822, dtype=torch.float64)   实验回归残差 tensor(0.0804, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1677, dtype=torch.float64)   测试集实验回归残差 tensor(0.1440, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 20   测试集置换矩阵误差 tensor(0.9487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 20   条件数 1.0
