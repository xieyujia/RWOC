# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(80,81,100): 
        for num_X2feature in [3,2,1]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.008
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-5:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############### 3 80 w绝对误差 tensor(1.0140, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0864, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1126, dtype=torch.float64)   实验回归残差 tensor(0.1083, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1266, dtype=torch.float64)   测试集实验回归残差 tensor(0.2325, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2037420425584613
# ###################### 3 80 w绝对误差 tensor(0.4743, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0670, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2132, dtype=torch.float64)   实验回归残差 tensor(0.2455, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2292, dtype=torch.float64)   测试集实验回归残差 tensor(0.2778, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3340613987568877
# ############################ 3 80 w绝对误差 tensor(1.6206, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9981, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0607, dtype=torch.float64)   实验回归残差 tensor(0.1621, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0492, dtype=torch.float64)   测试集实验回归残差 tensor(0.1774, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.309359533187511
# ############## 3 80 w绝对误差 tensor(1.4024, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1549, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0792, dtype=torch.float64)   实验回归残差 tensor(0.1701, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0954, dtype=torch.float64)   测试集实验回归残差 tensor(0.2893, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.293491334045546
# ############################# 3 80 w绝对误差 tensor(1.5396, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2215, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0772, dtype=torch.float64)   实验回归残差 tensor(0.1791, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0655, dtype=torch.float64)   测试集实验回归残差 tensor(0.2458, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.275761479924965
# ############# 3 80 w绝对误差 tensor(1.2764, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1392, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0835, dtype=torch.float64)   实验回归残差 tensor(0.1016, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0786, dtype=torch.float64)   测试集实验回归残差 tensor(0.3024, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4367633259081856
# ####################### 3 80 w绝对误差 tensor(1.2116, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5209, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0450, dtype=torch.float64)   实验回归残差 tensor(0.0852, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0425, dtype=torch.float64)   测试集实验回归残差 tensor(0.1551, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.274641198738983
# ############### 3 80 w绝对误差 tensor(1.1725, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7286, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0441, dtype=torch.float64)   实验回归残差 tensor(0.1058, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0682, dtype=torch.float64)   测试集实验回归残差 tensor(0.2616, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3825932526710474
# ####################### 3 80 w绝对误差 tensor(1.4805, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2437, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0855, dtype=torch.float64)   实验回归残差 tensor(0.1701, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0832, dtype=torch.float64)   测试集实验回归残差 tensor(0.1926, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.5568875130968876
# ######## 3 80 w绝对误差 tensor(1.6058, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7654, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0479, dtype=torch.float64)   实验回归残差 tensor(0.1460, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0550, dtype=torch.float64)   测试集实验回归残差 tensor(0.1603, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0787749848998982
# ########################################## 2 80 w绝对误差 tensor(0.0398, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0317, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0728, dtype=torch.float64)   实验回归残差 tensor(0.0416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0821, dtype=torch.float64)   测试集实验回归残差 tensor(0.0564, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2550, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1901350338081866
# ########################### 2 80 w绝对误差 tensor(0.6393, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2658, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2129, dtype=torch.float64)   实验回归残差 tensor(0.1516, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1634, dtype=torch.float64)   测试集实验回归残差 tensor(0.2961, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.201634965045948
# ######################## 2 80 w绝对误差 tensor(0.5850, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4262, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1639, dtype=torch.float64)   实验回归残差 tensor(0.1519, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2451, dtype=torch.float64)   测试集实验回归残差 tensor(0.2498, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.171963103102442
# ############ 2 80 w绝对误差 tensor(0.0101, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0065, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0543, dtype=torch.float64)   实验回归残差 tensor(0.0388, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0683, dtype=torch.float64)   测试集实验回归残差 tensor(0.0443, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0607, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1442418305300954
# ######################### 2 80 w绝对误差 tensor(0.0516, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0647, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1352, dtype=torch.float64)   实验回归残差 tensor(0.0624, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1154, dtype=torch.float64)   测试集实验回归残差 tensor(0.0738, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2450, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2042, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1319070018152155
# ################################### 2 80 w绝对误差 tensor(0.0174, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0171, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0825, dtype=torch.float64)   实验回归残差 tensor(0.0515, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1002, dtype=torch.float64)   测试集实验回归残差 tensor(0.0689, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2224, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.3032086479014335
# ############################ 2 80 w绝对误差 tensor(0.0317, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0460, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1274, dtype=torch.float64)   实验回归残差 tensor(0.0615, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1292, dtype=torch.float64)   测试集实验回归残差 tensor(0.0723, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2942, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2353943585378426
# ####### 2 80 w绝对误差 tensor(1.1638, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9494, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0996, dtype=torch.float64)   实验回归残差 tensor(0.1414, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0973, dtype=torch.float64)   测试集实验回归残差 tensor(0.2475, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.276019492733857
# ################################################################## 2 80 w绝对误差 tensor(0.2187, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1628, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0786, dtype=torch.float64)   实验回归残差 tensor(0.0693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0744, dtype=torch.float64)   测试集实验回归残差 tensor(0.0803, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3134, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2942, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2532928383571158
# ################ 2 80 w绝对误差 tensor(1.0098, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3901, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0364, dtype=torch.float64)   实验回归残差 tensor(0.0875, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0378, dtype=torch.float64)   测试集实验回归残差 tensor(0.1466, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2676182008097923
# ######### 1 80 w绝对误差 tensor(0.0069, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0111, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1620, dtype=torch.float64)   实验回归残差 tensor(0.0759, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1695, dtype=torch.float64)   测试集实验回归残差 tensor(0.0900, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3379, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.0
# ################# 1 80 w绝对误差 tensor(0.0091, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0301, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3002, dtype=torch.float64)   实验回归残差 tensor(0.1036, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3515, dtype=torch.float64)   测试集实验回归残差 tensor(0.1021, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3134, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########## 1 80 w绝对误差 tensor(0.0088, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0055, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0548, dtype=torch.float64)   实验回归残差 tensor(0.0352, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0689, dtype=torch.float64)   测试集实验回归残差 tensor(0.0462, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0724, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########### 1 80 w绝对误差 tensor(0.0002, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0003, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1737, dtype=torch.float64)   实验回归残差 tensor(0.0834, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1799, dtype=torch.float64)   测试集实验回归残差 tensor(0.0806, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2942, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ################################################ 1 80 w绝对误差 tensor(0.0136, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0068, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0447, dtype=torch.float64)   实验回归残差 tensor(0.0343, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0487, dtype=torch.float64)   测试集实验回归残差 tensor(0.0324, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1180, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1068, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ############ 1 80 w绝对误差 tensor(0.0061, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0161, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2247, dtype=torch.float64)   实验回归残差 tensor(0.1124, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2348, dtype=torch.float64)   测试集实验回归残差 tensor(0.0923, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3595, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# #### 1 80 w绝对误差 tensor(0.0069, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0104, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1689, dtype=torch.float64)   实验回归残差 tensor(0.0908, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1272, dtype=torch.float64)   测试集实验回归残差 tensor(0.0655, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######## 1 80 w绝对误差 tensor(0.0130, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0563, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4500, dtype=torch.float64)   实验回归残差 tensor(0.1523, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3579, dtype=torch.float64)   测试集实验回归残差 tensor(0.1181, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4037, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######## 1 80 w绝对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0029, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0838, dtype=torch.float64)   实验回归残差 tensor(0.0522, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0857, dtype=torch.float64)   测试集实验回归残差 tensor(0.0560, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######### 1 80 w绝对误差 tensor(1.1846, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9515, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1651, dtype=torch.float64)   实验回归残差 tensor(0.2425, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1763, dtype=torch.float64)   测试集实验回归残差 tensor(0.2852, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ############# 3 80 w绝对误差 tensor(0.3801, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5510, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1367, dtype=torch.float64)   实验回归残差 tensor(0.1327, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1380, dtype=torch.float64)   测试集实验回归残差 tensor(0.1240, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.204622473703159
# ########### 3 80 w绝对误差 tensor(1.3292, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3302, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0950, dtype=torch.float64)   实验回归残差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1020, dtype=torch.float64)   测试集实验回归残差 tensor(0.2674, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.25788260242574
# ######################################## 3 80 w绝对误差 tensor(0.0339, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0208, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0613, dtype=torch.float64)   实验回归残差 tensor(0.0330, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0652, dtype=torch.float64)   测试集实验回归残差 tensor(0.0544, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2845, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1791377503911564
# ############### 3 80 w绝对误差 tensor(0.0095, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0304, dtype=torch.float64)   实验回归残差 tensor(0.0252, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0288, dtype=torch.float64)   测试集实验回归残差 tensor(0.0234, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(0.9618, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.0247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1440224073974168
# ######################## 3 80 w绝对误差 tensor(0.9571, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1628, dtype=torch.float64)   实验回归残差 tensor(0.1436, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1422, dtype=torch.float64)   测试集实验回归残差 tensor(0.4976, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3107373125533053
# ########### 3 80 w绝对误差 tensor(0.3632, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2378, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2610, dtype=torch.float64)   实验回归残差 tensor(0.2033, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3162, dtype=torch.float64)   测试集实验回归残差 tensor(0.2049, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1517793103967358
# ############### 3 80 w绝对误差 tensor(1.1614, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8838, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0848, dtype=torch.float64)   实验回归残差 tensor(0.1504, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0708, dtype=torch.float64)   测试集实验回归残差 tensor(0.1572, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4230997056066876
# ################ 3 80 w绝对误差 tensor(3.5204, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2453, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0348, dtype=torch.float64)   实验回归残差 tensor(0.1583, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0348, dtype=torch.float64)   测试集实验回归残差 tensor(0.1718, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.183805659698174
# ######################### 3 80 w绝对误差 tensor(3.1809, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5108, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0637, dtype=torch.float64)   实验回归残差 tensor(0.2520, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0466, dtype=torch.float64)   测试集实验回归残差 tensor(0.4443, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3578444464134483
# ################## 3 80 w绝对误差 tensor(1.0342, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4602, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0464, dtype=torch.float64)   实验回归残差 tensor(0.0751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0410, dtype=torch.float64)   测试集实验回归残差 tensor(0.1153, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2483765368253996
# ####### 2 80 w绝对误差 tensor(0.6545, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7594, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1237, dtype=torch.float64)   实验回归残差 tensor(0.1330, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1187, dtype=torch.float64)   测试集实验回归残差 tensor(0.2203, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1815360394501573
# ################### 2 80 w绝对误差 tensor(0.0142, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0135, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0966, dtype=torch.float64)   实验回归残差 tensor(0.0493, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0850, dtype=torch.float64)   测试集实验回归残差 tensor(0.0575, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2042, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0586935436726623
# ######### 2 80 w绝对误差 tensor(1.0942, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1665, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1089, dtype=torch.float64)   实验回归残差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1082, dtype=torch.float64)   测试集实验回归残差 tensor(0.2541, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0984599045670906
# ########### 2 80 w绝对误差 tensor(1.4347, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6986, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0454, dtype=torch.float64)   实验回归残差 tensor(0.1437, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0505, dtype=torch.float64)   测试集实验回归残差 tensor(0.2111, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1162858978627084
# ######### 2 80 w绝对误差 tensor(0.7952, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5635, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0612, dtype=torch.float64)   实验回归残差 tensor(0.1007, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0666, dtype=torch.float64)   测试集实验回归残差 tensor(0.2346, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3001692282413795
# ######### 2 80 w绝对误差 tensor(0.9716, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3528, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0362, dtype=torch.float64)   实验回归残差 tensor(0.0975, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0346, dtype=torch.float64)   测试集实验回归残差 tensor(0.1183, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3323, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.125471623009106
# ############### 2 80 w绝对误差 tensor(0.0187, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0141, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0852, dtype=torch.float64)   实验回归残差 tensor(0.0531, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0657, dtype=torch.float64)   测试集实验回归残差 tensor(0.0523, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1511, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.0724, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.121077416677764
# ####### 2 80 w绝对误差 tensor(0.1554, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4724, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3142, dtype=torch.float64)   实验回归残差 tensor(0.1359, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3044, dtype=torch.float64)   测试集实验回归残差 tensor(0.1373, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1710159476946833
# ######################################## 2 80 w绝对误差 tensor(0.0185, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0162, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0858, dtype=torch.float64)   实验回归残差 tensor(0.0428, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0649, dtype=torch.float64)   测试集实验回归残差 tensor(0.0487, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2845, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1068, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2399441061430352
# ######### 2 80 w绝对误差 tensor(1.1585, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0553, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0821, dtype=torch.float64)   实验回归残差 tensor(0.1446, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0985, dtype=torch.float64)   测试集实验回归残差 tensor(0.2721, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0635375227591577
# ###### 1 80 w绝对误差 tensor(0.0475, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4338, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.7186, dtype=torch.float64)   实验回归残差 tensor(0.2544, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.6656, dtype=torch.float64)   测试集实验回归残差 tensor(0.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3739, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######## 1 80 w绝对误差 tensor(0.0067, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0035, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0615, dtype=torch.float64)   实验回归残差 tensor(0.0391, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0504, dtype=torch.float64)   测试集实验回归残差 tensor(0.0391, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2450, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.0840, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ###### 1 80 w绝对误差 tensor(0.0359, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4513, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.8521, dtype=torch.float64)   实验回归残差 tensor(0.1745, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7150, dtype=torch.float64)   测试集实验回归残差 tensor(0.1787, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3954, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.3684, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.0
# ########## 1 80 w绝对误差 tensor(0.0038, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0033, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0909, dtype=torch.float64)   实验回归残差 tensor(0.0536, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0867, dtype=torch.float64)   测试集实验回归残差 tensor(0.0511, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2042, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2450, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ################ 1 80 w绝对误差 tensor(0.0240, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0726, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2599, dtype=torch.float64)   实验回归残差 tensor(0.0918, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3039, dtype=torch.float64)   测试集实验回归残差 tensor(0.1483, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3559, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######## 1 80 w绝对误差 tensor(0.0036, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0032, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0792, dtype=torch.float64)   实验回归残差 tensor(0.0492, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0994, dtype=torch.float64)   测试集实验回归残差 tensor(0.0574, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2450, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######## 1 80 w绝对误差 tensor(0.0176, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0856, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.5070, dtype=torch.float64)   实验回归残差 tensor(0.1126, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3311, dtype=torch.float64)   测试集实验回归残差 tensor(0.1456, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3600, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########## 1 80 w绝对误差 tensor(0.0109, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0041, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0367, dtype=torch.float64)   实验回归残差 tensor(0.0255, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0379, dtype=torch.float64)   测试集实验回归残差 tensor(0.0313, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0607, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1., dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########## 1 80 w绝对误差 tensor(0.0058, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0241, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3869, dtype=torch.float64)   实验回归残差 tensor(0.1210, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4236, dtype=torch.float64)   测试集实验回归残差 tensor(0.1350, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########## 1 80 w绝对误差 tensor(0.0157, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0186, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1273, dtype=torch.float64)   实验回归残差 tensor(0.0709, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1285, dtype=torch.float64)   测试集实验回归残差 tensor(0.0747, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2550, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2349, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########################## 3 80 w绝对误差 tensor(1.0506, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0181, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0925, dtype=torch.float64)   实验回归残差 tensor(0.1897, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1045, dtype=torch.float64)   测试集实验回归残差 tensor(0.2196, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.418532446939374
# ################# 3 80 w绝对误差 tensor(0.1740, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2007, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1115, dtype=torch.float64)   实验回归残差 tensor(0.0686, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1233, dtype=torch.float64)   测试集实验回归残差 tensor(0.1246, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3198, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.3669955520661163
# ##################### 3 80 w绝对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0044, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0631, dtype=torch.float64)   实验回归残差 tensor(0.0372, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0730, dtype=torch.float64)   测试集实验回归残差 tensor(0.0451, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1511, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1795112739459008
# ############################### 3 80 w绝对误差 tensor(1.8252, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3467, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0622, dtype=torch.float64)   实验回归残差 tensor(0.1899, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0881, dtype=torch.float64)   测试集实验回归残差 tensor(0.2444, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4135, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2091835433644804
# ############################# 3 80 w绝对误差 tensor(1.0134, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0793, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1271, dtype=torch.float64)   实验回归残差 tensor(0.2195, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0943, dtype=torch.float64)   测试集实验回归残差 tensor(0.4528, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4715421315239023
# ###################### 3 80 w绝对误差 tensor(1.5190, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0984, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0707, dtype=torch.float64)   实验回归残差 tensor(0.1104, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0743, dtype=torch.float64)   测试集实验回归残差 tensor(0.2300, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2208266442436717
# ########################## 3 80 w绝对误差 tensor(1.6640, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0561, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0841, dtype=torch.float64)   实验回归残差 tensor(0.1609, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0541, dtype=torch.float64)   测试集实验回归残差 tensor(0.2886, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3363400074424991
# ######################### 3 80 w绝对误差 tensor(3.8156, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5780, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0399, dtype=torch.float64)   实验回归残差 tensor(0.1684, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0428, dtype=torch.float64)   测试集实验回归残差 tensor(0.3194, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.4477601832758011
# ############## 3 80 w绝对误差 tensor(0.8830, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4610, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0605, dtype=torch.float64)   实验回归残差 tensor(0.1122, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0497, dtype=torch.float64)   测试集实验回归残差 tensor(0.1026, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3526080764897306
# #################################### 3 80 w绝对误差 tensor(0.0647, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0715, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1062, dtype=torch.float64)   实验回归残差 tensor(0.0495, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1072, dtype=torch.float64)   测试集实验回归残差 tensor(0.0810, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2349, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2845, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2743219050971089
# ############# 2 80 w绝对误差 tensor(0.9902, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0317, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1081, dtype=torch.float64)   实验回归残差 tensor(0.1724, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1180, dtype=torch.float64)   测试集实验回归残差 tensor(0.2050, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.25983575666769
# ################ 2 80 w绝对误差 tensor(2.7929, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5658, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0546, dtype=torch.float64)   实验回归残差 tensor(0.1968, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0508, dtype=torch.float64)   测试集实验回归残差 tensor(0.2549, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.110688078619155
# ########### 2 80 w绝对误差 tensor(0.8516, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6836, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0739, dtype=torch.float64)   实验回归残差 tensor(0.1145, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0881, dtype=torch.float64)   测试集实验回归残差 tensor(0.2215, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.129535151877774
# ########## 2 80 w绝对误差 tensor(0.0160, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0675, dtype=torch.float64)   实验回归残差 tensor(0.0409, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0629, dtype=torch.float64)   测试集实验回归残差 tensor(0.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1726, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1511, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.018718778931061
# ###################### 2 80 w绝对误差 tensor(0.1016, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2879, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2743, dtype=torch.float64)   实验回归残差 tensor(0.1268, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2878, dtype=torch.float64)   测试集实验回归残差 tensor(0.1560, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.3696362993973912
# ######################## 2 80 w绝对误差 tensor(2.2787, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3360, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0653, dtype=torch.float64)   实验回归残差 tensor(0.1403, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0485, dtype=torch.float64)   测试集实验回归残差 tensor(0.2808, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.357899467373453
# ############ 2 80 w绝对误差 tensor(0.9737, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1841, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1558, dtype=torch.float64)   实验回归残差 tensor(0.1757, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1003, dtype=torch.float64)   测试集实验回归残差 tensor(0.3670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1413258382138
# ################################## 2 80 w绝对误差 tensor(0.4516, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3628, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0812, dtype=torch.float64)   实验回归残差 tensor(0.0967, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0906, dtype=torch.float64)   测试集实验回归残差 tensor(0.1463, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3783, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2445915977277753
# ###################### 2 80 w绝对误差 tensor(0.0114, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0068, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0459, dtype=torch.float64)   实验回归残差 tensor(0.0312, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0630, dtype=torch.float64)   测试集实验回归残差 tensor(0.0417, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2042, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.098118804317584
# ###### 2 80 w绝对误差 tensor(0.0257, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0887, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3593, dtype=torch.float64)   实验回归残差 tensor(0.0926, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3804, dtype=torch.float64)   测试集实验回归残差 tensor(0.1061, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0722431538618438
# ########### 1 80 w绝对误差 tensor(0.0019, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0014, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0738, dtype=torch.float64)   实验回归残差 tensor(0.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0844, dtype=torch.float64)   测试集实验回归残差 tensor(0.0504, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2042, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ##### 1 80 w绝对误差 tensor(0.0631, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0275, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9048, dtype=torch.float64)   实验回归残差 tensor(0.1730, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.8605, dtype=torch.float64)   测试集实验回归残差 tensor(0.1955, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4054, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ...
# ################## 3 80 w绝对误差 tensor(1.2951, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1014, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0880, dtype=torch.float64)   实验回归残差 tensor(0.1995, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0825, dtype=torch.float64)   测试集实验回归残差 tensor(0.2756, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.301068969720644
# ######################## 3 80 w绝对误差 tensor(0.0425, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0268, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0598, dtype=torch.float64)   实验回归残差 tensor(0.0411, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0563, dtype=torch.float64)   测试集实验回归残差 tensor(0.0456, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2844721385728264
# ############################ 3 80 w绝对误差 tensor(0.0598, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0548, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0892, dtype=torch.float64)   实验回归残差 tensor(0.0452, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0821, dtype=torch.float64)   测试集实验回归残差 tensor(0.0588, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2845, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2681336731374986
# ####################### 3 80 w绝对误差 tensor(1.9662, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8444, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0483, dtype=torch.float64)   实验回归残差 tensor(0.0722, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0367, dtype=torch.float64)   测试集实验回归残差 tensor(0.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2243734617632052
# ######################## 3 80 w绝对误差 tensor(2.0819, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2412, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0633, dtype=torch.float64)   实验回归残差 tensor(0.2215, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0485, dtype=torch.float64)   测试集实验回归残差 tensor(0.1691, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2408471073434053
# ################# 3 80 w绝对误差 tensor(0.8908, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4587, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0497, dtype=torch.float64)   实验回归残差 tensor(0.1253, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0580, dtype=torch.float64)   测试集实验回归残差 tensor(0.1458, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1181549680218479
# ###################### 3 80 w绝对误差 tensor(0.6787, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3152, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0541, dtype=torch.float64)   实验回归残差 tensor(0.0865, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0481, dtype=torch.float64)   测试集实验回归残差 tensor(0.1793, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2799606238684773
# ############### 2 80 w绝对误差 tensor(0.0355, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0388, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1035, dtype=torch.float64)   实验回归残差 tensor(0.0680, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1094, dtype=torch.float64)   测试集实验回归残差 tensor(0.0797, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2748, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2140, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.131701121874182
# ################ 2 80 w绝对误差 tensor(0.8724, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0058, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1255, dtype=torch.float64)   实验回归残差 tensor(0.1981, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0972, dtype=torch.float64)   测试集实验回归残差 tensor(0.2650, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4053, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0735254522518036
# ################# 2 80 w绝对误差 tensor(0.0640, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5845, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.7102, dtype=torch.float64)   实验回归残差 tensor(0.1501, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.6270, dtype=torch.float64)   测试集实验回归残差 tensor(0.1622, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4029, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.222564948866976
# ########################################### 2 80 w绝对误差 tensor(0.0590, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0833, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1278, dtype=torch.float64)   实验回归残差 tensor(0.0785, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1413, dtype=torch.float64)   测试集实验回归残差 tensor(0.0771, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3323, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3134, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1567904620557514
# ################# 2 80 w绝对误差 tensor(0.4687, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3167, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0634, dtype=torch.float64)   实验回归残差 tensor(0.0955, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0673, dtype=torch.float64)   测试集实验回归残差 tensor(0.1415, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3874, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.1456263360417016
# ######### 2 80 w绝对误差 tensor(0.6843, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5720, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0849, dtype=torch.float64)   实验回归残差 tensor(0.1402, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0804, dtype=torch.float64)   测试集实验回归残差 tensor(0.2195, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0477720629625646
# ###################################### 2 80 w绝对误差 tensor(3.0531, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9192, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0774, dtype=torch.float64)   实验回归残差 tensor(0.1341, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0658, dtype=torch.float64)   测试集实验回归残差 tensor(0.2059, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2437017807355328
# #################################### 2 80 w绝对误差 tensor(0.0223, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0221, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1070, dtype=torch.float64)   实验回归残差 tensor(0.0665, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0932, dtype=torch.float64)   测试集实验回归残差 tensor(0.0521, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2748, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3229, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2316491576331374
# ########## 2 80 w绝对误差 tensor(0.5860, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4519, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0748, dtype=torch.float64)   实验回归残差 tensor(0.1418, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0822, dtype=torch.float64)   测试集实验回归残差 tensor(0.1269, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3964, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.01599091558493
# ################################ 2 80 w绝对误差 tensor(0.0053, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0039, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0666, dtype=torch.float64)   实验回归残差 tensor(0.0461, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0712, dtype=torch.float64)   测试集实验回归残差 tensor(0.0517, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1832, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.0954, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.2001008750809472
# ################# 1 80 w绝对误差 tensor(0.7613, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9312, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2415, dtype=torch.float64)   实验回归残差 tensor(0.2726, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2407, dtype=torch.float64)   测试集实验回归残差 tensor(0.3789, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.0
# ############ 1 80 w绝对误差 tensor(0.0063, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0051, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0842, dtype=torch.float64)   实验回归残差 tensor(0.0467, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0664, dtype=torch.float64)   测试集实验回归残差 tensor(0.0463, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2649, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2550, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ###### 1 80 w绝对误差 tensor(1.6362, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9939, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1102, dtype=torch.float64)   实验回归残差 tensor(0.1459, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1130, dtype=torch.float64)   测试集实验回归残差 tensor(0.2250, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ########### 1 80 w绝对误差 tensor(0.0246, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0940, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3255, dtype=torch.float64)   实验回归残差 tensor(0.1618, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3398, dtype=torch.float64)   测试集实验回归残差 tensor(0.1394, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3601, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.0
# ##### 1 80 w绝对误差 tensor(0.0168, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0073, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0483, dtype=torch.float64)   实验回归残差 tensor(0.0348, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0375, dtype=torch.float64)   测试集实验回归残差 tensor(0.0308, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1785, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 78   测试集置换矩阵误差 tensor(1.0488, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ####### 1 80 w绝对误差 tensor(0.0055, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1199, dtype=torch.float64)   实验回归残差 tensor(0.0617, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1028, dtype=torch.float64)   测试集实验回归残差 tensor(0.0615, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.2547, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 78   条件数 1.0
# ################# 1 80 w绝对误差 tensor(0.0008, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0017, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2012, dtype=torch.float64)   实验回归残差 tensor(0.0902, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2046, dtype=torch.float64)   测试集实验回归残差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ############## 1 80 w绝对误差 tensor(0.0122, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0180, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1470, dtype=torch.float64)   实验回归残差 tensor(0.0719, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1531, dtype=torch.float64)   测试集实验回归残差 tensor(0.0718, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3229, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ####### 1 80 w绝对误差 tensor(0.0175, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0178, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1092, dtype=torch.float64)   实验回归残差 tensor(0.0576, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1234, dtype=torch.float64)   测试集实验回归残差 tensor(0.0757, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2042, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3038, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
# ######## 1 80 w绝对误差 tensor(0.0018, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0062, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3078, dtype=torch.float64)   实验回归残差 tensor(0.1409, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3421, dtype=torch.float64)   测试集实验回归残差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3323, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 80   测试集置换矩阵误差 tensor(1.3509, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 80   条件数 1.0
