# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    X2_=torch.mm(P,X2_before_)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    return y_,X2_,true_w2,P,error_reg,conditionnumber

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(150,151,100): 
        for num_X2feature in [1,2,3]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber)=generatedata(noise=0.3)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.002
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-7:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'绝对误差',error_each,end='   ')
                print('相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归误差',error_reg1,end='   ')
                print('实验回归误差',error_reg2,end='   ')
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ################ 1 150 绝对误差 tensor(0.0189, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0251, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4456, dtype=torch.float64)   实验回归误差 tensor(0.1286, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ##### 1 150 绝对误差 tensor(0.0803, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0999, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3926, dtype=torch.float64)   实验回归误差 tensor(0.1134, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.5052, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.1193, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9000, dtype=torch.float64)   实验回归误差 tensor(0.1608, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4132, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.1416, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4636, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6689, dtype=torch.float64)   实验回归误差 tensor(0.1510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0437, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0302, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1764, dtype=torch.float64)   实验回归误差 tensor(0.0681, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0295, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0331, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3102, dtype=torch.float64)   实验回归误差 tensor(0.0882, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0961, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2794, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6035, dtype=torch.float64)   实验回归误差 tensor(0.1162, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.0031, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0025, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2570, dtype=torch.float64)   实验回归误差 tensor(0.0817, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.2360, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.7720, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9836, dtype=torch.float64)   实验回归误差 tensor(0.1290, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4120, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ########### 1 150 绝对误差 tensor(2.7588, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9974, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1919, dtype=torch.float64)   实验回归误差 tensor(0.0777, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############################# 2 150 绝对误差 tensor(0.7838, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1286, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4021, dtype=torch.float64)   实验回归误差 tensor(0.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4094, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0692774068793227
# ####################################### 2 150 绝对误差 tensor(1.6978, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1354, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2076, dtype=torch.float64)   实验回归误差 tensor(0.1710, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0663845659526678
# ################################################################################################# 2 150 绝对误差 tensor(1.2012, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8986, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2180, dtype=torch.float64)   实验回归误差 tensor(0.1050, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1039346037547813
# ################################################################################# 2 150 绝对误差 tensor(0.1779, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2174, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3094, dtype=torch.float64)   实验回归误差 tensor(0.0825, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3903, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0329317890162992
# ################# 2 150 绝对误差 tensor(1.5928, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7108, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1400, dtype=torch.float64)   实验回归误差 tensor(0.1369, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1159912188802157
# ############################################################################################################################################# 2 150 绝对误差 tensor(0.2445, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.8384, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9727, dtype=torch.float64)   实验回归误差 tensor(0.1015, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4046, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.073886893986966
# ############## 2 150 绝对误差 tensor(1.9807, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.0423, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2971, dtype=torch.float64)   实验回归误差 tensor(0.1248, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0984120635396917
# ############################# 2 150 绝对误差 tensor(0.6554, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4399, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6364, dtype=torch.float64)   实验回归误差 tensor(0.1694, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0613600614872454
# ################################### 2 150 绝对误差 tensor(1.6125, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7655, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2523, dtype=torch.float64)   实验回归误差 tensor(0.0896, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1452859573890004
# ########################################## 2 150 绝对误差 tensor(0.2558, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7364, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6812, dtype=torch.float64)   实验回归误差 tensor(0.0877, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0831458079628546
# ##################################################################################### 3 150 绝对误差 tensor(1.1524, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8187, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2094, dtype=torch.float64)   实验回归误差 tensor(0.1541, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.130858769847899
# #################################################################################################### 3 150 绝对误差 tensor(1.8927, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8552, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1439, dtype=torch.float64)   实验回归误差 tensor(0.0805, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1721916507463226
# ####################################################################### 3 150 绝对误差 tensor(2.3357, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7842, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1028, dtype=torch.float64)   实验回归误差 tensor(0.1316, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1978729055490813
# ######################################################## 3 150 绝对误差 tensor(0.0664, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0644, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2633, dtype=torch.float64)   实验回归误差 tensor(0.0670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1169141446724327
# ###################### 3 150 绝对误差 tensor(2.6082, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4239, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1803, dtype=torch.float64)   实验回归误差 tensor(0.1394, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.133009564282091
# ############################################################################################### 3 150 绝对误差 tensor(2.5713, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9449, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1089, dtype=torch.float64)   实验回归误差 tensor(0.1510, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2086404042538759
# ################################## 3 150 绝对误差 tensor(0.6631, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3669, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1806, dtype=torch.float64)   实验回归误差 tensor(0.0865, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2287690608360853
# ########################################################################################################################################################################################################超过迭代上限
#  3 150 绝对误差 tensor(0.7766, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1948, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4479, dtype=torch.float64)   实验回归误差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.116462506867357
# ################## 3 150 绝对误差 tensor(2.1909, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1473, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1604, dtype=torch.float64)   实验回归误差 tensor(0.1894, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0757076095550748
# ##################################################### 3 150 绝对误差 tensor(1.3407, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7890, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1635, dtype=torch.float64)   实验回归误差 tensor(0.1337, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1036500262862223
# ########### 1 150 绝对误差 tensor(0.0394, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0331, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2330, dtype=torch.float64)   实验回归误差 tensor(0.0595, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0571, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0505, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2739, dtype=torch.float64)   实验回归误差 tensor(0.0830, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0217, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0229, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3385, dtype=torch.float64)   实验回归误差 tensor(0.0690, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.1652, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4863, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6742, dtype=torch.float64)   实验回归误差 tensor(0.1280, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4043, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################ 1 150 绝对误差 tensor(0.0362, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0412, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3778, dtype=torch.float64)   实验回归误差 tensor(0.0913, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3833, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0213, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0174, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2384, dtype=torch.float64)   实验回归误差 tensor(0.0665, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.2825, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(22.7702, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9989, dtype=torch.float64)   实验回归误差 tensor(0.0979, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4045, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.1193, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4230, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7152, dtype=torch.float64)   实验回归误差 tensor(0.1381, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3978, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.0337, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0362, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3536, dtype=torch.float64)   实验回归误差 tensor(0.0899, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0230, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0184, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2406, dtype=torch.float64)   实验回归误差 tensor(0.0780, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ######################################################################################################################################### 2 150 绝对误差 tensor(0.6069, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5905, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3039, dtype=torch.float64)   实验回归误差 tensor(0.0893, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0664630242013562
# #################################### 2 150 绝对误差 tensor(0.0762, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0353, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1404, dtype=torch.float64)   实验回归误差 tensor(0.0527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3264, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1266541580145166
# #################################################### 2 150 绝对误差 tensor(1.5904, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0683, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2024, dtype=torch.float64)   实验回归误差 tensor(0.1001, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0617669893622257
# ######################### 2 150 绝对误差 tensor(2.7918, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3740, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1464, dtype=torch.float64)   实验回归误差 tensor(0.1664, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0557492778858406
# ############################################################################################################################################################################################# 2 150 绝对误差 tensor(0.6339, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4990, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2313, dtype=torch.float64)   实验回归误差 tensor(0.0820, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0840889835339964
# ################################### 2 150 绝对误差 tensor(1.7347, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3799, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2540, dtype=torch.float64)   实验回归误差 tensor(0.1478, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1918002609815006
# ########################### 2 150 绝对误差 tensor(2.5080, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3585, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1707, dtype=torch.float64)   实验回归误差 tensor(0.1364, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1388899804547405
# ######################################################################################################################################################################### 2 150 绝对误差 tensor(0.3779, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5612, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4273, dtype=torch.float64)   实验回归误差 tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1375948171643149
# ##################################################################################################### 2 150 绝对误差 tensor(0.0750, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0423, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1583, dtype=torch.float64)   实验回归误差 tensor(0.0602, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1565262346028589
# ###################### 2 150 绝对误差 tensor(0.3354, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4967, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3569, dtype=torch.float64)   实验回归误差 tensor(0.1162, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3934, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0777132937853644
# ####################################################################################################### 3 150 绝对误差 tensor(1.4455, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5356, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1065, dtype=torch.float64)   实验回归误差 tensor(0.1043, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1263302070231025
# ############################ 3 150 绝对误差 tensor(0.8793, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8923, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2992, dtype=torch.float64)   实验回归误差 tensor(0.0868, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2664313156088238
# #################################################################################################################### 3 150 绝对误差 tensor(2.5488, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3908, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1566, dtype=torch.float64)   实验回归误差 tensor(0.1033, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1711151828414246
# ################################################################### 3 150 绝对误差 tensor(1.7236, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9597, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1674, dtype=torch.float64)   实验回归误差 tensor(0.0960, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4074, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1029769468960613
# ######################################################################### 3 150 绝对误差 tensor(2.5391, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.2378, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1425, dtype=torch.float64)   实验回归误差 tensor(0.1429, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3994, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.222302659508046
# ######################################################################################################## 3 150 绝对误差 tensor(1.2651, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6333, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1510, dtype=torch.float64)   实验回归误差 tensor(0.0697, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2974945012680732
# ################################################### 3 150 绝对误差 tensor(1.5054, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7617, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3256, dtype=torch.float64)   实验回归误差 tensor(0.1182, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1449282770547804
# ############################################################################################# 3 150 绝对误差 tensor(2.6526, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1455, dtype=torch.float64)   实验回归误差 tensor(0.1219, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.12119259530808
# ######################################################################## 3 150 绝对误差 tensor(2.4093, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4149, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1611, dtype=torch.float64)   实验回归误差 tensor(0.1297, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1544992372663931
# ############################################# 3 150 绝对误差 tensor(3.3840, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3750, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1190, dtype=torch.float64)   实验回归误差 tensor(0.1805, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1367826000853867
# ############### 1 150 绝对误差 tensor(0.0050, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0044, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2686, dtype=torch.float64)   实验回归误差 tensor(0.0759, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3760, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0551, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0382, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1994, dtype=torch.float64)   实验回归误差 tensor(0.0683, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3466, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.1021, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4018, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7019, dtype=torch.float64)   实验回归误差 tensor(0.1406, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3994, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.6303, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.4850, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7701, dtype=torch.float64)   实验回归误差 tensor(0.1407, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4139, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################### 1 150 绝对误差 tensor(0.0270, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0168, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1963, dtype=torch.float64)   实验回归误差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3663, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.2455, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.7239, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9664, dtype=torch.float64)   实验回归误差 tensor(0.1920, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3980, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0013, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0012, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2717, dtype=torch.float64)   实验回归误差 tensor(0.0841, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ######### 1 150 绝对误差 tensor(0.0457, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0227, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1346, dtype=torch.float64)   实验回归误差 tensor(0.0498, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########### 1 150 绝对误差 tensor(0.0240, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0404, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4424, dtype=torch.float64)   实验回归误差 tensor(0.0935, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4047, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.0365, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0256, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1777, dtype=torch.float64)   实验回归误差 tensor(0.0768, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3565, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ####################################################### 2 150 绝对误差 tensor(0.6767, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1892, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4450, dtype=torch.float64)   实验回归误差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1212429356280564
# ########################################################################################################################## 2 150 绝对误差 tensor(0.3874, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4997, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3081, dtype=torch.float64)   实验回归误差 tensor(0.0845, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.097502768181608
# ##################################################### 2 150 绝对误差 tensor(1.2681, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8079, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1945, dtype=torch.float64)   实验回归误差 tensor(0.1122, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.045420056842081
# ############################## 2 150 绝对误差 tensor(1.4321, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7482, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1609, dtype=torch.float64)   实验回归误差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1117073897222767
# ########################################## 2 150 绝对误差 tensor(0.8932, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6906, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2251, dtype=torch.float64)   实验回归误差 tensor(0.0932, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0790311001288897
# ############################ 2 150 绝对误差 tensor(0.3592, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3661, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3117, dtype=torch.float64)   实验回归误差 tensor(0.0598, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0658857503117123
# ##################### 2 150 绝对误差 tensor(2.6792, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.9625, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2133, dtype=torch.float64)   实验回归误差 tensor(0.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4132, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1394344160503618
# ######################################################################################################################################## 2 150 绝对误差 tensor(0.2331, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2342, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2742, dtype=torch.float64)   实验回归误差 tensor(0.0745, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1771802740638808
# ##################### 2 150 绝对误差 tensor(0.2103, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(2.3238, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9454, dtype=torch.float64)   实验回归误差 tensor(0.1683, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4138, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.1296312480784714
# ################# 2 150 绝对误差 tensor(0.7391, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3263, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1228, dtype=torch.float64)   实验回归误差 tensor(0.0806, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.087414340105126
# ########################################################################################## 3 150 绝对误差 tensor(0.8621, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5340, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1805, dtype=torch.float64)   实验回归误差 tensor(0.0684, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.18635922984562
# ######################################################################## 3 150 绝对误差 tensor(1.6192, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.4006, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2473, dtype=torch.float64)   实验回归误差 tensor(0.1006, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.181099324486559
# ############################################################### 3 150 绝对误差 tensor(2.8986, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.5815, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1628, dtype=torch.float64)   实验回归误差 tensor(0.1262, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2149553009830376
# ###################################################### 3 150 绝对误差 tensor(1.6880, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8294, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1305, dtype=torch.float64)   实验回归误差 tensor(0.1109, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1468373627336332
# ###################################################################################################### 3 150 绝对误差 tensor(1.1506, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7620, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1995, dtype=torch.float64)   实验回归误差 tensor(0.1197, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.229019782438895
# ############################################################################################# 3 150 绝对误差 tensor(1.2144, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.6570, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1455, dtype=torch.float64)   实验回归误差 tensor(0.1357, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.149889633479688
# ######################################################################################################################### 3 150 绝对误差 tensor(0.3716, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2756, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2312, dtype=torch.float64)   实验回归误差 tensor(0.0698, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.260132518528617
# ######################### 3 150 绝对误差 tensor(0.2599, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1804, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2093, dtype=torch.float64)   实验回归误差 tensor(0.0734, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3614, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0890304326389735
# ########################################################################## 3 150 绝对误差 tensor(1.2495, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1877, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.3270, dtype=torch.float64)   实验回归误差 tensor(0.1382, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.079930040656986
# #################################################### 3 150 绝对误差 tensor(0.2333, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4228, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4622, dtype=torch.float64)   实验回归误差 tensor(0.1617, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3855, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1673396349919267
# ################# 1 150 绝对误差 tensor(0.1034, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2108, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5226, dtype=torch.float64)   实验回归误差 tensor(0.0899, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.4411, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(3.4436, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.9186, dtype=torch.float64)   实验回归误差 tensor(0.1986, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############### 1 150 绝对误差 tensor(0.0244, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0164, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1955, dtype=torch.float64)   实验回归误差 tensor(0.0725, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3462, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0957, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2682, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6187, dtype=torch.float64)   实验回归误差 tensor(0.0999, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############# 1 150 绝对误差 tensor(0.1602, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.5173, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7390, dtype=torch.float64)   实验回归误差 tensor(0.1352, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ################## 1 150 绝对误差 tensor(0.0671, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0515, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2451, dtype=torch.float64)   实验回归误差 tensor(0.0541, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ########## 1 150 绝对误差 tensor(0.1148, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3873, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.6612, dtype=torch.float64)   实验回归误差 tensor(0.1181, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4044, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 144   条件数 1.0
# ############## 1 150 绝对误差 tensor(0.2953, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(7.7042, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(1.0030, dtype=torch.float64)   实验回归误差 tensor(0.1170, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 148   条件数 1.0
# ################# 1 150 绝对误差 tensor(0.1257, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4261, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.8414, dtype=torch.float64)   实验回归误差 tensor(0.1901, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4095, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############ 1 150 绝对误差 tensor(0.0556, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0993, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4639, dtype=torch.float64)   实验回归误差 tensor(0.1138, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0
# ############################# 2 150 绝对误差 tensor(0.5373, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.9440, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4638, dtype=torch.float64)   实验回归误差 tensor(0.1657, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0704132767496026
# ####################################################################################### 2 150 绝对误差 tensor(0.0081, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0057, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1971, dtype=torch.float64)   实验回归误差 tensor(0.0718, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3367, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1145706593826012
# ###################### 2 150 绝对误差 tensor(3.7891, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.3046, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1261, dtype=torch.float64)   实验回归误差 tensor(0.1127, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.057806985429871
# ############# 2 150 绝对误差 tensor(0.5941, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2855, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1313, dtype=torch.float64)   实验回归误差 tensor(0.0834, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3808, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0329757467046086
# ################################################################# 2 150 绝对误差 tensor(0.0932, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.1640, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.4819, dtype=torch.float64)   实验回归误差 tensor(0.0869, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.021358625261566
# ########################################### 2 150 绝对误差 tensor(0.6208, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.3769, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2072, dtype=torch.float64)   实验回归误差 tensor(0.0998, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3904, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1536059633547786
# ############# 2 150 绝对误差 tensor(0.0723, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0698, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2722, dtype=torch.float64)   实验回归误差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1084512267212814
# ######################## 2 150 绝对误差 tensor(0.1317, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4534, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.7450, dtype=torch.float64)   实验回归误差 tensor(0.1745, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1510022459945897
# ######################## 2 150 绝对误差 tensor(1.2450, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.7495, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1601, dtype=torch.float64)   实验回归误差 tensor(0.0807, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0303627876073032
# ######################### 2 150 绝对误差 tensor(0.8244, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.7049, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.5044, dtype=torch.float64)   实验回归误差 tensor(0.1527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1193823394840603
# ############################################ 3 150 绝对误差 tensor(1.2812, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.4579, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1129, dtype=torch.float64)   实验回归误差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.069333478508257
# ########################### 3 150 绝对误差 tensor(1.2220, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.2593, dtype=torch.float64)   实验回归误差 tensor(0.1644, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.170639095841677
# ####################################### 3 150 绝对误差 tensor(2.1332, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1200, dtype=torch.float64)   实验回归误差 tensor(0.1359, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.112759546529582
# ###################################################### 3 150 绝对误差 tensor(0.2606, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.2003, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1922, dtype=torch.float64)   实验回归误差 tensor(0.0854, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3711, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2754679159418818
# ######################################### 3 150 绝对误差 tensor(0.1343, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.0907, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1882, dtype=torch.float64)   实验回归误差 tensor(0.0638, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.0991681275209515
# ####################################################################################################### 3 150 绝对误差 tensor(1.7035, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(0.8424, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1446, dtype=torch.float64)   实验回归误差 tensor(0.1479, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2520570335830161
# ##################################################################################################### 3 150 绝对误差 tensor(2.6343, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0242, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1242, dtype=torch.float64)   实验回归误差 tensor(0.1045, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.1862310154641085
# #################################################################################### 3 150 绝对误差 tensor(2.3976, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.0948, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1236, dtype=torch.float64)   实验回归误差 tensor(0.1201, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.2096608580507977
# ################################################################################################################################################################# 3 150 绝对误差 tensor(2.7547, dtype=torch.float64, grad_fn=<NormBackward0>)   相对误差 tensor(1.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归误差 tensor(0.1260, dtype=torch.float64)   实验回归误差 tensor(0.1764, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4000, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 150   条件数 1.168367454441403
# ##
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-969596dde127> in <module>()
#      37                         for i in range(num_example):
#      38                             for j in range(num_example):
# ---> 39                                 C[i][j]=(Y1[i]-Y2[j])**2
#      40
#      41                         #S=SinkhornIPOT(C)
#
# KeyboardInterrupt:
