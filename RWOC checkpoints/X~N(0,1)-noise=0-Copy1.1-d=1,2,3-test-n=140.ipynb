# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(3):
    for num_example in range(140,141,100): 
        for num_X2feature in [3,2,1]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ############## 3 140 w绝对误差 tensor(1.4068, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5113, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0364, dtype=torch.float64)   实验回归残差 tensor(0.0986, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0313, dtype=torch.float64)   测试集实验回归残差 tensor(0.0978, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1803307045739704
# ##################################################################################################### 3 140 w绝对误差 tensor(0.9277, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4663, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0480, dtype=torch.float64)   实验回归残差 tensor(0.0925, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0521, dtype=torch.float64)   测试集实验回归残差 tensor(0.1649, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1710805420563457
# ################################ 3 140 w绝对误差 tensor(0.7556, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7763, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1018, dtype=torch.float64)   实验回归残差 tensor(0.1190, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1052, dtype=torch.float64)   测试集实验回归残差 tensor(0.1633, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2513741300506374
# ############################################### 3 140 w绝对误差 tensor(2.1449, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2608, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0602, dtype=torch.float64)   实验回归残差 tensor(0.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0582, dtype=torch.float64)   测试集实验回归残差 tensor(0.2468, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2385069693817836
# ####################### 3 140 w绝对误差 tensor(1.4367, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5066, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0359, dtype=torch.float64)   实验回归残差 tensor(0.0677, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0434, dtype=torch.float64)   测试集实验回归残差 tensor(0.1108, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1343432948474979
# ####################### 3 140 w绝对误差 tensor(2.9396, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1705, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0385, dtype=torch.float64)   实验回归残差 tensor(0.1813, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0455, dtype=torch.float64)   测试集实验回归残差 tensor(0.1948, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2563974023185567
# ###################################### 3 140 w绝对误差 tensor(3.1817, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.0177, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0672, dtype=torch.float64)   实验回归残差 tensor(0.0900, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0618, dtype=torch.float64)   测试集实验回归残差 tensor(0.2149, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3716539761094635
# ############### 3 140 w绝对误差 tensor(2.9167, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8657, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0273, dtype=torch.float64)   实验回归残差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0293, dtype=torch.float64)   测试集实验回归残差 tensor(0.1231, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1497497852034526
# ####################################### 3 140 w绝对误差 tensor(0.4128, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7568, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1712, dtype=torch.float64)   实验回归残差 tensor(0.1207, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1799, dtype=torch.float64)   测试集实验回归残差 tensor(0.1443, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3783, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.14001980700187
# #################### 3 140 w绝对误差 tensor(1.6356, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6809, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0905, dtype=torch.float64)   实验回归残差 tensor(0.1116, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1009, dtype=torch.float64)   测试集实验回归残差 tensor(0.1305, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1833413254181127
# ################## 2 140 w绝对误差 tensor(1.1389, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3627, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1263, dtype=torch.float64)   实验回归残差 tensor(0.1625, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1089, dtype=torch.float64)   测试集实验回归残差 tensor(0.2083, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4084, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0607959658279535
# ################################## 2 140 w绝对误差 tensor(0.9210, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4174, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0470, dtype=torch.float64)   实验回归残差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0410, dtype=torch.float64)   测试集实验回归残差 tensor(0.0990, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0820348610378556
# ################################## 2 140 w绝对误差 tensor(3.1333, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2902, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0393, dtype=torch.float64)   实验回归残差 tensor(0.1867, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0418, dtype=torch.float64)   测试集实验回归残差 tensor(0.1529, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1018203500708736
# ############################### 2 140 w绝对误差 tensor(0.3104, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7427, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2080, dtype=torch.float64)   实验回归残差 tensor(0.0957, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2286, dtype=torch.float64)   测试集实验回归残差 tensor(0.1234, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1066943347510687
# ############################################################################# 2 140 w绝对误差 tensor(1.3883, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7241, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0488, dtype=torch.float64)   实验回归残差 tensor(0.1058, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0566, dtype=torch.float64)   测试集实验回归残差 tensor(0.1016, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3886, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1503936566108437
# ############################ 2 140 w绝对误差 tensor(0.6996, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4136, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0570, dtype=torch.float64)   实验回归残差 tensor(0.0888, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0641, dtype=torch.float64)   测试集实验回归残差 tensor(0.1582, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3680, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0970992428024833
# ################################ 2 140 w绝对误差 tensor(0.3867, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2425, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0634, dtype=torch.float64)   实验回归残差 tensor(0.0612, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0569, dtype=torch.float64)   测试集实验回归残差 tensor(0.0932, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3680, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3628, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1028192801436876
# ################################### 2 140 w绝对误差 tensor(2.1205, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5987, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0245, dtype=torch.float64)   实验回归残差 tensor(0.0850, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.1663, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1108270853900137
# ######################## 2 140 w绝对误差 tensor(0.2614, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1022, dtype=torch.float64)   实验回归残差 tensor(0.0686, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1037, dtype=torch.float64)   测试集实验回归残差 tensor(0.1209, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3628, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3628, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.242760723921282
# ##################### 2 140 w绝对误差 tensor(1.3149, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3063, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0910, dtype=torch.float64)   实验回归残差 tensor(0.0911, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1205, dtype=torch.float64)   测试集实验回归残差 tensor(0.2898, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1606139390037664
# ###################### 1 140 w绝对误差 tensor(0.0156, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0455, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2887, dtype=torch.float64)   实验回归残差 tensor(0.0826, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2818, dtype=torch.float64)   测试集实验回归残差 tensor(0.0885, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3884, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################ 1 140 w绝对误差 tensor(0.0262, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0336, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1289, dtype=torch.float64)   实验回归残差 tensor(0.0556, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1502, dtype=torch.float64)   测试集实验回归残差 tensor(0.0686, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3363, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3363, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ########################################################################################################################################################################################################超过迭代上限
#  1 140 w绝对误差 tensor(0.0939, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0680, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0658, dtype=torch.float64)   实验回归残差 tensor(0.0727, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0683, dtype=torch.float64)   测试集实验回归残差 tensor(0.0702, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2873, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2189, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################# 1 140 w绝对误差 tensor(0.0014, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0009, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0679, dtype=torch.float64)   实验回归残差 tensor(0.0372, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0644, dtype=torch.float64)   测试集实验回归残差 tensor(0.0346, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2364, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2536, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ##################################### 1 140 w绝对误差 tensor(0.0219, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.1520, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.5654, dtype=torch.float64)   实验回归残差 tensor(0.1099, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.5041, dtype=torch.float64)   测试集实验回归残差 tensor(0.1530, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4084, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3908, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 136   条件数 1.0
# ################################## 1 140 w绝对误差 tensor(0.0175, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0700, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3726, dtype=torch.float64)   实验回归残差 tensor(0.0675, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4076, dtype=torch.float64)   测试集实验回归残差 tensor(0.0943, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3969, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3763, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 136   条件数 1.0
# #################################################################################### 1 140 w绝对误差 tensor(0.0183, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0083, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0400, dtype=torch.float64)   实验回归残差 tensor(0.0261, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0473, dtype=torch.float64)   测试集实验回归残差 tensor(0.0297, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1339, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ##########################################################################################################################################################################################超过迭代上限
#  1 140 w绝对误差 tensor(0.5448, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0036, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1643, dtype=torch.float64)   实验回归残差 tensor(0.9965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2034, dtype=torch.float64)   测试集实验回归残差 tensor(0.9966, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3789, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 95   条件数 1.0
# ####################### 1 140 w绝对误差 tensor(0.0001, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0004, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3120, dtype=torch.float64)   实验回归残差 tensor(0.0904, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2664, dtype=torch.float64)   测试集实验回归残差 tensor(0.0877, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3826, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# #################### 1 140 w绝对误差 tensor(0.0315, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0870, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2606, dtype=torch.float64)   实验回归残差 tensor(0.0852, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2433, dtype=torch.float64)   测试集实验回归残差 tensor(0.0922, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3497, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3680, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# #################################### 3 140 w绝对误差 tensor(0.0721, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2831, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3334, dtype=torch.float64)   实验回归残差 tensor(0.1106, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3526, dtype=torch.float64)   测试集实验回归残差 tensor(0.0900, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3759, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4091, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1507788325401134
# ############################### 3 140 w绝对误差 tensor(1.8863, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1573, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0554, dtype=torch.float64)   实验回归残差 tensor(0.2344, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0542, dtype=torch.float64)   测试集实验回归残差 tensor(0.2533, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1573798864200469
# ################################################################################################# 3 140 w绝对误差 tensor(0.0207, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0115, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0522, dtype=torch.float64)   实验回归残差 tensor(0.0295, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0579, dtype=torch.float64)   测试集实验回归残差 tensor(0.0331, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2479, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1091979747854464
# ################# 3 140 w绝对误差 tensor(0.9881, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6891, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0694, dtype=torch.float64)   实验回归残差 tensor(0.0973, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0774, dtype=torch.float64)   测试集实验回归残差 tensor(0.1302, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1987093875452481
# ########################## 3 140 w绝对误差 tensor(2.4127, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1355, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0483, dtype=torch.float64)   实验回归残差 tensor(0.0848, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0442, dtype=torch.float64)   测试集实验回归残差 tensor(0.1378, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3974, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2020347002776766
# ##################### 3 140 w绝对误差 tensor(4.1822, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5694, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0327, dtype=torch.float64)   实验回归残差 tensor(0.1592, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0377, dtype=torch.float64)   测试集实验回归残差 tensor(0.3277, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2069270851936618
# ############################# 3 140 w绝对误差 tensor(1.7436, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4143, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0766, dtype=torch.float64)   实验回归残差 tensor(0.1761, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0772, dtype=torch.float64)   测试集实验回归残差 tensor(0.2388, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2873835092940267
# ################ 3 140 w绝对误差 tensor(1.4982, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0608, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0778, dtype=torch.float64)   实验回归残差 tensor(0.1258, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0652, dtype=torch.float64)   测试集实验回归残差 tensor(0.1949, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2039537190703888
# ########################################## 3 140 w绝对误差 tensor(0.5445, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1270, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2137, dtype=torch.float64)   实验回归残差 tensor(0.1064, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2115, dtype=torch.float64)   测试集实验回归残差 tensor(0.1424, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4039, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1326739095019311
# #################################################### 3 140 w绝对误差 tensor(2.4806, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1053, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0508, dtype=torch.float64)   实验回归残差 tensor(0.1925, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0417, dtype=torch.float64)   测试集实验回归残差 tensor(0.2149, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2026531956257476
# ############################### 2 140 w绝对误差 tensor(0.5661, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8254, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1546, dtype=torch.float64)   实验回归残差 tensor(0.1763, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1644, dtype=torch.float64)   测试集实验回归残差 tensor(0.1945, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2242231341744128
# #################### 2 140 w绝对误差 tensor(2.0510, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3365, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0583, dtype=torch.float64)   实验回归残差 tensor(0.0992, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0631, dtype=torch.float64)   测试集实验回归残差 tensor(0.2600, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1699586877675583
# ################################################## 2 140 w绝对误差 tensor(0.0058, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0038, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0659, dtype=torch.float64)   实验回归残差 tensor(0.0324, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0662, dtype=torch.float64)   测试集实验回归残差 tensor(0.0366, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2306, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2306, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1316789194715517
# ###################### 2 140 w绝对误差 tensor(3.3245, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6513, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0476, dtype=torch.float64)   实验回归残差 tensor(0.1656, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0542, dtype=torch.float64)   测试集实验回归残差 tensor(0.2523, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0794529231143186
# ##################################################################### 2 140 w绝对误差 tensor(1.3684, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3217, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0953, dtype=torch.float64)   实验回归残差 tensor(0.0876, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0975, dtype=torch.float64)   测试集实验回归残差 tensor(0.1539, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0381947295165541
# ################### 2 140 w绝对误差 tensor(1.0530, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7881, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0665, dtype=torch.float64)   实验回归残差 tensor(0.1201, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0935, dtype=torch.float64)   测试集实验回归残差 tensor(0.1796, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0837924767690357
# ############# 2 140 w绝对误差 tensor(1.4339, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3430, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0965, dtype=torch.float64)   实验回归残差 tensor(0.1484, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0964, dtype=torch.float64)   测试集实验回归残差 tensor(0.2661, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1054369035585143
# ################# 2 140 w绝对误差 tensor(0.5696, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4056, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0648, dtype=torch.float64)   实验回归残差 tensor(0.1062, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0680, dtype=torch.float64)   测试集实验回归残差 tensor(0.1353, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3887, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.062772637761664
# ############################### 2 140 w绝对误差 tensor(0.0184, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0547, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2784, dtype=torch.float64)   实验回归残差 tensor(0.0894, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3002, dtype=torch.float64)   测试集实验回归残差 tensor(0.0926, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1137725398056126
# ########################## 2 140 w绝对误差 tensor(2.1585, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5981, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0833, dtype=torch.float64)   实验回归残差 tensor(0.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0780, dtype=torch.float64)   测试集实验回归残差 tensor(0.2551, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0314219721579474
# ############################################## 1 140 w绝对误差 tensor(0.0126, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0311, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2228, dtype=torch.float64)   实验回归残差 tensor(0.0748, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2288, dtype=torch.float64)   测试集实验回归残差 tensor(0.0593, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3756, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 136   条件数 1.0
# #################### 1 140 w绝对误差 tensor(0.0085, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0164, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1903, dtype=torch.float64)   实验回归残差 tensor(0.0878, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2139, dtype=torch.float64)   测试集实验回归残差 tensor(0.0769, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3470, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3680, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ############################################# 1 140 w绝对误差 tensor(0.0446, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5245, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.7435, dtype=torch.float64)   实验回归残差 tensor(0.1435, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7808, dtype=torch.float64)   测试集实验回归残差 tensor(0.1471, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4027, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 128   条件数 1.0
# ########################################################################################################################################################################################################超过迭代上限
#  1 140 w绝对误差 tensor(0.1745, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0478, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4907, dtype=torch.float64)   实验回归残差 tensor(1.0413, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.5571, dtype=torch.float64)   测试集实验回归残差 tensor(0.9616, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3979, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3701, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 99   条件数 1.0
# ############################################## 1 140 w绝对误差 tensor(0.0085, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0218, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2371, dtype=torch.float64)   实验回归残差 tensor(0.0615, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2517, dtype=torch.float64)   测试集实验回归残差 tensor(0.0876, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################ 1 140 w绝对误差 tensor(0.4063, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.1741, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4764, dtype=torch.float64)   实验回归残差 tensor(0.1271, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4607, dtype=torch.float64)   测试集实验回归残差 tensor(0.1172, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4138, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4124, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ############### 1 140 w绝对误差 tensor(0.0100, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0166, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1753, dtype=torch.float64)   实验回归残差 tensor(0.0716, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1675, dtype=torch.float64)   测试集实验回归残差 tensor(0.0678, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3574, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3414, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################################################################### 1 140 w绝对误差 tensor(0.0053, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0043, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0717, dtype=torch.float64)   实验回归残差 tensor(0.0367, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0737, dtype=torch.float64)   测试集实验回归残差 tensor(0.0419, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2421, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ###################################### 1 140 w绝对误差 tensor(0.4108, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.1501, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4722, dtype=torch.float64)   实验回归残差 tensor(0.1775, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4679, dtype=torch.float64)   测试集实验回归残差 tensor(0.2054, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4091, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ######################## 1 140 w绝对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0010, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1592, dtype=torch.float64)   实验回归残差 tensor(0.0635, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1342, dtype=torch.float64)   测试集实验回归残差 tensor(0.0520, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3310, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3470, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# #################### 3 140 w绝对误差 tensor(0.2528, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2134, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0883, dtype=torch.float64)   实验回归残差 tensor(0.0738, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0905, dtype=torch.float64)   测试集实验回归残差 tensor(0.0875, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3938, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3732, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2241315185367683
# ############################################################ 3 140 w绝对误差 tensor(0.0260, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0136, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0470, dtype=torch.float64)   实验回归残差 tensor(0.0289, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0593, dtype=torch.float64)   测试集实验回归残差 tensor(0.0338, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2634239688979125
# ############################################################################### 3 140 w绝对误差 tensor(1.7498, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7893, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0469, dtype=torch.float64)   实验回归残差 tensor(0.1170, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0471, dtype=torch.float64)   测试集实验回归残差 tensor(0.1675, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2319538675914923
# ##################### 3 140 w绝对误差 tensor(2.7837, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3405, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0427, dtype=torch.float64)   实验回归残差 tensor(0.2006, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0488, dtype=torch.float64)   测试集实验回归残差 tensor(0.1588, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.189606756390701
# #################################################################### 3 140 w绝对误差 tensor(1.5940, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6410, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1012, dtype=torch.float64)   实验回归残差 tensor(0.1009, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1141, dtype=torch.float64)   测试集实验回归残差 tensor(0.2620, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1543174566383878
# ######################### 3 140 w绝对误差 tensor(1.0828, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6449, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0635, dtype=torch.float64)   实验回归残差 tensor(0.1099, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0627, dtype=torch.float64)   测试集实验回归残差 tensor(0.1527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3836, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2625022227631368
# ############################################################### 3 140 w绝对误差 tensor(1.9407, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3083, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0658, dtype=torch.float64)   实验回归残差 tensor(0.0957, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0781, dtype=torch.float64)   测试集实验回归残差 tensor(0.4801, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.3355711562796277
# ################################################ 3 140 w绝对误差 tensor(2.1296, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4316, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0656, dtype=torch.float64)   实验回归残差 tensor(0.1083, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0658, dtype=torch.float64)   测试集实验回归残差 tensor(0.1315, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1311201843121979
# #################### 3 140 w绝对误差 tensor(2.4746, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6072, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0681, dtype=torch.float64)   实验回归残差 tensor(0.1780, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0730, dtype=torch.float64)   测试集实验回归残差 tensor(0.1627, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2071237563086323
# ########################################### 3 140 w绝对误差 tensor(0.7540, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9893, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1275, dtype=torch.float64)   实验回归残差 tensor(0.1119, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1280, dtype=torch.float64)   测试集实验回归残差 tensor(0.1611, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3990, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1155914402552014
# ################### 2 140 w绝对误差 tensor(1.7620, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2674, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0754, dtype=torch.float64)   实验回归残差 tensor(0.1759, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0751, dtype=torch.float64)   测试集实验回归残差 tensor(0.1522, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0917905213657249
# ############################ 2 140 w绝对误差 tensor(0.0822, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(6.6151, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.9790, dtype=torch.float64)   实验回归残差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.9771, dtype=torch.float64)   测试集实验回归残差 tensor(0.1428, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3890, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 127   测试集置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 127   条件数 1.0765713077936425
# ################# 2 140 w绝对误差 tensor(0.4440, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3287, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2751, dtype=torch.float64)   实验回归残差 tensor(0.1136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2888, dtype=torch.float64)   测试集实验回归残差 tensor(0.2392, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4091, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4091, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.2543711811337603
# ############################# 2 140 w绝对误差 tensor(0.0269, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0216, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0772, dtype=torch.float64)   实验回归残差 tensor(0.0390, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0818, dtype=torch.float64)   测试集实验回归残差 tensor(0.0436, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2928, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2593, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.1461675500635804
# ###################### 2 140 w绝对误差 tensor(1.3603, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7044, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1069, dtype=torch.float64)   实验回归残差 tensor(0.1039, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1332, dtype=torch.float64)   测试集实验回归残差 tensor(0.2987, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2457918542159496
# ############################### 2 140 w绝对误差 tensor(0.9245, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7612, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0857, dtype=torch.float64)   实验回归残差 tensor(0.1275, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0780, dtype=torch.float64)   测试集实验回归残差 tensor(0.1340, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0899545838088651
# ############################# 2 140 w绝对误差 tensor(1.6087, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8939, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0613, dtype=torch.float64)   实验回归残差 tensor(0.0801, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0552, dtype=torch.float64)   测试集实验回归残差 tensor(0.2043, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.068920824358341
# #################### 2 140 w绝对误差 tensor(0.0567, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2410, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.4096, dtype=torch.float64)   实验回归残差 tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3745, dtype=torch.float64)   测试集实验回归残差 tensor(0.1520, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3772, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3666, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.1472063315497136
# ############################################################## 2 140 w绝对误差 tensor(3.2966, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4661, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0410, dtype=torch.float64)   实验回归残差 tensor(0.0883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0442, dtype=torch.float64)   测试集实验回归残差 tensor(0.1432, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3939, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0740792832284725
# ################# 2 140 w绝对误差 tensor(0.0291, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0303, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1096, dtype=torch.float64)   实验回归残差 tensor(0.0461, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0912, dtype=torch.float64)   测试集实验回归残差 tensor(0.0466, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3202, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3256, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.2056396885763967
# #################################################### 1 140 w绝对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0005, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0785, dtype=torch.float64)   实验回归残差 tensor(0.0388, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0932, dtype=torch.float64)   测试集实验回归残差 tensor(0.0462, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2705, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3148, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# #################### 1 140 w绝对误差 tensor(1.0536, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9961, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1854, dtype=torch.float64)   实验回归残差 tensor(0.1215, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1633, dtype=torch.float64)   测试集实验回归残差 tensor(0.2561, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.4041, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ################################################################################################## 1 140 w绝对误差 tensor(0.1986, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(2.4895, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.7123, dtype=torch.float64)   实验回归残差 tensor(0.1125, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.7262, dtype=torch.float64)   测试集实验回归残差 tensor(0.1724, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4016, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.4058, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 136   条件数 1.0
# #################################################### 1 140 w绝对误差 tensor(0.0002, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0006, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2604, dtype=torch.float64)   实验回归残差 tensor(0.0731, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2289, dtype=torch.float64)   测试集实验回归残差 tensor(0.0822, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3827, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.3394, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ######################## 1 140 w绝对误差 tensor(0.0193, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0484, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.2408, dtype=torch.float64)   实验回归残差 tensor(0.0730, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.2440, dtype=torch.float64)   测试集实验回归残差 tensor(0.0823, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3784, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.3622, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ####################### 1 140 w绝对误差 tensor(0.0107, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0606, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.6040, dtype=torch.float64)   实验回归残差 tensor(0.1218, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.4958, dtype=torch.float64)   测试集实验回归残差 tensor(0.1285, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3903, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3908, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 138   条件数 1.0
# ################## 1 140 w绝对误差 tensor(0.0150, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0092, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0591, dtype=torch.float64)   实验回归残差 tensor(0.0345, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0574, dtype=torch.float64)   测试集实验回归残差 tensor(0.0326, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2130, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2536, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
# ########################################################################################################################################################################################################超过迭代上限
#  1 140 w绝对误差 tensor(1.6380, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9994, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0486, dtype=torch.float64)   实验回归残差 tensor(0.9994, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0661, dtype=torch.float64)   测试集实验回归残差 tensor(0.9994, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.1952, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 140   测试集置换矩阵误差 tensor(1.2552, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 106   条件数 1.0
# ########################################################################################################################################################################################################超过迭代上限
#  1 140 w绝对误差 tensor(0.2751, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0179, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.3047, dtype=torch.float64)   实验回归残差 tensor(1.0167, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.3645, dtype=torch.float64)   测试集实验回归残差 tensor(0.9835, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3856, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 136   测试集置换矩阵误差 tensor(1.3959, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 117   条件数 1.0
# ########################### 1 140 w绝对误差 tensor(1.0366, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9943, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1873, dtype=torch.float64)   实验回归残差 tensor(0.1206, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1807, dtype=torch.float64)   测试集实验回归残差 tensor(0.1843, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4134, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 138   测试集置换矩阵误差 tensor(1.4092, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 140   条件数 1.0
