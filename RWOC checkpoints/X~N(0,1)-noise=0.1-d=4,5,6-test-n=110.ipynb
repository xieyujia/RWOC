# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(5):
    for num_example in range(110,111,100): 
        for num_X2feature in [4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.006
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ###################### 4 110 w绝对误差 tensor(2.0434, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1061, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0622, dtype=torch.float64)   实验回归残差 tensor(0.0929, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0501, dtype=torch.float64)   测试集实验回归残差 tensor(0.2763, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3515749708474463
# ############################################################ 4 110 w绝对误差 tensor(0.8012, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5447, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0700, dtype=torch.float64)   实验回归残差 tensor(0.1017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0608, dtype=torch.float64)   测试集实验回归残差 tensor(0.0991, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.433024687942329
# ################################# 4 110 w绝对误差 tensor(1.3582, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8217, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0647, dtype=torch.float64)   实验回归残差 tensor(0.0942, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0659, dtype=torch.float64)   测试集实验回归残差 tensor(0.1131, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2097264206558298
# ############################ 4 110 w绝对误差 tensor(2.2658, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4660, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0583, dtype=torch.float64)   实验回归残差 tensor(0.1760, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0635, dtype=torch.float64)   测试集实验回归残差 tensor(0.2811, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4296537562445777
# ####################################### 4 110 w绝对误差 tensor(0.7333, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8215, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1112, dtype=torch.float64)   实验回归残差 tensor(0.1434, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1046, dtype=torch.float64)   测试集实验回归残差 tensor(0.2193, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2737768256735145
# ################################################## 4 110 w绝对误差 tensor(3.1467, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9916, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0299, dtype=torch.float64)   实验回归残差 tensor(0.1192, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0307, dtype=torch.float64)   测试集实验回归残差 tensor(0.2008, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3397405295094063
# ######################## 4 110 w绝对误差 tensor(2.4208, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4523, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0531, dtype=torch.float64)   实验回归残差 tensor(0.1225, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0641, dtype=torch.float64)   测试集实验回归残差 tensor(0.1939, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2888050528970232
# ####################### 4 110 w绝对误差 tensor(1.8534, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6672, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0386, dtype=torch.float64)   实验回归残差 tensor(0.1247, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0344, dtype=torch.float64)   测试集实验回归残差 tensor(0.1642, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.302713654519803
# ##################################### 4 110 w绝对误差 tensor(4.0276, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6119, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0406, dtype=torch.float64)   实验回归残差 tensor(0.2142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0412, dtype=torch.float64)   测试集实验回归残差 tensor(0.2742, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.299351759245176
# ################################# 4 110 w绝对误差 tensor(1.5445, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0012, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0593, dtype=torch.float64)   实验回归残差 tensor(0.1268, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0652, dtype=torch.float64)   测试集实验回归残差 tensor(0.1754, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3465189287506565
# ################ 5 110 w绝对误差 tensor(0.6241, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0558, dtype=torch.float64)   实验回归残差 tensor(0.0587, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0569, dtype=torch.float64)   测试集实验回归残差 tensor(0.1465, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3310125981645085
# ############################## 5 110 w绝对误差 tensor(2.0172, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0670, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0456, dtype=torch.float64)   实验回归残差 tensor(0.1107, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0610, dtype=torch.float64)   测试集实验回归残差 tensor(0.3083, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3166851434286648
# ################################################################### 5 110 w绝对误差 tensor(3.5842, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6432, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0525, dtype=torch.float64)   实验回归残差 tensor(0.1109, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0429, dtype=torch.float64)   测试集实验回归残差 tensor(0.2407, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3587955503931914
# ################### 5 110 w绝对误差 tensor(1.4910, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7586, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0558, dtype=torch.float64)   实验回归残差 tensor(0.1342, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0439, dtype=torch.float64)   测试集实验回归残差 tensor(0.1995, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3912173226261073
# ##################### 5 110 w绝对误差 tensor(2.3116, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8627, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0337, dtype=torch.float64)   实验回归残差 tensor(0.1431, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0338, dtype=torch.float64)   测试集实验回归残差 tensor(0.1437, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.6186619054725808
# ################################## 5 110 w绝对误差 tensor(1.0423, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6542, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0665, dtype=torch.float64)   实验回归残差 tensor(0.0762, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0558, dtype=torch.float64)   测试集实验回归残差 tensor(0.2151, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.362588625515834
# ########################################################################### 5 110 w绝对误差 tensor(5.5504, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8088, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0340, dtype=torch.float64)   实验回归残差 tensor(0.1404, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0355, dtype=torch.float64)   测试集实验回归残差 tensor(0.2062, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3270380665384378
# ########################### 5 110 w绝对误差 tensor(1.7050, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2098, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0792, dtype=torch.float64)   实验回归残差 tensor(0.2126, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0655, dtype=torch.float64)   测试集实验回归残差 tensor(0.1532, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4794146765787302
# ############################ 5 110 w绝对误差 tensor(2.6590, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2399, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0505, dtype=torch.float64)   实验回归残差 tensor(0.1602, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0400, dtype=torch.float64)   测试集实验回归残差 tensor(0.2151, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3465572293361645
# ##################################################### 6 110 w绝对误差 tensor(2.9697, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9773, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0287, dtype=torch.float64)   实验回归残差 tensor(0.1068, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.1310, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4476297393816795
# ################################################################## 6 110 w绝对误差 tensor(3.1712, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5631, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0413, dtype=torch.float64)   实验回归残差 tensor(0.1011, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0473, dtype=torch.float64)   测试集实验回归残差 tensor(0.1735, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4528164170259965
# ############################# 6 110 w绝对误差 tensor(3.0276, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2901, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0396, dtype=torch.float64)   实验回归残差 tensor(0.1604, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0450, dtype=torch.float64)   测试集实验回归残差 tensor(0.2272, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3237817278904584
# ################### 6 110 w绝对误差 tensor(3.5150, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3949, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0368, dtype=torch.float64)   实验回归残差 tensor(0.2050, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0348, dtype=torch.float64)   测试集实验回归残差 tensor(0.1670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.7364550398177239
# ############################### 6 110 w绝对误差 tensor(2.6273, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8930, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0377, dtype=torch.float64)   实验回归残差 tensor(0.1393, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0326, dtype=torch.float64)   测试集实验回归残差 tensor(0.2124, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5526994581084685
# ##################################### 6 110 w绝对误差 tensor(2.8183, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3485, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0477, dtype=torch.float64)   实验回归残差 tensor(0.0936, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0489, dtype=torch.float64)   测试集实验回归残差 tensor(0.3853, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.615707702202084
# ############################################################ 6 110 w绝对误差 tensor(2.9628, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1224, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0380, dtype=torch.float64)   实验回归残差 tensor(0.1265, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0457, dtype=torch.float64)   测试集实验回归残差 tensor(0.1336, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5714950279045343
# ####################### 6 110 w绝对误差 tensor(2.2042, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6626, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0293, dtype=torch.float64)   实验回归残差 tensor(0.1115, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0328, dtype=torch.float64)   测试集实验回归残差 tensor(0.1405, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3493401437498913
# ################################### 6 110 w绝对误差 tensor(1.9497, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0329, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0453, dtype=torch.float64)   实验回归残差 tensor(0.1966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0528, dtype=torch.float64)   测试集实验回归残差 tensor(0.1457, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2766443318376626
# ############################################ 6 110 w绝对误差 tensor(1.1360, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5254, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0435, dtype=torch.float64)   实验回归残差 tensor(0.0707, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0416, dtype=torch.float64)   测试集实验回归残差 tensor(0.1298, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3685, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4125746250356275
# ########################### 4 110 w绝对误差 tensor(0.8530, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6091, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0646, dtype=torch.float64)   实验回归残差 tensor(0.0962, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0692, dtype=torch.float64)   测试集实验回归残差 tensor(0.2506, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4179294279388932
# ############################################## 4 110 w绝对误差 tensor(0.2688, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2390, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0847, dtype=torch.float64)   实验回归残差 tensor(0.0613, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0796, dtype=torch.float64)   测试集实验回归残差 tensor(0.1250, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3280, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2714339478312695
# ####################### 4 110 w绝对误差 tensor(2.9483, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4415, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0509, dtype=torch.float64)   实验回归残差 tensor(0.1937, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0503, dtype=torch.float64)   测试集实验回归残差 tensor(0.2258, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3207499636507671
# ########################### 4 110 w绝对误差 tensor(2.4853, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0104, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0445, dtype=torch.float64)   实验回归残差 tensor(0.1480, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0387, dtype=torch.float64)   测试集实验回归残差 tensor(0.2384, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2868681504655184
# ############### 4 110 w绝对误差 tensor(1.7875, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7477, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0354, dtype=torch.float64)   实验回归残差 tensor(0.1012, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0369, dtype=torch.float64)   测试集实验回归残差 tensor(0.1471, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3551, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2295432129790191
# ####################### 4 110 w绝对误差 tensor(1.1840, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9150, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0658, dtype=torch.float64)   实验回归残差 tensor(0.1427, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0742, dtype=torch.float64)   测试集实验回归残差 tensor(0.1976, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3137769416790386
# ###################### 4 110 w绝对误差 tensor(1.7972, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1116, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0673, dtype=torch.float64)   实验回归残差 tensor(0.1571, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0668, dtype=torch.float64)   测试集实验回归残差 tensor(0.2075, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1330024038902646
# ################################################## 4 110 w绝对误差 tensor(0.5312, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3513, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0566, dtype=torch.float64)   实验回归残差 tensor(0.0829, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0528, dtype=torch.float64)   测试集实验回归残差 tensor(0.1087, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3416, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3484, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2777152523191195
# ####################### 4 110 w绝对误差 tensor(0.7761, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4297, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0588, dtype=torch.float64)   实验回归残差 tensor(0.0750, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0530, dtype=torch.float64)   测试集实验回归残差 tensor(0.1092, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2291554781435825
# ######################################################################## 4 110 w绝对误差 tensor(1.4406, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5543, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1123, dtype=torch.float64)   实验回归残差 tensor(0.0968, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1208, dtype=torch.float64)   测试集实验回归残差 tensor(0.2363, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3179246593449103
# ##################################### 5 110 w绝对误差 tensor(2.5991, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2852, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0585, dtype=torch.float64)   实验回归残差 tensor(0.1448, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0460, dtype=torch.float64)   测试集实验回归残差 tensor(0.3479, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3250985004457714
# ############################## 5 110 w绝对误差 tensor(1.3728, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1471, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0756, dtype=torch.float64)   实验回归残差 tensor(0.1323, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0791, dtype=torch.float64)   测试集实验回归残差 tensor(0.1750, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3873716600163235
# #################################### 5 110 w绝对误差 tensor(2.3962, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1263, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0481, dtype=torch.float64)   实验回归残差 tensor(0.1879, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0467, dtype=torch.float64)   测试集实验回归残差 tensor(0.1966, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3958798338906626
# ############################# 5 110 w绝对误差 tensor(0.8902, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3425, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0377, dtype=torch.float64)   实验回归残差 tensor(0.0643, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0417, dtype=torch.float64)   测试集实验回归残差 tensor(0.0842, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3484, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.35274403549038
# #################################################################### 5 110 w绝对误差 tensor(3.3887, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4851, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0460, dtype=torch.float64)   实验回归残差 tensor(0.0965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0474, dtype=torch.float64)   测试集实验回归残差 tensor(0.3375, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3346833955296358
# ################################################# 5 110 w绝对误差 tensor(1.7030, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8729, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0546, dtype=torch.float64)   实验回归残差 tensor(0.1238, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0482, dtype=torch.float64)   测试集实验回归残差 tensor(0.1541, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3224855330886922
# ################################### 5 110 w绝对误差 tensor(1.8387, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0147, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0500, dtype=torch.float64)   实验回归残差 tensor(0.1229, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0639, dtype=torch.float64)   测试集实验回归残差 tensor(0.1578, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3530518282424777
# ######################### 5 110 w绝对误差 tensor(2.1753, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9230, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0417, dtype=torch.float64)   实验回归残差 tensor(0.1389, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0405, dtype=torch.float64)   测试集实验回归残差 tensor(0.1075, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4077, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4070771117606893
# ############################ 5 110 w绝对误差 tensor(1.7736, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3531, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0898, dtype=torch.float64)   实验回归残差 tensor(0.1169, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0627, dtype=torch.float64)   测试集实验回归残差 tensor(0.2774, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4136, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.3236120699085492
# ################################################################### 5 110 w绝对误差 tensor(1.5056, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9923, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0648, dtype=torch.float64)   实验回归残差 tensor(0.1466, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0646, dtype=torch.float64)   测试集实验回归残差 tensor(0.2532, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3803811291882027
# ######################################################### 6 110 w绝对误差 tensor(3.1408, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5674, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0468, dtype=torch.float64)   实验回归残差 tensor(0.1137, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0462, dtype=torch.float64)   测试集实验回归残差 tensor(0.2597, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3188698515274415
# ######################################################################## 6 110 w绝对误差 tensor(5.2054, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5082, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0288, dtype=torch.float64)   实验回归残差 tensor(0.0987, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0257, dtype=torch.float64)   测试集实验回归残差 tensor(0.3471, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.475637671893669
# ############################################################ 6 110 w绝对误差 tensor(4.4940, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1003, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0247, dtype=torch.float64)   实验回归残差 tensor(0.0679, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0258, dtype=torch.float64)   测试集实验回归残差 tensor(0.3015, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5043621074257556
# ################# 6 110 w绝对误差 tensor(2.6275, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1502, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0432, dtype=torch.float64)   实验回归残差 tensor(0.1498, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0492, dtype=torch.float64)   测试集实验回归残差 tensor(0.1876, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4144726593319208
# ###################################################### 6 110 w绝对误差 tensor(2.6163, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0507, dtype=torch.float64)   实验回归残差 tensor(0.1384, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0442, dtype=torch.float64)   测试集实验回归残差 tensor(0.1687, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3311636576266206
# ########################################################################################################################################################################################################超过迭代上限
#  6 110 w绝对误差 tensor(2.5520, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1611, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0432, dtype=torch.float64)   实验回归残差 tensor(0.0999, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0443, dtype=torch.float64)   测试集实验回归残差 tensor(0.3236, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5238329397062496
# ########################################################################################################################################################################################################超过迭代上限
#  6 110 w绝对误差 tensor(2.1542, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8975, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0430, dtype=torch.float64)   实验回归残差 tensor(0.1430, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0398, dtype=torch.float64)   测试集实验回归残差 tensor(0.3160, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.621719354140888
# ################################### 6 110 w绝对误差 tensor(1.5112, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6451, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0497, dtype=torch.float64)   实验回归残差 tensor(0.0793, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0449, dtype=torch.float64)   测试集实验回归残差 tensor(0.1693, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2981956481675883
# ################################# 6 110 w绝对误差 tensor(4.0501, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0192, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0257, dtype=torch.float64)   实验回归残差 tensor(0.0939, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0250, dtype=torch.float64)   测试集实验回归残差 tensor(0.1915, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5670473241314264
# ####################################### 6 110 w绝对误差 tensor(1.8074, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1194, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0493, dtype=torch.float64)   实验回归残差 tensor(0.0894, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0510, dtype=torch.float64)   测试集实验回归残差 tensor(0.1764, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5545996296133662
# ##################################################### 4 110 w绝对误差 tensor(3.1248, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0951, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0335, dtype=torch.float64)   实验回归残差 tensor(0.0860, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0378, dtype=torch.float64)   测试集实验回归残差 tensor(0.2165, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.371101568762471
# ################# 4 110 w绝对误差 tensor(2.5918, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2035, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0421, dtype=torch.float64)   实验回归残差 tensor(0.2270, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0489, dtype=torch.float64)   测试集实验回归残差 tensor(0.1974, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2336854940798438
# ########################################################### 4 110 w绝对误差 tensor(3.2857, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6196, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0525, dtype=torch.float64)   实验回归残差 tensor(0.0945, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0504, dtype=torch.float64)   测试集实验回归残差 tensor(0.1881, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3896839596726704
# ################################ 4 110 w绝对误差 tensor(2.1778, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9991, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0432, dtype=torch.float64)   实验回归残差 tensor(0.0934, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0512, dtype=torch.float64)   测试集实验回归残差 tensor(0.1642, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2292351696538226
# ############################# 4 110 w绝对误差 tensor(1.3639, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7363, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0458, dtype=torch.float64)   实验回归残差 tensor(0.0755, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0570, dtype=torch.float64)   测试集实验回归残差 tensor(0.2342, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3689198807940417
# ######################################## 4 110 w绝对误差 tensor(2.2074, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7669, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0359, dtype=torch.float64)   实验回归残差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0314, dtype=torch.float64)   测试集实验回归残差 tensor(0.1959, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.289549414481078
# ################## 4 110 w绝对误差 tensor(2.3032, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9542, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0444, dtype=torch.float64)   实验回归残差 tensor(0.1307, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0426, dtype=torch.float64)   测试集实验回归残差 tensor(0.1626, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2604651671467282
# #################### 4 110 w绝对误差 tensor(0.8543, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3870, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0436, dtype=torch.float64)   实验回归残差 tensor(0.0964, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0459, dtype=torch.float64)   测试集实验回归残差 tensor(0.1439, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3551, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.208992564323729
# ##################################################### 4 110 w绝对误差 tensor(2.2018, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6195, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0620, dtype=torch.float64)   实验回归残差 tensor(0.1032, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0646, dtype=torch.float64)   测试集实验回归残差 tensor(0.2909, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   ###################################### 4 110 w绝对误差 tensor(3.3980, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4790, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0380, dtype=torch.float64)   实验回归残差 tensor(0.1438, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0438, dtype=torch.float64)   测试集实验回归残差 tensor(0.1612, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2830867726879738
# ################################################ 5 110 w绝对误差 tensor(4.4760, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6107, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0391, dtype=torch.float64)   实验回归残差 tensor(0.1276, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0346, dtype=torch.float64)   测试集实验回归残差 tensor(0.1978, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2355774312373162
# ##################### 5 110 w绝对误差 tensor(4.2505, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4721, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0350, dtype=torch.float64)   实验回归残差 tensor(0.2230, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0380, dtype=torch.float64)   测试集实验回归残差 tensor(0.2758, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3318426557786163
# ######################### 5 110 w绝对误差 tensor(2.3105, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1355, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0525, dtype=torch.float64)   实验回归残差 tensor(0.1592, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0466, dtype=torch.float64)   测试集实验回归残差 tensor(0.1658, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.38184296104428
# ################################################################## 5 110 w绝对误差 tensor(1.5850, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5593, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1053, dtype=torch.float64)   实验回归残差 tensor(0.1342, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0926, dtype=torch.float64)   测试集实验回归残差 tensor(0.2416, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.514649129094766
# ############## 5 110 w绝对误差 tensor(0.9410, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9005, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1096, dtype=torch.float64)   实验回归残差 tensor(0.0956, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0887, dtype=torch.float64)   测试集实验回归残差 tensor(0.2129, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4905339216220457
# ############################################# 5 110 w绝对误差 tensor(2.3815, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8743, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0378, dtype=torch.float64)   实验回归残差 tensor(0.1942, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0378, dtype=torch.float64)   测试集实验回归残差 tensor(0.2011, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2525437613813266
# ############################################ 5 110 w绝对误差 tensor(1.8020, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8087, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0398, dtype=torch.float64)   实验回归残差 tensor(0.0935, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0375, dtype=torch.float64)   测试集实验回归残差 tensor(0.2617, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5655387946013424
# ################################################### 5 110 w绝对误差 tensor(2.3558, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5401, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0631, dtype=torch.float64)   实验回归残差 tensor(0.1423, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0561, dtype=torch.float64)   测试集实验回归残差 tensor(0.2234, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   ################################ 5 110 w绝对误差 tensor(2.4510, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6312, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0281, dtype=torch.float64)   实验回归残差 tensor(0.0853, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0289, dtype=torch.float64)   测试集实验回归残差 tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.451297770082585
# ...
# ################### 4 110 w绝对误差 tensor(1.7680, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9216, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0597, dtype=torch.float64)   实验回归残差 tensor(0.1965, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0601, dtype=torch.float64)   测试集实验回归残差 tensor(0.1697, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3361996701892704
# ######################## 4 110 w绝对误差 tensor(2.6712, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1446, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0405, dtype=torch.float64)   实验回归残差 tensor(0.1355, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0389, dtype=torch.float64)   测试集实验回归残差 tensor(0.2416, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2909708273729066
# ########################## 4 110 w绝对误差 tensor(2.8197, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1776, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0427, dtype=torch.float64)   实验回归残差 tensor(0.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0414, dtype=torch.float64)   测试集实验回归残差 tensor(0.1946, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.353386141570366
# ########################### 4 110 w绝对误差 tensor(2.1191, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1059, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0452, dtype=torch.float64)   实验回归残差 tensor(0.1865, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0497, dtype=torch.float64)   测试集实验回归残差 tensor(0.1400, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.2598688959288542
# ############################# 4 110 w绝对误差 tensor(2.3228, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2131, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0515, dtype=torch.float64)   实验回归残差 tensor(0.0952, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0534, dtype=torch.float64)   测试集实验回归残差 tensor(0.1609, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3897, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 108   条件数 1.1497111478159505
# ################################ 4 110 w绝对误差 tensor(1.8023, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7989, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0886, dtype=torch.float64)   实验回归残差 tensor(0.1478, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0960, dtype=torch.float64)   测试集实验回归残差 tensor(0.2633, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.299429216212058
# ################# 4 110 w绝对误差 tensor(0.5578, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4966, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0777, dtype=torch.float64)   实验回归残差 tensor(0.1017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0950, dtype=torch.float64)   测试集实验回归残差 tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3685, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.1679720005603582
# ################################################### 5 110 w绝对误差 tensor(4.7837, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6046, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0353, dtype=torch.float64)   实验回归残差 tensor(0.1392, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.3594, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.235932079319361
# ########################### 5 110 w绝对误差 tensor(1.1021, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4167, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0379, dtype=torch.float64)   实验回归残差 tensor(0.0808, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.1312, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3618, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3300213197340285
# ################## 5 110 w绝对误差 tensor(2.5449, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9083, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0373, dtype=torch.float64)   实验回归残差 tensor(0.1203, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0439, dtype=torch.float64)   测试集实验回归残差 tensor(0.1591, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4148245459814617
# ####################################################################################### 5 110 w绝对误差 tensor(2.5401, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8696, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0357, dtype=torch.float64)   实验回归残差 tensor(0.0918, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0315, dtype=torch.float64)   测试集实验回归残差 tensor(0.1255, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.404134989449404
# ################## 5 110 w绝对误差 tensor(2.2817, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4662, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0733, dtype=torch.float64)   实验回归残差 tensor(0.1487, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0628, dtype=torch.float64)   测试集实验回归残差 tensor(0.1662, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3252236335544167
# ################################################## 5 110 w绝对误差 tensor(3.6383, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5634, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0406, dtype=torch.float64)   实验回归残差 tensor(0.1285, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0456, dtype=torch.float64)   测试集实验回归残差 tensor(0.2199, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.327178846837335
# ################# 5 110 w绝对误差 tensor(1.4696, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9292, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0629, dtype=torch.float64)   实验回归残差 tensor(0.1493, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0593, dtype=torch.float64)   测试集实验回归残差 tensor(0.1600, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3974700005018734
# ################################################################### 5 110 w绝对误差 tensor(0.0929, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0613, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0635, dtype=torch.float64)   实验回归残差 tensor(0.0345, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0669, dtype=torch.float64)   测试集实验回归残差 tensor(0.0527, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2210, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.2432, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5072746155524561
# ###################################### 5 110 w绝对误差 tensor(1.1156, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8753, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0709, dtype=torch.float64)   实验回归残差 tensor(0.1074, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0943, dtype=torch.float64)   测试集实验回归残差 tensor(0.2507, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4420108386964734
# ####################################### 6 110 w绝对误差 tensor(2.7211, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9845, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0391, dtype=torch.float64)   实验回归残差 tensor(0.1074, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0381, dtype=torch.float64)   测试集实验回归残差 tensor(0.1659, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4959726443309402
# ############################### 6 110 w绝对误差 tensor(1.8089, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1648, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0581, dtype=torch.float64)   实验回归残差 tensor(0.1344, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0597, dtype=torch.float64)   测试集实验回归残差 tensor(0.1697, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4541264001357324
# ################################################################ 6 110 w绝对误差 tensor(4.4868, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6080, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0370, dtype=torch.float64)   实验回归残差 tensor(0.1313, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0345, dtype=torch.float64)   测试集实验回归残差 tensor(0.1430, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.6211717721085637
# ######################## 6 110 w绝对误差 tensor(1.1858, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5944, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0460, dtype=torch.float64)   实验回归残差 tensor(0.0966, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0512, dtype=torch.float64)   测试集实验回归残差 tensor(0.1542, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5331241925532604
# ##################################### 6 110 w绝对误差 tensor(3.4569, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4304, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0395, dtype=torch.float64)   实验回归残差 tensor(0.1859, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0406, dtype=torch.float64)   测试集实验回归残差 tensor(0.1651, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4641822187396967
# ##################################### 6 110 w绝对误差 tensor(2.0149, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1103, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0635, dtype=torch.float64)   实验回归残差 tensor(0.1762, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0574, dtype=torch.float64)   测试集实验回归残差 tensor(0.1220, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.3344105416616936
# ###################################### 6 110 w绝对误差 tensor(1.5433, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8002, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0596, dtype=torch.float64)   实验回归残差 tensor(0.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0394, dtype=torch.float64)   测试集实验回归残差 tensor(0.2739, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3817, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4714102596511833
# ######################## 6 110 w绝对误差 tensor(2.4852, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0641, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0465, dtype=torch.float64)   实验回归残差 tensor(0.1283, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0380, dtype=torch.float64)   测试集实验回归残差 tensor(0.1837, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3948, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.4402999062585382
# ################################################################# 6 110 w绝对误差 tensor(1.9009, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0474, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0588, dtype=torch.float64)   实验回归残差 tensor(0.1046, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0553, dtype=torch.float64)   测试集实验回归残差 tensor(0.2381, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3883, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.3751, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.401513640738028
# ################################################################ 6 110 w绝对误差 tensor(3.5161, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3240, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0372, dtype=torch.float64)   实验回归残差 tensor(0.0812, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0390, dtype=torch.float64)   测试集实验回归残差 tensor(0.2283, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 110   测试集置换矩阵误差 tensor(1.4078, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 110   条件数 1.5797354500050502
