# %%
#%matplotlib inline 
import torch 
#from IPython import display 
#from matplotlib import pyplot as plt
import numpy as np 
import random
import math
#from time import time
#from torch import optim

# %%
def generatedata(noise,showpermutation=False,showtrue_w=False):
    true_w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if showtrue_w:
        print('true_w2:',true_w2)
    X2_before_ =torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    X2_test_before=torch.from_numpy(np.random.normal(0, 1, (num_example, num_X2feature)))
    y_ = torch.mm(X2_before_,true_w2)
    y_test=torch.mm(X2_test_before,true_w2)
    y_ += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    y_test += torch.from_numpy(np.random.normal(0, noise ,size=y_.size()))
    P_array=np.random.permutation(num_example)
    P=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P[i][P_array[i]]=1
    if showpermutation:
        print('打乱X2的置换矩阵为',P)
    P_arraytest=np.random.permutation(num_example)
    P_test=torch.zeros(num_example,num_example,dtype=torch.float64)
    for i in range(num_example):
        P_test[i][P_arraytest[i]]=1
    X2_=torch.mm(P,X2_before_)
    X2_test=torch.mm(P_test,X2_test_before)
    conditionnumber=np.linalg.cond(X2_.numpy())
    #X2_=X2_before_
    error_reg=(torch.norm(y_-torch.mm(X2_before_,true_w2))/torch.norm(y_))
    error_reg_test=(torch.norm(y_test-torch.mm(X2_test_before,true_w2))/torch.norm(y_test))
    return y_,X2_,true_w2,P,error_reg,conditionnumber,y_test,X2_test,P_test,error_reg_test

# %%
def generateinitialw(method,showinitialw=False):
    if method=='normal':
        w2 = torch.from_numpy(np.random.normal(0, 1,(num_X2feature,1)))
    if method=='zeros':
        w2=torch.zeros(num_X2feature,1,dtype=torch.float64)
    if showinitialw:
        print('initial w2:',w2)
    return w2

# %%
def sinkhorn_stabilized(a, b, M, reg, numItermax=1000, tau=1e3, stopThr=1e-9,
                        warmstart=None, verbose=False, print_period=20,
                        log=False, **kwargs):

#     a = np.asarray(a, dtype=np.float64)
#     b = np.asarray(b, dtype=np.float64)
#     M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M

#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # test if multiple target
#     if len(b.shape) > 1:
#         n_hists = b.shape[1]
#         a = a[:, np.newaxis]
#     else:
#         n_hists = 0
    n_hists = 0
    # init data
    dim_a = len(a)
    dim_b = len(b)

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    if n_hists:
        u = torch.ones((dim_a, n_hists)) / dim_a
        v = torch.ones((dim_b, n_hists)) / dim_b
    else:
        u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))- beta.reshape((1, dim_b))) / reg)

    def get_Gamma(alpha, beta, u, v):
        """log space gamma computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1)) - beta.reshape((1, dim_b)))
                      / reg + torch.log(u.reshape((dim_a, 1))) + torch.log(v.reshape((1, dim_b))))

    # print(np.min(K))

    K = get_K(alpha, beta)
    transp = K
    loop = 1
    cpt = 0
    err = 1
    while loop:

        uprev = u
        vprev = v
        # sinkhornrn update
        v = b / (torch.mm(K.transpose(1,0), u) + 1e-16)
        u = a / (torch.mm(K, v) + 1e-16)
        # remove numerical problems and store them in K
        if torch.abs(u).max() > tau or torch.abs(v).max() > tau:
            if n_hists:
                alpha, beta = alpha + reg * \
                    torch.max(torch.log(u), 1), beta + reg * torch.max(np.log(v))
            else:
                alpha, beta = alpha + reg * torch.log(u), beta + reg * torch.log(v)
                if n_hists:
                    u, v = torch.ones((dim_a, n_hists)) / dim_a, torch.ones((dim_b, n_hists)) / dim_b
                else:
                    u, v = torch.ones(dim_a,1,dtype=torch.float64) / dim_a, torch.ones(dim_b,1,dtype=torch.float64) / dim_b
            K = get_K(alpha, beta)
            

        if cpt % print_period == 0:
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            if n_hists:
                err_u = abs(u - uprev).max()
                err_u /= max(abs(u).max(), abs(uprev).max(), 1.)
                err_v = abs(v - vprev).max()
                err_v /= max(abs(v).max(), abs(vprev).max(), 1.)
                err = 0.5 * (err_u + err_v)
            else:
                transp = get_Gamma(alpha, beta, u, v)
                err = torch.norm((torch.sum(transp, axis=0) - b))
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 20) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr:
            loop = False

        if cpt >= numItermax:
            loop = False

        if np.any(np.isnan(u.detach().numpy())) or np.any(np.isnan(v.detach().numpy())):
            # we have reached the machine precision
            # come back to previous solution and quit loop
            print('Warning: numerical errors at iteration', cpt)
            u = uprev
            v = vprev
            break

        cpt = cpt + 1
    #print(cpt)
    if log:
        if n_hists:
            alpha = alpha[:, None]
            beta = beta[:, None]
        logu = alpha / reg + torch.log(u)
        logv = beta / reg + torch.log(v)
        log['logu'] = logu
        log['logv'] = logv
        log['alpha'] = alpha + reg * torch.log(u)
        log['beta'] = beta + reg * torch.log(v)
        log['warmstart'] = (log['alpha'], log['beta'])
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res, log

        else:
            return get_Gamma(alpha, beta, u, v), log
    else:
        if n_hists:
            res = torch.zeros((n_hists))
            for i in range(n_hists):
                res[i] = torch.sum(get_Gamma(alpha, beta, u[:, i], v[:, i]) * M)
            return res
        else:
            return get_Gamma(alpha, beta, u, v)

# %%
def sinkhorn_epsilon_scaling(a, b, M, reg, numItermax=100, epsilon0=1e4,
                             numInnerItermax=100, tau=1e3, stopThr=1e-9,
                             warmstart=None, verbose=False, print_period=10,
                             log=False, **kwargs):
    #a = np.asarray(a, dtype=np.float64)
    #b = np.asarray(b, dtype=np.float64)
    #M = np.asarray(M, dtype=np.float64)
    a=a
    b=b
    M=M
#     if len(a) == 0:
#         a = np.ones((M.shape[0],), dtype=np.float64) / M.shape[0]
#     if len(b) == 0:
#         b = np.ones((M.shape[1],), dtype=np.float64) / M.shape[1]

    # init data
    dim_a = len(a)
    #dim_a=num_example
    dim_b = len(b)
    #dim_b=num_example
    # nrelative umerical precision with 64 bits
    numItermin = 35
    numItermax = max(numItermin, numItermax)  # ensure that last velue is exact

    cpt = 0
    if log:
        log = {'err': []}

    # we assume that no distances are null except those of the diagonal of
    # distances
    if warmstart is None:
        alpha, beta = torch.zeros(dim_a,1,dtype=torch.float64), torch.zeros(dim_b,1,dtype=torch.float64)
    else:
        alpha, beta = warmstart

    def get_K(alpha, beta):
        """log space computation"""
        return torch.exp(-(M - alpha.reshape((dim_a, 1))
                        - beta.reshape((1, dim_b))) / reg)

    # print(np.min(K))
    def get_reg(n):  # exponential decreasing
        return (epsilon0 - reg) * np.exp(-n) + reg

    loop = 1
    cpt = 0
    err = 1
    while loop:

        regi = get_reg(cpt)

        G, logi = sinkhorn_stabilized(a, b, M, regi,
                                      numItermax=numInnerItermax, stopThr=1e-9,
                                      warmstart=(alpha, beta), verbose=False,
                                      print_period=20, tau=tau, log=True)

        alpha = logi['alpha']
        beta = logi['beta']

        if cpt >= numItermax:
            loop = False

        if cpt % (print_period) == 0:  # spsion nearly converged
            # we can speed up the process by checking for the error only all
            # the 10th iterations
            transp = G
            err = torch.norm(
                (torch.sum(transp, axis=0) - b))**2 + torch.norm((torch.sum(transp, axis=1) - a))**2
            if log:
                log['err'].append(err)

            if verbose:
                if cpt % (print_period * 10) == 0:
                    print(
                        '{:5s}|{:12s}'.format('It.', 'Err') + '\n' + '-' * 19)
                print('{:5d}|{:8e}|'.format(cpt, err))

        if err <= stopThr and cpt > numItermin:
            loop = False

        cpt = cpt + 1
    # print('err=',err,' cpt=',cpt)
    if log:
        log['alpha'] = alpha
        log['beta'] = beta
        log['warmstart'] = (log['alpha'], log['beta'])
        return G, log
    else:
        return G

# %%
gama_=1
eta=0
starts=1
for i_____ in range(3):
    for num_example in range(170,171,100): 
        for num_X2feature in [4,5,6]:
            for i____ in range(10):
                (y_,X2_,true_w2,true_P,error_reg1,conditionnumber,y_test,X2_test,true_P_test,error_reg_test)=generatedata(noise=0.1)
                y=y_
                X2=X2_
                results_Loss = []
                results_w2=[]
                results_error=[]
                for i__ in range(starts):
    #                     P_array=np.random.permutation(num_example)
    #                     P=torch.zeros(num_example,num_example,dtype=torch.float64)
    #                     for i in range(num_example):
    #                         P[i][P_array[i]]=1
    #                     X_=torch.cat([X1,X2],1)
    #                     X=torch.mm(P,X_)
    #                     w=torch.mm(torch.mm(torch.tensor(np.linalg.inv(torch.mm(X.transpose(1,0),X))),X.transpose(1,0)),y)
    #                     w1,w2=w.split([num_X1feature,num_X2feature],dim=0)
    #                     w1=torch.from_numpy(np.random.normal(0, 0,(num_X1feature,1)))
    #                     w2=torch.from_numpy(np.random.normal(0, 0,(num_X2feature,1)))
                    w2=generateinitialw(method='zeros')
                    #w2=true_w2
                    w2.requires_grad_(requires_grad=True)
    #                 results_Loss = []
                    lr=0.005
                    results_S=[]
                    t=0
                    before1=0
                    while True:                     
                        Y1=y
                        Y2=torch.mm(X2,w2)
                        C=torch.zeros(num_example,num_example,dtype=torch.float64)
                        for i in range(num_example):
                            for j in range(num_example):
                                C[i][j]=(Y1[i]-Y2[j])**2            

                        #S=SinkhornIPOT(C)
                        a=torch.ones(num_example,1,dtype=torch.float64)
                        b=torch.ones(num_example,1,dtype=torch.float64)
                        S=sinkhorn_epsilon_scaling(a, b, C, 0.00000001)
                        #print(S.transpose(1,0).half())
                        #results_S.append(S)
                        #if t>0:
                            #print('        S变化',(torch.norm(results_S[t]-results_S[t-1]))/(torch.norm(results_S[t-1])))
                        #Loss=torch.sum(S*C)
                        Loss=torch.norm(Y1-torch.mm(S,Y2))**2
                        if Loss<1e-2:
                            break
                        Loss.backward()
    #                         results_Loss.append(Loss)
    #                         for i_ in range(num_X1features):
    #                             results_w1[t][i_]=(w1[i_].data)
    #                         for i_ in range(num_X2features):
    #                             results_w2[t][i_]=(w2[i_].data)
                        w2.data-=lr*(w2.grad+np.random.normal(0,np.sqrt(eta/(1+t)**gama_)))
                        #print(w2.grad)
    #                     if t==num_epochs-1:
    #                         print('最终w1梯度：',w1.grad)
    #                         print('最终w2梯度：',w2.grad)
                        w2.grad.data.zero_() 

                        #print('Loss',t,'=',Loss)
    #                     if t%6==0:
    #                         if torch.norm(Loss-before1)<1e-4:
    #                             break
    #                         before1=Loss
                        if torch.norm(Loss-before1)/before1<1e-6:
                            break
                        before1=Loss
                        if t>=200:
                            print('超过迭代上限')
                            break
                        if math.isnan(Loss):
                            break
                        t+=1
                        print('#',end='')



                    print(' ',end='')
                    error_each=(torch.norm(w2-true_w2))
                    #results_error.append(error_each)
                    error_each2=(torch.norm(w2-true_w2))/torch.norm(true_w2)
                    
                    #results_Loss.append(Loss)
                    #results_w1.append(w1.data)
                    #results_w2.append(w2.data)


                #w1=results_w1[results_Loss.index(min(results_Loss))]
                #w2=results_w2[results_Loss.index(min(results_Loss))]

    #                     for i_ in range(starts):
    #                         results_w1[i_]=(w1[i_].data)
    #                     for i_ in range(starts):
    #                         results_w2[i_]=(w2[i_].data)


                #error_w=((torch.norm(w1-true_w1))/(torch.norm(true_w1))+(torch.norm(w2-true_w2))/(torch.norm(true_w2)))/2
                #print(num_X1feature,num_X2feature,num_example,'平均相对误差1：',error_w)
                #print(num_X2feature,num_example,'平均相对误差2：',np.min(results_error),end='   ')
                print(num_X2feature,num_example,'w绝对误差',error_each,end='   ')
                print('w相对误差',error_each2,end='   ')
                #print('真实置换矩阵为：',true_P)               
                error_reg2=(torch.norm(y_-torch.mm(torch.mm(S,X2_),w2))/torch.norm(y_))
                print('真实回归残差',error_reg1,end='   ')
                print('实验回归残差',error_reg2,end='   ')
                #error_reg_test2=(torch.norm(y_test-torch.mm(X2_test,w2))/torch.norm(y_test))
                #print('测试集真实回归残差',error_reg_test,end='   ')
                #print('测试集实验回归残差',error_reg_test2,end='   ')
                Y1_test=y_test
                Y2_test=torch.mm(X2_test,w2)
                C_test=torch.zeros(num_example,num_example,dtype=torch.float64)
                for i in range(num_example):
                    for j in range(num_example):
                        C_test[i][j]=(Y1_test[i]-Y2_test[j])**2            
                a=torch.ones(num_example,1,dtype=torch.float64)
                b=torch.ones(num_example,1,dtype=torch.float64)
                S_test=sinkhorn_epsilon_scaling(a, b, C_test, 0.00000001)
                error_reg_test2=(torch.norm(Y1_test-torch.mm(S_test,Y2_test))/torch.norm(Y1_test))
                print('测试集真实回归残差',error_reg_test,end='   ')
                print('测试集实验回归残差',error_reg_test2,end='   ')               
                error_P=(torch.norm(S.transpose(1,0)-true_P))/(torch.norm(true_P))
                print('置换矩阵误差',error_P,end='   ')
                matrix_count=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S[i_2][j_2]-1)<0.02):
                            matrix_count+=1
                print('离置换矩阵距离',matrix_count,end='   ')
                error_Ptest=(torch.norm(S_test.transpose(1,0)-true_P_test))/(torch.norm(true_P_test))
                print('测试集置换矩阵误差',error_Ptest,end='   ')
                matrix_count_test=0
                for i_2 in range(num_example):
                    for j_2 in range(num_example):
                        if (abs(S_test[i_2][j_2]-1)<0.02):
                            matrix_count_test+=1
                print('测试集离置换矩阵距离',matrix_count_test,end='   ')
                print('条件数',conditionnumber)
                #print('双随机矩阵S为：',S.transpose(1,0).half())
                #print(results)
    #                 plt.figure(figsize=(6,6))
    #                 plt.plot(results_w1_0,results_Loss, '-o',label='$w1[0]$')
    #                 plt.plot(results_w1_1,results_Loss, '-o',label='$w1[1]$')
    #                 plt.plot(results_w1_2,results_Loss, '-o',label='$w1[2]$')
    #                 plt.plot(results_w2_0,results_Loss, '-o',label='$w2[0]$')
    #                 plt.plot(results_w2_1,results_Loss, '-o',label='$w2[1]$')
    #                 plt.plot(results_w2_2,results_Loss, '-o',label='$w2[2]$')
    #                 plt.legend()
    #                 plt.show()
# Out:
# ######################################################### 4 170 w绝对误差 tensor(1.0871, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6230, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0530, dtype=torch.float64)   实验回归残差 tensor(0.0662, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0613, dtype=torch.float64)   测试集实验回归残差 tensor(0.0827, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2727960343600486
# ############################################## 4 170 w绝对误差 tensor(4.1637, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4252, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0353, dtype=torch.float64)   实验回归残差 tensor(0.1524, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0345, dtype=torch.float64)   测试集实验回归残差 tensor(0.2040, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1498286241661828
# ############################ 4 170 w绝对误差 tensor(2.3481, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5346, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0671, dtype=torch.float64)   实验回归残差 tensor(0.1347, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0675, dtype=torch.float64)   测试集实验回归残差 tensor(0.0988, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1663482246494272
# ##################### 4 170 w绝对误差 tensor(1.9995, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0548, dtype=torch.float64)   实验回归残差 tensor(0.1157, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0571, dtype=torch.float64)   测试集实验回归残差 tensor(0.1895, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2029078863025338
# ########################## 4 170 w绝对误差 tensor(1.4778, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1027, dtype=torch.float64)   实验回归残差 tensor(0.1070, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0974, dtype=torch.float64)   测试集实验回归残差 tensor(0.2637, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1670222887807484
# ################################################################## 4 170 w绝对误差 tensor(1.2859, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5453, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1329, dtype=torch.float64)   实验回归残差 tensor(0.1324, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1033, dtype=torch.float64)   测试集实验回归残差 tensor(0.2415, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4042, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2379165890854837
# ########################### 4 170 w绝对误差 tensor(2.0344, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7277, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0341, dtype=torch.float64)   实验回归残差 tensor(0.1016, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0353, dtype=torch.float64)   测试集实验回归残差 tensor(0.0838, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2476893347613556
# ########################## 4 170 w绝对误差 tensor(1.0135, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1685, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1225, dtype=torch.float64)   实验回归残差 tensor(0.0847, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1086, dtype=torch.float64)   测试集实验回归残差 tensor(0.1670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4004, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.2229720188587327
# ########################## 4 170 w绝对误差 tensor(2.6170, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2075, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0464, dtype=torch.float64)   实验回归残差 tensor(0.1242, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0415, dtype=torch.float64)   测试集实验回归残差 tensor(0.1212, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2814842173460481
# ###################################################### 5 170 w绝对误差 tensor(3.4969, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2016, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0346, dtype=torch.float64)   实验回归残差 tensor(0.0716, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0297, dtype=torch.float64)   测试集实验回归残差 tensor(0.1777, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3409318236528203
# ############################################################ 5 170 w绝对误差 tensor(2.0637, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9645, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0460, dtype=torch.float64)   实验回归残差 tensor(0.1023, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0467, dtype=torch.float64)   测试集实验回归残差 tensor(0.2096, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4016, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2505677309825196
# ######################################################################################### 5 170 w绝对误差 tensor(1.7070, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9767, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0552, dtype=torch.float64)   实验回归残差 tensor(0.1082, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0537, dtype=torch.float64)   测试集实验回归残差 tensor(0.1077, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1846634034351968
# ###################################### 5 170 w绝对误差 tensor(2.3561, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3954, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0528, dtype=torch.float64)   实验回归残差 tensor(0.0934, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0612, dtype=torch.float64)   测试集实验回归残差 tensor(0.1775, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2500949920482858
# ############################################################################ 5 170 w绝对误差 tensor(3.6266, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2112, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0374, dtype=torch.float64)   实验回归残差 tensor(0.1251, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0335, dtype=torch.float64)   测试集实验回归残差 tensor(0.2317, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3621872622361768
# ################################################################ 5 170 w绝对误差 tensor(1.3924, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1491, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0837, dtype=torch.float64)   实验回归残差 tensor(0.1159, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0776, dtype=torch.float64)   测试集实验回归残差 tensor(0.1787, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2891621135193112
# ####################################################### 5 170 w绝对误差 tensor(0.6738, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.5429, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0814, dtype=torch.float64)   实验回归残差 tensor(0.0935, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0856, dtype=torch.float64)   测试集实验回归残差 tensor(0.1667, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.27401395237644
# ####################################### 5 170 w绝对误差 tensor(4.0543, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9275, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0543, dtype=torch.float64)   实验回归残差 tensor(0.0823, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0496, dtype=torch.float64)   测试集实验回归残差 tensor(0.1739, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2115861803482557
# ################# 5 170 w绝对误差 tensor(3.1467, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2394, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0381, dtype=torch.float64)   实验回归残差 tensor(0.0969, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0343, dtype=torch.float64)   测试集实验回归残差 tensor(0.1545, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2682656137560129
# ########################################################################### 5 170 w绝对误差 tensor(3.1216, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3748, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0432, dtype=torch.float64)   实验回归残差 tensor(0.1245, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0488, dtype=torch.float64)   测试集实验回归残差 tensor(0.2086, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3033221323731143
# ##################################### 6 170 w绝对误差 tensor(2.7328, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3905, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0493, dtype=torch.float64)   实验回归残差 tensor(0.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0549, dtype=torch.float64)   测试集实验回归残差 tensor(0.2011, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3280421828477447
# #################### 6 170 w绝对误差 tensor(1.0117, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8904, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0956, dtype=torch.float64)   实验回归残差 tensor(0.1044, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0852, dtype=torch.float64)   测试集实验回归残差 tensor(0.2611, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3933, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2242218446077346
# ############################## 6 170 w绝对误差 tensor(3.6365, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5906, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0383, dtype=torch.float64)   实验回归残差 tensor(0.0696, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0430, dtype=torch.float64)   测试集实验回归残差 tensor(0.2524, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4042, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.339390706400213
# ############################## 6 170 w绝对误差 tensor(2.8788, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1248, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0533, dtype=torch.float64)   实验回归残差 tensor(0.0976, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0336, dtype=torch.float64)   测试集实验回归残差 tensor(0.2421, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.450535719795406
# ####################################################### 6 170 w绝对误差 tensor(0.5708, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.2167, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0412, dtype=torch.float64)   实验回归残差 tensor(0.0451, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0349, dtype=torch.float64)   测试集实验回归残差 tensor(0.0742, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3677, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3720, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3265028473985279
# ############################################# 6 170 w绝对误差 tensor(2.4026, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4734, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0637, dtype=torch.float64)   实验回归残差 tensor(0.1401, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0629, dtype=torch.float64)   测试集实验回归残差 tensor(0.1120, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2366710648959172
# ###################################### 6 170 w绝对误差 tensor(1.7424, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7975, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0543, dtype=torch.float64)   实验回归残差 tensor(0.1128, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0435, dtype=torch.float64)   测试集实验回归残差 tensor(0.1388, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.5330157527236106
# ######################################################################### 6 170 w绝对误差 tensor(2.6598, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6342, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0569, dtype=torch.float64)   实验回归残差 tensor(0.0862, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0678, dtype=torch.float64)   测试集实验回归残差 tensor(0.1539, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3151050801745572
# ###################################### 6 170 w绝对误差 tensor(3.1897, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6430, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0509, dtype=torch.float64)   实验回归残差 tensor(0.1213, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0476, dtype=torch.float64)   测试集实验回归残差 tensor(0.2097, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3601969995131238
# ############################################################################################# 6 170 w绝对误差 tensor(4.8311, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3319, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0261, dtype=torch.float64)   实验回归残差 tensor(0.0636, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0268, dtype=torch.float64)   测试集实验回归残差 tensor(0.1205, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.29574594504644
# ######################## 4 170 w绝对误差 tensor(2.4349, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4813, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0596, dtype=torch.float64)   实验回归残差 tensor(0.0893, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0496, dtype=torch.float64)   测试集实验回归残差 tensor(0.1670, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.168199995680246
# ################################# 4 170 w绝对误差 tensor(5.1165, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6873, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0309, dtype=torch.float64)   实验回归残差 tensor(0.0919, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0349, dtype=torch.float64)   测试集实验回归残差 tensor(0.1993, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1591734629608637
# ########################## 4 170 w绝对误差 tensor(1.6903, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0794, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0610, dtype=torch.float64)   实验回归残差 tensor(0.0918, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0625, dtype=torch.float64)   测试集实验回归残差 tensor(0.2052, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1687055188683142
# ###################### 4 170 w绝对误差 tensor(1.7111, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7908, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0498, dtype=torch.float64)   实验回归残差 tensor(0.0998, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0440, dtype=torch.float64)   测试集实验回归残差 tensor(0.1286, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2070019182174914
# ########################## 4 170 w绝对误差 tensor(1.4334, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1021, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0819, dtype=torch.float64)   实验回归残差 tensor(0.1252, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0805, dtype=torch.float64)   测试集实验回归残差 tensor(0.1382, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3348825300270244
# ########################################## 4 170 w绝对误差 tensor(2.9752, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2678, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0515, dtype=torch.float64)   实验回归残差 tensor(0.0864, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0425, dtype=torch.float64)   测试集实验回归残差 tensor(0.1103, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2746509146496676
# ############################################### 4 170 w绝对误差 tensor(2.9449, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1084, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0469, dtype=torch.float64)   实验回归残差 tensor(0.1008, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0348, dtype=torch.float64)   测试集实验回归残差 tensor(0.2697, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2793598915253017
# ############################################################################# 4 170 w绝对误差 tensor(2.0581, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4198, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0659, dtype=torch.float64)   实验回归残差 tensor(0.0862, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0603, dtype=torch.float64)   测试集实验回归残差 tensor(0.1296, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1666775287115965
# ################### 4 170 w绝对误差 tensor(0.6015, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3192, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0528, dtype=torch.float64)   实验回归残差 tensor(0.0807, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0581, dtype=torch.float64)   测试集实验回归残差 tensor(0.0951, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3885, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.226303901174326
# #################################### 4 170 w绝对误差 tensor(2.2065, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8665, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0367, dtype=torch.float64)   实验回归残差 tensor(0.1028, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0437, dtype=torch.float64)   测试集实验回归残差 tensor(0.1746, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.329360763659837
# ################################################################################# 5 170 w绝对误差 tensor(1.6689, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.7577, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0447, dtype=torch.float64)   实验回归残差 tensor(0.0696, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0474, dtype=torch.float64)   测试集实验回归残差 tensor(0.1129, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3927, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.2883961384717142
# ########################### 5 170 w绝对误差 tensor(2.2548, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3343, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0591, dtype=torch.float64)   实验回归残差 tensor(0.1355, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0602, dtype=torch.float64)   测试集实验回归残差 tensor(0.1353, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2398600713990693
# ###################### 5 170 w绝对误差 tensor(2.5730, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4723, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0495, dtype=torch.float64)   实验回归残差 tensor(0.1348, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0579, dtype=torch.float64)   测试集实验回归残差 tensor(0.2124, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4083, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2353089600483487
# ########################## 5 170 w绝对误差 tensor(1.7528, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2119, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0672, dtype=torch.float64)   实验回归残差 tensor(0.1065, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0632, dtype=torch.float64)   测试集实验回归残差 tensor(0.1748, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4013, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3150339150496795
# ################################################################################################## 5 170 w绝对误差 tensor(3.9189, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3451, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0328, dtype=torch.float64)   实验回归残差 tensor(0.0592, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0338, dtype=torch.float64)   测试集实验回归残差 tensor(0.1944, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1559998101165894
# ######################################################## 5 170 w绝对误差 tensor(3.7711, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6101, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0421, dtype=torch.float64)   实验回归残差 tensor(0.1067, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0448, dtype=torch.float64)   测试集实验回归残差 tensor(0.1506, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4131, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3265167568938752
# ################################################## 5 170 w绝对误差 tensor(2.4202, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2203, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0469, dtype=torch.float64)   实验回归残差 tensor(0.1470, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0500, dtype=torch.float64)   测试集实验回归残差 tensor(0.1471, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3086519004123496
# ################### 5 170 w绝对误差 tensor(2.7152, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.9846, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0690, dtype=torch.float64)   实验回归残差 tensor(0.0974, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0749, dtype=torch.float64)   测试集实验回归残差 tensor(0.3747, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.4856244695779453
# ###################################################### 5 170 w绝对误差 tensor(2.4054, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4663, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0623, dtype=torch.float64)   实验回归残差 tensor(0.1084, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0653, dtype=torch.float64)   测试集实验回归残差 tensor(0.3387, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.425590160539334
# ########################################################### 5 170 w绝对误差 tensor(0.4305, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.4842, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1164, dtype=torch.float64)   实验回归残差 tensor(0.0826, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1132, dtype=torch.float64)   测试集实验回归残差 tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4054, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.3783717605661803
# ############################ 6 170 w绝对误差 tensor(1.4550, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9656, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0683, dtype=torch.float64)   实验回归残差 tensor(0.1235, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0777, dtype=torch.float64)   测试集实验回归残差 tensor(0.1216, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3969, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.4677069905555693
# ########################################################################################################################################################################################################超过迭代上限
#  6 170 w绝对误差 tensor(1.3042, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6012, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0476, dtype=torch.float64)   实验回归残差 tensor(0.0667, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0432, dtype=torch.float64)   测试集实验回归残差 tensor(0.1288, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3303352209937644
# ##################################################### 6 170 w绝对误差 tensor(3.1663, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1398, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0367, dtype=torch.float64)   实验回归残差 tensor(0.1292, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0357, dtype=torch.float64)   测试集实验回归残差 tensor(0.1375, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2665405988572154
# ########################################################################################################################################################################################################超过迭代上限
#  6 170 w绝对误差 tensor(1.1524, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.3693, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0418, dtype=torch.float64)   实验回归残差 tensor(0.0700, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0330, dtype=torch.float64)   测试集实验回归残差 tensor(0.1385, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3763, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3890, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.4791212358422163
# ################################################################################################################# 6 170 w绝对误差 tensor(3.6275, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4454, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0354, dtype=torch.float64)   实验回归残差 tensor(0.0695, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0392, dtype=torch.float64)   测试集实验回归残差 tensor(0.1626, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3736343224327139
# ################################## 6 170 w绝对误差 tensor(2.2013, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3225, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0645, dtype=torch.float64)   实验回归残差 tensor(0.0987, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0574, dtype=torch.float64)   测试集实验回归残差 tensor(0.2016, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2818764900391697
# ########################### 6 170 w绝对误差 tensor(1.7594, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1321, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0713, dtype=torch.float64)   实验回归残差 tensor(0.1329, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0680, dtype=torch.float64)   测试集实验回归残差 tensor(0.1572, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3629759014348195
# ########################################################################################################################################################################################################超过迭代上限
#  6 170 w绝对误差 tensor(2.7504, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2097, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0443, dtype=torch.float64)   实验回归残差 tensor(0.0746, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0407, dtype=torch.float64)   测试集实验回归残差 tensor(0.1909, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3751806735228826
# ########################################################################################################################################################################################################超过迭代上限
#  6 170 w绝对误差 tensor(3.3800, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.1200, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0365, dtype=torch.float64)   实验回归残差 tensor(0.0749, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0309, dtype=torch.float64)   测试集实验回归残差 tensor(0.1215, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3972897184623874
# ##################################### 6 170 w绝对误差 tensor(3.8173, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.5701, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0400, dtype=torch.float64)   实验回归残差 tensor(0.0866, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0403, dtype=torch.float64)   测试集实验回归残差 tensor(0.1693, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3759319929853089
# ############################ 4 170 w绝对误差 tensor(1.5889, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2332, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0816, dtype=torch.float64)   实验回归残差 tensor(0.1286, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0785, dtype=torch.float64)   测试集实验回归残差 tensor(0.1777, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1648057112168584
# ################################ 4 170 w绝对误差 tensor(0.0114, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.0059, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0496, dtype=torch.float64)   实验回归残差 tensor(0.0273, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0475, dtype=torch.float64)   测试集实验回归残差 tensor(0.0273, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.2603, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.2603, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2568457722600799
# ###################### 4 170 w绝对误差 tensor(1.7486, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0584, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0609, dtype=torch.float64)   实验回归残差 tensor(0.1387, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0546, dtype=torch.float64)   测试集实验回归残差 tensor(0.0985, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1612382031093753
# ############################## 4 170 w绝对误差 tensor(3.7892, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6189, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0408, dtype=torch.float64)   实验回归残差 tensor(0.0938, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0402, dtype=torch.float64)   测试集实验回归残差 tensor(0.3919, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2943061580049087
# ######################################################################### 4 170 w绝对误差 tensor(0.8849, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3514, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1481, dtype=torch.float64)   实验回归残差 tensor(0.0937, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1327, dtype=torch.float64)   测试集实验回归残差 tensor(0.2354, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4048, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 168   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2188340567323825
# ########################## 4 170 w绝对误差 tensor(1.5905, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.8908, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0544, dtype=torch.float64)   实验回归残差 tensor(0.1054, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0540, dtype=torch.float64)   测试集实验回归残差 tensor(0.1326, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2011514043448182
# ################################################################################################# 4 170 w绝对误差 tensor(2.7870, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4636, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0606, dtype=torch.float64)   实验回归残差 tensor(0.1019, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0519, dtype=torch.float64)   测试集实验回归残差 tensor(0.3037, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3046934170112312
# ############################# 4 170 w绝对误差 tensor(2.2025, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0078, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0524, dtype=torch.float64)   实验回归残差 tensor(0.1281, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0532, dtype=torch.float64)   测试集实验回归残差 tensor(0.2211, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.337324565133692
# ##################################### 4 170 w绝对误差 tensor(1.1872, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0273, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0942, dtype=torch.float64)   实验回归残差 tensor(0.0772, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0836, dtype=torch.float64)   测试集实验回归残差 tensor(0.1478, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2738170684911183
# ######################## 4 170 w绝对误差 tensor(1.2071, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3277, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0976, dtype=torch.float64)   实验回归残差 tensor(0.0920, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1116, dtype=torch.float64)   测试集实验回归残差 tensor(0.1869, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4089, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.189869639263781
# ################################################################### 5 170 w绝对误差 tensor(3.3626, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2931, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0341, dtype=torch.float64)   实验回归残差 tensor(0.1544, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0374, dtype=torch.float64)   测试集实验回归残差 tensor(0.1845, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2865995278774693
# ########################################### 5 170 w绝对误差 tensor(2.8963, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0575, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0342, dtype=torch.float64)   实验回归残差 tensor(0.0423, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0359, dtype=torch.float64)   测试集实验回归残差 tensor(0.3305, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2592329081023943
# ########################### 5 170 w绝对误差 tensor(1.6053, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0837, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0691, dtype=torch.float64)   实验回归残差 tensor(0.1068, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0764, dtype=torch.float64)   测试集实验回归残差 tensor(0.1919, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3890, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.321412766018478
# ############################################################# 5 170 w绝对误差 tensor(5.0025, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2974, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0279, dtype=torch.float64)   实验回归残差 tensor(0.0797, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0245, dtype=torch.float64)   测试集实验回归残差 tensor(0.1492, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4097, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 168   条件数 1.2781088510965772
# ############################### 5 170 w绝对误差 tensor(2.8824, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7963, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0578, dtype=torch.float64)   实验回归残差 tensor(0.0832, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0618, dtype=torch.float64)   测试集实验回归残差 tensor(0.1947, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3152605145141092
# ################################# 5 170 w绝对误差 tensor(2.3171, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9887, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0472, dtype=torch.float64)   实验回归残差 tensor(0.1261, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0399, dtype=torch.float64)   测试集实验回归残差 tensor(0.1388, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3033592658415112
# ################################ 5 170 w绝对误差 tensor(2.5822, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.0576, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0417, dtype=torch.float64)   实验回归残差 tensor(0.0784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0396, dtype=torch.float64)   测试集实验回归残差 tensor(0.1012, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.1489371939101765
# ############################################# 5 170 w绝对误差 tensor(1.4813, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6490, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.1055, dtype=torch.float64)   实验回归残差 tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.1101, dtype=torch.float64)   测试集实验回归残差 tensor(0.1705, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2834757418655383
# ############### 5 170 w绝对误差 tensor(1.6020, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3796, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0762, dtype=torch.float64)   实验回归残差 tensor(0.0960, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0915, dtype=torch.float64)   测试集实验回归残差 tensor(0.1762, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.317289827699324
# ############################################################################################### 5 170 w绝对误差 tensor(1.2891, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.6211, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0483, dtype=torch.float64)   实验回归残差 tensor(0.0891, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0456, dtype=torch.float64)   测试集实验回归残差 tensor(0.1499, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.3975, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2377194989451
# ################################## 6 170 w绝对误差 tensor(2.7601, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2637, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0462, dtype=torch.float64)   实验回归残差 tensor(0.1003, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0389, dtype=torch.float64)   测试集实验回归残差 tensor(0.1547, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.2267107206537946
# #################################################################################################### 6 170 w绝对误差 tensor(2.3835, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.2728, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0465, dtype=torch.float64)   实验回归残差 tensor(0.0979, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0536, dtype=torch.float64)   测试集实验回归残差 tensor(0.1992, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3248349435411906
# ########################################################################################################################################################################################################超过迭代上限
#  6 170 w绝对误差 tensor(3.7194, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7991, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0532, dtype=torch.float64)   实验回归残差 tensor(0.0674, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0541, dtype=torch.float64)   测试集实验回归残差 tensor(0.1369, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.432309374692295
# ########################################### 6 170 w绝对误差 tensor(2.0220, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.3828, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0687, dtype=torch.float64)   实验回归残差 tensor(0.0784, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0724, dtype=torch.float64)   测试集实验回归残差 tensor(0.2836, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3581507585489754
# ####################################################################### 6 170 w绝对误差 tensor(3.3250, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.8067, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0554, dtype=torch.float64)   实验回归残差 tensor(0.0892, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0516, dtype=torch.float64)   测试集实验回归残差 tensor(0.1925, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3551784610373867
# ################################################## 6 170 w绝对误差 tensor(3.8351, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.7837, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0557, dtype=torch.float64)   实验回归残差 tensor(0.1505, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0435, dtype=torch.float64)   测试集实验回归残差 tensor(0.1969, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.5127890506438537
# #################################################################################### 6 170 w绝对误差 tensor(1.9360, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9767, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0516, dtype=torch.float64)   实验回归残差 tensor(0.1338, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0535, dtype=torch.float64)   测试集实验回归残差 tensor(0.1058, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4059, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3142571979806814
# #################################################### 6 170 w绝对误差 tensor(1.7043, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(0.9877, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0518, dtype=torch.float64)   实验回归残差 tensor(0.0713, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0575, dtype=torch.float64)   测试集实验回归残差 tensor(0.1072, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.453574821274203
# ############################################################################# 6 170 w绝对误差 tensor(3.6502, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.6542, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0428, dtype=torch.float64)   实验回归残差 tensor(0.1046, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0482, dtype=torch.float64)   测试集实验回归残差 tensor(0.3052, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4017, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3738069691867179
# #################################################################################################################################################################################### 6 170 w绝对误差 tensor(2.8222, dtype=torch.float64, grad_fn=<NormBackward0>)   w相对误差 tensor(1.4785, dtype=torch.float64, grad_fn=<DivBackward0>)   真实回归残差 tensor(0.0571, dtype=torch.float64)   实验回归残差 tensor(0.1060, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集真实回归残差 tensor(0.0514, dtype=torch.float64)   测试集实验回归残差 tensor(0.1261, dtype=torch.float64, grad_fn=<DivBackward0>)   置换矩阵误差 tensor(1.4142, dtype=torch.float64, grad_fn=<DivBackward0>)   离置换矩阵距离 170   测试集置换矩阵误差 tensor(1.4100, dtype=torch.float64, grad_fn=<DivBackward0>)   测试集离置换矩阵距离 170   条件数 1.3866757042874998
